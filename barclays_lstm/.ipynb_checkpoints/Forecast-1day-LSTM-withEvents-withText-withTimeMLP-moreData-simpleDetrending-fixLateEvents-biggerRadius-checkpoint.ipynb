# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# Using TensorFlow backend.

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("barclays_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2013-02-22  2013-02-22 19:30:00
# 1           1  2015-10-09  2015-10-09 19:30:00
# 2           2  2015-03-20  2015-03-20 19:30:00
# 3           3  2013-11-18  2013-11-18 19:30:00
# 4           4  2015-04-12  2015-04-12 20:00:00
#
#                                        title  \
# 0           Brooklyn Nets vs Houston Rockets
# 1  New York Islanders vs. Chicago Blackhawks
# 2          Brooklyn Nets vs. Milwaukee Bucks
# 3   Brooklyn Nets vs. Portland Trail Blazers
# 4                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                      title  \
# 0  2013-02-22 2013-02-22 19:30:00           Brooklyn Nets vs Houston Rockets
# 1  2015-10-09 2015-10-09 19:30:00  New York Islanders vs. Chicago Blackhawks
# 2  2015-03-20 2015-03-20 19:30:00          Brooklyn Nets vs. Milwaukee Bucks
# 3  2013-11-18 2013-11-18 19:30:00   Brooklyn Nets vs. Portland Trail Blazers
# 4  2015-04-12 2015-04-12 20:00:00                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
# late events
print len(events["start_time"].dt.hour.values)
print np.sum(events["start_time"].dt.hour.values >= 20)
print np.sum(events["start_time"].dt.hour.values >= 21)
plt.hist(events["start_time"].dt.hour.values)
# Out:
# 885
# 172
# 11
# (array([  31.,    0.,    0.,    0.,   13.,   67.,   63.,   51.,  488.,  172.]),
#  array([  0. ,   2.2,   4.4,   6.6,   8.8,  11. ,  13.2,  15.4,  17.6,
#          19.8,  22. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/home/fmpr/data/pickups_barclays_center_0.005.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0        7
# 1  2009-01-01     0       1       33
# 2  2009-01-01     1       0       40
# 3  2009-01-01     1       1       34
# 4  2009-01-01     2       0       49

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      625  2009-01-01    3
# 2009-01-02      329  2009-01-02    4
# 2009-01-03      599  2009-01-03    5
# 2009-01-04      644  2009-01-04    6
# 2009-01-05      224  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
late_event = np.zeros((len(df_sum)))
really_late_event = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
        for e in events[events.date == df_sum.iloc[i].date]["start_time"]:
            if e.hour >= 20:
                late_event[i] = 1
            if e.hour >= 21:
                really_late_event[i] = 1
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["late_event"] = late_event
df_sum["really_late_event"] = really_late_event
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["late_event_next_day"] = pd.Series(df_sum["late_event"]).shift(-1)
df_sum["really_late_event_next_day"] = pd.Series(df_sum["really_late_event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      625  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      329  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      599  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      644  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05      224  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day event_next_day_desc
# date
# 2009-01-01                         0.0                None
# 2009-01-02                         0.0                None
# 2009-01-03                         0.0                None
# 2009-01-04                         0.0                None
# 2009-01-05                         0.0                None

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01     1187  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      380  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      429  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      481  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05     1083  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc
# date
# 2013-01-01                                               None
# 2013-01-02                                               None
# 2013-01-03                                               None
# 2013-01-04  net home game schedule highlight include oneti...
# 2013-01-05                                               None

# %%
df_sum.describe()
# Out:
#            pickups          dow        event   late_event  really_late_event  \
# count  1277.000000  1277.000000  1277.000000  1277.000000        1277.000000
# mean   1548.921691     2.997651     0.431480     0.097103           0.006265
# std     631.493721     1.999411     0.495477     0.296213           0.078932
# min     370.000000     0.000000     0.000000     0.000000           0.000000
# 25%    1108.000000     1.000000     0.000000     0.000000           0.000000
# 50%    1534.000000     3.000000     0.000000     0.000000           0.000000
# 75%    1987.000000     5.000000     1.000000     0.000000           0.000000
# max    3740.000000     6.000000     1.000000     1.000000           1.000000
#
#        event_next_day  late_event_next_day  really_late_event_next_day
# count     1276.000000          1276.000000                 1276.000000
# mean         0.431818             0.097179                    0.006270
# std          0.495524             0.296317                    0.078963
# min          0.000000             0.000000                    0.000000
# 25%          0.000000             0.000000                    0.000000
# 50%          0.000000             0.000000                    0.000000
# 75%          1.000000             0.000000                    0.000000
# max          1.000000             1.000000                    1.000000

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01     1187  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      380  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      429  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      481  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05     1083  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc  year
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013

# %%
trend_mean = df_sum[df_sum.index.year < 2015].groupby(["dow"]).mean()["pickups"]
trend_mean
# Out:
# dow
# 0     932.173077
# 1     986.114286
# 2    1078.723810
# 3    1124.596154
# 4    1371.211538
# 5    1812.298077
# 6    1593.942308
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 631.49372117367579

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1277

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01     1187  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      380  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      429  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      481  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05     1083  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                   trend         std  detrended
# date
# 2013-01-01   986.114286  631.493721   0.318112
# 2013-01-02  1078.723810  631.493721  -1.106462
# 2013-01-03  1124.596154  631.493721  -1.101509
# 2013-01-04  1371.211538  631.493721  -1.409692
# 2013-01-05  1812.298077  631.493721  -1.154878

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2015, "detrended"][:50], "k-")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "event"][:50], "r--")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "late_event"][:50], "b--")

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.17669701],
#        [ 0.17669701,  1.        ]])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"][:-1], df_sum["late_event_next_day"][:-1])
# Out:
# array([[ 1.        , -0.10431438],
#        [-0.10431438,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.20584400292557151, pvalue=1.0996199411308802e-13)

# %% [markdown]
# ## Build lags

# %%
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01     1187  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      380  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      429  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      481  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05     1083  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                   trend         std  detrended
# date
# 2013-01-01   986.114286  631.493721   0.318112
# 2013-01-02  1078.723810  631.493721  -1.106462
# 2013-01-03  1124.596154  631.493721  -1.101509
# 2013-01-04  1371.211538  631.493721  -1.409692
# 2013-01-05  1812.298077  631.493721  -1.154878

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = np.concatenate([df_sum["event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["late_event"].as_matrix()[:,np.newaxis],
                             #df_sum["late_event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event_next_day"].as_matrix()[:,np.newaxis]], axis=1)
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1,:]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1266, 10)
# event_feats: (1266, 4)
# lags_event_feats: (1266, 10)
# event_texts: (1266,)
# preds: (1266,)
# trends: (1266,)
# stds: (1266,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.84887305431
# 1 0.775617048409
# 2 0.740214316551
# 3 0.746503591495
# 4 0.756490518332
# 5 0.773808860195
# 6 0.799395237353
# 7 0.783691805272
# 8 0.748614252674
# 9 0.732673645513

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.170987820185
# 1 0.171951569823
# 2 0.173052291092
# 3 0.17423356881
# 4 0.175697276221
# 5 0.17740539224
# 6 0.175907539845
# 7 0.17638640071
# 8 0.177522050174

# %%
np.corrcoef(preds[:], event_feats[:,0])
# Out:
# array([[ 1.        ,  0.17239412],
#        [ 0.17239412,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train,:] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val,:] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test,:]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640, 4)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# y_train: (640,)
# y_val: (90,)
# y_test: (535,)
# trend_test: (535,)
# std_test: (535,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline

# %%
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  196.740
# RMSE: 274.611
# R2:   0.605

# %% [markdown]
# ## Linear regression with events

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train[:,:1]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test[:,:1]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  181.674
# RMSE: 257.195
# R2:   0.653

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  178.930
# RMSE: 254.128
# R2:   0.661

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  178.338
# RMSE: 252.768
# R2:   0.665

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  173.889
# RMSE: 248.691
# R2:   0.676

# %% [markdown]
# ## Simple LSTM

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    lags_train,
    y_train,
    batch_size=64,
    epochs=300,
    validation_data=(lags_val, y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 11.98498, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 11.98498 to 11.20240, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.20240 to 10.36931, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.36931 to 9.57236, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.57236 to 8.66839, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 8.66839 to 8.16321, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.16321 to 7.42298, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 7.42298 to 6.74432, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 6.74432 to 6.36462, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.36462 to 5.76317, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 5.76317 to 5.27149, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 5.27149 to 4.96400, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 4.96400 to 4.55478, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 4.55478 to 4.34251, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.34251 to 3.96582, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 3.96582 to 3.82392, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.82392 to 3.42150, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.42150 to 3.25076, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.25076 to 3.00671, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 3.00671 to 2.81957, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.81957 to 2.61442, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.61442 to 2.50325, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.50325 to 2.38536, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.38536 to 2.20558, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.20558 to 2.11819, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.11819 to 2.02225, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.02225 to 1.94381, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.94381 to 1.85960, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.85960 to 1.81827, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.81827 to 1.79324, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.79324 to 1.61350, saving model to weights.best.hdf5
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss improved from 1.61350 to 1.49076, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.49076 to 1.46601, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.46601 to 1.38855, saving model to weights.best.hdf5
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss improved from 1.38855 to 1.29263, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.29263 to 1.18170, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss improved from 1.18170 to 1.16000, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 1.16000 to 1.14707, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss improved from 1.14707 to 1.04392, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.04392 to 0.95343, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss improved from 0.95343 to 0.94123, saving model to weights.best.hdf5
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.94123 to 0.90913, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.90913 to 0.86721, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.86721 to 0.83709, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.83709 to 0.77866, saving model to weights.best.hdf5
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss improved from 0.77866 to 0.74521, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.74521 to 0.71452, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.71452 to 0.69639, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.69639 to 0.67472, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.67472 to 0.58581, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss improved from 0.58581 to 0.48921, saving model to weights.best.hdf5
# Epoch 00069: val_loss improved from 0.48921 to 0.47198, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.47198 to 0.46678, saving model to weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss improved from 0.46678 to 0.43940, saving model to weights.best.hdf5
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.43940 to 0.39291, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.39291 to 0.38230, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.38230 to 0.33565, saving model to weights.best.hdf5
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss improved from 0.33565 to 0.32000, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.32000 to 0.30749, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.30749 to 0.26959, saving model to weights.best.hdf5
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss improved from 0.26959 to 0.26803, saving model to weights.best.hdf5
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss improved from 0.26803 to 0.26409, saving model to weights.best.hdf5
# Epoch 00090: val_loss improved from 0.26409 to 0.26103, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss improved from 0.26103 to 0.25941, saving model to weights.best.hdf5
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss improved from 0.25941 to 0.25866, saving model to weights.best.hdf5
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss improved from 0.25866 to 0.25711, saving model to weights.best.hdf5
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     227    Best: 0.132419770211
# Best val_loss at iteratation: 196    Best: 0.257106021378

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  194.134
# RMSE: 271.346
# R2:   0.614

# %% [markdown]
# ## LSTM with events information (no text)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 4, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_1/concat:0", shape=(?, 14), dtype=float32)
# Epoch 00000: val_loss improved from inf to 13.04860, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 13.04860 to 12.08350, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 12.08350 to 10.89018, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.89018 to 10.00050, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 10.00050 to 9.05270, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 9.05270 to 8.25125, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.25125 to 7.52584, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 7.52584 to 6.86145, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 6.86145 to 6.17100, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.17100 to 5.70124, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 5.70124 to 5.16940, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 5.16940 to 4.79685, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 4.79685 to 4.28181, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 4.28181 to 4.00893, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.00893 to 3.77240, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 3.77240 to 3.43165, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.43165 to 3.19094, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.19094 to 2.95527, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 2.95527 to 2.79436, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 2.79436 to 2.57733, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.57733 to 2.39176, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.39176 to 2.32645, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.32645 to 2.14505, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.14505 to 2.04965, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.04965 to 1.93944, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.93944 to 1.89411, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.89411 to 1.74690, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.74690 to 1.67579, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.67579 to 1.60086, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.60086 to 1.54050, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.54050 to 1.46267, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.46267 to 1.38806, saving model to weights.best.hdf5
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 1.38806 to 1.34073, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.34073 to 1.33136, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.33136 to 1.30438, saving model to weights.best.hdf5
# Epoch 00036: val_loss did not improve
# Epoch 00037: val_loss improved from 1.30438 to 1.19881, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss improved from 1.19881 to 1.15887, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 1.15887 to 1.15272, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 1.15272 to 1.07709, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss improved from 1.07709 to 1.05455, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.05455 to 0.97432, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss improved from 0.97432 to 0.95286, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 0.95286 to 0.93034, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.93034 to 0.84895, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.84895 to 0.79004, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.79004 to 0.62621, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss improved from 0.62621 to 0.57039, saving model to weights.best.hdf5
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.57039 to 0.50204, saving model to weights.best.hdf5
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.50204 to 0.48132, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss improved from 0.48132 to 0.46452, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.46452 to 0.42035, saving model to weights.best.hdf5
# Epoch 00069: val_loss improved from 0.42035 to 0.38063, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.38063 to 0.36817, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.36817 to 0.34988, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.34988 to 0.33045, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss improved from 0.33045 to 0.31416, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.31416 to 0.30050, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.30050 to 0.29635, saving model to weights.best.hdf5
# Epoch 00078: val_loss improved from 0.29635 to 0.26741, saving model to weights.best.hdf5
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.26741 to 0.22279, saving model to weights.best.hdf5
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss improved from 0.22279 to 0.22177, saving model to weights.best.hdf5
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss improved from 0.22177 to 0.21524, saving model to weights.best.hdf5
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss improved from 0.21524 to 0.21455, saving model to weights.best.hdf5
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss improved from 0.21455 to 0.21088, saving model to weights.best.hdf5
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     156    Best: 0.120232682675
# Best val_loss at iteratation: 218    Best: 0.210881710052

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.178487044768
# (535, 1)
# (535,)
# MAE:  176.659
# RMSE: 250.491
# R2:   0.671

# %% [markdown]
# ## LSTM with events information (no text) v2

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 14, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_2/concat:0", shape=(?, 24), dtype=float32)
# Epoch 00000: val_loss improved from inf to 16.02839, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 16.02839 to 14.89281, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 14.89281 to 13.74335, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 13.74335 to 12.29694, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 12.29694 to 11.14896, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 11.14896 to 10.11967, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 10.11967 to 9.10142, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 9.10142 to 8.15076, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 8.15076 to 7.43553, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 7.43553 to 6.68092, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 6.68092 to 6.04649, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 6.04649 to 5.45036, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.45036 to 4.91533, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 4.91533 to 4.47948, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.47948 to 3.98650, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 3.98650 to 3.64751, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.64751 to 3.31440, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.31440 to 3.08610, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.08610 to 2.78872, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 2.78872 to 2.63113, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.63113 to 2.42249, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.42249 to 2.24631, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.24631 to 2.09987, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.09987 to 2.00771, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.00771 to 1.89379, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.89379 to 1.80997, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.80997 to 1.67273, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.67273 to 1.65975, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.65975 to 1.49478, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.49478 to 1.48275, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.48275 to 1.45630, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.45630 to 1.37199, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.37199 to 1.27642, saving model to weights.best.hdf5
# Epoch 00033: val_loss did not improve
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss improved from 1.27642 to 1.24842, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.24842 to 1.21438, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.21438 to 1.16826, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 1.16826 to 1.12817, saving model to weights.best.hdf5
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 1.12817 to 1.09783, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.09783 to 1.08437, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.08437 to 1.08120, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 1.08120 to 1.06424, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 1.06424 to 1.04258, saving model to weights.best.hdf5
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 1.04258 to 0.99965, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 0.99965 to 0.92948, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.92948 to 0.89533, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 0.89533 to 0.73430, saving model to weights.best.hdf5
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.73430 to 0.70799, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss improved from 0.70799 to 0.62523, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.62523 to 0.53072, saving model to weights.best.hdf5
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss improved from 0.53072 to 0.52109, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.52109 to 0.49612, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.49612 to 0.39828, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss improved from 0.39828 to 0.37489, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.37489 to 0.34933, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.34933 to 0.29076, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.29076 to 0.27515, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.27515 to 0.26226, saving model to weights.best.hdf5
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss improved from 0.26226 to 0.25536, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.25536 to 0.25266, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.25266 to 0.23481, saving model to weights.best.hdf5
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss improved from 0.23481 to 0.22589, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss improved from 0.22589 to 0.21831, saving model to weights.best.hdf5
# Epoch 00086: val_loss improved from 0.21831 to 0.21777, saving model to weights.best.hdf5
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss improved from 0.21777 to 0.20796, saving model to weights.best.hdf5
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss improved from 0.20796 to 0.20762, saving model to weights.best.hdf5
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss improved from 0.20762 to 0.20579, saving model to weights.best.hdf5
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss improved from 0.20579 to 0.20293, saving model to weights.best.hdf5
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     120    Best: 0.120449502021
# Best val_loss at iteratation: 191    Best: 0.202927837107

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.174145171304
# (535, 1)
# (535,)
# MAE:  172.973
# RMSE: 245.719
# R2:   0.683

# %% [markdown]
# ## LSTM with events information + event text

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 3461 unique tokens.
# ('Shape of train tensor:', (640, 600))
# ('Shape of val tensor:', (90, 600))
# ('Shape of test tensor:', (535, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 4, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,:]], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,:]], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_1/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_6:0", shape=(?, 10), dtype=float32)
# Tensor("input_7:0", shape=(?, 4), dtype=float32)
# Tensor("dropout_11/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_4/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 12.73388, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 12.73388 to 10.94029, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 10.94029 to 9.41041, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 9.41041 to 8.09085, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 8.09085 to 6.88691, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 6.88691 to 5.97452, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 5.97452 to 5.12908, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 5.12908 to 4.45309, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 4.45309 to 3.99258, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 3.99258 to 3.57070, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 3.57070 to 3.05972, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.05972 to 2.86042, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.86042 to 2.66756, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.66756 to 2.32728, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.32728 to 2.28282, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.28282 to 2.09850, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 2.09850 to 1.94229, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.94229 to 1.93824, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.93824 to 1.83874, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.83874 to 1.75682, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.75682 to 1.65540, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.65540 to 1.54279, saving model to weights.best.hdf5
# Epoch 00022: val_loss did not improve
# Epoch 00023: val_loss did not improve
# Epoch 00024: val_loss did not improve
# Epoch 00025: val_loss improved from 1.54279 to 1.53866, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.53866 to 1.44817, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.44817 to 1.42879, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.42879 to 1.42732, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.42732 to 1.38957, saving model to weights.best.hdf5
# Epoch 00030: val_loss did not improve
# Epoch 00031: val_loss improved from 1.38957 to 1.37343, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.37343 to 1.34837, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.34837 to 1.33150, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.33150 to 1.28354, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.28354 to 1.21723, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.21723 to 1.18839, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.18839 to 1.14092, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.14092 to 1.12596, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.12596 to 1.09178, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.09178 to 0.98766, saving model to weights.best.hdf5
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 0.98766 to 0.83697, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 0.83697 to 0.76417, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 0.76417 to 0.57378, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.57378 to 0.45723, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss improved from 0.45723 to 0.33405, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss improved from 0.33405 to 0.30374, saving model to weights.best.hdf5
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.30374 to 0.29958, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss improved from 0.29958 to 0.28073, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.28073 to 0.26214, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.26214 to 0.25178, saving model to weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.25178 to 0.23932, saving model to weights.best.hdf5
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss improved from 0.23932 to 0.23762, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.23762 to 0.23637, saving model to weights.best.hdf5
# Epoch 00078: val_loss improved from 0.23637 to 0.22996, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.22996 to 0.22839, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss improved from 0.22839 to 0.22468, saving model to weights.best.hdf5
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss improved from 0.22468 to 0.22029, saving model to weights.best.hdf5
# Epoch 00087: val_loss improved from 0.22029 to 0.21294, saving model to weights.best.hdf5
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss improved from 0.21294 to 0.21036, saving model to weights.best.hdf5
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss improved from 0.21036 to 0.21013, saving model to weights.best.hdf5
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss improved from 0.21013 to 0.20926, saving model to weights.best.hdf5
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss improved from 0.20926 to 0.20618, saving model to weights.best.hdf5
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss improved from 0.20618 to 0.20591, saving model to weights.best.hdf5
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     477    Best: 0.0976324856281
# Best val_loss at iteratation: 386    Best: 0.205914084117

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.177023040775
# (535, 1)
# (535,)
# MAE:  174.588
# RMSE: 248.605
# R2:   0.676

# %% [markdown]
# ## LSTM with events information + event text (v2)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 14, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_2/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_9:0", shape=(?, 10), dtype=float32)
# Tensor("input_10:0", shape=(?, 14), dtype=float32)
# Tensor("dropout_16/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_6/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 15.69218, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 15.69218 to 12.99264, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 12.99264 to 10.87457, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.87457 to 9.28770, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.28770 to 7.93686, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 7.93686 to 6.69055, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 6.69055 to 5.57298, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 5.57298 to 4.81454, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 4.81454 to 4.14103, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 4.14103 to 3.56528, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 3.56528 to 3.17047, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.17047 to 2.82816, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.82816 to 2.57239, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.57239 to 2.41263, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.41263 to 2.23039, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.23039 to 2.04395, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 2.04395 to 1.91886, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.91886 to 1.77155, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.77155 to 1.68329, saving model to weights.best.hdf5
# Epoch 00019: val_loss did not improve
# Epoch 00020: val_loss improved from 1.68329 to 1.55617, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.55617 to 1.55429, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.55429 to 1.47643, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 1.47643 to 1.43679, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 1.43679 to 1.42491, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.42491 to 1.37969, saving model to weights.best.hdf5
# Epoch 00026: val_loss did not improve
# Epoch 00027: val_loss improved from 1.37969 to 1.34417, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.34417 to 1.29671, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.29671 to 1.26271, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.26271 to 1.24872, saving model to weights.best.hdf5
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss improved from 1.24872 to 1.19340, saving model to weights.best.hdf5
# Epoch 00033: val_loss did not improve
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss improved from 1.19340 to 1.16146, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.16146 to 1.02088, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 1.02088 to 1.00046, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.00046 to 0.94052, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.94052 to 0.91560, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss improved from 0.91560 to 0.78051, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.78051 to 0.56022, saving model to weights.best.hdf5
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.56022 to 0.49270, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.49270 to 0.40841, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.40841 to 0.39631, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss improved from 0.39631 to 0.35284, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.35284 to 0.31166, saving model to weights.best.hdf5
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.31166 to 0.26017, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss improved from 0.26017 to 0.25331, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.25331 to 0.22381, saving model to weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.22381 to 0.21672, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss improved from 0.21672 to 0.21349, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss improved from 0.21349 to 0.21310, saving model to weights.best.hdf5
# Epoch 00091: val_loss improved from 0.21310 to 0.21033, saving model to weights.best.hdf5
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss improved from 0.21033 to 0.20364, saving model to weights.best.hdf5
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss improved from 0.20364 to 0.19361, saving model to weights.best.hdf5
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     490    Best: 0.0958429411054
# Best val_loss at iteratation: 205    Best: 0.193612470892

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.176936605928
# (535, 1)
# (535,)
# MAE:  170.959
# RMSE: 245.168
# R2:   0.685
