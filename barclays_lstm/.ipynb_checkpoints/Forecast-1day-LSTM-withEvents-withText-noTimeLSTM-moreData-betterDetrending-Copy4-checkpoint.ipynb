# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# Using TensorFlow backend.

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("barclays_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2013-02-22  2013-02-22 19:30:00
# 1           1  2015-10-09  2015-10-09 19:30:00
# 2           2  2015-03-20  2015-03-20 19:30:00
# 3           3  2013-11-18  2013-11-18 19:30:00
# 4           4  2015-04-12  2015-04-12 20:00:00
#
#                                        title  \
# 0           Brooklyn Nets vs Houston Rockets
# 1  New York Islanders vs. Chicago Blackhawks
# 2          Brooklyn Nets vs. Milwaukee Bucks
# 3   Brooklyn Nets vs. Portland Trail Blazers
# 4                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                      title  \
# 0  2013-02-22 2013-02-22 19:30:00           Brooklyn Nets vs Houston Rockets
# 1  2015-10-09 2015-10-09 19:30:00  New York Islanders vs. Chicago Blackhawks
# 2  2015-03-20 2015-03-20 19:30:00          Brooklyn Nets vs. Milwaukee Bucks
# 3  2013-11-18 2013-11-18 19:30:00   Brooklyn Nets vs. Portland Trail Blazers
# 4  2015-04-12 2015-04-12 20:00:00                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/mnt/sdb1/nyc_taxi_data/venue-centered_anomalies/30min/data/pickups_barclays_center_0.003.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0        2
# 1  2009-01-01     0       1       15
# 2  2009-01-01     1       0       13
# 3  2009-01-01     1       1       16
# 4  2009-01-01     2       0       19

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      253  2009-01-01    3
# 2009-01-02      137  2009-01-02    4
# 2009-01-03      239  2009-01-03    5
# 2009-01-04      218  2009-01-04    6
# 2009-01-05       92  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event event_desc  event_next_day  \
# date
# 2009-01-01      253  2009-01-01    3    0.0       None             0.0
# 2009-01-02      137  2009-01-02    4    0.0       None             0.0
# 2009-01-03      239  2009-01-03    5    0.0       None             0.0
# 2009-01-04      218  2009-01-04    6    0.0       None             0.0
# 2009-01-05       92  2009-01-05    0    0.0       None             0.0
#
#            event_next_day_desc
# date
# 2009-01-01                None
# 2009-01-02                None
# 2009-01-03                None
# 2009-01-04                None
# 2009-01-05                None

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc
# date
# 2013-01-01                                               None
# 2013-01-02                                               None
# 2013-01-03                                               None
# 2013-01-04  net home game schedule highlight include oneti...
# 2013-01-05                                               None

# %%
df_sum["year"] = df_sum.index.year.values
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013

# %%
trend_mean = df_sum.groupby(["year","dow"]).mean()["pickups"]
trend_mean
# Out:
# year  dow
# 2013  0       313.173077
#       1       339.660377
#       2       347.326923
#       3       352.923077
#       4       418.538462
#       5       576.442308
#       6       545.250000
# 2014  0       627.903846
#       1       629.673077
#       2       702.301887
#       3       702.230769
#       4       888.653846
#       5      1047.942308
#       6       931.692308
# 2015  0       752.153846
#       1       744.500000
#       2       823.634615
#       3       849.113208
#       4      1035.711538
#       5      1207.807692
#       6      1049.634615
# 2016  0       790.538462
#       1       791.653846
#       2       884.807692
#       3       897.269231
#       4      1088.307692
#       5      1295.000000
#       6      1133.230769
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 313.32834892618996

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.year, row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1277

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  339.660377  313.328349   0.792586
# 2013-01-02  347.326923  313.328349  -0.521264
# 2013-01-03  352.923077  313.328349  -0.548699
# 2013-01-04  418.538462  313.328349  -0.604920
# 2013-01-05  576.442308  313.328349  -0.135456

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.52109956],
#        [ 0.52109956,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.54869789454211626, pvalue=2.7270846947793041e-101)

# %% [markdown]
# ## Build lags

# %%
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  339.660377  313.328349   0.792586
# 2013-01-02  347.326923  313.328349  -0.521264
# 2013-01-03  352.923077  313.328349  -0.548699
# 2013-01-04  418.538462  313.328349  -0.604920
# 2013-01-05  576.442308  313.328349  -0.135456

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = df_sum["event_next_day"].as_matrix()
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1266, 10)
# event_feats: (1266,)
# lags_event_feats: (1266, 10)
# event_texts: (1266,)
# preds: (1266,)
# trends: (1266,)
# stds: (1266,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.413526782924
# 1 0.310562672081
# 2 0.222922620149
# 3 0.258214904486
# 4 0.243971001481
# 5 0.204408880348
# 6 0.254780099514
# 7 0.219397928498
# 8 0.189302507405
# 9 0.172688930548

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.520366805882
# 1 0.520235050112
# 2 0.520240974554
# 3 0.52037433096
# 4 0.520666498464
# 5 0.520850213151
# 6 0.520353223018
# 7 0.520530211469
# 8 0.520528808358

# %%
np.corrcoef(preds[:], event_feats[:])
# Out:
# array([[ 1.        ,  0.52095074],
#        [ 0.52095074,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2+90
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640,)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# y_train: (640,)
# y_val: (180,)
# y_test: (445,)
# trend_test: (445,)
# std_test: (445,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline

# %%
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  112.318
# RMSE: 155.007
# R2:   0.591

# %% [markdown]
# ## Linear regression with events

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train[:,np.newaxis]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test[:,np.newaxis]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  90.345
# RMSE: 132.528
# R2:   0.701

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  90.162
# RMSE: 132.533
# R2:   0.701

# %% [markdown]
# ## Simple LSTM

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    #preds = Dense(units=num_preds)(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.5))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    lags_train,
    y_train,
    batch_size=64,
    epochs=3000,
    validation_data=(lags_val, y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 2.02725, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 2.02725 to 2.00189, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 2.00189 to 1.96665, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 1.96665 to 1.92458, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 1.92458 to 1.86723, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 1.86723 to 1.82021, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 1.82021 to 1.77026, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 1.77026 to 1.71942, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 1.71942 to 1.67867, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 1.67867 to 1.63935, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 1.63935 to 1.59341, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 1.59341 to 1.55324, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 1.55324 to 1.51000, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 1.51000 to 1.47149, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.47149 to 1.43418, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.43418 to 1.39361, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.39361 to 1.35280, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.35280 to 1.31546, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.31546 to 1.28011, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.28011 to 1.24437, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.24437 to 1.20389, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.20389 to 1.17075, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.17075 to 1.13736, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 1.13736 to 1.10340, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 1.10340 to 1.06938, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.06938 to 1.03654, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.03654 to 1.00454, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.00454 to 0.97195, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.97195 to 0.94222, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.94222 to 0.91587, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.91587 to 0.88714, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.88714 to 0.86267, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.86267 to 0.83798, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.83798 to 0.81261, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.81261 to 0.78968, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 0.78968 to 0.76762, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.76762 to 0.74330, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 0.74330 to 0.72140, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 0.72140 to 0.70255, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.70255 to 0.68516, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 0.68516 to 0.66573, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 0.66573 to 0.64935, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.64935 to 0.63304, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.63304 to 0.61755, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.61755 to 0.60332, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.60332 to 0.59143, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.59143 to 0.57817, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 0.57817 to 0.56557, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 0.56557 to 0.55177, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 0.55177 to 0.53976, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 0.53976 to 0.52950, saving model to weights.best.hdf5
# Epoch 00051: val_loss improved from 0.52950 to 0.52074, saving model to weights.best.hdf5
# Epoch 00052: val_loss improved from 0.52074 to 0.51230, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.51230 to 0.50102, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 0.50102 to 0.49405, saving model to weights.best.hdf5
# Epoch 00055: val_loss improved from 0.49405 to 0.48761, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.48761 to 0.47889, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.47889 to 0.47004, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.47004 to 0.46381, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.46381 to 0.45654, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.45654 to 0.44943, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.44943 to 0.44270, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.44270 to 0.43710, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.43710 to 0.43106, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.43106 to 0.42590, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.42590 to 0.42041, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 0.42041 to 0.41524, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.41524 to 0.41123, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.41123 to 0.40702, saving model to weights.best.hdf5
# Epoch 00069: val_loss improved from 0.40702 to 0.40167, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.40167 to 0.39842, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.39842 to 0.39471, saving model to weights.best.hdf5
# Epoch 00072: val_loss improved from 0.39471 to 0.39181, saving model to weights.best.hdf5
# Epoch 00073: val_loss improved from 0.39181 to 0.38843, saving model to weights.best.hdf5
# Epoch 00074: val_loss improved from 0.38843 to 0.38502, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.38502 to 0.38231, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.38231 to 0.37887, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.37887 to 0.37653, saving model to weights.best.hdf5
# Epoch 00078: val_loss improved from 0.37653 to 0.37288, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.37288 to 0.36970, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.36970 to 0.36772, saving model to weights.best.hdf5
# Epoch 00081: val_loss improved from 0.36772 to 0.36612, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.36612 to 0.36292, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.36292 to 0.36249, saving model to weights.best.hdf5
# Epoch 00084: val_loss improved from 0.36249 to 0.36045, saving model to weights.best.hdf5
# Epoch 00085: val_loss improved from 0.36045 to 0.35756, saving model to weights.best.hdf5
# Epoch 00086: val_loss improved from 0.35756 to 0.35480, saving model to weights.best.hdf5
# Epoch 00087: val_loss improved from 0.35480 to 0.35287, saving model to weights.best.hdf5
# Epoch 00088: val_loss improved from 0.35287 to 0.35059, saving model to weights.best.hdf5
# Epoch 00089: val_loss improved from 0.35059 to 0.35017, saving model to weights.best.hdf5
# Epoch 00090: val_loss improved from 0.35017 to 0.34765, saving model to weights.best.hdf5
# Epoch 00091: val_loss improved from 0.34765 to 0.34701, saving model to weights.best.hdf5
# Epoch 00092: val_loss improved from 0.34701 to 0.34543, saving model to weights.best.hdf5
# Epoch 00093: val_loss improved from 0.34543 to 0.34325, saving model to weights.best.hdf5
# Epoch 00094: val_loss improved from 0.34325 to 0.34127, saving model to weights.best.hdf5
# Epoch 00095: val_loss improved from 0.34127 to 0.34079, saving model to weights.best.hdf5
# Epoch 00096: val_loss improved from 0.34079 to 0.33804, saving model to weights.best.hdf5
# Epoch 00097: val_loss improved from 0.33804 to 0.33744, saving model to weights.best.hdf5
# Epoch 00098: val_loss improved from 0.33744 to 0.33633, saving model to weights.best.hdf5
# Epoch 00099: val_loss improved from 0.33633 to 0.33518, saving model to weights.best.hdf5
# Epoch 00100: val_loss improved from 0.33518 to 0.33486, saving model to weights.best.hdf5
# Epoch 00101: val_loss improved from 0.33486 to 0.33422, saving model to weights.best.hdf5
# Epoch 00102: val_loss improved from 0.33422 to 0.33237, saving model to weights.best.hdf5
# Epoch 00103: val_loss improved from 0.33237 to 0.33118, saving model to weights.best.hdf5
# Epoch 00104: val_loss improved from 0.33118 to 0.33060, saving model to weights.best.hdf5
# Epoch 00105: val_loss improved from 0.33060 to 0.32954, saving model to weights.best.hdf5
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss improved from 0.32954 to 0.32803, saving model to weights.best.hdf5
# Epoch 00108: val_loss improved from 0.32803 to 0.32725, saving model to weights.best.hdf5
# Epoch 00109: val_loss improved from 0.32725 to 0.32658, saving model to weights.best.hdf5
# Epoch 00110: val_loss improved from 0.32658 to 0.32570, saving model to weights.best.hdf5
# Epoch 00111: val_loss improved from 0.32570 to 0.32533, saving model to weights.best.hdf5
# Epoch 00112: val_loss improved from 0.32533 to 0.32467, saving model to weights.best.hdf5
# Epoch 00113: val_loss improved from 0.32467 to 0.32342, saving model to weights.best.hdf5
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss improved from 0.32342 to 0.32289, saving model to weights.best.hdf5
# Epoch 00116: val_loss improved from 0.32289 to 0.32181, saving model to weights.best.hdf5
# Epoch 00117: val_loss improved from 0.32181 to 0.32179, saving model to weights.best.hdf5
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss improved from 0.32179 to 0.32080, saving model to weights.best.hdf5
# Epoch 00120: val_loss improved from 0.32080 to 0.31993, saving model to weights.best.hdf5
# Epoch 00121: val_loss improved from 0.31993 to 0.31883, saving model to weights.best.hdf5
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss improved from 0.31883 to 0.31844, saving model to weights.best.hdf5
# Epoch 00124: val_loss improved from 0.31844 to 0.31742, saving model to weights.best.hdf5
# Epoch 00125: val_loss improved from 0.31742 to 0.31638, saving model to weights.best.hdf5
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss improved from 0.31638 to 0.31574, saving model to weights.best.hdf5
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss improved from 0.31574 to 0.31530, saving model to weights.best.hdf5
# Epoch 00130: val_loss improved from 0.31530 to 0.31444, saving model to weights.best.hdf5
# Epoch 00131: val_loss improved from 0.31444 to 0.31312, saving model to weights.best.hdf5
# Epoch 00132: val_loss improved from 0.31312 to 0.31272, saving model to weights.best.hdf5
# Epoch 00133: val_loss improved from 0.31272 to 0.31261, saving model to weights.best.hdf5
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss improved from 0.31261 to 0.31250, saving model to weights.best.hdf5
# Epoch 00136: val_loss improved from 0.31250 to 0.31175, saving model to weights.best.hdf5
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss improved from 0.31175 to 0.31154, saving model to weights.best.hdf5
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss improved from 0.31154 to 0.31093, saving model to weights.best.hdf5
# Epoch 00143: val_loss improved from 0.31093 to 0.31093, saving model to weights.best.hdf5
# Epoch 00144: val_loss improved from 0.31093 to 0.31065, saving model to weights.best.hdf5
# Epoch 00145: val_loss improved from 0.31065 to 0.31043, saving model to weights.best.hdf5
# Epoch 00146: val_loss improved from 0.31043 to 0.30963, saving model to weights.best.hdf5
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss improved from 0.30963 to 0.30874, saving model to weights.best.hdf5
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss improved from 0.30874 to 0.30790, saving model to weights.best.hdf5
# Epoch 00155: val_loss improved from 0.30790 to 0.30779, saving model to weights.best.hdf5
# Epoch 00156: val_loss improved from 0.30779 to 0.30767, saving model to weights.best.hdf5
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss improved from 0.30767 to 0.30727, saving model to weights.best.hdf5
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss improved from 0.30727 to 0.30683, saving model to weights.best.hdf5
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss improved from 0.30683 to 0.30651, saving model to weights.best.hdf5
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss improved from 0.30651 to 0.30638, saving model to weights.best.hdf5
# Epoch 00171: val_loss improved from 0.30638 to 0.30638, saving model to weights.best.hdf5
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss improved from 0.30638 to 0.30637, saving model to weights.best.hdf5
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss improved from 0.30637 to 0.30589, saving model to weights.best.hdf5
# Epoch 00180: val_loss improved from 0.30589 to 0.30558, saving model to weights.best.hdf5
# Epoch 00181: val_loss improved from 0.30558 to 0.30544, saving model to weights.best.hdf5
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss improved from 0.30544 to 0.30497, saving model to weights.best.hdf5
# Epoch 00185: val_loss improved from 0.30497 to 0.30457, saving model to weights.best.hdf5
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss improved from 0.30457 to 0.30444, saving model to weights.best.hdf5
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss improved from 0.30444 to 0.30353, saving model to weights.best.hdf5
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss improved from 0.30353 to 0.30311, saving model to weights.best.hdf5
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss improved from 0.30311 to 0.30306, saving model to weights.best.hdf5
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss improved from 0.30306 to 0.30295, saving model to weights.best.hdf5
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss improved from 0.30295 to 0.30237, saving model to weights.best.hdf5
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss improved from 0.30237 to 0.30203, saving model to weights.best.hdf5
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss improved from 0.30203 to 0.30143, saving model to weights.best.hdf5
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss improved from 0.30143 to 0.30134, saving model to weights.best.hdf5
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss improved from 0.30134 to 0.30112, saving model to weights.best.hdf5
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss improved from 0.30112 to 0.30095, saving model to weights.best.hdf5
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss improved from 0.30095 to 0.30093, saving model to weights.best.hdf5
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss improved from 0.30093 to 0.30076, saving model to weights.best.hdf5
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve
# Epoch 00500: val_loss did not improve
# Epoch 00501: val_loss did not improve
# Epoch 00502: val_loss did not improve
# Epoch 00503: val_loss did not improve
# Epoch 00504: val_loss did not improve
# Epoch 00505: val_loss did not improve
# Epoch 00506: val_loss did not improve
# Epoch 00507: val_loss did not improve
# Epoch 00508: val_loss did not improve
# Epoch 00509: val_loss did not improve
# Epoch 00510: val_loss did not improve
# Epoch 00511: val_loss did not improve
# Epoch 00512: val_loss did not improve
# Epoch 00513: val_loss did not improve
# Epoch 00514: val_loss did not improve
# Epoch 00515: val_loss did not improve
# Epoch 00516: val_loss did not improve
# Epoch 00517: val_loss did not improve
# Epoch 00518: val_loss did not improve
# Epoch 00519: val_loss did not improve
# Epoch 00520: val_loss did not improve
# Epoch 00521: val_loss did not improve
# Epoch 00522: val_loss did not improve
# Epoch 00523: val_loss did not improve
# Epoch 00524: val_loss did not improve
# Epoch 00525: val_loss did not improve
# Epoch 00526: val_loss did not improve
# Epoch 00527: val_loss did not improve
# Epoch 00528: val_loss did not improve
# Epoch 00529: val_loss did not improve
# Epoch 00530: val_loss did not improve
# Epoch 00531: val_loss did not improve
# Epoch 00532: val_loss did not improve
# Epoch 00533: val_loss did not improve
# Epoch 00534: val_loss did not improve
# Epoch 00535: val_loss did not improve
# Epoch 00536: val_loss did not improve
# Epoch 00537: val_loss did not improve
# Epoch 00538: val_loss did not improve
# Epoch 00539: val_loss did not improve
# Epoch 00540: val_loss did not improve
# Epoch 00541: val_loss did not improve
# Epoch 00542: val_loss did not improve
# Epoch 00543: val_loss did not improve
# Epoch 00544: val_loss did not improve
# Epoch 00545: val_loss did not improve
# Epoch 00546: val_loss did not improve
# Epoch 00547: val_loss did not improve
# Epoch 00548: val_loss did not improve
# Epoch 00549: val_loss did not improve
# Epoch 00550: val_loss did not improve
# Epoch 00551: val_loss did not improve
# Epoch 00552: val_loss did not improve
# Epoch 00553: val_loss did not improve
# Epoch 00554: val_loss improved from 0.30076 to 0.30048, saving model to weights.best.hdf5
# Epoch 00555: val_loss did not improve
# Epoch 00556: val_loss did not improve
# Epoch 00557: val_loss did not improve
# Epoch 00558: val_loss did not improve
# Epoch 00559: val_loss did not improve
# Epoch 00560: val_loss did not improve
# Epoch 00561: val_loss did not improve
# Epoch 00562: val_loss did not improve
# Epoch 00563: val_loss did not improve
# Epoch 00564: val_loss did not improve
# Epoch 00565: val_loss did not improve
# Epoch 00566: val_loss did not improve
# Epoch 00567: val_loss did not improve
# Epoch 00568: val_loss did not improve
# Epoch 00569: val_loss did not improve
# Epoch 00570: val_loss did not improve
# Epoch 00571: val_loss did not improve
# Epoch 00572: val_loss did not improve
# Epoch 00573: val_loss did not improve
# Epoch 00574: val_loss did not improve
# Epoch 00575: val_loss did not improve
# Epoch 00576: val_loss did not improve
# Epoch 00577: val_loss did not improve
# Epoch 00578: val_loss did not improve
# Epoch 00579: val_loss did not improve
# Epoch 00580: val_loss did not improve
# Epoch 00581: val_loss did not improve
# Epoch 00582: val_loss did not improve
# Epoch 00583: val_loss did not improve
# Epoch 00584: val_loss did not improve
# Epoch 00585: val_loss did not improve
# Epoch 00586: val_loss did not improve
# Epoch 00587: val_loss did not improve
# Epoch 00588: val_loss did not improve
# Epoch 00589: val_loss did not improve
# Epoch 00590: val_loss did not improve
# Epoch 00591: val_loss did not improve
# Epoch 00592: val_loss improved from 0.30048 to 0.29955, saving model to weights.best.hdf5
# Epoch 00593: val_loss did not improve
# Epoch 00594: val_loss did not improve
# Epoch 00595: val_loss did not improve
# Epoch 00596: val_loss did not improve
# Epoch 00597: val_loss did not improve
# Epoch 00598: val_loss did not improve
# Epoch 00599: val_loss did not improve
# Epoch 00600: val_loss did not improve
# Epoch 00601: val_loss did not improve
# Epoch 00602: val_loss did not improve
# Epoch 00603: val_loss did not improve
# Epoch 00604: val_loss did not improve
# Epoch 00605: val_loss did not improve
# Epoch 00606: val_loss did not improve
# Epoch 00607: val_loss did not improve
# Epoch 00608: val_loss did not improve
# Epoch 00609: val_loss did not improve
# Epoch 00610: val_loss did not improve
# Epoch 00611: val_loss did not improve
# Epoch 00612: val_loss did not improve
# Epoch 00613: val_loss did not improve
# Epoch 00614: val_loss did not improve
# Epoch 00615: val_loss did not improve
# Epoch 00616: val_loss did not improve
# Epoch 00617: val_loss did not improve
# Epoch 00618: val_loss did not improve
# Epoch 00619: val_loss did not improve
# Epoch 00620: val_loss did not improve
# Epoch 00621: val_loss did not improve
# Epoch 00622: val_loss did not improve
# Epoch 00623: val_loss did not improve
# Epoch 00624: val_loss did not improve
# Epoch 00625: val_loss did not improve
# Epoch 00626: val_loss did not improve
# Epoch 00627: val_loss did not improve
# Epoch 00628: val_loss did not improve
# Epoch 00629: val_loss did not improve
# Epoch 00630: val_loss did not improve
# Epoch 00631: val_loss did not improve
# Epoch 00632: val_loss did not improve
# Epoch 00633: val_loss improved from 0.29955 to 0.29909, saving model to weights.best.hdf5
# Epoch 00634: val_loss did not improve
# Epoch 00635: val_loss did not improve
# Epoch 00636: val_loss did not improve
# Epoch 00637: val_loss did not improve
# Epoch 00638: val_loss did not improve
# Epoch 00639: val_loss did not improve
# Epoch 00640: val_loss did not improve
# Epoch 00641: val_loss did not improve
# Epoch 00642: val_loss did not improve
# Epoch 00643: val_loss did not improve
# Epoch 00644: val_loss did not improve
# Epoch 00645: val_loss did not improve
# Epoch 00646: val_loss did not improve
# Epoch 00647: val_loss did not improve
# Epoch 00648: val_loss did not improve
# Epoch 00649: val_loss did not improve
# Epoch 00650: val_loss did not improve
# Epoch 00651: val_loss did not improve
# Epoch 00652: val_loss did not improve
# Epoch 00653: val_loss did not improve
# Epoch 00654: val_loss did not improve
# Epoch 00655: val_loss did not improve
# Epoch 00656: val_loss did not improve
# Epoch 00657: val_loss did not improve
# Epoch 00658: val_loss did not improve
# Epoch 00659: val_loss did not improve
# Epoch 00660: val_loss did not improve
# Epoch 00661: val_loss did not improve
# Epoch 00662: val_loss did not improve
# Epoch 00663: val_loss did not improve
# Epoch 00664: val_loss did not improve
# Epoch 00665: val_loss did not improve
# Epoch 00666: val_loss did not improve
# Epoch 00667: val_loss did not improve
# Epoch 00668: val_loss did not improve
# Epoch 00669: val_loss did not improve
# Epoch 00670: val_loss did not improve
# Epoch 00671: val_loss did not improve
# Epoch 00672: val_loss did not improve
# Epoch 00673: val_loss did not improve
# Epoch 00674: val_loss did not improve
# Epoch 00675: val_loss did not improve
# Epoch 00676: val_loss did not improve
# Epoch 00677: val_loss did not improve
# Epoch 00678: val_loss did not improve
# Epoch 00679: val_loss did not improve
# Epoch 00680: val_loss did not improve
# Epoch 00681: val_loss did not improve
# Epoch 00682: val_loss did not improve
# Epoch 00683: val_loss did not improve
# Epoch 00684: val_loss did not improve
# Epoch 00685: val_loss did not improve
# Epoch 00686: val_loss did not improve
# Epoch 00687: val_loss did not improve
# Epoch 00688: val_loss did not improve
# Epoch 00689: val_loss did not improve
# Epoch 00690: val_loss did not improve
# Epoch 00691: val_loss did not improve
# Epoch 00692: val_loss did not improve
# Epoch 00693: val_loss did not improve
# Epoch 00694: val_loss did not improve
# Epoch 00695: val_loss did not improve
# Epoch 00696: val_loss did not improve
# Epoch 00697: val_loss did not improve
# Epoch 00698: val_loss did not improve
# Epoch 00699: val_loss did not improve
# Epoch 00700: val_loss did not improve
# Epoch 00701: val_loss did not improve
# Epoch 00702: val_loss did not improve
# Epoch 00703: val_loss did not improve
# Epoch 00704: val_loss did not improve
# Epoch 00705: val_loss did not improve
# Epoch 00706: val_loss did not improve
# Epoch 00707: val_loss did not improve
# Epoch 00708: val_loss did not improve
# Epoch 00709: val_loss did not improve
# Epoch 00710: val_loss did not improve
# Epoch 00711: val_loss did not improve
# Epoch 00712: val_loss did not improve
# Epoch 00713: val_loss did not improve
# Epoch 00714: val_loss did not improve
# Epoch 00715: val_loss did not improve
# Epoch 00716: val_loss did not improve
# Epoch 00717: val_loss did not improve
# Epoch 00718: val_loss did not improve
# Epoch 00719: val_loss did not improve
# Epoch 00720: val_loss did not improve
# Epoch 00721: val_loss did not improve
# Epoch 00722: val_loss did not improve
# Epoch 00723: val_loss did not improve
# Epoch 00724: val_loss did not improve
# Epoch 00725: val_loss did not improve
# Epoch 00726: val_loss did not improve
# Epoch 00727: val_loss did not improve
# Epoch 00728: val_loss did not improve
# Epoch 00729: val_loss did not improve
# Epoch 00730: val_loss did not improve
# Epoch 00731: val_loss did not improve
# Epoch 00732: val_loss did not improve
# Epoch 00733: val_loss did not improve
# Epoch 00734: val_loss did not improve
# Epoch 00735: val_loss did not improve
# Epoch 00736: val_loss did not improve
# Epoch 00737: val_loss did not improve
# Epoch 00738: val_loss did not improve
# Epoch 00739: val_loss did not improve
# Epoch 00740: val_loss did not improve
# Epoch 00741: val_loss did not improve
# Epoch 00742: val_loss did not improve
# Epoch 00743: val_loss did not improve
# Epoch 00744: val_loss did not improve
# Epoch 00745: val_loss did not improve
# Epoch 00746: val_loss did not improve
# Epoch 00747: val_loss did not improve
# Epoch 00748: val_loss did not improve
# Epoch 00749: val_loss did not improve
# Epoch 00750: val_loss did not improve
# Epoch 00751: val_loss did not improve
# Epoch 00752: val_loss did not improve
# Epoch 00753: val_loss did not improve
# Epoch 00754: val_loss did not improve
# Epoch 00755: val_loss did not improve
# Epoch 00756: val_loss did not improve
# Epoch 00757: val_loss did not improve
# Epoch 00758: val_loss did not improve
# Epoch 00759: val_loss did not improve
# Epoch 00760: val_loss did not improve
# Epoch 00761: val_loss improved from 0.29909 to 0.29902, saving model to weights.best.hdf5
# Epoch 00762: val_loss improved from 0.29902 to 0.29874, saving model to weights.best.hdf5
# Epoch 00763: val_loss did not improve
# Epoch 00764: val_loss did not improve
# Epoch 00765: val_loss did not improve
# Epoch 00766: val_loss did not improve
# Epoch 00767: val_loss did not improve
# Epoch 00768: val_loss did not improve
# Epoch 00769: val_loss did not improve
# Epoch 00770: val_loss did not improve
# Epoch 00771: val_loss did not improve
# Epoch 00772: val_loss did not improve
# Epoch 00773: val_loss did not improve
# Epoch 00774: val_loss did not improve
# Epoch 00775: val_loss did not improve
# Epoch 00776: val_loss did not improve
# Epoch 00777: val_loss did not improve
# Epoch 00778: val_loss did not improve
# Epoch 00779: val_loss improved from 0.29874 to 0.29859, saving model to weights.best.hdf5
# Epoch 00780: val_loss did not improve
# Epoch 00781: val_loss did not improve
# Epoch 00782: val_loss did not improve
# Epoch 00783: val_loss did not improve
# Epoch 00784: val_loss did not improve
# Epoch 00785: val_loss did not improve
# Epoch 00786: val_loss did not improve
# Epoch 00787: val_loss did not improve
# Epoch 00788: val_loss did not improve
# Epoch 00789: val_loss did not improve
# Epoch 00790: val_loss did not improve
# Epoch 00791: val_loss did not improve
# Epoch 00792: val_loss did not improve
# Epoch 00793: val_loss did not improve
# Epoch 00794: val_loss did not improve
# Epoch 00795: val_loss did not improve
# Epoch 00796: val_loss did not improve
# Epoch 00797: val_loss did not improve
# Epoch 00798: val_loss did not improve
# Epoch 00799: val_loss did not improve
# Epoch 00800: val_loss did not improve
# Epoch 00801: val_loss did not improve
# Epoch 00802: val_loss did not improve
# Epoch 00803: val_loss did not improve
# Epoch 00804: val_loss did not improve
# Epoch 00805: val_loss did not improve
# Epoch 00806: val_loss did not improve
# Epoch 00807: val_loss did not improve
# Epoch 00808: val_loss did not improve
# Epoch 00809: val_loss did not improve
# Epoch 00810: val_loss did not improve
# Epoch 00811: val_loss did not improve
# Epoch 00812: val_loss did not improve
# Epoch 00813: val_loss did not improve
# Epoch 00814: val_loss did not improve
# Epoch 00815: val_loss did not improve
# Epoch 00816: val_loss did not improve
# Epoch 00817: val_loss did not improve
# Epoch 00818: val_loss did not improve
# Epoch 00819: val_loss did not improve
# Epoch 00820: val_loss did not improve
# Epoch 00821: val_loss did not improve
# Epoch 00822: val_loss did not improve
# Epoch 00823: val_loss did not improve
# Epoch 00824: val_loss did not improve
# Epoch 00825: val_loss did not improve
# Epoch 00826: val_loss did not improve
# Epoch 00827: val_loss did not improve
# Epoch 00828: val_loss did not improve
# Epoch 00829: val_loss did not improve
# Epoch 00830: val_loss did not improve
# Epoch 00831: val_loss did not improve
# Epoch 00832: val_loss did not improve
# Epoch 00833: val_loss improved from 0.29859 to 0.29788, saving model to weights.best.hdf5
# Epoch 00834: val_loss did not improve
# Epoch 00835: val_loss did not improve
# Epoch 00836: val_loss did not improve
# Epoch 00837: val_loss did not improve
# Epoch 00838: val_loss did not improve
# Epoch 00839: val_loss did not improve
# Epoch 00840: val_loss did not improve
# Epoch 00841: val_loss did not improve
# Epoch 00842: val_loss did not improve
# Epoch 00843: val_loss did not improve
# Epoch 00844: val_loss did not improve
# Epoch 00845: val_loss did not improve
# Epoch 00846: val_loss did not improve
# Epoch 00847: val_loss did not improve
# Epoch 00848: val_loss did not improve
# Epoch 00849: val_loss did not improve
# Epoch 00850: val_loss did not improve
# Epoch 00851: val_loss did not improve
# Epoch 00852: val_loss did not improve
# Epoch 00853: val_loss did not improve
# Epoch 00854: val_loss did not improve
# Epoch 00855: val_loss did not improve
# Epoch 00856: val_loss did not improve
# Epoch 00857: val_loss did not improve
# Epoch 00858: val_loss did not improve
# Epoch 00859: val_loss did not improve
# Epoch 00860: val_loss did not improve
# Epoch 00861: val_loss did not improve
# Epoch 00862: val_loss did not improve
# Epoch 00863: val_loss did not improve
# Epoch 00864: val_loss did not improve
# Epoch 00865: val_loss did not improve
# Epoch 00866: val_loss did not improve
# Epoch 00867: val_loss did not improve
# Epoch 00868: val_loss did not improve
# Epoch 00869: val_loss did not improve
# Epoch 00870: val_loss did not improve
# Epoch 00871: val_loss did not improve
# Epoch 00872: val_loss did not improve
# Epoch 00873: val_loss did not improve
# Epoch 00874: val_loss did not improve
# Epoch 00875: val_loss did not improve
# Epoch 00876: val_loss did not improve
# Epoch 00877: val_loss did not improve
# Epoch 00878: val_loss did not improve
# Epoch 00879: val_loss did not improve
# Epoch 00880: val_loss did not improve
# Epoch 00881: val_loss did not improve
# Epoch 00882: val_loss did not improve
# Epoch 00883: val_loss did not improve
# Epoch 00884: val_loss did not improve
# Epoch 00885: val_loss did not improve
# Epoch 00886: val_loss did not improve
# Epoch 00887: val_loss did not improve
# Epoch 00888: val_loss did not improve
# Epoch 00889: val_loss did not improve
# Epoch 00890: val_loss did not improve
# Epoch 00891: val_loss did not improve
# Epoch 00892: val_loss did not improve
# Epoch 00893: val_loss did not improve
# Epoch 00894: val_loss did not improve
# Epoch 00895: val_loss did not improve
# Epoch 00896: val_loss did not improve
# Epoch 00897: val_loss did not improve
# Epoch 00898: val_loss did not improve
# Epoch 00899: val_loss did not improve
# Epoch 00900: val_loss did not improve
# Epoch 00901: val_loss did not improve
# Epoch 00902: val_loss did not improve
# Epoch 00903: val_loss did not improve
# Epoch 00904: val_loss did not improve
# Epoch 00905: val_loss did not improve
# Epoch 00906: val_loss did not improve
# Epoch 00907: val_loss did not improve
# Epoch 00908: val_loss did not improve
# Epoch 00909: val_loss did not improve
# Epoch 00910: val_loss did not improve
# Epoch 00911: val_loss did not improve
# Epoch 00912: val_loss did not improve
# Epoch 00913: val_loss did not improve
# Epoch 00914: val_loss did not improve
# Epoch 00915: val_loss did not improve
# Epoch 00916: val_loss did not improve
# Epoch 00917: val_loss did not improve
# Epoch 00918: val_loss did not improve
# Epoch 00919: val_loss did not improve
# Epoch 00920: val_loss did not improve
# Epoch 00921: val_loss did not improve
# Epoch 00922: val_loss did not improve
# Epoch 00923: val_loss did not improve
# Epoch 00924: val_loss did not improve
# Epoch 00925: val_loss did not improve
# Epoch 00926: val_loss did not improve
# Epoch 00927: val_loss improved from 0.29788 to 0.29708, saving model to weights.best.hdf5
# Epoch 00928: val_loss did not improve
# Epoch 00929: val_loss did not improve
# Epoch 00930: val_loss did not improve
# Epoch 00931: val_loss did not improve
# Epoch 00932: val_loss did not improve
# Epoch 00933: val_loss did not improve
# Epoch 00934: val_loss did not improve
# Epoch 00935: val_loss did not improve
# Epoch 00936: val_loss did not improve
# Epoch 00937: val_loss did not improve
# Epoch 00938: val_loss did not improve
# Epoch 00939: val_loss did not improve
# Epoch 00940: val_loss did not improve
# Epoch 00941: val_loss did not improve
# Epoch 00942: val_loss did not improve
# Epoch 00943: val_loss did not improve
# Epoch 00944: val_loss did not improve
# Epoch 00945: val_loss did not improve
# Epoch 00946: val_loss did not improve
# Epoch 00947: val_loss did not improve
# Epoch 00948: val_loss did not improve
# Epoch 00949: val_loss did not improve
# Epoch 00950: val_loss did not improve
# Epoch 00951: val_loss did not improve
# Epoch 00952: val_loss did not improve
# Epoch 00953: val_loss did not improve
# Epoch 00954: val_loss did not improve
# Epoch 00955: val_loss did not improve
# Epoch 00956: val_loss did not improve
# Epoch 00957: val_loss did not improve
# Epoch 00958: val_loss did not improve
# Epoch 00959: val_loss did not improve
# Epoch 00960: val_loss did not improve
# Epoch 00961: val_loss did not improve
# Epoch 00962: val_loss did not improve
# Epoch 00963: val_loss did not improve
# Epoch 00964: val_loss did not improve
# Epoch 00965: val_loss did not improve
# Epoch 00966: val_loss did not improve
# Epoch 00967: val_loss did not improve
# Epoch 00968: val_loss did not improve
# Epoch 00969: val_loss did not improve
# Epoch 00970: val_loss did not improve
# Epoch 00971: val_loss did not improve
# Epoch 00972: val_loss did not improve
# Epoch 00973: val_loss did not improve
# Epoch 00974: val_loss did not improve
# Epoch 00975: val_loss did not improve
# Epoch 00976: val_loss did not improve
# Epoch 00977: val_loss did not improve
# Epoch 00978: val_loss did not improve
# Epoch 00979: val_loss did not improve
# Epoch 00980: val_loss did not improve
# Epoch 00981: val_loss did not improve
# Epoch 00982: val_loss did not improve
# Epoch 00983: val_loss did not improve
# Epoch 00984: val_loss did not improve
# Epoch 00985: val_loss did not improve
# Epoch 00986: val_loss did not improve
# Epoch 00987: val_loss did not improve
# Epoch 00988: val_loss did not improve
# Epoch 00989: val_loss did not improve
# Epoch 00990: val_loss did not improve
# Epoch 00991: val_loss did not improve
# Epoch 00992: val_loss did not improve
# Epoch 00993: val_loss did not improve
# Epoch 00994: val_loss did not improve
# Epoch 00995: val_loss did not improve
# Epoch 00996: val_loss did not improve
# Epoch 00997: val_loss did not improve
# Epoch 00998: val_loss did not improve
# Epoch 00999: val_loss did not improve
# Epoch 01000: val_loss did not improve
# Epoch 01001: val_loss did not improve
# Epoch 01002: val_loss did not improve
# Epoch 01003: val_loss did not improve
# Epoch 01004: val_loss did not improve
# Epoch 01005: val_loss did not improve
# Epoch 01006: val_loss did not improve
# Epoch 01007: val_loss did not improve
# Epoch 01008: val_loss did not improve
# Epoch 01009: val_loss did not improve
# Epoch 01010: val_loss did not improve
# Epoch 01011: val_loss did not improve
# Epoch 01012: val_loss did not improve
# Epoch 01013: val_loss did not improve
# Epoch 01014: val_loss did not improve
# Epoch 01015: val_loss did not improve
# Epoch 01016: val_loss did not improve
# Epoch 01017: val_loss did not improve
# Epoch 01018: val_loss did not improve
# Epoch 01019: val_loss did not improve
# Epoch 01020: val_loss did not improve
# Epoch 01021: val_loss did not improve
# Epoch 01022: val_loss did not improve
# Epoch 01023: val_loss did not improve
# Epoch 01024: val_loss did not improve
# Epoch 01025: val_loss did not improve
# Epoch 01026: val_loss did not improve
# ...
# Epoch 02582: val_loss did not improve
# Epoch 02583: val_loss did not improve
# Epoch 02584: val_loss did not improve
# Epoch 02585: val_loss did not improve
# Epoch 02586: val_loss did not improve
# Epoch 02587: val_loss did not improve
# Epoch 02588: val_loss did not improve
# Epoch 02589: val_loss did not improve
# Epoch 02590: val_loss did not improve
# Epoch 02591: val_loss did not improve
# Epoch 02592: val_loss improved from 0.29500 to 0.29461, saving model to weights.best.hdf5
# Epoch 02593: val_loss did not improve
# Epoch 02594: val_loss did not improve
# Epoch 02595: val_loss did not improve
# Epoch 02596: val_loss did not improve
# Epoch 02597: val_loss did not improve
# Epoch 02598: val_loss did not improve
# Epoch 02599: val_loss did not improve
# Epoch 02600: val_loss did not improve
# Epoch 02601: val_loss did not improve
# Epoch 02602: val_loss did not improve
# Epoch 02603: val_loss did not improve
# Epoch 02604: val_loss did not improve
# Epoch 02605: val_loss did not improve
# Epoch 02606: val_loss did not improve
# Epoch 02607: val_loss did not improve
# Epoch 02608: val_loss did not improve
# Epoch 02609: val_loss did not improve
# Epoch 02610: val_loss did not improve
# Epoch 02611: val_loss did not improve
# Epoch 02612: val_loss did not improve
# Epoch 02613: val_loss did not improve
# Epoch 02614: val_loss did not improve
# Epoch 02615: val_loss did not improve
# Epoch 02616: val_loss did not improve
# Epoch 02617: val_loss did not improve
# Epoch 02618: val_loss did not improve
# Epoch 02619: val_loss did not improve
# Epoch 02620: val_loss did not improve
# Epoch 02621: val_loss did not improve
# Epoch 02622: val_loss did not improve
# Epoch 02623: val_loss did not improve
# Epoch 02624: val_loss did not improve
# Epoch 02625: val_loss did not improve
# Epoch 02626: val_loss did not improve
# Epoch 02627: val_loss did not improve
# Epoch 02628: val_loss did not improve
# Epoch 02629: val_loss did not improve
# Epoch 02630: val_loss did not improve
# Epoch 02631: val_loss did not improve
# Epoch 02632: val_loss did not improve
# Epoch 02633: val_loss did not improve
# Epoch 02634: val_loss did not improve
# Epoch 02635: val_loss did not improve
# Epoch 02636: val_loss did not improve
# Epoch 02637: val_loss did not improve
# Epoch 02638: val_loss did not improve
# Epoch 02639: val_loss did not improve
# Epoch 02640: val_loss did not improve
# Epoch 02641: val_loss did not improve
# Epoch 02642: val_loss did not improve
# Epoch 02643: val_loss did not improve
# Epoch 02644: val_loss did not improve
# Epoch 02645: val_loss did not improve
# Epoch 02646: val_loss did not improve
# Epoch 02647: val_loss did not improve
# Epoch 02648: val_loss did not improve
# Epoch 02649: val_loss did not improve
# Epoch 02650: val_loss did not improve
# Epoch 02651: val_loss did not improve
# Epoch 02652: val_loss did not improve
# Epoch 02653: val_loss did not improve
# Epoch 02654: val_loss did not improve
# Epoch 02655: val_loss did not improve
# Epoch 02656: val_loss did not improve
# Epoch 02657: val_loss did not improve
# Epoch 02658: val_loss did not improve
# Epoch 02659: val_loss did not improve
# Epoch 02660: val_loss did not improve
# Epoch 02661: val_loss did not improve
# Epoch 02662: val_loss did not improve
# Epoch 02663: val_loss did not improve
# Epoch 02664: val_loss did not improve
# Epoch 02665: val_loss did not improve
# Epoch 02666: val_loss did not improve
# Epoch 02667: val_loss did not improve
# Epoch 02668: val_loss did not improve
# Epoch 02669: val_loss did not improve
# Epoch 02670: val_loss did not improve
# Epoch 02671: val_loss did not improve
# Epoch 02672: val_loss did not improve
# Epoch 02673: val_loss did not improve
# Epoch 02674: val_loss did not improve
# Epoch 02675: val_loss did not improve
# Epoch 02676: val_loss did not improve
# Epoch 02677: val_loss did not improve
# Epoch 02678: val_loss did not improve
# Epoch 02679: val_loss did not improve
# Epoch 02680: val_loss did not improve
# Epoch 02681: val_loss did not improve
# Epoch 02682: val_loss did not improve
# Epoch 02683: val_loss did not improve
# Epoch 02684: val_loss did not improve
# Epoch 02685: val_loss did not improve
# Epoch 02686: val_loss did not improve
# Epoch 02687: val_loss did not improve
# Epoch 02688: val_loss did not improve
# Epoch 02689: val_loss did not improve
# Epoch 02690: val_loss did not improve
# Epoch 02691: val_loss did not improve
# Epoch 02692: val_loss did not improve
# Epoch 02693: val_loss did not improve
# Epoch 02694: val_loss did not improve
# Epoch 02695: val_loss did not improve
# Epoch 02696: val_loss did not improve
# Epoch 02697: val_loss did not improve
# Epoch 02698: val_loss did not improve
# Epoch 02699: val_loss did not improve
# Epoch 02700: val_loss did not improve
# Epoch 02701: val_loss did not improve
# Epoch 02702: val_loss did not improve
# Epoch 02703: val_loss did not improve
# Epoch 02704: val_loss did not improve
# Epoch 02705: val_loss did not improve
# Epoch 02706: val_loss did not improve
# Epoch 02707: val_loss did not improve
# Epoch 02708: val_loss did not improve
# Epoch 02709: val_loss did not improve
# Epoch 02710: val_loss did not improve
# Epoch 02711: val_loss did not improve
# Epoch 02712: val_loss did not improve
# Epoch 02713: val_loss did not improve
# Epoch 02714: val_loss did not improve
# Epoch 02715: val_loss did not improve
# Epoch 02716: val_loss did not improve
# Epoch 02717: val_loss did not improve
# Epoch 02718: val_loss did not improve
# Epoch 02719: val_loss did not improve
# Epoch 02720: val_loss did not improve
# Epoch 02721: val_loss did not improve
# Epoch 02722: val_loss did not improve
# Epoch 02723: val_loss did not improve
# Epoch 02724: val_loss did not improve
# Epoch 02725: val_loss did not improve
# Epoch 02726: val_loss did not improve
# Epoch 02727: val_loss did not improve
# Epoch 02728: val_loss did not improve
# Epoch 02729: val_loss did not improve
# Epoch 02730: val_loss did not improve
# Epoch 02731: val_loss did not improve
# Epoch 02732: val_loss did not improve
# Epoch 02733: val_loss did not improve
# Epoch 02734: val_loss did not improve
# Epoch 02735: val_loss did not improve
# Epoch 02736: val_loss did not improve
# Epoch 02737: val_loss did not improve
# Epoch 02738: val_loss did not improve
# Epoch 02739: val_loss did not improve
# Epoch 02740: val_loss did not improve
# Epoch 02741: val_loss did not improve
# Epoch 02742: val_loss did not improve
# Epoch 02743: val_loss did not improve
# Epoch 02744: val_loss did not improve
# Epoch 02745: val_loss did not improve
# Epoch 02746: val_loss did not improve
# Epoch 02747: val_loss did not improve
# Epoch 02748: val_loss did not improve
# Epoch 02749: val_loss did not improve
# Epoch 02750: val_loss did not improve
# Epoch 02751: val_loss did not improve
# Epoch 02752: val_loss did not improve
# Epoch 02753: val_loss did not improve
# Epoch 02754: val_loss did not improve
# Epoch 02755: val_loss did not improve
# Epoch 02756: val_loss did not improve
# Epoch 02757: val_loss did not improve
# Epoch 02758: val_loss did not improve
# Epoch 02759: val_loss did not improve
# Epoch 02760: val_loss did not improve
# Epoch 02761: val_loss did not improve
# Epoch 02762: val_loss did not improve
# Epoch 02763: val_loss did not improve
# Epoch 02764: val_loss did not improve
# Epoch 02765: val_loss did not improve
# Epoch 02766: val_loss did not improve
# Epoch 02767: val_loss did not improve
# Epoch 02768: val_loss did not improve
# Epoch 02769: val_loss did not improve
# Epoch 02770: val_loss did not improve
# Epoch 02771: val_loss did not improve
# Epoch 02772: val_loss did not improve
# Epoch 02773: val_loss did not improve
# Epoch 02774: val_loss did not improve
# Epoch 02775: val_loss did not improve
# Epoch 02776: val_loss did not improve
# Epoch 02777: val_loss did not improve
# Epoch 02778: val_loss did not improve
# Epoch 02779: val_loss did not improve
# Epoch 02780: val_loss did not improve
# Epoch 02781: val_loss did not improve
# Epoch 02782: val_loss did not improve
# Epoch 02783: val_loss did not improve
# Epoch 02784: val_loss did not improve
# Epoch 02785: val_loss did not improve
# Epoch 02786: val_loss did not improve
# Epoch 02787: val_loss did not improve
# Epoch 02788: val_loss did not improve
# Epoch 02789: val_loss did not improve
# Epoch 02790: val_loss did not improve
# Epoch 02791: val_loss did not improve
# Epoch 02792: val_loss did not improve
# Epoch 02793: val_loss did not improve
# Epoch 02794: val_loss did not improve
# Epoch 02795: val_loss did not improve
# Epoch 02796: val_loss did not improve
# Epoch 02797: val_loss did not improve
# Epoch 02798: val_loss did not improve
# Epoch 02799: val_loss did not improve
# Epoch 02800: val_loss did not improve
# Epoch 02801: val_loss did not improve
# Epoch 02802: val_loss did not improve
# Epoch 02803: val_loss did not improve
# Epoch 02804: val_loss did not improve
# Epoch 02805: val_loss did not improve
# Epoch 02806: val_loss did not improve
# Epoch 02807: val_loss did not improve
# Epoch 02808: val_loss did not improve
# Epoch 02809: val_loss did not improve
# Epoch 02810: val_loss did not improve
# Epoch 02811: val_loss did not improve
# Epoch 02812: val_loss did not improve
# Epoch 02813: val_loss did not improve
# Epoch 02814: val_loss did not improve
# Epoch 02815: val_loss did not improve
# Epoch 02816: val_loss did not improve
# Epoch 02817: val_loss did not improve
# Epoch 02818: val_loss did not improve
# Epoch 02819: val_loss did not improve
# Epoch 02820: val_loss did not improve
# Epoch 02821: val_loss did not improve
# Epoch 02822: val_loss did not improve
# Epoch 02823: val_loss did not improve
# Epoch 02824: val_loss did not improve
# Epoch 02825: val_loss did not improve
# Epoch 02826: val_loss did not improve
# Epoch 02827: val_loss did not improve
# Epoch 02828: val_loss did not improve
# Epoch 02829: val_loss did not improve
# Epoch 02830: val_loss did not improve
# Epoch 02831: val_loss did not improve
# Epoch 02832: val_loss did not improve
# Epoch 02833: val_loss did not improve
# Epoch 02834: val_loss did not improve
# Epoch 02835: val_loss did not improve
# Epoch 02836: val_loss did not improve
# Epoch 02837: val_loss did not improve
# Epoch 02838: val_loss did not improve
# Epoch 02839: val_loss did not improve
# Epoch 02840: val_loss did not improve
# Epoch 02841: val_loss did not improve
# Epoch 02842: val_loss did not improve
# Epoch 02843: val_loss did not improve
# Epoch 02844: val_loss did not improve
# Epoch 02845: val_loss did not improve
# Epoch 02846: val_loss did not improve
# Epoch 02847: val_loss did not improve
# Epoch 02848: val_loss did not improve
# Epoch 02849: val_loss did not improve
# Epoch 02850: val_loss did not improve
# Epoch 02851: val_loss did not improve
# Epoch 02852: val_loss did not improve
# Epoch 02853: val_loss did not improve
# Epoch 02854: val_loss did not improve
# Epoch 02855: val_loss did not improve
# Epoch 02856: val_loss did not improve
# Epoch 02857: val_loss did not improve
# Epoch 02858: val_loss did not improve
# Epoch 02859: val_loss did not improve
# Epoch 02860: val_loss did not improve
# Epoch 02861: val_loss did not improve
# Epoch 02862: val_loss did not improve
# Epoch 02863: val_loss did not improve
# Epoch 02864: val_loss did not improve
# Epoch 02865: val_loss did not improve
# Epoch 02866: val_loss did not improve
# Epoch 02867: val_loss did not improve
# Epoch 02868: val_loss did not improve
# Epoch 02869: val_loss did not improve
# Epoch 02870: val_loss did not improve
# Epoch 02871: val_loss did not improve
# Epoch 02872: val_loss did not improve
# Epoch 02873: val_loss did not improve
# Epoch 02874: val_loss did not improve
# Epoch 02875: val_loss did not improve
# Epoch 02876: val_loss did not improve
# Epoch 02877: val_loss did not improve
# Epoch 02878: val_loss did not improve
# Epoch 02879: val_loss did not improve
# Epoch 02880: val_loss did not improve
# Epoch 02881: val_loss did not improve
# Epoch 02882: val_loss did not improve
# Epoch 02883: val_loss did not improve
# Epoch 02884: val_loss did not improve
# Epoch 02885: val_loss did not improve
# Epoch 02886: val_loss did not improve
# Epoch 02887: val_loss did not improve
# Epoch 02888: val_loss did not improve
# Epoch 02889: val_loss did not improve
# Epoch 02890: val_loss did not improve
# Epoch 02891: val_loss did not improve
# Epoch 02892: val_loss did not improve
# Epoch 02893: val_loss did not improve
# Epoch 02894: val_loss did not improve
# Epoch 02895: val_loss did not improve
# Epoch 02896: val_loss did not improve
# Epoch 02897: val_loss did not improve
# Epoch 02898: val_loss did not improve
# Epoch 02899: val_loss did not improve
# Epoch 02900: val_loss did not improve
# Epoch 02901: val_loss did not improve
# Epoch 02902: val_loss did not improve
# Epoch 02903: val_loss did not improve
# Epoch 02904: val_loss did not improve
# Epoch 02905: val_loss did not improve
# Epoch 02906: val_loss did not improve
# Epoch 02907: val_loss did not improve
# Epoch 02908: val_loss did not improve
# Epoch 02909: val_loss did not improve
# Epoch 02910: val_loss did not improve
# Epoch 02911: val_loss did not improve
# Epoch 02912: val_loss did not improve
# Epoch 02913: val_loss did not improve
# Epoch 02914: val_loss did not improve
# Epoch 02915: val_loss did not improve
# Epoch 02916: val_loss did not improve
# Epoch 02917: val_loss did not improve
# Epoch 02918: val_loss did not improve
# Epoch 02919: val_loss did not improve
# Epoch 02920: val_loss did not improve
# Epoch 02921: val_loss did not improve
# Epoch 02922: val_loss did not improve
# Epoch 02923: val_loss did not improve
# Epoch 02924: val_loss did not improve
# Epoch 02925: val_loss did not improve
# Epoch 02926: val_loss did not improve
# Epoch 02927: val_loss improved from 0.29461 to 0.29457, saving model to weights.best.hdf5
# Epoch 02928: val_loss did not improve
# Epoch 02929: val_loss did not improve
# Epoch 02930: val_loss did not improve
# Epoch 02931: val_loss did not improve
# Epoch 02932: val_loss did not improve
# Epoch 02933: val_loss did not improve
# Epoch 02934: val_loss did not improve
# Epoch 02935: val_loss did not improve
# Epoch 02936: val_loss did not improve
# Epoch 02937: val_loss did not improve
# Epoch 02938: val_loss did not improve
# Epoch 02939: val_loss did not improve
# Epoch 02940: val_loss did not improve
# Epoch 02941: val_loss did not improve
# Epoch 02942: val_loss did not improve
# Epoch 02943: val_loss did not improve
# Epoch 02944: val_loss did not improve
# Epoch 02945: val_loss did not improve
# Epoch 02946: val_loss did not improve
# Epoch 02947: val_loss did not improve
# Epoch 02948: val_loss did not improve
# Epoch 02949: val_loss did not improve
# Epoch 02950: val_loss did not improve
# Epoch 02951: val_loss did not improve
# Epoch 02952: val_loss did not improve
# Epoch 02953: val_loss did not improve
# Epoch 02954: val_loss did not improve
# Epoch 02955: val_loss did not improve
# Epoch 02956: val_loss did not improve
# Epoch 02957: val_loss did not improve
# Epoch 02958: val_loss did not improve
# Epoch 02959: val_loss did not improve
# Epoch 02960: val_loss did not improve
# Epoch 02961: val_loss did not improve
# Epoch 02962: val_loss did not improve
# Epoch 02963: val_loss did not improve
# Epoch 02964: val_loss did not improve
# Epoch 02965: val_loss did not improve
# Epoch 02966: val_loss did not improve
# Epoch 02967: val_loss did not improve
# Epoch 02968: val_loss did not improve
# Epoch 02969: val_loss did not improve
# Epoch 02970: val_loss did not improve
# Epoch 02971: val_loss did not improve
# Epoch 02972: val_loss did not improve
# Epoch 02973: val_loss did not improve
# Epoch 02974: val_loss did not improve
# Epoch 02975: val_loss did not improve
# Epoch 02976: val_loss did not improve
# Epoch 02977: val_loss did not improve
# Epoch 02978: val_loss did not improve
# Epoch 02979: val_loss did not improve
# Epoch 02980: val_loss did not improve
# Epoch 02981: val_loss did not improve
# Epoch 02982: val_loss did not improve
# Epoch 02983: val_loss did not improve
# Epoch 02984: val_loss did not improve
# Epoch 02985: val_loss did not improve
# Epoch 02986: val_loss did not improve
# Epoch 02987: val_loss did not improve
# Epoch 02988: val_loss did not improve
# Epoch 02989: val_loss did not improve
# Epoch 02990: val_loss did not improve
# Epoch 02991: val_loss did not improve
# Epoch 02992: val_loss did not improve
# Epoch 02993: val_loss did not improve
# Epoch 02994: val_loss did not improve
# Epoch 02995: val_loss did not improve
# Epoch 02996: val_loss did not improve
# Epoch 02997: val_loss did not improve
# Epoch 02998: val_loss did not improve
# Epoch 02999: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   3000
# Best loss at iteratation:     2672    Best: 0.174608148634
# Best val_loss at iteratation: 2927    Best: 0.29456766016

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (445, 1)
# (445,)
# MAE:  112.025
# RMSE: 154.881
# R2:   0.592

# %% [markdown]
# ## LSTM with events information (no text)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    feat = BatchNormalization()(feat)
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.5))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=4000,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_1/concat:0", shape=(?, 21), dtype=float32)
# Epoch 00000: val_loss improved from inf to 1.91745, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 1.91745 to 1.87853, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 1.87853 to 1.82968, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 1.82968 to 1.77335, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 1.77335 to 1.72176, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 1.72176 to 1.67235, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 1.67235 to 1.62934, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 1.62934 to 1.58535, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 1.58535 to 1.53973, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 1.53973 to 1.49947, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 1.49947 to 1.45452, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 1.45452 to 1.41529, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 1.41529 to 1.37164, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 1.37164 to 1.33062, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.33062 to 1.28808, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.28808 to 1.24931, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.24931 to 1.20873, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.20873 to 1.17395, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.17395 to 1.13250, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.13250 to 1.09428, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.09428 to 1.05680, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.05680 to 1.01952, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.01952 to 0.98276, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.98276 to 0.94794, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.94794 to 0.91135, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.91135 to 0.87976, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.87976 to 0.84779, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.84779 to 0.81728, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.81728 to 0.78831, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.78831 to 0.75805, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.75805 to 0.73014, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.73014 to 0.70504, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.70504 to 0.67989, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.67989 to 0.65693, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.65693 to 0.63323, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 0.63323 to 0.61061, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.61061 to 0.59010, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 0.59010 to 0.56893, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 0.56893 to 0.54919, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.54919 to 0.53244, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 0.53244 to 0.51495, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 0.51495 to 0.49947, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.49947 to 0.48551, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.48551 to 0.47030, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.47030 to 0.45792, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.45792 to 0.44493, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.44493 to 0.43311, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 0.43311 to 0.42057, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 0.42057 to 0.41089, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 0.41089 to 0.40031, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 0.40031 to 0.39069, saving model to weights.best.hdf5
# Epoch 00051: val_loss improved from 0.39069 to 0.37991, saving model to weights.best.hdf5
# Epoch 00052: val_loss improved from 0.37991 to 0.37144, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.37144 to 0.36307, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 0.36307 to 0.35518, saving model to weights.best.hdf5
# Epoch 00055: val_loss improved from 0.35518 to 0.34817, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.34817 to 0.34091, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.34091 to 0.33507, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.33507 to 0.32911, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.32911 to 0.32365, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.32365 to 0.31887, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.31887 to 0.31306, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.31306 to 0.30859, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.30859 to 0.30369, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.30369 to 0.29997, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.29997 to 0.29557, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 0.29557 to 0.29169, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.29169 to 0.28794, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.28794 to 0.28473, saving model to weights.best.hdf5
# Epoch 00069: val_loss improved from 0.28473 to 0.28253, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.28253 to 0.27861, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.27861 to 0.27643, saving model to weights.best.hdf5
# Epoch 00072: val_loss improved from 0.27643 to 0.27451, saving model to weights.best.hdf5
# Epoch 00073: val_loss improved from 0.27451 to 0.27176, saving model to weights.best.hdf5
# Epoch 00074: val_loss improved from 0.27176 to 0.26996, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.26996 to 0.26749, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.26749 to 0.26570, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.26570 to 0.26367, saving model to weights.best.hdf5
# Epoch 00078: val_loss improved from 0.26367 to 0.26152, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.26152 to 0.26011, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.26011 to 0.25720, saving model to weights.best.hdf5
# Epoch 00081: val_loss improved from 0.25720 to 0.25635, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.25635 to 0.25483, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.25483 to 0.25341, saving model to weights.best.hdf5
# Epoch 00084: val_loss improved from 0.25341 to 0.25242, saving model to weights.best.hdf5
# Epoch 00085: val_loss improved from 0.25242 to 0.25024, saving model to weights.best.hdf5
# Epoch 00086: val_loss improved from 0.25024 to 0.25014, saving model to weights.best.hdf5
# Epoch 00087: val_loss improved from 0.25014 to 0.24920, saving model to weights.best.hdf5
# Epoch 00088: val_loss improved from 0.24920 to 0.24860, saving model to weights.best.hdf5
# Epoch 00089: val_loss improved from 0.24860 to 0.24738, saving model to weights.best.hdf5
# Epoch 00090: val_loss improved from 0.24738 to 0.24675, saving model to weights.best.hdf5
# Epoch 00091: val_loss improved from 0.24675 to 0.24556, saving model to weights.best.hdf5
# Epoch 00092: val_loss improved from 0.24556 to 0.24528, saving model to weights.best.hdf5
# Epoch 00093: val_loss improved from 0.24528 to 0.24446, saving model to weights.best.hdf5
# Epoch 00094: val_loss improved from 0.24446 to 0.24302, saving model to weights.best.hdf5
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss improved from 0.24302 to 0.24176, saving model to weights.best.hdf5
# Epoch 00097: val_loss improved from 0.24176 to 0.24043, saving model to weights.best.hdf5
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss improved from 0.24043 to 0.23922, saving model to weights.best.hdf5
# Epoch 00102: val_loss improved from 0.23922 to 0.23842, saving model to weights.best.hdf5
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss improved from 0.23842 to 0.23816, saving model to weights.best.hdf5
# Epoch 00106: val_loss improved from 0.23816 to 0.23759, saving model to weights.best.hdf5
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss improved from 0.23759 to 0.23649, saving model to weights.best.hdf5
# Epoch 00109: val_loss improved from 0.23649 to 0.23605, saving model to weights.best.hdf5
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss improved from 0.23605 to 0.23558, saving model to weights.best.hdf5
# Epoch 00113: val_loss improved from 0.23558 to 0.23524, saving model to weights.best.hdf5
# Epoch 00114: val_loss improved from 0.23524 to 0.23482, saving model to weights.best.hdf5
# Epoch 00115: val_loss improved from 0.23482 to 0.23389, saving model to weights.best.hdf5
# Epoch 00116: val_loss improved from 0.23389 to 0.23363, saving model to weights.best.hdf5
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss improved from 0.23363 to 0.23360, saving model to weights.best.hdf5
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss improved from 0.23360 to 0.23287, saving model to weights.best.hdf5
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss improved from 0.23287 to 0.23271, saving model to weights.best.hdf5
# Epoch 00130: val_loss improved from 0.23271 to 0.23165, saving model to weights.best.hdf5
# Epoch 00131: val_loss improved from 0.23165 to 0.23141, saving model to weights.best.hdf5
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss improved from 0.23141 to 0.23071, saving model to weights.best.hdf5
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss improved from 0.23071 to 0.23058, saving model to weights.best.hdf5
# Epoch 00142: val_loss improved from 0.23058 to 0.23018, saving model to weights.best.hdf5
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss improved from 0.23018 to 0.22950, saving model to weights.best.hdf5
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss improved from 0.22950 to 0.22934, saving model to weights.best.hdf5
# Epoch 00157: val_loss improved from 0.22934 to 0.22933, saving model to weights.best.hdf5
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss improved from 0.22933 to 0.22927, saving model to weights.best.hdf5
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss improved from 0.22927 to 0.22849, saving model to weights.best.hdf5
# Epoch 00165: val_loss improved from 0.22849 to 0.22806, saving model to weights.best.hdf5
# Epoch 00166: val_loss improved from 0.22806 to 0.22743, saving model to weights.best.hdf5
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss improved from 0.22743 to 0.22702, saving model to weights.best.hdf5
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss improved from 0.22702 to 0.22692, saving model to weights.best.hdf5
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss improved from 0.22692 to 0.22605, saving model to weights.best.hdf5
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss improved from 0.22605 to 0.22603, saving model to weights.best.hdf5
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss improved from 0.22603 to 0.22565, saving model to weights.best.hdf5
# Epoch 00196: val_loss improved from 0.22565 to 0.22564, saving model to weights.best.hdf5
# Epoch 00197: val_loss improved from 0.22564 to 0.22525, saving model to weights.best.hdf5
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss improved from 0.22525 to 0.22482, saving model to weights.best.hdf5
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss improved from 0.22482 to 0.22454, saving model to weights.best.hdf5
# Epoch 00214: val_loss improved from 0.22454 to 0.22440, saving model to weights.best.hdf5
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss improved from 0.22440 to 0.22352, saving model to weights.best.hdf5
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss improved from 0.22352 to 0.22295, saving model to weights.best.hdf5
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss improved from 0.22295 to 0.22266, saving model to weights.best.hdf5
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss improved from 0.22266 to 0.22247, saving model to weights.best.hdf5
# Epoch 00243: val_loss improved from 0.22247 to 0.22201, saving model to weights.best.hdf5
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss improved from 0.22201 to 0.22080, saving model to weights.best.hdf5
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss improved from 0.22080 to 0.22078, saving model to weights.best.hdf5
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss improved from 0.22078 to 0.21928, saving model to weights.best.hdf5
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss improved from 0.21928 to 0.21892, saving model to weights.best.hdf5
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss improved from 0.21892 to 0.21868, saving model to weights.best.hdf5
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss improved from 0.21868 to 0.21857, saving model to weights.best.hdf5
# Epoch 00305: val_loss improved from 0.21857 to 0.21804, saving model to weights.best.hdf5
# Epoch 00306: val_loss improved from 0.21804 to 0.21801, saving model to weights.best.hdf5
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss improved from 0.21801 to 0.21721, saving model to weights.best.hdf5
# Epoch 00322: val_loss improved from 0.21721 to 0.21715, saving model to weights.best.hdf5
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss improved from 0.21715 to 0.21694, saving model to weights.best.hdf5
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss improved from 0.21694 to 0.21686, saving model to weights.best.hdf5
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss improved from 0.21686 to 0.21684, saving model to weights.best.hdf5
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss improved from 0.21684 to 0.21558, saving model to weights.best.hdf5
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss improved from 0.21558 to 0.21531, saving model to weights.best.hdf5
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss improved from 0.21531 to 0.21500, saving model to weights.best.hdf5
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss improved from 0.21500 to 0.21481, saving model to weights.best.hdf5
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss improved from 0.21481 to 0.21463, saving model to weights.best.hdf5
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss improved from 0.21463 to 0.21408, saving model to weights.best.hdf5
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss improved from 0.21408 to 0.21360, saving model to weights.best.hdf5
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss improved from 0.21360 to 0.21343, saving model to weights.best.hdf5
# Epoch 00390: val_loss improved from 0.21343 to 0.21335, saving model to weights.best.hdf5
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss improved from 0.21335 to 0.21281, saving model to weights.best.hdf5
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss improved from 0.21281 to 0.21274, saving model to weights.best.hdf5
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss improved from 0.21274 to 0.21253, saving model to weights.best.hdf5
# Epoch 00412: val_loss improved from 0.21253 to 0.21189, saving model to weights.best.hdf5
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss improved from 0.21189 to 0.21113, saving model to weights.best.hdf5
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss improved from 0.21113 to 0.21088, saving model to weights.best.hdf5
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss improved from 0.21088 to 0.20927, saving model to weights.best.hdf5
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss improved from 0.20927 to 0.20872, saving model to weights.best.hdf5
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss improved from 0.20872 to 0.20842, saving model to weights.best.hdf5
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve
# Epoch 00500: val_loss did not improve
# Epoch 00501: val_loss did not improve
# Epoch 00502: val_loss did not improve
# Epoch 00503: val_loss did not improve
# Epoch 00504: val_loss did not improve
# Epoch 00505: val_loss did not improve
# Epoch 00506: val_loss did not improve
# Epoch 00507: val_loss did not improve
# Epoch 00508: val_loss did not improve
# Epoch 00509: val_loss did not improve
# Epoch 00510: val_loss improved from 0.20842 to 0.20731, saving model to weights.best.hdf5
# Epoch 00511: val_loss did not improve
# Epoch 00512: val_loss did not improve
# Epoch 00513: val_loss did not improve
# Epoch 00514: val_loss did not improve
# Epoch 00515: val_loss did not improve
# Epoch 00516: val_loss did not improve
# Epoch 00517: val_loss did not improve
# Epoch 00518: val_loss did not improve
# Epoch 00519: val_loss did not improve
# Epoch 00520: val_loss did not improve
# Epoch 00521: val_loss did not improve
# Epoch 00522: val_loss did not improve
# Epoch 00523: val_loss did not improve
# Epoch 00524: val_loss did not improve
# Epoch 00525: val_loss did not improve
# Epoch 00526: val_loss did not improve
# Epoch 00527: val_loss did not improve
# Epoch 00528: val_loss did not improve
# Epoch 00529: val_loss improved from 0.20731 to 0.20707, saving model to weights.best.hdf5
# Epoch 00530: val_loss did not improve
# Epoch 00531: val_loss did not improve
# Epoch 00532: val_loss did not improve
# Epoch 00533: val_loss did not improve
# Epoch 00534: val_loss did not improve
# Epoch 00535: val_loss did not improve
# Epoch 00536: val_loss did not improve
# Epoch 00537: val_loss did not improve
# Epoch 00538: val_loss did not improve
# Epoch 00539: val_loss did not improve
# Epoch 00540: val_loss did not improve
# Epoch 00541: val_loss did not improve
# Epoch 00542: val_loss did not improve
# Epoch 00543: val_loss did not improve
# Epoch 00544: val_loss did not improve
# Epoch 00545: val_loss did not improve
# Epoch 00546: val_loss did not improve
# Epoch 00547: val_loss did not improve
# Epoch 00548: val_loss improved from 0.20707 to 0.20691, saving model to weights.best.hdf5
# Epoch 00549: val_loss improved from 0.20691 to 0.20677, saving model to weights.best.hdf5
# Epoch 00550: val_loss did not improve
# Epoch 00551: val_loss did not improve
# Epoch 00552: val_loss did not improve
# Epoch 00553: val_loss did not improve
# Epoch 00554: val_loss did not improve
# Epoch 00555: val_loss did not improve
# Epoch 00556: val_loss did not improve
# Epoch 00557: val_loss did not improve
# Epoch 00558: val_loss did not improve
# Epoch 00559: val_loss did not improve
# Epoch 00560: val_loss did not improve
# Epoch 00561: val_loss did not improve
# Epoch 00562: val_loss did not improve
# Epoch 00563: val_loss did not improve
# Epoch 00564: val_loss did not improve
# Epoch 00565: val_loss did not improve
# Epoch 00566: val_loss did not improve
# Epoch 00567: val_loss did not improve
# Epoch 00568: val_loss did not improve
# Epoch 00569: val_loss did not improve
# Epoch 00570: val_loss did not improve
# Epoch 00571: val_loss did not improve
# Epoch 00572: val_loss did not improve
# Epoch 00573: val_loss did not improve
# Epoch 00574: val_loss did not improve
# Epoch 00575: val_loss improved from 0.20677 to 0.20599, saving model to weights.best.hdf5
# Epoch 00576: val_loss did not improve
# Epoch 00577: val_loss did not improve
# Epoch 00578: val_loss did not improve
# Epoch 00579: val_loss did not improve
# Epoch 00580: val_loss improved from 0.20599 to 0.20570, saving model to weights.best.hdf5
# Epoch 00581: val_loss did not improve
# Epoch 00582: val_loss did not improve
# Epoch 00583: val_loss improved from 0.20570 to 0.20531, saving model to weights.best.hdf5
# Epoch 00584: val_loss did not improve
# Epoch 00585: val_loss did not improve
# Epoch 00586: val_loss did not improve
# Epoch 00587: val_loss did not improve
# Epoch 00588: val_loss did not improve
# Epoch 00589: val_loss did not improve
# Epoch 00590: val_loss did not improve
# Epoch 00591: val_loss did not improve
# Epoch 00592: val_loss did not improve
# Epoch 00593: val_loss did not improve
# Epoch 00594: val_loss did not improve
# Epoch 00595: val_loss did not improve
# Epoch 00596: val_loss did not improve
# Epoch 00597: val_loss did not improve
# Epoch 00598: val_loss did not improve
# Epoch 00599: val_loss improved from 0.20531 to 0.20508, saving model to weights.best.hdf5
# Epoch 00600: val_loss did not improve
# Epoch 00601: val_loss did not improve
# Epoch 00602: val_loss did not improve
# Epoch 00603: val_loss did not improve
# Epoch 00604: val_loss did not improve
# Epoch 00605: val_loss did not improve
# Epoch 00606: val_loss did not improve
# Epoch 00607: val_loss did not improve
# Epoch 00608: val_loss did not improve
# Epoch 00609: val_loss did not improve
# Epoch 00610: val_loss did not improve
# Epoch 00611: val_loss did not improve
# Epoch 00612: val_loss did not improve
# Epoch 00613: val_loss did not improve
# Epoch 00614: val_loss did not improve
# Epoch 00615: val_loss did not improve
# Epoch 00616: val_loss did not improve
# Epoch 00617: val_loss did not improve
# Epoch 00618: val_loss did not improve
# Epoch 00619: val_loss did not improve
# Epoch 00620: val_loss did not improve
# Epoch 00621: val_loss did not improve
# Epoch 00622: val_loss did not improve
# Epoch 00623: val_loss did not improve
# Epoch 00624: val_loss did not improve
# Epoch 00625: val_loss did not improve
# Epoch 00626: val_loss did not improve
# Epoch 00627: val_loss did not improve
# Epoch 00628: val_loss did not improve
# Epoch 00629: val_loss did not improve
# Epoch 00630: val_loss did not improve
# Epoch 00631: val_loss did not improve
# Epoch 00632: val_loss did not improve
# Epoch 00633: val_loss did not improve
# Epoch 00634: val_loss did not improve
# Epoch 00635: val_loss did not improve
# Epoch 00636: val_loss did not improve
# Epoch 00637: val_loss did not improve
# Epoch 00638: val_loss did not improve
# Epoch 00639: val_loss did not improve
# Epoch 00640: val_loss improved from 0.20508 to 0.20403, saving model to weights.best.hdf5
# Epoch 00641: val_loss did not improve
# Epoch 00642: val_loss did not improve
# Epoch 00643: val_loss did not improve
# Epoch 00644: val_loss did not improve
# Epoch 00645: val_loss did not improve
# Epoch 00646: val_loss did not improve
# Epoch 00647: val_loss did not improve
# Epoch 00648: val_loss did not improve
# Epoch 00649: val_loss did not improve
# Epoch 00650: val_loss did not improve
# Epoch 00651: val_loss did not improve
# Epoch 00652: val_loss did not improve
# Epoch 00653: val_loss did not improve
# Epoch 00654: val_loss did not improve
# Epoch 00655: val_loss did not improve
# Epoch 00656: val_loss did not improve
# Epoch 00657: val_loss did not improve
# Epoch 00658: val_loss did not improve
# Epoch 00659: val_loss did not improve
# Epoch 00660: val_loss did not improve
# Epoch 00661: val_loss improved from 0.20403 to 0.20334, saving model to weights.best.hdf5
# Epoch 00662: val_loss did not improve
# Epoch 00663: val_loss did not improve
# Epoch 00664: val_loss did not improve
# Epoch 00665: val_loss did not improve
# Epoch 00666: val_loss did not improve
# Epoch 00667: val_loss did not improve
# Epoch 00668: val_loss did not improve
# Epoch 00669: val_loss did not improve
# Epoch 00670: val_loss did not improve
# Epoch 00671: val_loss did not improve
# Epoch 00672: val_loss did not improve
# Epoch 00673: val_loss did not improve
# Epoch 00674: val_loss did not improve
# Epoch 00675: val_loss did not improve
# Epoch 00676: val_loss did not improve
# Epoch 00677: val_loss did not improve
# Epoch 00678: val_loss did not improve
# Epoch 00679: val_loss did not improve
# Epoch 00680: val_loss did not improve
# Epoch 00681: val_loss did not improve
# Epoch 00682: val_loss did not improve
# Epoch 00683: val_loss did not improve
# Epoch 00684: val_loss did not improve
# Epoch 00685: val_loss did not improve
# Epoch 00686: val_loss did not improve
# Epoch 00687: val_loss did not improve
# Epoch 00688: val_loss did not improve
# Epoch 00689: val_loss did not improve
# Epoch 00690: val_loss did not improve
# Epoch 00691: val_loss did not improve
# Epoch 00692: val_loss did not improve
# Epoch 00693: val_loss did not improve
# Epoch 00694: val_loss did not improve
# Epoch 00695: val_loss did not improve
# Epoch 00696: val_loss did not improve
# Epoch 00697: val_loss did not improve
# Epoch 00698: val_loss did not improve
# Epoch 00699: val_loss did not improve
# Epoch 00700: val_loss did not improve
# Epoch 00701: val_loss did not improve
# Epoch 00702: val_loss did not improve
# Epoch 00703: val_loss did not improve
# Epoch 00704: val_loss did not improve
# Epoch 00705: val_loss did not improve
# Epoch 00706: val_loss did not improve
# Epoch 00707: val_loss did not improve
# Epoch 00708: val_loss did not improve
# Epoch 00709: val_loss did not improve
# Epoch 00710: val_loss did not improve
# Epoch 00711: val_loss did not improve
# Epoch 00712: val_loss did not improve
# Epoch 00713: val_loss did not improve
# Epoch 00714: val_loss improved from 0.20334 to 0.20273, saving model to weights.best.hdf5
# Epoch 00715: val_loss did not improve
# Epoch 00716: val_loss did not improve
# Epoch 00717: val_loss did not improve
# Epoch 00718: val_loss did not improve
# Epoch 00719: val_loss did not improve
# Epoch 00720: val_loss did not improve
# Epoch 00721: val_loss did not improve
# Epoch 00722: val_loss did not improve
# Epoch 00723: val_loss did not improve
# Epoch 00724: val_loss did not improve
# Epoch 00725: val_loss did not improve
# Epoch 00726: val_loss did not improve
# Epoch 00727: val_loss did not improve
# Epoch 00728: val_loss did not improve
# Epoch 00729: val_loss did not improve
# Epoch 00730: val_loss did not improve
# Epoch 00731: val_loss did not improve
# Epoch 00732: val_loss did not improve
# Epoch 00733: val_loss improved from 0.20273 to 0.20237, saving model to weights.best.hdf5
# Epoch 00734: val_loss did not improve
# Epoch 00735: val_loss did not improve
# Epoch 00736: val_loss did not improve
# Epoch 00737: val_loss did not improve
# Epoch 00738: val_loss did not improve
# Epoch 00739: val_loss did not improve
# Epoch 00740: val_loss did not improve
# Epoch 00741: val_loss did not improve
# Epoch 00742: val_loss did not improve
# Epoch 00743: val_loss did not improve
# Epoch 00744: val_loss did not improve
# Epoch 00745: val_loss did not improve
# Epoch 00746: val_loss did not improve
# Epoch 00747: val_loss did not improve
# Epoch 00748: val_loss did not improve
# Epoch 00749: val_loss improved from 0.20237 to 0.20213, saving model to weights.best.hdf5
# Epoch 00750: val_loss did not improve
# Epoch 00751: val_loss did not improve
# Epoch 00752: val_loss did not improve
# Epoch 00753: val_loss did not improve
# Epoch 00754: val_loss did not improve
# Epoch 00755: val_loss did not improve
# Epoch 00756: val_loss did not improve
# Epoch 00757: val_loss did not improve
# Epoch 00758: val_loss did not improve
# Epoch 00759: val_loss did not improve
# Epoch 00760: val_loss improved from 0.20213 to 0.20175, saving model to weights.best.hdf5
# Epoch 00761: val_loss did not improve
# Epoch 00762: val_loss did not improve
# Epoch 00763: val_loss did not improve
# Epoch 00764: val_loss did not improve
# Epoch 00765: val_loss did not improve
# Epoch 00766: val_loss did not improve
# Epoch 00767: val_loss did not improve
# Epoch 00768: val_loss did not improve
# Epoch 00769: val_loss did not improve
# Epoch 00770: val_loss did not improve
# Epoch 00771: val_loss did not improve
# Epoch 00772: val_loss did not improve
# Epoch 00773: val_loss did not improve
# Epoch 00774: val_loss did not improve
# Epoch 00775: val_loss did not improve
# Epoch 00776: val_loss did not improve
# Epoch 00777: val_loss improved from 0.20175 to 0.20166, saving model to weights.best.hdf5
# Epoch 00778: val_loss did not improve
# Epoch 00779: val_loss did not improve
# Epoch 00780: val_loss did not improve
# Epoch 00781: val_loss did not improve
# Epoch 00782: val_loss did not improve
# Epoch 00783: val_loss did not improve
# Epoch 00784: val_loss did not improve
# Epoch 00785: val_loss did not improve
# Epoch 00786: val_loss did not improve
# Epoch 00787: val_loss did not improve
# Epoch 00788: val_loss did not improve
# Epoch 00789: val_loss did not improve
# Epoch 00790: val_loss did not improve
# Epoch 00791: val_loss did not improve
# Epoch 00792: val_loss did not improve
# Epoch 00793: val_loss did not improve
# Epoch 00794: val_loss did not improve
# Epoch 00795: val_loss did not improve
# Epoch 00796: val_loss did not improve
# Epoch 00797: val_loss did not improve
# Epoch 00798: val_loss did not improve
# Epoch 00799: val_loss improved from 0.20166 to 0.20128, saving model to weights.best.hdf5
# Epoch 00800: val_loss did not improve
# Epoch 00801: val_loss did not improve
# Epoch 00802: val_loss improved from 0.20128 to 0.20105, saving model to weights.best.hdf5
# Epoch 00803: val_loss did not improve
# Epoch 00804: val_loss did not improve
# Epoch 00805: val_loss did not improve
# Epoch 00806: val_loss did not improve
# Epoch 00807: val_loss did not improve
# Epoch 00808: val_loss did not improve
# Epoch 00809: val_loss did not improve
# Epoch 00810: val_loss did not improve
# Epoch 00811: val_loss did not improve
# Epoch 00812: val_loss did not improve
# Epoch 00813: val_loss did not improve
# Epoch 00814: val_loss did not improve
# Epoch 00815: val_loss did not improve
# Epoch 00816: val_loss did not improve
# Epoch 00817: val_loss did not improve
# Epoch 00818: val_loss did not improve
# Epoch 00819: val_loss did not improve
# Epoch 00820: val_loss did not improve
# Epoch 00821: val_loss did not improve
# Epoch 00822: val_loss did not improve
# Epoch 00823: val_loss did not improve
# Epoch 00824: val_loss did not improve
# Epoch 00825: val_loss did not improve
# Epoch 00826: val_loss did not improve
# Epoch 00827: val_loss did not improve
# Epoch 00828: val_loss did not improve
# Epoch 00829: val_loss did not improve
# Epoch 00830: val_loss did not improve
# Epoch 00831: val_loss did not improve
# Epoch 00832: val_loss did not improve
# Epoch 00833: val_loss did not improve
# Epoch 00834: val_loss did not improve
# Epoch 00835: val_loss did not improve
# Epoch 00836: val_loss did not improve
# Epoch 00837: val_loss did not improve
# Epoch 00838: val_loss did not improve
# Epoch 00839: val_loss did not improve
# Epoch 00840: val_loss did not improve
# Epoch 00841: val_loss did not improve
# Epoch 00842: val_loss did not improve
# Epoch 00843: val_loss did not improve
# Epoch 00844: val_loss did not improve
# Epoch 00845: val_loss did not improve
# Epoch 00846: val_loss did not improve
# Epoch 00847: val_loss did not improve
# Epoch 00848: val_loss did not improve
# Epoch 00849: val_loss did not improve
# Epoch 00850: val_loss did not improve
# Epoch 00851: val_loss did not improve
# Epoch 00852: val_loss did not improve
# Epoch 00853: val_loss did not improve
# Epoch 00854: val_loss did not improve
# Epoch 00855: val_loss did not improve
# Epoch 00856: val_loss did not improve
# Epoch 00857: val_loss did not improve
# Epoch 00858: val_loss did not improve
# Epoch 00859: val_loss did not improve
# Epoch 00860: val_loss did not improve
# Epoch 00861: val_loss improved from 0.20105 to 0.20090, saving model to weights.best.hdf5
# Epoch 00862: val_loss did not improve
# Epoch 00863: val_loss did not improve
# Epoch 00864: val_loss did not improve
# Epoch 00865: val_loss did not improve
# Epoch 00866: val_loss did not improve
# Epoch 00867: val_loss did not improve
# Epoch 00868: val_loss did not improve
# Epoch 00869: val_loss did not improve
# Epoch 00870: val_loss did not improve
# Epoch 00871: val_loss did not improve
# Epoch 00872: val_loss did not improve
# Epoch 00873: val_loss did not improve
# Epoch 00874: val_loss did not improve
# Epoch 00875: val_loss did not improve
# Epoch 00876: val_loss did not improve
# Epoch 00877: val_loss did not improve
# Epoch 00878: val_loss did not improve
# Epoch 00879: val_loss did not improve
# Epoch 00880: val_loss did not improve
# Epoch 00881: val_loss did not improve
# Epoch 00882: val_loss did not improve
# Epoch 00883: val_loss improved from 0.20090 to 0.20070, saving model to weights.best.hdf5
# Epoch 00884: val_loss did not improve
# Epoch 00885: val_loss did not improve
# Epoch 00886: val_loss did not improve
# Epoch 00887: val_loss improved from 0.20070 to 0.20047, saving model to weights.best.hdf5
# Epoch 00888: val_loss did not improve
# Epoch 00889: val_loss did not improve
# Epoch 00890: val_loss did not improve
# Epoch 00891: val_loss did not improve
# Epoch 00892: val_loss did not improve
# Epoch 00893: val_loss did not improve
# Epoch 00894: val_loss did not improve
# Epoch 00895: val_loss improved from 0.20047 to 0.20032, saving model to weights.best.hdf5
# Epoch 00896: val_loss did not improve
# Epoch 00897: val_loss did not improve
# Epoch 00898: val_loss did not improve
# Epoch 00899: val_loss did not improve
# Epoch 00900: val_loss did not improve
# Epoch 00901: val_loss did not improve
# Epoch 00902: val_loss did not improve
# Epoch 00903: val_loss did not improve
# Epoch 00904: val_loss improved from 0.20032 to 0.20018, saving model to weights.best.hdf5
# Epoch 00905: val_loss did not improve
# Epoch 00906: val_loss did not improve
# Epoch 00907: val_loss did not improve
# Epoch 00908: val_loss did not improve
# Epoch 00909: val_loss did not improve
# Epoch 00910: val_loss did not improve
# Epoch 00911: val_loss did not improve
# Epoch 00912: val_loss did not improve
# Epoch 00913: val_loss improved from 0.20018 to 0.19950, saving model to weights.best.hdf5
# Epoch 00914: val_loss did not improve
# Epoch 00915: val_loss did not improve
# Epoch 00916: val_loss did not improve
# Epoch 00917: val_loss improved from 0.19950 to 0.19916, saving model to weights.best.hdf5
# Epoch 00918: val_loss did not improve
# Epoch 00919: val_loss did not improve
# Epoch 00920: val_loss did not improve
# Epoch 00921: val_loss did not improve
# Epoch 00922: val_loss did not improve
# Epoch 00923: val_loss did not improve
# Epoch 00924: val_loss did not improve
# Epoch 00925: val_loss did not improve
# Epoch 00926: val_loss did not improve
# Epoch 00927: val_loss did not improve
# Epoch 00928: val_loss did not improve
# Epoch 00929: val_loss did not improve
# Epoch 00930: val_loss did not improve
# Epoch 00931: val_loss did not improve
# Epoch 00932: val_loss did not improve
# Epoch 00933: val_loss did not improve
# Epoch 00934: val_loss did not improve
# Epoch 00935: val_loss did not improve
# Epoch 00936: val_loss did not improve
# Epoch 00937: val_loss did not improve
# Epoch 00938: val_loss did not improve
# Epoch 00939: val_loss did not improve
# Epoch 00940: val_loss did not improve
# Epoch 00941: val_loss did not improve
# Epoch 00942: val_loss did not improve
# Epoch 00943: val_loss did not improve
# Epoch 00944: val_loss did not improve
# Epoch 00945: val_loss did not improve
# Epoch 00946: val_loss did not improve
# Epoch 00947: val_loss did not improve
# Epoch 00948: val_loss did not improve
# Epoch 00949: val_loss did not improve
# Epoch 00950: val_loss did not improve
# Epoch 00951: val_loss did not improve
# Epoch 00952: val_loss did not improve
# Epoch 00953: val_loss improved from 0.19916 to 0.19895, saving model to weights.best.hdf5
# Epoch 00954: val_loss did not improve
# Epoch 00955: val_loss did not improve
# Epoch 00956: val_loss did not improve
# Epoch 00957: val_loss did not improve
# Epoch 00958: val_loss did not improve
# Epoch 00959: val_loss did not improve
# Epoch 00960: val_loss did not improve
# Epoch 00961: val_loss did not improve
# Epoch 00962: val_loss did not improve
# Epoch 00963: val_loss did not improve
# Epoch 00964: val_loss did not improve
# Epoch 00965: val_loss did not improve
# Epoch 00966: val_loss did not improve
# Epoch 00967: val_loss did not improve
# Epoch 00968: val_loss did not improve
# Epoch 00969: val_loss did not improve
# Epoch 00970: val_loss did not improve
# Epoch 00971: val_loss did not improve
# Epoch 00972: val_loss did not improve
# Epoch 00973: val_loss did not improve
# Epoch 00974: val_loss did not improve
# Epoch 00975: val_loss did not improve
# Epoch 00976: val_loss did not improve
# Epoch 00977: val_loss did not improve
# Epoch 00978: val_loss did not improve
# Epoch 00979: val_loss did not improve
# Epoch 00980: val_loss did not improve
# Epoch 00981: val_loss did not improve
# Epoch 00982: val_loss did not improve
# Epoch 00983: val_loss did not improve
# Epoch 00984: val_loss did not improve
# Epoch 00985: val_loss did not improve
# Epoch 00986: val_loss did not improve
# Epoch 00987: val_loss did not improve
# Epoch 00988: val_loss did not improve
# Epoch 00989: val_loss did not improve
# Epoch 00990: val_loss did not improve
# Epoch 00991: val_loss did not improve
# Epoch 00992: val_loss did not improve
# Epoch 00993: val_loss did not improve
# Epoch 00994: val_loss did not improve
# Epoch 00995: val_loss did not improve
# ...
# Epoch 03581: val_loss did not improve
# Epoch 03582: val_loss did not improve
# Epoch 03583: val_loss did not improve
# Epoch 03584: val_loss did not improve
# Epoch 03585: val_loss did not improve
# Epoch 03586: val_loss did not improve
# Epoch 03587: val_loss did not improve
# Epoch 03588: val_loss did not improve
# Epoch 03589: val_loss did not improve
# Epoch 03590: val_loss did not improve
# Epoch 03591: val_loss did not improve
# Epoch 03592: val_loss did not improve
# Epoch 03593: val_loss did not improve
# Epoch 03594: val_loss did not improve
# Epoch 03595: val_loss did not improve
# Epoch 03596: val_loss did not improve
# Epoch 03597: val_loss did not improve
# Epoch 03598: val_loss did not improve
# Epoch 03599: val_loss did not improve
# Epoch 03600: val_loss did not improve
# Epoch 03601: val_loss did not improve
# Epoch 03602: val_loss did not improve
# Epoch 03603: val_loss did not improve
# Epoch 03604: val_loss did not improve
# Epoch 03605: val_loss did not improve
# Epoch 03606: val_loss did not improve
# Epoch 03607: val_loss did not improve
# Epoch 03608: val_loss did not improve
# Epoch 03609: val_loss did not improve
# Epoch 03610: val_loss did not improve
# Epoch 03611: val_loss did not improve
# Epoch 03612: val_loss did not improve
# Epoch 03613: val_loss did not improve
# Epoch 03614: val_loss did not improve
# Epoch 03615: val_loss did not improve
# Epoch 03616: val_loss did not improve
# Epoch 03617: val_loss did not improve
# Epoch 03618: val_loss did not improve
# Epoch 03619: val_loss did not improve
# Epoch 03620: val_loss did not improve
# Epoch 03621: val_loss did not improve
# Epoch 03622: val_loss did not improve
# Epoch 03623: val_loss did not improve
# Epoch 03624: val_loss did not improve
# Epoch 03625: val_loss did not improve
# Epoch 03626: val_loss did not improve
# Epoch 03627: val_loss did not improve
# Epoch 03628: val_loss did not improve
# Epoch 03629: val_loss did not improve
# Epoch 03630: val_loss did not improve
# Epoch 03631: val_loss did not improve
# Epoch 03632: val_loss did not improve
# Epoch 03633: val_loss did not improve
# Epoch 03634: val_loss did not improve
# Epoch 03635: val_loss did not improve
# Epoch 03636: val_loss did not improve
# Epoch 03637: val_loss did not improve
# Epoch 03638: val_loss did not improve
# Epoch 03639: val_loss did not improve
# Epoch 03640: val_loss did not improve
# Epoch 03641: val_loss did not improve
# Epoch 03642: val_loss did not improve
# Epoch 03643: val_loss did not improve
# Epoch 03644: val_loss did not improve
# Epoch 03645: val_loss did not improve
# Epoch 03646: val_loss did not improve
# Epoch 03647: val_loss did not improve
# Epoch 03648: val_loss did not improve
# Epoch 03649: val_loss did not improve
# Epoch 03650: val_loss did not improve
# Epoch 03651: val_loss did not improve
# Epoch 03652: val_loss improved from 0.19021 to 0.18905, saving model to weights.best.hdf5
# Epoch 03653: val_loss did not improve
# Epoch 03654: val_loss did not improve
# Epoch 03655: val_loss did not improve
# Epoch 03656: val_loss did not improve
# Epoch 03657: val_loss did not improve
# Epoch 03658: val_loss did not improve
# Epoch 03659: val_loss did not improve
# Epoch 03660: val_loss did not improve
# Epoch 03661: val_loss did not improve
# Epoch 03662: val_loss did not improve
# Epoch 03663: val_loss did not improve
# Epoch 03664: val_loss did not improve
# Epoch 03665: val_loss did not improve
# Epoch 03666: val_loss did not improve
# Epoch 03667: val_loss did not improve
# Epoch 03668: val_loss did not improve
# Epoch 03669: val_loss did not improve
# Epoch 03670: val_loss did not improve
# Epoch 03671: val_loss did not improve
# Epoch 03672: val_loss did not improve
# Epoch 03673: val_loss did not improve
# Epoch 03674: val_loss did not improve
# Epoch 03675: val_loss did not improve
# Epoch 03676: val_loss did not improve
# Epoch 03677: val_loss did not improve
# Epoch 03678: val_loss did not improve
# Epoch 03679: val_loss did not improve
# Epoch 03680: val_loss did not improve
# Epoch 03681: val_loss did not improve
# Epoch 03682: val_loss did not improve
# Epoch 03683: val_loss did not improve
# Epoch 03684: val_loss did not improve
# Epoch 03685: val_loss did not improve
# Epoch 03686: val_loss did not improve
# Epoch 03687: val_loss did not improve
# Epoch 03688: val_loss did not improve
# Epoch 03689: val_loss did not improve
# Epoch 03690: val_loss did not improve
# Epoch 03691: val_loss did not improve
# Epoch 03692: val_loss did not improve
# Epoch 03693: val_loss did not improve
# Epoch 03694: val_loss did not improve
# Epoch 03695: val_loss did not improve
# Epoch 03696: val_loss did not improve
# Epoch 03697: val_loss did not improve
# Epoch 03698: val_loss did not improve
# Epoch 03699: val_loss did not improve
# Epoch 03700: val_loss did not improve
# Epoch 03701: val_loss did not improve
# Epoch 03702: val_loss did not improve
# Epoch 03703: val_loss did not improve
# Epoch 03704: val_loss did not improve
# Epoch 03705: val_loss did not improve
# Epoch 03706: val_loss did not improve
# Epoch 03707: val_loss did not improve
# Epoch 03708: val_loss did not improve
# Epoch 03709: val_loss did not improve
# Epoch 03710: val_loss did not improve
# Epoch 03711: val_loss did not improve
# Epoch 03712: val_loss did not improve
# Epoch 03713: val_loss did not improve
# Epoch 03714: val_loss did not improve
# Epoch 03715: val_loss did not improve
# Epoch 03716: val_loss did not improve
# Epoch 03717: val_loss did not improve
# Epoch 03718: val_loss did not improve
# Epoch 03719: val_loss did not improve
# Epoch 03720: val_loss did not improve
# Epoch 03721: val_loss did not improve
# Epoch 03722: val_loss did not improve
# Epoch 03723: val_loss did not improve
# Epoch 03724: val_loss did not improve
# Epoch 03725: val_loss did not improve
# Epoch 03726: val_loss did not improve
# Epoch 03727: val_loss did not improve
# Epoch 03728: val_loss did not improve
# Epoch 03729: val_loss did not improve
# Epoch 03730: val_loss did not improve
# Epoch 03731: val_loss did not improve
# Epoch 03732: val_loss did not improve
# Epoch 03733: val_loss did not improve
# Epoch 03734: val_loss did not improve
# Epoch 03735: val_loss did not improve
# Epoch 03736: val_loss did not improve
# Epoch 03737: val_loss did not improve
# Epoch 03738: val_loss did not improve
# Epoch 03739: val_loss did not improve
# Epoch 03740: val_loss did not improve
# Epoch 03741: val_loss did not improve
# Epoch 03742: val_loss did not improve
# Epoch 03743: val_loss did not improve
# Epoch 03744: val_loss did not improve
# Epoch 03745: val_loss did not improve
# Epoch 03746: val_loss did not improve
# Epoch 03747: val_loss did not improve
# Epoch 03748: val_loss did not improve
# Epoch 03749: val_loss did not improve
# Epoch 03750: val_loss did not improve
# Epoch 03751: val_loss did not improve
# Epoch 03752: val_loss did not improve
# Epoch 03753: val_loss did not improve
# Epoch 03754: val_loss did not improve
# Epoch 03755: val_loss did not improve
# Epoch 03756: val_loss did not improve
# Epoch 03757: val_loss did not improve
# Epoch 03758: val_loss did not improve
# Epoch 03759: val_loss did not improve
# Epoch 03760: val_loss did not improve
# Epoch 03761: val_loss did not improve
# Epoch 03762: val_loss did not improve
# Epoch 03763: val_loss did not improve
# Epoch 03764: val_loss did not improve
# Epoch 03765: val_loss did not improve
# Epoch 03766: val_loss did not improve
# Epoch 03767: val_loss did not improve
# Epoch 03768: val_loss did not improve
# Epoch 03769: val_loss did not improve
# Epoch 03770: val_loss did not improve
# Epoch 03771: val_loss did not improve
# Epoch 03772: val_loss did not improve
# Epoch 03773: val_loss did not improve
# Epoch 03774: val_loss did not improve
# Epoch 03775: val_loss did not improve
# Epoch 03776: val_loss did not improve
# Epoch 03777: val_loss did not improve
# Epoch 03778: val_loss did not improve
# Epoch 03779: val_loss did not improve
# Epoch 03780: val_loss did not improve
# Epoch 03781: val_loss did not improve
# Epoch 03782: val_loss did not improve
# Epoch 03783: val_loss did not improve
# Epoch 03784: val_loss did not improve
# Epoch 03785: val_loss did not improve
# Epoch 03786: val_loss did not improve
# Epoch 03787: val_loss did not improve
# Epoch 03788: val_loss did not improve
# Epoch 03789: val_loss did not improve
# Epoch 03790: val_loss did not improve
# Epoch 03791: val_loss did not improve
# Epoch 03792: val_loss did not improve
# Epoch 03793: val_loss did not improve
# Epoch 03794: val_loss did not improve
# Epoch 03795: val_loss did not improve
# Epoch 03796: val_loss did not improve
# Epoch 03797: val_loss did not improve
# Epoch 03798: val_loss did not improve
# Epoch 03799: val_loss did not improve
# Epoch 03800: val_loss did not improve
# Epoch 03801: val_loss did not improve
# Epoch 03802: val_loss did not improve
# Epoch 03803: val_loss did not improve
# Epoch 03804: val_loss did not improve
# Epoch 03805: val_loss did not improve
# Epoch 03806: val_loss did not improve
# Epoch 03807: val_loss did not improve
# Epoch 03808: val_loss did not improve
# Epoch 03809: val_loss did not improve
# Epoch 03810: val_loss did not improve
# Epoch 03811: val_loss did not improve
# Epoch 03812: val_loss did not improve
# Epoch 03813: val_loss did not improve
# Epoch 03814: val_loss did not improve
# Epoch 03815: val_loss did not improve
# Epoch 03816: val_loss did not improve
# Epoch 03817: val_loss did not improve
# Epoch 03818: val_loss did not improve
# Epoch 03819: val_loss did not improve
# Epoch 03820: val_loss did not improve
# Epoch 03821: val_loss did not improve
# Epoch 03822: val_loss did not improve
# Epoch 03823: val_loss did not improve
# Epoch 03824: val_loss did not improve
# Epoch 03825: val_loss did not improve
# Epoch 03826: val_loss did not improve
# Epoch 03827: val_loss did not improve
# Epoch 03828: val_loss did not improve
# Epoch 03829: val_loss did not improve
# Epoch 03830: val_loss did not improve
# Epoch 03831: val_loss did not improve
# Epoch 03832: val_loss did not improve
# Epoch 03833: val_loss did not improve
# Epoch 03834: val_loss did not improve
# Epoch 03835: val_loss did not improve
# Epoch 03836: val_loss did not improve
# Epoch 03837: val_loss did not improve
# Epoch 03838: val_loss did not improve
# Epoch 03839: val_loss did not improve
# Epoch 03840: val_loss did not improve
# Epoch 03841: val_loss did not improve
# Epoch 03842: val_loss did not improve
# Epoch 03843: val_loss did not improve
# Epoch 03844: val_loss did not improve
# Epoch 03845: val_loss did not improve
# Epoch 03846: val_loss did not improve
# Epoch 03847: val_loss did not improve
# Epoch 03848: val_loss did not improve
# Epoch 03849: val_loss did not improve
# Epoch 03850: val_loss did not improve
# Epoch 03851: val_loss did not improve
# Epoch 03852: val_loss did not improve
# Epoch 03853: val_loss did not improve
# Epoch 03854: val_loss did not improve
# Epoch 03855: val_loss did not improve
# Epoch 03856: val_loss did not improve
# Epoch 03857: val_loss did not improve
# Epoch 03858: val_loss did not improve
# Epoch 03859: val_loss did not improve
# Epoch 03860: val_loss did not improve
# Epoch 03861: val_loss did not improve
# Epoch 03862: val_loss did not improve
# Epoch 03863: val_loss did not improve
# Epoch 03864: val_loss did not improve
# Epoch 03865: val_loss did not improve
# Epoch 03866: val_loss did not improve
# Epoch 03867: val_loss did not improve
# Epoch 03868: val_loss did not improve
# Epoch 03869: val_loss did not improve
# Epoch 03870: val_loss did not improve
# Epoch 03871: val_loss did not improve
# Epoch 03872: val_loss did not improve
# Epoch 03873: val_loss did not improve
# Epoch 03874: val_loss did not improve
# Epoch 03875: val_loss did not improve
# Epoch 03876: val_loss did not improve
# Epoch 03877: val_loss did not improve
# Epoch 03878: val_loss did not improve
# Epoch 03879: val_loss did not improve
# Epoch 03880: val_loss did not improve
# Epoch 03881: val_loss did not improve
# Epoch 03882: val_loss did not improve
# Epoch 03883: val_loss did not improve
# Epoch 03884: val_loss did not improve
# Epoch 03885: val_loss did not improve
# Epoch 03886: val_loss did not improve
# Epoch 03887: val_loss did not improve
# Epoch 03888: val_loss did not improve
# Epoch 03889: val_loss did not improve
# Epoch 03890: val_loss did not improve
# Epoch 03891: val_loss did not improve
# Epoch 03892: val_loss did not improve
# Epoch 03893: val_loss did not improve
# Epoch 03894: val_loss did not improve
# Epoch 03895: val_loss did not improve
# Epoch 03896: val_loss did not improve
# Epoch 03897: val_loss did not improve
# Epoch 03898: val_loss did not improve
# Epoch 03899: val_loss did not improve
# Epoch 03900: val_loss did not improve
# Epoch 03901: val_loss did not improve
# Epoch 03902: val_loss did not improve
# Epoch 03903: val_loss did not improve
# Epoch 03904: val_loss did not improve
# Epoch 03905: val_loss did not improve
# Epoch 03906: val_loss did not improve
# Epoch 03907: val_loss did not improve
# Epoch 03908: val_loss did not improve
# Epoch 03909: val_loss did not improve
# Epoch 03910: val_loss did not improve
# Epoch 03911: val_loss did not improve
# Epoch 03912: val_loss did not improve
# Epoch 03913: val_loss did not improve
# Epoch 03914: val_loss did not improve
# Epoch 03915: val_loss did not improve
# Epoch 03916: val_loss did not improve
# Epoch 03917: val_loss did not improve
# Epoch 03918: val_loss did not improve
# Epoch 03919: val_loss did not improve
# Epoch 03920: val_loss did not improve
# Epoch 03921: val_loss did not improve
# Epoch 03922: val_loss did not improve
# Epoch 03923: val_loss did not improve
# Epoch 03924: val_loss did not improve
# Epoch 03925: val_loss did not improve
# Epoch 03926: val_loss did not improve
# Epoch 03927: val_loss did not improve
# Epoch 03928: val_loss did not improve
# Epoch 03929: val_loss did not improve
# Epoch 03930: val_loss did not improve
# Epoch 03931: val_loss did not improve
# Epoch 03932: val_loss did not improve
# Epoch 03933: val_loss did not improve
# Epoch 03934: val_loss did not improve
# Epoch 03935: val_loss did not improve
# Epoch 03936: val_loss did not improve
# Epoch 03937: val_loss did not improve
# Epoch 03938: val_loss did not improve
# Epoch 03939: val_loss did not improve
# Epoch 03940: val_loss did not improve
# Epoch 03941: val_loss did not improve
# Epoch 03942: val_loss did not improve
# Epoch 03943: val_loss did not improve
# Epoch 03944: val_loss did not improve
# Epoch 03945: val_loss did not improve
# Epoch 03946: val_loss did not improve
# Epoch 03947: val_loss did not improve
# Epoch 03948: val_loss did not improve
# Epoch 03949: val_loss did not improve
# Epoch 03950: val_loss did not improve
# Epoch 03951: val_loss did not improve
# Epoch 03952: val_loss did not improve
# Epoch 03953: val_loss did not improve
# Epoch 03954: val_loss did not improve
# Epoch 03955: val_loss did not improve
# Epoch 03956: val_loss did not improve
# Epoch 03957: val_loss did not improve
# Epoch 03958: val_loss did not improve
# Epoch 03959: val_loss did not improve
# Epoch 03960: val_loss did not improve
# Epoch 03961: val_loss did not improve
# Epoch 03962: val_loss did not improve
# Epoch 03963: val_loss did not improve
# Epoch 03964: val_loss did not improve
# Epoch 03965: val_loss did not improve
# Epoch 03966: val_loss did not improve
# Epoch 03967: val_loss did not improve
# Epoch 03968: val_loss did not improve
# Epoch 03969: val_loss did not improve
# Epoch 03970: val_loss did not improve
# Epoch 03971: val_loss did not improve
# Epoch 03972: val_loss did not improve
# Epoch 03973: val_loss did not improve
# Epoch 03974: val_loss did not improve
# Epoch 03975: val_loss did not improve
# Epoch 03976: val_loss did not improve
# Epoch 03977: val_loss did not improve
# Epoch 03978: val_loss did not improve
# Epoch 03979: val_loss did not improve
# Epoch 03980: val_loss did not improve
# Epoch 03981: val_loss did not improve
# Epoch 03982: val_loss did not improve
# Epoch 03983: val_loss did not improve
# Epoch 03984: val_loss did not improve
# Epoch 03985: val_loss did not improve
# Epoch 03986: val_loss did not improve
# Epoch 03987: val_loss did not improve
# Epoch 03988: val_loss did not improve
# Epoch 03989: val_loss did not improve
# Epoch 03990: val_loss did not improve
# Epoch 03991: val_loss did not improve
# Epoch 03992: val_loss did not improve
# Epoch 03993: val_loss did not improve
# Epoch 03994: val_loss did not improve
# Epoch 03995: val_loss did not improve
# Epoch 03996: val_loss did not improve
# Epoch 03997: val_loss did not improve
# Epoch 03998: val_loss did not improve
# Epoch 03999: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   4000
# Best loss at iteratation:     2381    Best: 0.127206771076
# Best val_loss at iteratation: 3652    Best: 0.189046745168

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.180481026121
# (445, 1)
# (445,)
# MAE:  89.849
# RMSE: 132.340
# R2:   0.702

# %% [markdown]
# ## LSTM with events information + event text

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 3461 unique tokens.
# ('Shape of train tensor:', (640, 600))
# ('Shape of val tensor:', (180, 600))
# ('Shape of test tensor:', (445, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.1)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.1)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.1)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.8))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_45/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_136:0", shape=(?, 10), dtype=float32)
# Tensor("input_137:0", shape=(?, 11), dtype=float32)
# Tensor("dropout_135/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_90/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 1.82333, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 1.82333 to 1.62137, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 1.62137 to 1.48333, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 1.48333 to 1.35099, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 1.35099 to 1.22182, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 1.22182 to 1.11339, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 1.11339 to 1.01242, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 1.01242 to 0.94821, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 0.94821 to 0.83008, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 0.83008 to 0.77092, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 0.77092 to 0.71343, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 0.71343 to 0.64761, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 0.64761 to 0.59772, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 0.59772 to 0.55921, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 0.55921 to 0.50707, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 0.50707 to 0.48553, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 0.48553 to 0.45153, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 0.45153 to 0.43826, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 0.43826 to 0.39499, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 0.39499 to 0.38668, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 0.38668 to 0.36678, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.36678 to 0.34980, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.34980 to 0.33779, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.33779 to 0.32387, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.32387 to 0.31363, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.31363 to 0.30535, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.30535 to 0.29624, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.29624 to 0.29176, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.29176 to 0.28112, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.28112 to 0.27937, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.27937 to 0.27810, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.27810 to 0.27333, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.27333 to 0.27109, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.27109 to 0.26820, saving model to weights.best.hdf5
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss improved from 0.26820 to 0.26661, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.26661 to 0.26566, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 0.26566 to 0.26374, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss improved from 0.26374 to 0.26018, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 0.26018 to 0.25782, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss improved from 0.25782 to 0.25291, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 0.25291 to 0.25123, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.25123 to 0.24962, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.24962 to 0.24682, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.24682 to 0.24306, saving model to weights.best.hdf5
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.24306 to 0.24118, saving model to weights.best.hdf5
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.24118 to 0.24061, saving model to weights.best.hdf5
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss improved from 0.24061 to 0.23912, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss improved from 0.23912 to 0.23815, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.23815 to 0.23498, saving model to weights.best.hdf5
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.23498 to 0.23336, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss improved from 0.23336 to 0.23336, saving model to weights.best.hdf5
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss improved from 0.23336 to 0.23075, saving model to weights.best.hdf5
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss improved from 0.23075 to 0.22793, saving model to weights.best.hdf5
# Epoch 00097: val_loss improved from 0.22793 to 0.22777, saving model to weights.best.hdf5
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss improved from 0.22777 to 0.22555, saving model to weights.best.hdf5
# Epoch 00122: val_loss improved from 0.22555 to 0.22334, saving model to weights.best.hdf5
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss improved from 0.22334 to 0.22161, saving model to weights.best.hdf5
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss improved from 0.22161 to 0.22035, saving model to weights.best.hdf5
# Epoch 00156: val_loss improved from 0.22035 to 0.21785, saving model to weights.best.hdf5
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss improved from 0.21785 to 0.21676, saving model to weights.best.hdf5
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss improved from 0.21676 to 0.21610, saving model to weights.best.hdf5
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss improved from 0.21610 to 0.21329, saving model to weights.best.hdf5
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss improved from 0.21329 to 0.21205, saving model to weights.best.hdf5
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss improved from 0.21205 to 0.21061, saving model to weights.best.hdf5
# Epoch 00202: val_loss improved from 0.21061 to 0.21050, saving model to weights.best.hdf5
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss improved from 0.21050 to 0.20916, saving model to weights.best.hdf5
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss improved from 0.20916 to 0.20782, saving model to weights.best.hdf5
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss improved from 0.20782 to 0.20691, saving model to weights.best.hdf5
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss improved from 0.20691 to 0.20079, saving model to weights.best.hdf5
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss improved from 0.20079 to 0.19999, saving model to weights.best.hdf5
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss improved from 0.19999 to 0.19831, saving model to weights.best.hdf5
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss improved from 0.19831 to 0.19649, saving model to weights.best.hdf5
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss improved from 0.19649 to 0.19634, saving model to weights.best.hdf5
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss improved from 0.19634 to 0.19614, saving model to weights.best.hdf5
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss improved from 0.19614 to 0.19489, saving model to weights.best.hdf5
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss improved from 0.19489 to 0.19326, saving model to weights.best.hdf5
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss improved from 0.19326 to 0.19180, saving model to weights.best.hdf5
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss improved from 0.19180 to 0.19002, saving model to weights.best.hdf5
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     400    Best: 0.085598327592
# Best val_loss at iteratation: 492    Best: 0.190024164981

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.180528300281
# (445, 1)
# (445,)
# MAE:  88.179
# RMSE: 129.405
# R2:   0.715

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.178987272452
# (445, 1)
# (445,)
# MAE:  87.639
# RMSE: 128.035
# R2:   0.721
