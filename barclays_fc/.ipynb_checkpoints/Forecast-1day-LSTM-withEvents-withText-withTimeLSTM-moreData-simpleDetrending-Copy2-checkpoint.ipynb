# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, GRU
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("barclays_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2013-02-22  2013-02-22 19:30:00
# 1           1  2015-10-09  2015-10-09 19:30:00
# 2           2  2015-03-20  2015-03-20 19:30:00
# 3           3  2013-11-18  2013-11-18 19:30:00
# 4           4  2015-04-12  2015-04-12 20:00:00
#
#                                        title  \
# 0           Brooklyn Nets vs Houston Rockets
# 1  New York Islanders vs. Chicago Blackhawks
# 2          Brooklyn Nets vs. Milwaukee Bucks
# 3   Brooklyn Nets vs. Portland Trail Blazers
# 4                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                      title  \
# 0  2013-02-22 2013-02-22 19:30:00           Brooklyn Nets vs Houston Rockets
# 1  2015-10-09 2015-10-09 19:30:00  New York Islanders vs. Chicago Blackhawks
# 2  2015-03-20 2015-03-20 19:30:00          Brooklyn Nets vs. Milwaukee Bucks
# 3  2013-11-18 2013-11-18 19:30:00   Brooklyn Nets vs. Portland Trail Blazers
# 4  2015-04-12 2015-04-12 20:00:00                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/mnt/sdb1/nyc_taxi_data/venue-centered_anomalies/30min/data/pickups_barclays_center_0.003.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0        2
# 1  2009-01-01     0       1       15
# 2  2009-01-01     1       0       13
# 3  2009-01-01     1       1       16
# 4  2009-01-01     2       0       19

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      253  2009-01-01    3
# 2009-01-02      137  2009-01-02    4
# 2009-01-03      239  2009-01-03    5
# 2009-01-04      218  2009-01-04    6
# 2009-01-05       92  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event event_desc  event_next_day  \
# date
# 2009-01-01      253  2009-01-01    3    0.0       None             0.0
# 2009-01-02      137  2009-01-02    4    0.0       None             0.0
# 2009-01-03      239  2009-01-03    5    0.0       None             0.0
# 2009-01-04      218  2009-01-04    6    0.0       None             0.0
# 2009-01-05       92  2009-01-05    0    0.0       None             0.0
#
#            event_next_day_desc
# date
# 2009-01-01                None
# 2009-01-02                None
# 2009-01-03                None
# 2009-01-04                None
# 2009-01-05                None

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc
# date
# 2013-01-01                                               None
# 2013-01-02                                               None
# 2013-01-03                                               None
# 2013-01-04  net home game schedule highlight include oneti...
# 2013-01-05                                               None

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013

# %%
trend_mean = df_sum[df_sum.index.year < 2015].groupby(["dow"]).mean()["pickups"]
trend_mean
# Out:
# dow
# 0    470.538462
# 1    483.285714
# 2    526.504762
# 3    527.576923
# 4    653.596154
# 5    812.192308
# 6    738.471154
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 313.32834892618996

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1277

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  483.285714  313.328349   0.334200
# 2013-01-02  526.504762  313.328349  -1.093118
# 2013-01-03  527.576923  313.328349  -1.106114
# 2013-01-04  653.596154  313.328349  -1.355116
# 2013-01-05  812.192308  313.328349  -0.887862

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.30268346],
#        [ 0.30268346,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.31527138544703964, pvalue=7.2897955011241835e-31)

# %% [markdown]
# ## Build lags

# %%
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  483.285714  313.328349   0.334200
# 2013-01-02  526.504762  313.328349  -1.093118
# 2013-01-03  527.576923  313.328349  -1.106114
# 2013-01-04  653.596154  313.328349  -1.355116
# 2013-01-05  812.192308  313.328349  -0.887862

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = df_sum["event_next_day"].as_matrix()
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1266, 10)
# event_feats: (1266,)
# lags_event_feats: (1266, 10)
# event_texts: (1266,)
# preds: (1266,)
# trends: (1266,)
# stds: (1266,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.782244174305
# 1 0.731196742354
# 2 0.691024188265
# 3 0.703718031704
# 4 0.711376942428
# 5 0.713914167655
# 6 0.742115173222
# 7 0.719673348891
# 8 0.69565035192
# 9 0.681006060537

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.298651917502
# 1 0.299359667567
# 2 0.300257449504
# 3 0.301239297957
# 4 0.302651598162
# 5 0.304190996274
# 6 0.303205486189
# 7 0.303308801188
# 8 0.304255471815

# %%
np.corrcoef(preds[:], event_feats[:])
# Out:
# array([[ 1.        ,  0.30006484],
#        [ 0.30006484,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640,)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# y_train: (640,)
# y_val: (90,)
# y_test: (535,)
# trend_test: (535,)
# std_test: (535,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline

# %%
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  119.619
# RMSE: 164.510
# R2:   0.448

# %% [markdown]
# ## Linear regression with events

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train[:,np.newaxis]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test[:,np.newaxis]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  103.086
# RMSE: 144.567
# R2:   0.574

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  97.458
# RMSE: 138.808
# R2:   0.607

# %% [markdown]
# ## Simple LSTM

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,1))
    
    x = input_lags
    #x = BatchNormalization()(x)
    x = LSTM(20, 
             kernel_regularizer=keras.regularizers.l2(0.1), 
             recurrent_regularizer=keras.regularizers.l2(0.1), 
             return_sequences=False)(x)
    #x = Activation("relu")(x)
    #x = Flatten()(x)
    x = BatchNormalization()(x)
    #x = Dropout(0.2)(x)
    #x = BatchNormalization()(x)
    
    #preds = Dense(units=num_preds)(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.05))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.05)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    lags_train[:,:,np.newaxis],
    y_train,
    batch_size=64,
    epochs=300,
    validation_data=(lags_val[:,:,np.newaxis], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 3.27355, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 3.27355 to 3.23429, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 3.23429 to 2.97397, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 2.97397 to 2.73128, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 2.73128 to 2.57254, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 2.57254 to 2.39553, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 2.39553 to 2.22893, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 2.22893 to 2.09884, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 2.09884 to 1.97276, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 1.97276 to 1.88481, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 1.88481 to 1.77858, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 1.77858 to 1.66420, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 1.66420 to 1.59081, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 1.59081 to 1.50205, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.50205 to 1.43411, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.43411 to 1.35595, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.35595 to 1.30338, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.30338 to 1.24665, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.24665 to 1.16451, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.16451 to 1.14149, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.14149 to 1.07566, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.07566 to 1.01588, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.01588 to 0.97848, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.97848 to 0.92995, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.92995 to 0.89063, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.89063 to 0.85395, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.85395 to 0.82415, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.82415 to 0.76420, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.76420 to 0.75490, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.75490 to 0.71309, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.71309 to 0.69077, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.69077 to 0.66313, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.66313 to 0.63907, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.63907 to 0.61863, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.61863 to 0.58949, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 0.58949 to 0.57600, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.57600 to 0.56082, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 0.56082 to 0.53601, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 0.53601 to 0.52646, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.52646 to 0.51420, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 0.51420 to 0.49857, saving model to weights.best.hdf5
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 0.49857 to 0.47684, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.47684 to 0.47251, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.47251 to 0.47226, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.47226 to 0.45619, saving model to weights.best.hdf5
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss improved from 0.45619 to 0.45489, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 0.45489 to 0.44515, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 0.44515 to 0.43693, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 0.43693 to 0.43671, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.43671 to 0.42373, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss improved from 0.42373 to 0.41886, saving model to weights.best.hdf5
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss improved from 0.41886 to 0.40642, saving model to weights.best.hdf5
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss improved from 0.40642 to 0.39994, saving model to weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.39994 to 0.39490, saving model to weights.best.hdf5
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.39490 to 0.39489, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss improved from 0.39489 to 0.38015, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.38015 to 0.37922, saving model to weights.best.hdf5
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.37922 to 0.37646, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss improved from 0.37646 to 0.37132, saving model to weights.best.hdf5
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.37132 to 0.36859, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.36859 to 0.36104, saving model to weights.best.hdf5
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss improved from 0.36104 to 0.36019, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss improved from 0.36019 to 0.35892, saving model to weights.best.hdf5
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss improved from 0.35892 to 0.35735, saving model to weights.best.hdf5
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss improved from 0.35735 to 0.35483, saving model to weights.best.hdf5
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss improved from 0.35483 to 0.35324, saving model to weights.best.hdf5
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss improved from 0.35324 to 0.35158, saving model to weights.best.hdf5
# Epoch 00094: val_loss improved from 0.35158 to 0.35058, saving model to weights.best.hdf5
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss improved from 0.35058 to 0.34975, saving model to weights.best.hdf5
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss improved from 0.34975 to 0.34897, saving model to weights.best.hdf5
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss improved from 0.34897 to 0.34617, saving model to weights.best.hdf5
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss improved from 0.34617 to 0.34286, saving model to weights.best.hdf5
# Epoch 00107: val_loss improved from 0.34286 to 0.34250, saving model to weights.best.hdf5
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss improved from 0.34250 to 0.34090, saving model to weights.best.hdf5
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss improved from 0.34090 to 0.34024, saving model to weights.best.hdf5
# Epoch 00112: val_loss improved from 0.34024 to 0.33987, saving model to weights.best.hdf5
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss improved from 0.33987 to 0.33714, saving model to weights.best.hdf5
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss improved from 0.33714 to 0.33692, saving model to weights.best.hdf5
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss improved from 0.33692 to 0.33640, saving model to weights.best.hdf5
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss improved from 0.33640 to 0.33484, saving model to weights.best.hdf5
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss improved from 0.33484 to 0.33461, saving model to weights.best.hdf5
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss improved from 0.33461 to 0.33175, saving model to weights.best.hdf5
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     297    Best: 0.206511482596
# Best val_loss at iteratation: 140    Best: 0.331747475598

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:,np.newaxis]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  125.501
# RMSE: 166.273
# R2:   0.436

# %% [markdown]
# ## LSTM with events information (no text)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,1))
    input_events = Input(shape=(num_feat,))
    
    x_lags = input_lags
    #x_lags = BatchNormalization()(x_lags)
    x_lags = LSTM(20, 
             kernel_regularizer=keras.regularizers.l2(0.1), 
             recurrent_regularizer=keras.regularizers.l2(0.1), 
             return_sequences=False)(x_lags)
    #x_lags = Activation("relu")(x_lags)
    #x_lags = Flatten()(x_lags)
    x_lags = BatchNormalization()(x_lags)
    #x_lags = Dropout(0.2)(x_lags)
    #x_lags = BatchNormalization()(x_lags)
    
    feat = Concatenate(axis=1)([x_lags, input_events])
    print feat
    
    feat = BatchNormalization()(feat)
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.5))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
#print model_weather.summary()
model.fit(
    [lags_train[:,:,np.newaxis], 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([lags_val[:,:,np.newaxis], 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_12/concat:0", shape=(?, 31), dtype=float32)
# Epoch 00000: val_loss improved from inf to 3.65288, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 3.65288 to 3.51266, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 3.51266 to 3.32603, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 3.32603 to 3.15380, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 3.15380 to 2.96480, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 2.96480 to 2.78780, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 2.78780 to 2.65238, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 2.65238 to 2.51849, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 2.51849 to 2.39154, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 2.39154 to 2.29395, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 2.29395 to 2.21716, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 2.21716 to 2.11581, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.11581 to 2.04828, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.04828 to 1.97541, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.97541 to 1.90897, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.90897 to 1.82486, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.82486 to 1.79293, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.79293 to 1.70446, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.70446 to 1.64815, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.64815 to 1.59634, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.59634 to 1.56007, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.56007 to 1.50872, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.50872 to 1.45953, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 1.45953 to 1.43584, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 1.43584 to 1.39381, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.39381 to 1.34834, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.34834 to 1.29897, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.29897 to 1.26525, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.26525 to 1.23477, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.23477 to 1.18081, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.18081 to 1.14445, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.14445 to 1.09897, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.09897 to 1.07684, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.07684 to 1.03709, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.03709 to 1.01193, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.01193 to 0.95786, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.95786 to 0.95385, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 0.95385 to 0.90832, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 0.90832 to 0.90707, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.90707 to 0.83080, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 0.83080 to 0.79591, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.79591 to 0.79467, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.79467 to 0.75254, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.75254 to 0.73168, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.73168 to 0.72151, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 0.72151 to 0.67759, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 0.67759 to 0.66934, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 0.66934 to 0.63512, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss improved from 0.63512 to 0.62239, saving model to weights.best.hdf5
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.62239 to 0.59132, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss improved from 0.59132 to 0.53875, saving model to weights.best.hdf5
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss improved from 0.53875 to 0.53649, saving model to weights.best.hdf5
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss improved from 0.53649 to 0.47570, saving model to weights.best.hdf5
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss improved from 0.47570 to 0.43728, saving model to weights.best.hdf5
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss improved from 0.43728 to 0.43671, saving model to weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.43671 to 0.38638, saving model to weights.best.hdf5
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss improved from 0.38638 to 0.34744, saving model to weights.best.hdf5
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss improved from 0.34744 to 0.34137, saving model to weights.best.hdf5
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss improved from 0.34137 to 0.32328, saving model to weights.best.hdf5
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss improved from 0.32328 to 0.28269, saving model to weights.best.hdf5
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss improved from 0.28269 to 0.27923, saving model to weights.best.hdf5
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss improved from 0.27923 to 0.27659, saving model to weights.best.hdf5
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss improved from 0.27659 to 0.27167, saving model to weights.best.hdf5
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss improved from 0.27167 to 0.27128, saving model to weights.best.hdf5
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss improved from 0.27128 to 0.27025, saving model to weights.best.hdf5
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss improved from 0.27025 to 0.26396, saving model to weights.best.hdf5
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss improved from 0.26396 to 0.26273, saving model to weights.best.hdf5
# Epoch 00159: val_loss improved from 0.26273 to 0.26154, saving model to weights.best.hdf5
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss improved from 0.26154 to 0.26128, saving model to weights.best.hdf5
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss improved from 0.26128 to 0.26004, saving model to weights.best.hdf5
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss improved from 0.26004 to 0.25806, saving model to weights.best.hdf5
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss improved from 0.25806 to 0.25616, saving model to weights.best.hdf5
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss improved from 0.25616 to 0.25368, saving model to weights.best.hdf5
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss improved from 0.25368 to 0.25140, saving model to weights.best.hdf5
# Epoch 00234: val_loss improved from 0.25140 to 0.25129, saving model to weights.best.hdf5
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss improved from 0.25129 to 0.25031, saving model to weights.best.hdf5
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss improved from 0.25031 to 0.24946, saving model to weights.best.hdf5
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss improved from 0.24946 to 0.24939, saving model to weights.best.hdf5
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     294    Best: 0.168585340679
# Best val_loss at iteratation: 275    Best: 0.249394004212

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:,np.newaxis]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:,np.newaxis]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.229121077451
# (535, 1)
# (535,)
# MAE:  108.034
# RMSE: 144.261
# R2:   0.576

# %% [markdown]
# ## LSTM with events information + event text

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 3461 unique tokens.
# ('Shape of train tensor:', (640, 600))
# ('Shape of val tensor:', (90, 600))
# ('Shape of test tensor:', (535, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,1))
    input_events = Input(shape=(num_feat,))
    
    x_lags = input_lags
    #x_lags = BatchNormalization()(x_lags)
    x_lags = LSTM(20, 
             kernel_regularizer=keras.regularizers.l2(0.1), 
             recurrent_regularizer=keras.regularizers.l2(0.1), 
             return_sequences=False)(x_lags)
    #x_lags = Activation("relu")(x_lags)
    #x_lags = Flatten()(x_lags)
    x_lags = BatchNormalization()(x_lags)
    #x_lags = Dropout(0.2)(x_lags)
    #x_lags = BatchNormalization()(x_lags)
    
    x_lags = Concatenate(axis=1)([x_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
model.fit(
    [lags_train[:,:,np.newaxis], 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=200,
    #validation_split=0.2,
    validation_data=([lags_val[:,:,np.newaxis], 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_4/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_148:0", shape=(?, 10, 1), dtype=float32)
# Tensor("input_149:0", shape=(?, 11), dtype=float32)
# Tensor("dropout_98/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_14/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 4.26770, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 4.26770 to 3.89010, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 3.89010 to 3.45561, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 3.45561 to 3.33484, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 3.33484 to 3.09864, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 3.09864 to 2.94511, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 2.94511 to 2.82040, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 2.82040 to 2.65409, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 2.65409 to 2.56348, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 2.56348 to 2.38996, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 2.38996 to 2.32218, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 2.32218 to 2.24001, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.24001 to 2.17378, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.17378 to 2.13807, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.13807 to 2.08186, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.08186 to 1.97289, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.97289 to 1.95571, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.95571 to 1.95141, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.95141 to 1.85373, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.85373 to 1.70860, saving model to weights.best.hdf5
# Epoch 00020: val_loss did not improve
# Epoch 00021: val_loss improved from 1.70860 to 1.64143, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.64143 to 1.62069, saving model to weights.best.hdf5
# Epoch 00023: val_loss did not improve
# Epoch 00024: val_loss improved from 1.62069 to 1.59628, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.59628 to 1.46163, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.46163 to 1.42972, saving model to weights.best.hdf5
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss improved from 1.42972 to 1.40621, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.40621 to 1.31984, saving model to weights.best.hdf5
# Epoch 00030: val_loss did not improve
# Epoch 00031: val_loss improved from 1.31984 to 1.31295, saving model to weights.best.hdf5
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 1.31295 to 1.19150, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.19150 to 1.16592, saving model to weights.best.hdf5
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss improved from 1.16592 to 1.14557, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.14557 to 1.12573, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.12573 to 1.11146, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.11146 to 1.04125, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.04125 to 1.03369, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.03369 to 0.95116, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss improved from 0.95116 to 0.93784, saving model to weights.best.hdf5
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss improved from 0.93784 to 0.90287, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.90287 to 0.86499, saving model to weights.best.hdf5
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 0.86499 to 0.81034, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss improved from 0.81034 to 0.77991, saving model to weights.best.hdf5
# Epoch 00052: val_loss improved from 0.77991 to 0.65200, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss improved from 0.65200 to 0.60331, saving model to weights.best.hdf5
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss improved from 0.60331 to 0.59853, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.59853 to 0.55444, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.55444 to 0.55114, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.55114 to 0.48329, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.48329 to 0.47727, saving model to weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.47727 to 0.40542, saving model to weights.best.hdf5
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.40542 to 0.35243, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.35243 to 0.30657, saving model to weights.best.hdf5
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.30657 to 0.30152, saving model to weights.best.hdf5
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.30152 to 0.26778, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.26778 to 0.24658, saving model to weights.best.hdf5
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss improved from 0.24658 to 0.24244, saving model to weights.best.hdf5
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss improved from 0.24244 to 0.23983, saving model to weights.best.hdf5
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss improved from 0.23983 to 0.23570, saving model to weights.best.hdf5
# Epoch 00120: val_loss improved from 0.23570 to 0.23560, saving model to weights.best.hdf5
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss improved from 0.23560 to 0.23279, saving model to weights.best.hdf5
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   200
# Best loss at iteratation:     187    Best: 0.145420040935
# Best val_loss at iteratation: 163    Best: 0.232786943515

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:,np.newaxis]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:,np.newaxis]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.212361139059
# (535, 1)
# (535,)
# MAE:  100.800
# RMSE: 139.590
# R2:   0.603

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.208311992104
# (535, 1)
# (535,)
# MAE:  95.151
# RMSE: 135.798
# R2:   0.624
