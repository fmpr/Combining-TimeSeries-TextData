# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# Using TensorFlow backend.

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("barclays_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2013-02-22  2013-02-22 19:30:00
# 1           1  2015-10-09  2015-10-09 19:30:00
# 2           2  2015-03-20  2015-03-20 19:30:00
# 3           3  2013-11-18  2013-11-18 19:30:00
# 4           4  2015-04-12  2015-04-12 20:00:00
#
#                                        title  \
# 0           Brooklyn Nets vs Houston Rockets
# 1  New York Islanders vs. Chicago Blackhawks
# 2          Brooklyn Nets vs. Milwaukee Bucks
# 3   Brooklyn Nets vs. Portland Trail Blazers
# 4                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                      title  \
# 0  2013-02-22 2013-02-22 19:30:00           Brooklyn Nets vs Houston Rockets
# 1  2015-10-09 2015-10-09 19:30:00  New York Islanders vs. Chicago Blackhawks
# 2  2015-03-20 2015-03-20 19:30:00          Brooklyn Nets vs. Milwaukee Bucks
# 3  2013-11-18 2013-11-18 19:30:00   Brooklyn Nets vs. Portland Trail Blazers
# 4  2015-04-12 2015-04-12 20:00:00                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
# late events
print len(events["start_time"].dt.hour.values)
print np.sum(events["start_time"].dt.hour.values >= 20)
print np.sum(events["start_time"].dt.hour.values >= 21)
plt.hist(events["start_time"].dt.hour.values)
# Out:
# 885
# 172
# 11
# (array([  31.,    0.,    0.,    0.,   13.,   67.,   63.,   51.,  488.,  172.]),
#  array([  0. ,   2.2,   4.4,   6.6,   8.8,  11. ,  13.2,  15.4,  17.6,
#          19.8,  22. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/home/fmpr/data/pickups_barclays_center_0.003.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0        2
# 1  2009-01-01     0       1       15
# 2  2009-01-01     1       0       13
# 3  2009-01-01     1       1       16
# 4  2009-01-01     2       0       19

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      253  2009-01-01    3
# 2009-01-02      137  2009-01-02    4
# 2009-01-03      239  2009-01-03    5
# 2009-01-04      218  2009-01-04    6
# 2009-01-05       92  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
late_event = np.zeros((len(df_sum)))
really_late_event = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
        for e in events[events.date == df_sum.iloc[i].date]["start_time"]:
            if e.hour >= 20:
                late_event[i] = 1
            if e.hour >= 21:
                really_late_event[i] = 1
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["late_event"] = late_event
df_sum["really_late_event"] = really_late_event
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["late_event_next_day"] = pd.Series(df_sum["late_event"]).shift(-1)
df_sum["really_late_event_next_day"] = pd.Series(df_sum["really_late_event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      253  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      137  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      239  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      218  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05       92  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day event_next_day_desc
# date
# 2009-01-01                         0.0                None
# 2009-01-02                         0.0                None
# 2009-01-03                         0.0                None
# 2009-01-04                         0.0                None
# 2009-01-05                         0.0                None

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      184  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      181  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      229  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05      534  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc
# date
# 2013-01-01                                               None
# 2013-01-02                                               None
# 2013-01-03                                               None
# 2013-01-04  net home game schedule highlight include oneti...
# 2013-01-05                                               None

# %%
df_sum.describe()
# Out:
#            pickups          dow        event   late_event  really_late_event  \
# count  1277.000000  1277.000000  1277.000000  1277.000000        1277.000000
# mean    747.750979     2.997651     0.431480     0.097103           0.006265
# std     313.328349     1.999411     0.495477     0.296213           0.078932
# min     156.000000     0.000000     0.000000     0.000000           0.000000
# 25%     532.000000     1.000000     0.000000     0.000000           0.000000
# 50%     734.000000     3.000000     0.000000     0.000000           0.000000
# 75%     968.000000     5.000000     1.000000     0.000000           0.000000
# max    1908.000000     6.000000     1.000000     1.000000           1.000000
#
#        event_next_day  late_event_next_day  really_late_event_next_day
# count     1276.000000          1276.000000                 1276.000000
# mean         0.431818             0.097179                    0.006270
# std          0.495524             0.296317                    0.078963
# min          0.000000             0.000000                    0.000000
# 25%          0.000000             0.000000                    0.000000
# 50%          0.000000             0.000000                    0.000000
# 75%          1.000000             0.000000                    0.000000
# max          1.000000             1.000000                    1.000000

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      184  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      181  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      229  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05      534  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc  year
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013

# %%
trend_mean = df_sum[df_sum.index.year < 2015].groupby(["dow"]).mean()["pickups"]
trend_mean
# Out:
# dow
# 0    470.538462
# 1    483.285714
# 2    526.504762
# 3    527.576923
# 4    653.596154
# 5    812.192308
# 6    738.471154
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 313.32834892618996

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1277

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      184  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      181  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      229  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05      534  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  483.285714  313.328349   0.334200
# 2013-01-02  526.504762  313.328349  -1.093118
# 2013-01-03  527.576923  313.328349  -1.106114
# 2013-01-04  653.596154  313.328349  -1.355116
# 2013-01-05  812.192308  313.328349  -0.887862

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2015, "detrended"][:50], "k-")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "event"][:50], "r--")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "late_event"][:50], "b--")

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.30268346],
#        [ 0.30268346,  1.        ]])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"][:-1], df_sum["late_event_next_day"][:-1])
# Out:
# array([[ 1.        , -0.09115803],
#        [-0.09115803,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.31527138544703964, pvalue=7.2897955011241835e-31)

# %% [markdown]
# ## Build lags

# %%
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      184  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      181  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      229  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05      534  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  \
# date
# 2013-01-01                  0.0                         0.0
# 2013-01-02                  0.0                         0.0
# 2013-01-03                  0.0                         0.0
# 2013-01-04                  0.0                         0.0
# 2013-01-05                  0.0                         0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  483.285714  313.328349   0.334200
# 2013-01-02  526.504762  313.328349  -1.093118
# 2013-01-03  527.576923  313.328349  -1.106114
# 2013-01-04  653.596154  313.328349  -1.355116
# 2013-01-05  812.192308  313.328349  -0.887862

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = np.concatenate([df_sum["event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["late_event"].as_matrix()[:,np.newaxis],
                             #df_sum["late_event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event_next_day"].as_matrix()[:,np.newaxis]], axis=1)
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1,:]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1266, 10)
# event_feats: (1266, 4)
# lags_event_feats: (1266, 10)
# event_texts: (1266,)
# preds: (1266,)
# trends: (1266,)
# stds: (1266,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.782244174305
# 1 0.731196742354
# 2 0.691024188265
# 3 0.703718031704
# 4 0.711376942428
# 5 0.713914167655
# 6 0.742115173222
# 7 0.719673348891
# 8 0.69565035192
# 9 0.681006060537

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.298651917502
# 1 0.299359667567
# 2 0.300257449504
# 3 0.301239297957
# 4 0.302651598162
# 5 0.304190996274
# 6 0.303205486189
# 7 0.303308801188
# 8 0.304255471815

# %%
np.corrcoef(preds[:], event_feats[:,0])
# Out:
# array([[ 1.        ,  0.30006484],
#        [ 0.30006484,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train,:] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val,:] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test,:]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640, 4)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# y_train: (640,)
# y_val: (90,)
# y_test: (535,)
# trend_test: (535,)
# std_test: (535,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline

# %%
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  119.619
# RMSE: 164.510
# R2:   0.448

# %% [markdown]
# ## Linear regression with events

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train[:,:1]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test[:,:1]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  103.086
# RMSE: 144.567
# R2:   0.574

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  101.831
# RMSE: 142.960
# R2:   0.583

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  97.458
# RMSE: 138.808
# R2:   0.607

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  95.298
# RMSE: 136.279
# R2:   0.621

# %% [markdown]
# ## Simple LSTM

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    lags_train,
    y_train,
    batch_size=64,
    epochs=300,
    validation_data=(lags_val, y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 11.93557, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 11.93557 to 11.58357, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.58357 to 10.69232, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.69232 to 9.79378, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.79378 to 9.10028, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 9.10028 to 8.38839, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.38839 to 7.68719, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 7.68719 to 7.20221, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 7.20221 to 6.65954, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.65954 to 6.25743, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 6.25743 to 5.72598, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 5.72598 to 5.52117, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.52117 to 5.08618, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.08618 to 4.65530, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.65530 to 4.33806, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 4.33806 to 3.99148, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.99148 to 3.79351, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.79351 to 3.54546, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.54546 to 3.26695, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 3.26695 to 3.04787, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 3.04787 to 2.88127, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.88127 to 2.77844, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.77844 to 2.60360, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.60360 to 2.50004, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.50004 to 2.35766, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.35766 to 2.14379, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.14379 to 2.09268, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 2.09268 to 2.02836, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 2.02836 to 1.89500, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.89500 to 1.85532, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.85532 to 1.66769, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.66769 to 1.65523, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.65523 to 1.60673, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.60673 to 1.56813, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.56813 to 1.49911, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.49911 to 1.45212, saving model to weights.best.hdf5
# Epoch 00036: val_loss did not improve
# Epoch 00037: val_loss improved from 1.45212 to 1.44150, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.44150 to 1.42479, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.42479 to 1.31390, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.31390 to 1.22888, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.22888 to 1.19241, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.19241 to 1.17047, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.17047 to 1.14691, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.14691 to 1.07875, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 1.07875 to 1.02334, saving model to weights.best.hdf5
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 1.02334 to 0.95737, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 0.95737 to 0.92183, saving model to weights.best.hdf5
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.92183 to 0.91697, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.91697 to 0.87092, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.87092 to 0.84120, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.84120 to 0.76411, saving model to weights.best.hdf5
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.76411 to 0.70934, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.70934 to 0.67618, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.67618 to 0.62690, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 0.62690 to 0.57153, saving model to weights.best.hdf5
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss improved from 0.57153 to 0.56426, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.56426 to 0.49788, saving model to weights.best.hdf5
# Epoch 00072: val_loss improved from 0.49788 to 0.47836, saving model to weights.best.hdf5
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss improved from 0.47836 to 0.42396, saving model to weights.best.hdf5
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss improved from 0.42396 to 0.37879, saving model to weights.best.hdf5
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss improved from 0.37879 to 0.34789, saving model to weights.best.hdf5
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss improved from 0.34789 to 0.34589, saving model to weights.best.hdf5
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss improved from 0.34589 to 0.34145, saving model to weights.best.hdf5
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss improved from 0.34145 to 0.33719, saving model to weights.best.hdf5
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss improved from 0.33719 to 0.33672, saving model to weights.best.hdf5
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     170    Best: 0.206129322946
# Best val_loss at iteratation: 248    Best: 0.336717309554

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  119.704
# RMSE: 160.619
# R2:   0.474

# %% [markdown]
# ## LSTM with events information (no text)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 4, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_2/concat:0", shape=(?, 14), dtype=float32)
# Epoch 00000: val_loss improved from inf to 13.52524, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 13.52524 to 13.32473, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 13.32473 to 11.93717, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 11.93717 to 11.23987, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 11.23987 to 10.65157, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 10.65157 to 9.71684, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 9.71684 to 9.07620, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 9.07620 to 8.44253, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 8.44253 to 7.76243, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 7.76243 to 7.30030, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 7.30030 to 6.77142, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 6.77142 to 6.29064, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 6.29064 to 5.88854, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.88854 to 5.40583, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 5.40583 to 5.01394, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 5.01394 to 4.70607, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 4.70607 to 4.37671, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 4.37671 to 4.09954, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 4.09954 to 3.73958, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 3.73958 to 3.59921, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 3.59921 to 3.31981, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 3.31981 to 3.17206, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 3.17206 to 2.93681, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.93681 to 2.77230, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.77230 to 2.65541, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.65541 to 2.49399, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.49399 to 2.25291, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 2.25291 to 2.10726, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 2.10726 to 2.08820, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 2.08820 to 1.91882, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.91882 to 1.83987, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.83987 to 1.78312, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.78312 to 1.70053, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.70053 to 1.68307, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.68307 to 1.56030, saving model to weights.best.hdf5
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss improved from 1.56030 to 1.45798, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.45798 to 1.45426, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.45426 to 1.34750, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.34750 to 1.27641, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 1.27641 to 1.24462, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss improved from 1.24462 to 1.19278, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.19278 to 1.17487, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 1.17487 to 1.16216, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 1.16216 to 1.14554, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.14554 to 1.08537, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 1.08537 to 1.03258, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 1.03258 to 0.98022, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.98022 to 0.93911, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss improved from 0.93911 to 0.93343, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.93343 to 0.88401, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss improved from 0.88401 to 0.78494, saving model to weights.best.hdf5
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss improved from 0.78494 to 0.74900, saving model to weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.74900 to 0.72237, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.72237 to 0.70240, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.70240 to 0.66714, saving model to weights.best.hdf5
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss improved from 0.66714 to 0.54051, saving model to weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.54051 to 0.47963, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss improved from 0.47963 to 0.44044, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.44044 to 0.40003, saving model to weights.best.hdf5
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.40003 to 0.38913, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.38913 to 0.33529, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.33529 to 0.30382, saving model to weights.best.hdf5
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss improved from 0.30382 to 0.29074, saving model to weights.best.hdf5
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss improved from 0.29074 to 0.28159, saving model to weights.best.hdf5
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss improved from 0.28159 to 0.27751, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss improved from 0.27751 to 0.26582, saving model to weights.best.hdf5
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss improved from 0.26582 to 0.24865, saving model to weights.best.hdf5
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     98    Best: 0.172400309891
# Best val_loss at iteratation: 94    Best: 0.248646148046

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.220543342606
# (535, 1)
# (535,)
# MAE:  100.679
# RMSE: 140.656
# R2:   0.597

# %% [markdown]
# ## LSTM with events information (no text) v2

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 14, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_6/concat:0", shape=(?, 24), dtype=float32)
# Epoch 00000: val_loss improved from inf to 16.11001, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 16.11001 to 14.81065, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 14.81065 to 13.55097, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 13.55097 to 12.34422, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 12.34422 to 11.05404, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 11.05404 to 10.04932, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 10.04932 to 9.02723, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 9.02723 to 8.09570, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 8.09570 to 7.47822, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 7.47822 to 6.74919, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 6.74919 to 6.06904, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 6.06904 to 5.50957, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.50957 to 5.07339, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.07339 to 4.50975, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.50975 to 4.27492, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 4.27492 to 3.89179, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.89179 to 3.50278, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.50278 to 3.29551, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.29551 to 3.03918, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 3.03918 to 2.77505, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.77505 to 2.63055, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.63055 to 2.43702, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.43702 to 2.29950, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.29950 to 2.17136, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.17136 to 2.03124, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.03124 to 1.90326, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.90326 to 1.81425, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.81425 to 1.76954, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.76954 to 1.66550, saving model to weights.best.hdf5
# Epoch 00029: val_loss did not improve
# Epoch 00030: val_loss improved from 1.66550 to 1.53506, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.53506 to 1.52300, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.52300 to 1.47934, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.47934 to 1.44138, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.44138 to 1.39288, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.39288 to 1.33643, saving model to weights.best.hdf5
# Epoch 00036: val_loss did not improve
# Epoch 00037: val_loss improved from 1.33643 to 1.28137, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss improved from 1.28137 to 1.22804, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 1.22804 to 1.22734, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.22734 to 1.18106, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 1.18106 to 1.15398, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss improved from 1.15398 to 1.11012, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.11012 to 1.03447, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 1.03447 to 0.99555, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 0.99555 to 0.99024, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.99024 to 0.93020, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss improved from 0.93020 to 0.91778, saving model to weights.best.hdf5
# Epoch 00055: val_loss improved from 0.91778 to 0.89745, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.89745 to 0.76519, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.76519 to 0.70881, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss improved from 0.70881 to 0.65079, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.65079 to 0.60497, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.60497 to 0.56428, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.56428 to 0.54801, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 0.54801 to 0.51326, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.51326 to 0.49449, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.49449 to 0.48272, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.48272 to 0.34348, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.34348 to 0.30708, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss improved from 0.30708 to 0.29980, saving model to weights.best.hdf5
# Epoch 00081: val_loss improved from 0.29980 to 0.27122, saving model to weights.best.hdf5
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss improved from 0.27122 to 0.25427, saving model to weights.best.hdf5
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss improved from 0.25427 to 0.23902, saving model to weights.best.hdf5
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss improved from 0.23902 to 0.23790, saving model to weights.best.hdf5
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss improved from 0.23790 to 0.23780, saving model to weights.best.hdf5
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss improved from 0.23780 to 0.23672, saving model to weights.best.hdf5
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss improved from 0.23672 to 0.23474, saving model to weights.best.hdf5
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     197    Best: 0.165338271856
# Best val_loss at iteratation: 190    Best: 0.234738495615

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.212862642416
# (535, 1)
# (535,)
# MAE:  94.786
# RMSE: 134.606
# R2:   0.631

# %% [markdown]
# ## LSTM with events information + event text

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 3461 unique tokens.
# ('Shape of train tensor:', (640, 600))
# ('Shape of val tensor:', (90, 600))
# ('Shape of test tensor:', (535, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 4, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,:]], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,:]], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_6/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_16:0", shape=(?, 10), dtype=float32)
# Tensor("input_17:0", shape=(?, 4), dtype=float32)
# Tensor("dropout_30/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_12/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 13.11776, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 13.11776 to 11.08071, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.08071 to 9.61397, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 9.61397 to 8.49897, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 8.49897 to 7.32855, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 7.32855 to 6.23795, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 6.23795 to 5.36228, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 5.36228 to 4.79314, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 4.79314 to 4.21493, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 4.21493 to 3.73056, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 3.73056 to 3.37824, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.37824 to 3.06290, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 3.06290 to 2.69480, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.69480 to 2.47393, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.47393 to 2.38706, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.38706 to 2.19036, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 2.19036 to 2.03959, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 2.03959 to 1.99390, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.99390 to 1.90381, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.90381 to 1.79226, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.79226 to 1.76283, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.76283 to 1.70109, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.70109 to 1.66316, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 1.66316 to 1.62750, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 1.62750 to 1.48859, saving model to weights.best.hdf5
# Epoch 00025: val_loss did not improve
# Epoch 00026: val_loss did not improve
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss improved from 1.48859 to 1.47856, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.47856 to 1.41577, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.41577 to 1.39809, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.39809 to 1.30072, saving model to weights.best.hdf5
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 1.30072 to 1.29188, saving model to weights.best.hdf5
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss did not improve
# Epoch 00037: val_loss improved from 1.29188 to 1.08450, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 1.08450 to 0.97408, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss improved from 0.97408 to 0.96026, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.96026 to 0.94229, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss improved from 0.94229 to 0.82724, saving model to weights.best.hdf5
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 0.82724 to 0.62520, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss improved from 0.62520 to 0.54075, saving model to weights.best.hdf5
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.54075 to 0.50325, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss improved from 0.50325 to 0.42176, saving model to weights.best.hdf5
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss improved from 0.42176 to 0.36307, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.36307 to 0.32250, saving model to weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.32250 to 0.30135, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.30135 to 0.28164, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss improved from 0.28164 to 0.27777, saving model to weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.27777 to 0.26277, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss improved from 0.26277 to 0.25762, saving model to weights.best.hdf5
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.25762 to 0.25492, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss improved from 0.25492 to 0.24909, saving model to weights.best.hdf5
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss improved from 0.24909 to 0.24466, saving model to weights.best.hdf5
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss improved from 0.24466 to 0.24341, saving model to weights.best.hdf5
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss improved from 0.24341 to 0.24113, saving model to weights.best.hdf5
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss improved from 0.24113 to 0.23750, saving model to weights.best.hdf5
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss improved from 0.23750 to 0.23598, saving model to weights.best.hdf5
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss improved from 0.23598 to 0.23562, saving model to weights.best.hdf5
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     497    Best: 0.128295535594
# Best val_loss at iteratation: 202    Best: 0.235624395476

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.218653014581
# (535, 1)
# (535,)
# MAE:  97.565
# RMSE: 137.023
# R2:   0.617

# %% [markdown]
# ## LSTM with events information + event text (v2)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(100, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 14, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_2/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_4:0", shape=(?, 10), dtype=float32)
# Tensor("input_5:0", shape=(?, 14), dtype=float32)
# Tensor("dropout_10/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_4/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 15.74133, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 15.74133 to 13.17029, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 13.17029 to 11.09932, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 11.09932 to 9.50091, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.50091 to 8.00959, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 8.00959 to 6.80206, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 6.80206 to 5.89721, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 5.89721 to 4.96101, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 4.96101 to 4.32175, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 4.32175 to 3.82351, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 3.82351 to 3.28254, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.28254 to 2.88395, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.88395 to 2.69859, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.69859 to 2.50261, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.50261 to 2.26357, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.26357 to 2.25354, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 2.25354 to 2.10759, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 2.10759 to 1.99238, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.99238 to 1.78958, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.78958 to 1.73288, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.73288 to 1.67648, saving model to weights.best.hdf5
# Epoch 00021: val_loss did not improve
# Epoch 00022: val_loss improved from 1.67648 to 1.63062, saving model to weights.best.hdf5
# Epoch 00023: val_loss did not improve
# Epoch 00024: val_loss improved from 1.63062 to 1.53368, saving model to weights.best.hdf5
# Epoch 00025: val_loss did not improve
# Epoch 00026: val_loss did not improve
# Epoch 00027: val_loss improved from 1.53368 to 1.39570, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.39570 to 1.35034, saving model to weights.best.hdf5
# Epoch 00029: val_loss did not improve
# Epoch 00030: val_loss did not improve
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 1.35034 to 1.29594, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.29594 to 1.27256, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.27256 to 1.18548, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.18548 to 1.14247, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 1.14247 to 1.12320, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.12320 to 0.97559, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 0.97559 to 0.82742, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 0.82742 to 0.66917, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss improved from 0.66917 to 0.60282, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.60282 to 0.51763, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.51763 to 0.49155, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss improved from 0.49155 to 0.36900, saving model to weights.best.hdf5
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss improved from 0.36900 to 0.31734, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.31734 to 0.31275, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.31275 to 0.27774, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss improved from 0.27774 to 0.26456, saving model to weights.best.hdf5
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.26456 to 0.26349, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.26349 to 0.25957, saving model to weights.best.hdf5
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss improved from 0.25957 to 0.24993, saving model to weights.best.hdf5
# Epoch 00084: val_loss improved from 0.24993 to 0.24518, saving model to weights.best.hdf5
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss improved from 0.24518 to 0.23922, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss improved from 0.23922 to 0.23867, saving model to weights.best.hdf5
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss improved from 0.23867 to 0.22816, saving model to weights.best.hdf5
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss improved from 0.22816 to 0.22493, saving model to weights.best.hdf5
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     413    Best: 0.121649244428
# Best val_loss at iteratation: 201    Best: 0.224933123589

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.210088231756
# (535, 1)
# (535,)
# MAE:  92.727
# RMSE: 132.046
# R2:   0.645
