# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# Using TensorFlow backend.

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("barclays_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2013-02-22  2013-02-22 19:30:00
# 1           1  2015-10-09  2015-10-09 19:30:00
# 2           2  2015-03-20  2015-03-20 19:30:00
# 3           3  2013-11-18  2013-11-18 19:30:00
# 4           4  2015-04-12  2015-04-12 20:00:00
#
#                                        title  \
# 0           Brooklyn Nets vs Houston Rockets
# 1  New York Islanders vs. Chicago Blackhawks
# 2          Brooklyn Nets vs. Milwaukee Bucks
# 3   Brooklyn Nets vs. Portland Trail Blazers
# 4                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                      title  \
# 0  2013-02-22 2013-02-22 19:30:00           Brooklyn Nets vs Houston Rockets
# 1  2015-10-09 2015-10-09 19:30:00  New York Islanders vs. Chicago Blackhawks
# 2  2015-03-20 2015-03-20 19:30:00          Brooklyn Nets vs. Milwaukee Bucks
# 3  2013-11-18 2013-11-18 19:30:00   Brooklyn Nets vs. Portland Trail Blazers
# 4  2015-04-12 2015-04-12 20:00:00                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/home/fmpr/data/dropoffs_barclays_center_0.003.csv")
df.head()
# Out:
#          date  hour  minute  dropoffs
# 0  2009-01-01     0       0         4
# 1  2009-01-01     0       1        10
# 2  2009-01-01     1       0         5
# 3  2009-01-01     1       1         9
# 4  2009-01-01     2       0         8

# %%
df_sum = pd.DataFrame(df.groupby("date")["dropoffs"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             dropoffs        date  dow
# date
# 2009-01-01       198  2009-01-01    3
# 2009-01-02       170  2009-01-02    4
# 2009-01-03       224  2009-01-03    5
# 2009-01-04       237  2009-01-04    6
# 2009-01-05       102  2009-01-05    0

# %%
plt.plot(df_sum["dropoffs"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             dropoffs        date  dow  event event_desc  event_next_day  \
# date
# 2009-01-01       198  2009-01-01    3    0.0       None             0.0
# 2009-01-02       170  2009-01-02    4    0.0       None             0.0
# 2009-01-03       224  2009-01-03    5    0.0       None             0.0
# 2009-01-04       237  2009-01-04    6    0.0       None             0.0
# 2009-01-05       102  2009-01-05    0    0.0       None             0.0
#
#            event_next_day_desc
# date
# 2009-01-01                None
# 2009-01-02                None
# 2009-01-03                None
# 2009-01-04                None
# 2009-01-05                None

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             dropoffs        date  dow  event  \
# date
# 2013-01-01       317  2013-01-01    1    0.0
# 2013-01-02       164  2013-01-02    2    0.0
# 2013-01-03       194  2013-01-03    3    0.0
# 2013-01-04       211  2013-01-04    4    0.0
# 2013-01-05       476  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc
# date
# 2013-01-01                                               None
# 2013-01-02                                               None
# 2013-01-03                                               None
# 2013-01-04  net home game schedule highlight include oneti...
# 2013-01-05                                               None

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             dropoffs        date  dow  event  \
# date
# 2013-01-01       317  2013-01-01    1    0.0
# 2013-01-02       164  2013-01-02    2    0.0
# 2013-01-03       194  2013-01-03    3    0.0
# 2013-01-04       211  2013-01-04    4    0.0
# 2013-01-05       476  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013

# %%
trend_mean = df_sum[df_sum.index.year < 2015].groupby(["dow"]).mean()["dropoffs"]
trend_mean
# Out:
# dow
# 0    308.961538
# 1    323.695238
# 2    357.380952
# 3    352.951923
# 4    443.750000
# 5    559.846154
# 6    499.144231
# Name: dropoffs, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["dropoffs"]
trend_std = df_sum["dropoffs"].std()
trend_std
# Out:
# 171.40553466096665

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1278

# %%
# detrend data
df_sum["detrended"] = (df_sum["dropoffs"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             dropoffs        date  dow  event  \
# date
# 2013-01-01       317  2013-01-01    1    0.0
# 2013-01-02       164  2013-01-02    2    0.0
# 2013-01-03       194  2013-01-03    3    0.0
# 2013-01-04       211  2013-01-04    4    0.0
# 2013-01-05       476  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  323.695238  171.405535  -0.039061
# 2013-01-02  357.380952  171.405535  -1.128207
# 2013-01-03  352.951923  171.405535  -0.927344
# 2013-01-04  443.750000  171.405535  -1.357891
# 2013-01-05  559.846154  171.405535  -0.489168

# %%
plt.plot(df_sum["dropoffs"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.41649296],
#        [ 0.41649296,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.42395679681854215, pvalue=6.6277114410151106e-57)

# %% [markdown]
# ## Build lags

# %%
df_sum.head()
# Out:
#             dropoffs        date  dow  event  \
# date
# 2013-01-01       317  2013-01-01    1    0.0
# 2013-01-02       164  2013-01-02    2    0.0
# 2013-01-03       194  2013-01-03    3    0.0
# 2013-01-04       211  2013-01-04    4    0.0
# 2013-01-05       476  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  323.695238  171.405535  -0.039061
# 2013-01-02  357.380952  171.405535  -1.128207
# 2013-01-03  352.951923  171.405535  -0.927344
# 2013-01-04  443.750000  171.405535  -1.357891
# 2013-01-05  559.846154  171.405535  -0.489168

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = df_sum["event_next_day"].as_matrix()
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1267, 10)
# event_feats: (1267,)
# lags_event_feats: (1267, 10)
# event_texts: (1267,)
# preds: (1267,)
# trends: (1267,)
# stds: (1267,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.554412327113
# 1 0.526788063232
# 2 0.443755205833
# 3 0.457433765297
# 4 0.471358124935
# 5 0.476520852475
# 6 0.481031164481
# 7 0.489882912867
# 8 0.463164972546
# 9 0.442435956494

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.412953332663
# 1 0.413579433245
# 2 0.414066662179
# 3 0.414463853475
# 4 0.415126615835
# 5 0.415883978959
# 6 0.415749882499
# 7 0.416755577898
# 8 0.416967803361

# %%
np.corrcoef(preds[:], event_feats[:])
# Out:
# array([[ 1.        ,  0.41413285],
#        [ 0.41413285,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640,)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# y_train: (640,)
# y_val: (90,)
# y_test: (536,)
# trend_test: (536,)
# std_test: (536,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline

# %%
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  74.327
# RMSE: 105.295
# R2:   0.424

# %% [markdown]
# ## Linear regression with events

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train[:,np.newaxis]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test[:,np.newaxis]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  65.223
# RMSE: 91.409
# R2:   0.566

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  61.655
# RMSE: 86.764
# R2:   0.609

# %% [markdown]
# ## Simple LSTM

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    lags_train,
    y_train,
    batch_size=64,
    epochs=300,
    validation_data=(lags_val, y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 12.13300, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 12.13300 to 11.49610, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.49610 to 10.76858, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.76858 to 9.79788, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.79788 to 9.18950, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 9.18950 to 8.47252, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.47252 to 7.91881, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 7.91881 to 7.20279, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 7.20279 to 6.73053, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.73053 to 6.22764, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 6.22764 to 5.75600, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 5.75600 to 5.41461, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.41461 to 5.02159, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.02159 to 4.67433, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.67433 to 4.43602, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 4.43602 to 4.05358, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 4.05358 to 3.81804, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.81804 to 3.53290, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.53290 to 3.29814, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 3.29814 to 3.14070, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 3.14070 to 2.89926, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.89926 to 2.74551, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.74551 to 2.64334, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.64334 to 2.51505, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.51505 to 2.37462, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.37462 to 2.24384, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.24384 to 2.11516, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 2.11516 to 2.05237, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 2.05237 to 1.97698, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.97698 to 1.89775, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.89775 to 1.79429, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.79429 to 1.71867, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.71867 to 1.69119, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.69119 to 1.60340, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.60340 to 1.53433, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.53433 to 1.50685, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.50685 to 1.46241, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.46241 to 1.39560, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.39560 to 1.38514, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.38514 to 1.36655, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.36655 to 1.30897, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.30897 to 1.29367, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.29367 to 1.28278, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.28278 to 1.25288, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.25288 to 1.23682, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 1.23682 to 1.15799, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 1.15799 to 1.15763, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.15763 to 1.13465, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 1.13465 to 1.12113, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 1.12113 to 1.08951, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 1.08951 to 1.05865, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 1.05865 to 1.02156, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 1.02156 to 0.98272, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss improved from 0.98272 to 0.95359, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.95359 to 0.92468, saving model to weights.best.hdf5
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.92468 to 0.85119, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.85119 to 0.84065, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.84065 to 0.82100, saving model to weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.82100 to 0.77854, saving model to weights.best.hdf5
# Epoch 00074: val_loss improved from 0.77854 to 0.77501, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.77501 to 0.76020, saving model to weights.best.hdf5
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss improved from 0.76020 to 0.73819, saving model to weights.best.hdf5
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.73819 to 0.72049, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.72049 to 0.70201, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.70201 to 0.68169, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.68169 to 0.67374, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss improved from 0.67374 to 0.63975, saving model to weights.best.hdf5
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss improved from 0.63975 to 0.62351, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss improved from 0.62351 to 0.61328, saving model to weights.best.hdf5
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss improved from 0.61328 to 0.61082, saving model to weights.best.hdf5
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss improved from 0.61082 to 0.60931, saving model to weights.best.hdf5
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss improved from 0.60931 to 0.60820, saving model to weights.best.hdf5
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss improved from 0.60820 to 0.60302, saving model to weights.best.hdf5
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     82    Best: 0.363183820248
# Best val_loss at iteratation: 268    Best: 0.603022795253

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (536, 1)
# (536,)
# MAE:  74.913
# RMSE: 103.473
# R2:   0.444

# %% [markdown]
# ## LSTM with events information (no text)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 1, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis]], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis]], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_1/concat:0", shape=(?, 11), dtype=float32)
# Epoch 00000: val_loss improved from inf to 12.43064, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 12.43064 to 11.60317, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.60317 to 10.45083, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.45083 to 9.81283, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.81283 to 8.84933, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 8.84933 to 8.16648, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.16648 to 7.51669, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 7.51669 to 6.84642, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 6.84642 to 6.27612, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.27612 to 5.79743, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 5.79743 to 5.27885, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 5.27885 to 4.89627, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 4.89627 to 4.54896, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 4.54896 to 4.21821, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.21821 to 3.83588, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 3.83588 to 3.54762, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.54762 to 3.35866, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.35866 to 3.09488, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.09488 to 2.87368, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 2.87368 to 2.74002, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.74002 to 2.55822, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.55822 to 2.39043, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.39043 to 2.31390, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.31390 to 2.12705, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.12705 to 2.01695, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.01695 to 1.94097, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.94097 to 1.84524, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.84524 to 1.75227, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.75227 to 1.66653, saving model to weights.best.hdf5
# Epoch 00029: val_loss did not improve
# Epoch 00030: val_loss improved from 1.66653 to 1.52531, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.52531 to 1.49044, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.49044 to 1.47862, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.47862 to 1.41219, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.41219 to 1.36715, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.36715 to 1.30770, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.30770 to 1.27742, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.27742 to 1.24199, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss improved from 1.24199 to 1.21034, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.21034 to 1.19479, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.19479 to 1.14508, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.14508 to 1.12808, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 1.12808 to 1.08482, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss improved from 1.08482 to 1.04753, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss improved from 1.04753 to 0.98691, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.98691 to 0.96948, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.96948 to 0.96475, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss improved from 0.96475 to 0.93104, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.93104 to 0.92141, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.92141 to 0.85394, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss improved from 0.85394 to 0.79905, saving model to weights.best.hdf5
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss improved from 0.79905 to 0.79311, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.79311 to 0.76579, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.76579 to 0.73004, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.73004 to 0.68425, saving model to weights.best.hdf5
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss improved from 0.68425 to 0.63743, saving model to weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss improved from 0.63743 to 0.55290, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.55290 to 0.53702, saving model to weights.best.hdf5
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss improved from 0.53702 to 0.51349, saving model to weights.best.hdf5
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.51349 to 0.48938, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.48938 to 0.46539, saving model to weights.best.hdf5
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss improved from 0.46539 to 0.46497, saving model to weights.best.hdf5
# Epoch 00098: val_loss improved from 0.46497 to 0.45783, saving model to weights.best.hdf5
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss improved from 0.45783 to 0.44640, saving model to weights.best.hdf5
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss improved from 0.44640 to 0.44564, saving model to weights.best.hdf5
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss improved from 0.44564 to 0.44557, saving model to weights.best.hdf5
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss improved from 0.44557 to 0.44478, saving model to weights.best.hdf5
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     179    Best: 0.278009365499
# Best val_loss at iteratation: 250    Best: 0.444776674112

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis]], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis]], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.303725718117
# (536, 1)
# (536,)
# MAE:  64.406
# RMSE: 90.097
# R2:   0.578

# %% [markdown]
# ## LSTM with events information (no text) v2

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_2/concat:0", shape=(?, 21), dtype=float32)
# Epoch 00000: val_loss improved from inf to 15.46963, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 15.46963 to 14.59809, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 14.59809 to 13.84146, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 13.84146 to 12.62516, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 12.62516 to 11.46602, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 11.46602 to 10.59845, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 10.59845 to 9.78901, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 9.78901 to 9.01589, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 9.01589 to 8.29702, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 8.29702 to 7.61251, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 7.61251 to 7.06271, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 7.06271 to 6.47333, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 6.47333 to 5.97517, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.97517 to 5.52653, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 5.52653 to 5.05485, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 5.05485 to 4.64695, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 4.64695 to 4.36739, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 4.36739 to 3.99395, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.99395 to 3.70811, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 3.70811 to 3.42343, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 3.42343 to 3.22690, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 3.22690 to 2.93742, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.93742 to 2.75814, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.75814 to 2.57010, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.57010 to 2.47193, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.47193 to 2.27653, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.27653 to 2.15947, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 2.15947 to 2.04656, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 2.04656 to 1.92534, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.92534 to 1.84782, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.84782 to 1.75319, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.75319 to 1.69969, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.69969 to 1.65929, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.65929 to 1.60310, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.60310 to 1.55481, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.55481 to 1.47466, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.47466 to 1.41270, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 1.41270 to 1.28644, saving model to weights.best.hdf5
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 1.28644 to 1.24332, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.24332 to 1.23952, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.23952 to 1.19712, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.19712 to 1.17251, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.17251 to 1.16672, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 1.16672 to 1.12586, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 1.12586 to 1.12392, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.12392 to 1.08926, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 1.08926 to 1.06403, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 1.06403 to 1.01604, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 1.01604 to 0.92174, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.92174 to 0.89477, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss improved from 0.89477 to 0.89476, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.89476 to 0.86939, saving model to weights.best.hdf5
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss improved from 0.86939 to 0.82391, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.82391 to 0.79775, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.79775 to 0.79525, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.79525 to 0.70355, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.70355 to 0.68679, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 0.68679 to 0.66377, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.66377 to 0.62970, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.62970 to 0.57509, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.57509 to 0.56770, saving model to weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss improved from 0.56770 to 0.55559, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.55559 to 0.55042, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.55042 to 0.49626, saving model to weights.best.hdf5
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.49626 to 0.45814, saving model to weights.best.hdf5
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss improved from 0.45814 to 0.45164, saving model to weights.best.hdf5
# Epoch 00084: val_loss improved from 0.45164 to 0.44183, saving model to weights.best.hdf5
# Epoch 00085: val_loss improved from 0.44183 to 0.43897, saving model to weights.best.hdf5
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss improved from 0.43897 to 0.43548, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss improved from 0.43548 to 0.43016, saving model to weights.best.hdf5
# Epoch 00095: val_loss improved from 0.43016 to 0.41407, saving model to weights.best.hdf5
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss improved from 0.41407 to 0.41323, saving model to weights.best.hdf5
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss improved from 0.41323 to 0.40951, saving model to weights.best.hdf5
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss improved from 0.40951 to 0.40861, saving model to weights.best.hdf5
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss improved from 0.40861 to 0.40495, saving model to weights.best.hdf5
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     154    Best: 0.249621939659
# Best val_loss at iteratation: 216    Best: 0.404949812094

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.285986786236
# (536, 1)
# (536,)
# MAE:  61.387
# RMSE: 85.810
# R2:   0.617

# %% [markdown]
# ## LSTM with events information + event text

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 3461 unique tokens.
# ('Shape of train tensor:', (640, 600))
# ('Shape of val tensor:', (90, 600))
# ('Shape of test tensor:', (536, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.3))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 1, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis]], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis]], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_7/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_21:0", shape=(?, 10), dtype=float32)
# Tensor("input_22:0", shape=(?, 1), dtype=float32)
# Tensor("dropout_35/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_15/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 18.97027, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 18.97027 to 15.75314, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 15.75314 to 13.21174, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 13.21174 to 11.12223, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 11.12223 to 9.32864, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 9.32864 to 7.85183, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 7.85183 to 6.57974, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 6.57974 to 5.58790, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 5.58790 to 4.86707, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 4.86707 to 4.16602, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 4.16602 to 3.56762, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.56762 to 3.22285, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 3.22285 to 2.92195, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.92195 to 2.59050, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.59050 to 2.43143, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.43143 to 2.21558, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 2.21558 to 2.05584, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 2.05584 to 1.93909, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.93909 to 1.84202, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.84202 to 1.82201, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.82201 to 1.75709, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 1.75709 to 1.71632, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.71632 to 1.68402, saving model to weights.best.hdf5
# Epoch 00023: val_loss did not improve
# Epoch 00024: val_loss improved from 1.68402 to 1.66284, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.66284 to 1.53982, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.53982 to 1.52255, saving model to weights.best.hdf5
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss improved from 1.52255 to 1.43017, saving model to weights.best.hdf5
# Epoch 00029: val_loss did not improve
# Epoch 00030: val_loss improved from 1.43017 to 1.39888, saving model to weights.best.hdf5
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 1.39888 to 1.35136, saving model to weights.best.hdf5
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss improved from 1.35136 to 1.33635, saving model to weights.best.hdf5
# Epoch 00036: val_loss did not improve
# Epoch 00037: val_loss improved from 1.33635 to 1.28018, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.28018 to 1.26591, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.26591 to 1.23447, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.23447 to 1.20425, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.20425 to 1.11743, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss improved from 1.11743 to 0.99634, saving model to weights.best.hdf5
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss improved from 0.99634 to 0.93401, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 0.93401 to 0.86917, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 0.86917 to 0.76408, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.76408 to 0.72685, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.72685 to 0.72612, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.72612 to 0.67127, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.67127 to 0.61507, saving model to weights.best.hdf5
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.61507 to 0.55603, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.55603 to 0.53831, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.53831 to 0.52322, saving model to weights.best.hdf5
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss improved from 0.52322 to 0.47866, saving model to weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss improved from 0.47866 to 0.47628, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.47628 to 0.46250, saving model to weights.best.hdf5
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss improved from 0.46250 to 0.45134, saving model to weights.best.hdf5
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss improved from 0.45134 to 0.45023, saving model to weights.best.hdf5
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss improved from 0.45023 to 0.45011, saving model to weights.best.hdf5
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss improved from 0.45011 to 0.44570, saving model to weights.best.hdf5
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss improved from 0.44570 to 0.44195, saving model to weights.best.hdf5
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss improved from 0.44195 to 0.44025, saving model to weights.best.hdf5
# Epoch 00167: val_loss improved from 0.44025 to 0.43650, saving model to weights.best.hdf5
# Epoch 00168: val_loss improved from 0.43650 to 0.43397, saving model to weights.best.hdf5
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss improved from 0.43397 to 0.43183, saving model to weights.best.hdf5
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     426    Best: 0.153735104948
# Best val_loss at iteratation: 177    Best: 0.431832562553

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis]], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis]], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.309443571007
# (536, 1)
# (536,)
# MAE:  63.593
# RMSE: 89.613
# R2:   0.583

# %% [markdown]
# ## LSTM with events information + event text (v2)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.3))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    x_lags = BatchNormalization()(x_lags)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = BatchNormalization()(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    feat = BatchNormalization()(feat)
    
    x = feat
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = Dense(units=200, activation="relu", kernel_regularizer=keras.regularizers.l2(0.01))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = Dense(units=50, activation="relu", kernel_regularizer=keras.regularizers.l2(0.01))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    feat = BatchNormalization()(x)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.3))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_9/Gather:0", shape=(?, 600, 300), dtype=float32)
# Epoch 00000: val_loss improved from inf to 64.66286, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 64.66286 to 53.79637, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 53.79637 to 44.82144, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 44.82144 to 37.24470, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 37.24470 to 31.08530, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 31.08530 to 25.98361, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 25.98361 to 21.74285, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 21.74285 to 18.37007, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 18.37007 to 15.65956, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 15.65956 to 13.38174, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 13.38174 to 11.45044, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 11.45044 to 9.90158, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 9.90158 to 8.57978, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 8.57978 to 7.33936, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 7.33936 to 6.46628, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 6.46628 to 5.70351, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 5.70351 to 5.06178, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 5.06178 to 4.50026, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 4.50026 to 4.04555, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 4.04555 to 3.71979, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 3.71979 to 3.25826, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 3.25826 to 3.01192, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 3.01192 to 2.75414, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.75414 to 2.49348, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.49348 to 2.35444, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.35444 to 2.08616, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.08616 to 1.98092, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.98092 to 1.89248, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.89248 to 1.79998, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.79998 to 1.69333, saving model to weights.best.hdf5
# Epoch 00030: val_loss did not improve
# Epoch 00031: val_loss improved from 1.69333 to 1.53586, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.53586 to 1.47623, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.47623 to 1.40951, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.40951 to 1.36877, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.36877 to 1.26032, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.26032 to 1.23152, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.23152 to 1.18647, saving model to weights.best.hdf5
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 1.18647 to 1.17307, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.17307 to 1.14961, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss improved from 1.14961 to 1.06573, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.06573 to 1.02224, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss improved from 1.02224 to 1.02218, saving model to weights.best.hdf5
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 1.02218 to 0.99596, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 0.99596 to 0.95821, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.95821 to 0.89521, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.89521 to 0.87990, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss improved from 0.87990 to 0.87642, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.87642 to 0.85232, saving model to weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.85232 to 0.81479, saving model to weights.best.hdf5
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.81479 to 0.74296, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss improved from 0.74296 to 0.73140, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.73140 to 0.71924, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.71924 to 0.68426, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss improved from 0.68426 to 0.67227, saving model to weights.best.hdf5
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss improved from 0.67227 to 0.66856, saving model to weights.best.hdf5
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss improved from 0.66856 to 0.66608, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss improved from 0.66608 to 0.65672, saving model to weights.best.hdf5
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss improved from 0.65672 to 0.65484, saving model to weights.best.hdf5
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss improved from 0.65484 to 0.62026, saving model to weights.best.hdf5
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss improved from 0.62026 to 0.60773, saving model to weights.best.hdf5
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss improved from 0.60773 to 0.57019, saving model to weights.best.hdf5
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss improved from 0.57019 to 0.56794, saving model to weights.best.hdf5
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss improved from 0.56794 to 0.56616, saving model to weights.best.hdf5
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss improved from 0.56616 to 0.54421, saving model to weights.best.hdf5
# Epoch 00189: val_loss improved from 0.54421 to 0.51775, saving model to weights.best.hdf5
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss improved from 0.51775 to 0.51294, saving model to weights.best.hdf5
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss improved from 0.51294 to 0.51201, saving model to weights.best.hdf5
# Epoch 00242: val_loss improved from 0.51201 to 0.50342, saving model to weights.best.hdf5
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss improved from 0.50342 to 0.48388, saving model to weights.best.hdf5
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss improved from 0.48388 to 0.48372, saving model to weights.best.hdf5
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     461    Best: 0.213666956127
# Best val_loss at iteratation: 448    Best: 0.483721529113

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.329368549941
# (536, 1)
# (536,)
# MAE:  59.207
# RMSE: 84.571
# R2:   0.628
