# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# Using TensorFlow backend.

# %% [markdown]
# ## Load weather data

# %%
# load data
df = pd.read_csv("../central_park_weather.csv")
df = df.set_index("date")

# replace predefined values with NaN
df = df.replace(99.99, np.nan)
df = df.replace(999.9, np.nan)
df = df.replace(9999.9, np.nan)

# replace NaN with 0 for snow depth
df["snow_depth"] = df["snow_depth"].fillna(0)

# do interpolation for the remaining NaNs
df = df.interpolate()

# standardize data
removed_mean = df.mean()
removed_std = df.std()
weather = (df - removed_mean) / removed_std

weather.head()
# Out:
#             min_temp  max_temp  wind_speed  wind_gust  visibility  pressure  \
# date
# 2009-01-01 -2.016735 -2.128488    2.946112   2.512634    0.666065  0.571023
# 2009-01-02 -1.602221 -1.739134    0.276908  -0.188044    0.236614 -0.040850
# 2009-01-03 -1.108462 -1.472148    1.211129   0.018115    0.666065 -0.503153
# 2009-01-04 -1.413252 -1.238535    1.033182  -0.579745    0.666065  0.244691
# 2009-01-05 -0.626895 -1.188475    0.588315  -1.218837    0.666065 -0.272002
#
#             precipitation  snow_depth       fog  rain_drizzle  snow_ice  \
# date
# 2009-01-01      -0.273606   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-02      -0.378683   -0.240596 -0.326133     -0.709709  3.913921
# 2009-01-03      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-04      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-05      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
#
#              thunder
# date
# 2009-01-01 -0.037018
# 2009-01-02 -0.037018
# 2009-01-03 -0.037018
# 2009-01-04 -0.037018
# 2009-01-05 -0.037018

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("../facebook/terminal5nyc.tsv", sep="\t")
events.head()
# Out:
#                  start_time                                title  \
# 0  2014-03-15T20:00:00-0400                Carnage at Terminal 5
# 1  2014-11-11T20:00:00-0500         London Grammar at Terminal 5
# 2  2014-10-17T19:00:00-0400  Citizen Cope at Terminal 5 on 10/17
# 3  2015-11-19T19:00:00-0500                        Azealia Banks
# 4  2013-10-22T19:00:00-0400          Cold War Kids at Terminal 5
#
#                 url                                        description
# 0   593163697436226  CARNAGE at Terminal 5 on 03/15  18+  More Info...
# 1  1465453707047232  London Grammar at Terminal 5 on 11/11  All Age...
# 2   265560376982598  * Clarence Greenwood Recordings 10th Anniversa...
# 3  1526707847627630                                      Azealia Banks
# 4   641278195885283  COLD WAR KIDS at Terminal 5 on 10/22  Californ...

# %%
from datetime import datetime,timedelta
def dt_parse(t):
    ret = datetime.strptime(t[0:16],'%Y-%m-%dT%H:%M')
    #if t[19]=='+':
    #    ret-=timedelta(hours=int(t[19:22]),minutes=int(t[23:]))
    #elif t[19]=='-':
    #    ret+=timedelta(hours=int(t[19:22]),minutes=int(t[23:]))
    return ret

times = []
for t in events['start_time'].values:
    times.append(dt_parse(t))
events['start_time'] = times

# %%
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                title  \
# 0  2014-03-15 2014-03-15 20:00:00                Carnage at Terminal 5
# 1  2014-11-11 2014-11-11 20:00:00         London Grammar at Terminal 5
# 2  2014-10-17 2014-10-17 19:00:00  Citizen Cope at Terminal 5 on 10/17
# 3  2015-11-19 2015-11-19 19:00:00                        Azealia Banks
# 4  2013-10-22 2013-10-22 19:00:00          Cold War Kids at Terminal 5
#
#                 url                                        description
# 0   593163697436226  CARNAGE at Terminal 5 on 03/15  18+  More Info...
# 1  1465453707047232  London Grammar at Terminal 5 on 11/11  All Age...
# 2   265560376982598  * Clarence Greenwood Recordings 10th Anniversa...
# 3  1526707847627630                                      Azealia Banks
# 4   641278195885283  COLD WAR KIDS at Terminal 5 on 10/22  Californ...

# %%
# late events
print len(events["start_time"].dt.hour.values)
print np.sum(events["start_time"].dt.hour.values >= 20)
print np.sum(events["start_time"].dt.hour.values >= 21)
plt.hist(events["start_time"].dt.hour.values)
# Out:
# 591
# 220
# 24
# (array([   7.,    3.,    5.,    1.,    1.,    0.,    1.,    5.,  348.,  220.]),
#  array([  0. ,   2.2,   4.4,   6.6,   8.8,  11. ,  13.2,  15.4,  17.6,
#          19.8,  22. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/home/fmpr/data/pickups_terminal_5_0.003.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0       24
# 1  2009-01-01     0       1       35
# 2  2009-01-01     1       0       25
# 3  2009-01-01     1       1       25
# 4  2009-01-01     2       0       16

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      560  2009-01-01    3
# 2009-01-02      761  2009-01-02    4
# 2009-01-03      730  2009-01-03    5
# 2009-01-04      640  2009-01-04    6
# 2009-01-05     1127  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
late_event = np.zeros((len(df_sum)))
really_late_event = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
        for e in events[events.date == df_sum.iloc[i].date]["start_time"]:
            if e.hour >= 20:
                late_event[i] = 1
            if e.hour >= 21:
                really_late_event[i] = 1
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["late_event"] = late_event
df_sum["really_late_event"] = really_late_event
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["late_event_next_day"] = pd.Series(df_sum["late_event"]).shift(-1)
df_sum["really_late_event_next_day"] = pd.Series(df_sum["really_late_event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      560  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      761  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      730  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      640  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05     1127  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day event_next_day_desc
# date
# 2009-01-01                         0.0                None
# 2009-01-02                         0.0                None
# 2009-01-03                         0.0                None
# 2009-01-04                         0.0                None
# 2009-01-05                         0.0                None

# %%
# merge with weather data
df_sum = df_sum.join(weather, how='inner')
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      560  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      761  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      730  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      640  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05     1127  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day    ...    wind_speed  wind_gust  \
# date                                      ...
# 2009-01-01                         0.0    ...      2.946112   2.512634
# 2009-01-02                         0.0    ...      0.276908  -0.188044
# 2009-01-03                         0.0    ...      1.211129   0.018115
# 2009-01-04                         0.0    ...      1.033182  -0.579745
# 2009-01-05                         0.0    ...      0.588315  -1.218837
#
#             visibility  pressure  precipitation  snow_depth       fog  \
# date
# 2009-01-01    0.666065  0.571023      -0.273606   -0.240596 -0.326133
# 2009-01-02    0.236614 -0.040850      -0.378683   -0.240596 -0.326133
# 2009-01-03    0.666065 -0.503153      -0.378683   -0.240596 -0.326133
# 2009-01-04    0.666065  0.244691      -0.378683   -0.240596 -0.326133
# 2009-01-05    0.666065 -0.272002      -0.378683   -0.240596 -0.326133
#
#             rain_drizzle  snow_ice   thunder
# date
# 2009-01-01     -0.709709 -0.255411 -0.037018
# 2009-01-02     -0.709709  3.913921 -0.037018
# 2009-01-03     -0.709709 -0.255411 -0.037018
# 2009-01-04     -0.709709 -0.255411 -0.037018
# 2009-01-05     -0.709709 -0.255411 -0.037018
#
# [5 rows x 23 columns]

# %%
# keep only data after 2011
START_YEAR = 2011
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2011-01-01      428  2011-01-01    5    0.0         0.0                0.0
# 2011-01-02      348  2011-01-02    6    0.0         0.0                0.0
# 2011-01-03     1122  2011-01-03    0    0.0         0.0                0.0
# 2011-01-04     1228  2011-01-04    1    0.0         0.0                0.0
# 2011-01-05     1292  2011-01-05    2    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2011-01-01       None             0.0                  0.0
# 2011-01-02       None             0.0                  0.0
# 2011-01-03       None             0.0                  0.0
# 2011-01-04       None             0.0                  0.0
# 2011-01-05       None             0.0                  0.0
#
#             really_late_event_next_day    ...    wind_speed  wind_gust  \
# date                                      ...
# 2011-01-01                         0.0    ...     -0.835261   1.749847
# 2011-01-02                         0.0    ...     -1.146668   1.409686
# 2011-01-03                         0.0    ...      1.567023   1.069524
# 2011-01-04                         0.0    ...      0.276908  -0.827136
# 2011-01-05                         0.0    ...      0.276908  -0.579745
#
#             visibility  pressure  precipitation  snow_depth       fog  \
# date
# 2011-01-01   -1.726590  0.421454      -0.378683    4.975587 -0.326133
# 2011-01-02   -1.665240 -0.326390      -0.352414    4.494093  3.065185
# 2011-01-03    0.666065  0.258288      -0.378683    3.410732 -0.326133
# 2011-01-04    0.604715 -0.027253      -0.378683    2.126749 -0.326133
# 2011-01-05    0.666065 -0.870277      -0.378683    1.805753 -0.326133
#
#             rain_drizzle  snow_ice   thunder
# date
# 2011-01-01     -0.709709 -0.255411 -0.037018
# 2011-01-02      1.408545 -0.255411 -0.037018
# 2011-01-03     -0.709709 -0.255411 -0.037018
# 2011-01-04     -0.709709 -0.255411 -0.037018
# 2011-01-05     -0.709709 -0.255411 -0.037018
#
# [5 rows x 23 columns]

# %%
df_sum.describe()
# Out:
#            pickups          dow        event   late_event  really_late_event  \
# count  2008.000000  2008.000000  2008.000000  2008.000000        2008.000000
# mean   1405.517928     2.999502     0.218127     0.087151           0.011952
# std     398.604705     2.000872     0.413077     0.282127           0.108698
# min      67.000000     0.000000     0.000000     0.000000           0.000000
# 25%    1141.500000     1.000000     0.000000     0.000000           0.000000
# 50%    1416.000000     3.000000     0.000000     0.000000           0.000000
# 75%    1618.000000     5.000000     0.000000     0.000000           0.000000
# max    4052.000000     6.000000     1.000000     1.000000           1.000000
#
#        event_next_day  late_event_next_day  really_late_event_next_day  \
# count     2007.000000          2007.000000                 2007.000000
# mean         0.218236             0.087195                    0.011958
# std          0.413152             0.282191                    0.108725
# min          0.000000             0.000000                    0.000000
# 25%          0.000000             0.000000                    0.000000
# 50%          0.000000             0.000000                    0.000000
# 75%          0.000000             0.000000                    0.000000
# max          1.000000             1.000000                    1.000000
#
#           min_temp     max_temp   wind_speed    wind_gust   visibility  \
# count  2008.000000  2008.000000  2008.000000  2008.000000  2008.000000
# mean     -0.037649    -0.007828    -0.083838     0.011900    -0.030250
# std       1.006425     0.988927     0.932403     1.009364     1.023251
# min      -2.992062    -2.601275    -2.125376    -1.218837    -4.548696
# 25%      -0.797577    -0.799121    -0.746287    -0.703441    -0.453575
# 50%      -0.011219     0.029648    -0.212446    -0.188044     0.543364
# 75%       0.848287     0.875103     0.410368     0.430432     0.666065
# max       2.238128     2.143286     6.104671     8.078918     0.666065
#
#           pressure  precipitation   snow_depth          fog  rain_drizzle  \
# count  2008.000000    2008.000000  2008.000000  2008.000000   2008.000000
# mean      0.052357      -0.002214     0.045551     0.004892     -0.011361
# std       0.989536       1.036039     1.090292     1.006746      0.996034
# min      -4.065612      -0.378683    -0.240596    -0.326133     -0.709709
# 25%      -0.584736      -0.378683    -0.240596    -0.326133     -0.709709
# 50%       0.027136      -0.378683    -0.240596    -0.326133     -0.709709
# 75%       0.679800      -0.194799    -0.240596    -0.326133      1.408545
# max       3.494414      16.197188     8.907786     3.065185      1.408545
#
#           snow_ice      thunder
# count  2008.000000  2008.000000
# mean      0.014516    -0.037018
# std       1.026196     0.000000
# min      -0.255411    -0.037018
# 25%      -0.255411    -0.037018
# 50%      -0.255411    -0.037018
# 75%      -0.255411    -0.037018
# max       3.913921    -0.037018

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2011-01-01      428  2011-01-01    5    0.0         0.0                0.0
# 2011-01-02      348  2011-01-02    6    0.0         0.0                0.0
# 2011-01-03     1122  2011-01-03    0    0.0         0.0                0.0
# 2011-01-04     1228  2011-01-04    1    0.0         0.0                0.0
# 2011-01-05     1292  2011-01-05    2    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2011-01-01       None             0.0                  0.0
# 2011-01-02       None             0.0                  0.0
# 2011-01-03       None             0.0                  0.0
# 2011-01-04       None             0.0                  0.0
# 2011-01-05       None             0.0                  0.0
#
#             really_late_event_next_day  ...  wind_gust  visibility  pressure  \
# date                                    ...
# 2011-01-01                         0.0  ...   1.749847   -1.726590  0.421454
# 2011-01-02                         0.0  ...   1.409686   -1.665240 -0.326390
# 2011-01-03                         0.0  ...   1.069524    0.666065  0.258288
# 2011-01-04                         0.0  ...  -0.827136    0.604715 -0.027253
# 2011-01-05                         0.0  ...  -0.579745    0.666065 -0.870277
#
#             precipitation  snow_depth       fog  rain_drizzle  snow_ice  \
# date
# 2011-01-01      -0.378683    4.975587 -0.326133     -0.709709 -0.255411
# 2011-01-02      -0.352414    4.494093  3.065185      1.408545 -0.255411
# 2011-01-03      -0.378683    3.410732 -0.326133     -0.709709 -0.255411
# 2011-01-04      -0.378683    2.126749 -0.326133     -0.709709 -0.255411
# 2011-01-05      -0.378683    1.805753 -0.326133     -0.709709 -0.255411
#
#              thunder  year
# date
# 2011-01-01 -0.037018  2011
# 2011-01-02 -0.037018  2011
# 2011-01-03 -0.037018  2011
# 2011-01-04 -0.037018  2011
# 2011-01-05 -0.037018  2011
#
# [5 rows x 24 columns]

# %%
trend_mean = df_sum[df_sum.index.year < 2015].groupby(["dow"]).mean()["pickups"]
trend_mean
# Out:
# dow
# 0    1468.837321
# 1    1591.339713
# 2    1623.885167
# 3    1629.990385
# 4    1600.673077
# 5    1371.626794
# 6    1142.148325
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 398.60470480148155

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 2008

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2011-01-01      428  2011-01-01    5    0.0         0.0                0.0
# 2011-01-02      348  2011-01-02    6    0.0         0.0                0.0
# 2011-01-03     1122  2011-01-03    0    0.0         0.0                0.0
# 2011-01-04     1228  2011-01-04    1    0.0         0.0                0.0
# 2011-01-05     1292  2011-01-05    2    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2011-01-01       None             0.0                  0.0
# 2011-01-02       None             0.0                  0.0
# 2011-01-03       None             0.0                  0.0
# 2011-01-04       None             0.0                  0.0
# 2011-01-05       None             0.0                  0.0
#
#             really_late_event_next_day    ...     precipitation  snow_depth  \
# date                                      ...
# 2011-01-01                         0.0    ...         -0.378683    4.975587
# 2011-01-02                         0.0    ...         -0.352414    4.494093
# 2011-01-03                         0.0    ...         -0.378683    3.410732
# 2011-01-04                         0.0    ...         -0.378683    2.126749
# 2011-01-05                         0.0    ...         -0.378683    1.805753
#
#                  fog  rain_drizzle  snow_ice   thunder  year        trend  \
# date
# 2011-01-01 -0.326133     -0.709709 -0.255411 -0.037018  2011  1371.626794
# 2011-01-02  3.065185      1.408545 -0.255411 -0.037018  2011  1142.148325
# 2011-01-03 -0.326133     -0.709709 -0.255411 -0.037018  2011  1468.837321
# 2011-01-04 -0.326133     -0.709709 -0.255411 -0.037018  2011  1591.339713
# 2011-01-05 -0.326133     -0.709709 -0.255411 -0.037018  2011  1623.885167
#
#                    std  detrended
# date
# 2011-01-01  398.604705  -2.367325
# 2011-01-02  398.604705  -1.992321
# 2011-01-03  398.604705  -0.870129
# 2011-01-04  398.604705  -0.911529
# 2011-01-05  398.604705  -0.832617
#
# [5 rows x 27 columns]

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2015, "detrended"][:50], "k-")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "event"][:50], "r--")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "late_event"][:50], "b--")

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.25291694],
#        [ 0.25291694,  1.        ]])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"][:-1], df_sum["late_event_next_day"][:-1])
# Out:
# array([[ 1.       ,  0.0548478],
#        [ 0.0548478,  1.       ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.28060729931781647, pvalue=1.1892486896305748e-37)

# %% [markdown]
# ## Build lags and features

# %%
df_sum.columns
# Out:
# Index([u'pickups', u'date', u'dow', u'event', u'late_event',
#        u'really_late_event', u'event_desc', u'event_next_day',
#        u'late_event_next_day', u'really_late_event_next_day',
#        u'event_next_day_desc', u'min_temp', u'max_temp', u'wind_speed',
#        u'wind_gust', u'visibility', u'pressure', u'precipitation',
#        u'snow_depth', u'fog', u'rain_drizzle', u'snow_ice', u'thunder',
#        u'year', u'trend', u'std', u'detrended'],
#       dtype='object')

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = np.concatenate([df_sum["event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["late_event"].as_matrix()[:,np.newaxis],
                             #df_sum["late_event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event_next_day"].as_matrix()[:,np.newaxis]], axis=1)
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
weather_feats = df_sum[['min_temp', u'max_temp', u'wind_speed',
       u'wind_gust', u'visibility', u'pressure', u'precipitation',
       u'snow_depth', u'fog', u'rain_drizzle', u'snow_ice', u'thunder']].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1,:]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
weather_feats = weather_feats[NUM_LAGS:-1,:]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "weather_feats:", weather_feats.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1997, 10)
# event_feats: (1997, 4)
# lags_event_feats: (1997, 10)
# event_texts: (1997,)
# weather_feats: (1997, 12)
# preds: (1997,)
# trends: (1997,)
# stds: (1997,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.678237678901
# 1 0.506070993546
# 2 0.385031078631
# 3 0.30802869179
# 4 0.254561740427
# 5 0.272885421815
# 6 0.296213775718
# 7 0.299406934851
# 8 0.265375284482
# 9 0.25397372093

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.252344477224
# 1 0.251446731463
# 2 0.250969701563
# 3 0.2508111344
# 4 0.250713007339
# 5 0.250666461441
# 6 0.252278427797
# 7 0.252206819578
# 8 0.252104576577

# %%
np.corrcoef(preds[:], event_feats[:,0])
# Out:
# array([[ 1.        ,  0.25308608],
#        [ 0.25308608,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*4-180 # 2011 to Jun2014
i_val = 365*4 
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train,:] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
weather_feats_train = weather_feats[:i_train,:] # weather data
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val,:] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
weather_feats_val = weather_feats[i_train:i_val,:] # weather data
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test,:]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
weather_feats_test = weather_feats[i_val:i_test,:]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "weather_feats_train:", weather_feats_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (1280, 10)
# event_feats_train: (1280, 4)
# lags_event_feats_train: (1280, 10)
# event_texts_train: (1280,)
# weather_feats_train: (1280, 12)
# y_train: (1280,)
# y_val: (180,)
# y_test: (536,)
# trend_test: (536,)
# std_test: (536,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline (just lags)

# %%
# linear regression (just lags)
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  196.249
# RMSE: 255.936
# R2:   0.460

# %% [markdown]
# ## Linear regression with weather

# %%
# linear regression lags + weather
sel = [0,2,4,5,7,8,9]
sel = [2]
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  196.188
# RMSE: 255.795
# R2:   0.461

# %%
# linear regression lags + weather
sel = [0,2,4,5,7,8,9]
sel = [2,3]
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  195.679
# RMSE: 255.711
# R2:   0.461

# %%
# linear regression lags + weather
sel = [0,2,4,5,7,8,9]
sel = [2,3,6]
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  195.260
# RMSE: 255.485
# R2:   0.462

# %%
# linear regression lags + weather
sel = [0,2,4,5,7,8,9]
sel = [2,3,6,10]
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  194.669
# RMSE: 254.932
# R2:   0.465

# %% [markdown]
# ## Linear regression with weather + events

# %%
# linear regression lags + weather + events
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel], event_feats_train[:,:1]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel], event_feats_test[:,:1]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  196.935
# RMSE: 252.769
# R2:   0.474

# %%
# linear regression lags + weather + events + late
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel], event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel], event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  198.284
# RMSE: 254.547
# R2:   0.466

# %%
# linear regression lags + weather + events + late + event_lags
regr = linear_model.LinearRegression()
sel2 = [0,1,2]
regr.fit(np.concatenate([lags_train, event_feats_train, lags_event_feats_train[:,sel2], weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test, lags_event_feats_test[:,sel2], weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  192.449
# RMSE: 249.553
# R2:   0.487

# %%
# linear regression lags + weather + events + late + event_lags
regr = linear_model.LinearRegression()
sel2 = [0,1,2,7]
regr.fit(np.concatenate([lags_train, event_feats_train, lags_event_feats_train[:,sel2], weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test, lags_event_feats_test[:,sel2], weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  191.563
# RMSE: 248.963
# R2:   0.489

# %% [markdown]
# ## MLP (just lags)

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.1))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    #lags_train,
    np.concatenate([lags_train], axis=1),
    y_train,
    batch_size=64,
    epochs=300,
    #validation_data=(lags_val, y_val),
    validation_data=(np.concatenate([lags_val], axis=1), y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 10.82813, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 10.82813 to 9.22989, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 9.22989 to 7.85553, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 7.85553 to 6.68967, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 6.68967 to 5.69552, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 5.69552 to 4.85698, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 4.85698 to 4.19255, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 4.19255 to 3.57207, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 3.57207 to 3.10599, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 3.10599 to 2.69655, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 2.69655 to 2.35063, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 2.35063 to 2.06078, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.06078 to 1.80566, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 1.80566 to 1.60764, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.60764 to 1.42975, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.42975 to 1.28847, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.28847 to 1.14974, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.14974 to 1.06715, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.06715 to 0.96094, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 0.96094 to 0.87657, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 0.87657 to 0.85165, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.85165 to 0.77997, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.77997 to 0.72267, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.72267 to 0.69226, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.69226 to 0.66607, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.66607 to 0.62745, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.62745 to 0.62208, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.62208 to 0.58287, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.58287 to 0.56645, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.56645 to 0.54895, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.54895 to 0.54299, saving model to weights.best.hdf5
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss improved from 0.54299 to 0.52674, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.52674 to 0.50892, saving model to weights.best.hdf5
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss improved from 0.50892 to 0.49525, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.49525 to 0.48261, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 0.48261 to 0.46554, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.46554 to 0.46113, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 0.46113 to 0.45462, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.45462 to 0.45391, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.45391 to 0.45346, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss improved from 0.45346 to 0.45321, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.45321 to 0.44998, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss improved from 0.44998 to 0.44985, saving model to weights.best.hdf5
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     77    Best: 0.526730541885
# Best val_loss at iteratation: 250    Best: 0.449851651986

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (536, 1)
# (536,)
# MAE:  188.606
# RMSE: 249.903
# R2:   0.486

# %% [markdown]
# ## MLP lags + weather

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS+len(sel), 1)
model.fit(
    #lags_train,
    np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1),
    y_train,
    batch_size=64,
    epochs=300,
    #validation_data=(lags_val, y_val),
    validation_data=(np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 12.39235, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 12.39235 to 10.87832, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 10.87832 to 9.49337, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 9.49337 to 8.23004, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 8.23004 to 7.13804, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 7.13804 to 6.20841, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 6.20841 to 5.37819, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 5.37819 to 4.65910, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 4.65910 to 4.03928, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 4.03928 to 3.51679, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 3.51679 to 3.08301, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.08301 to 2.67526, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.67526 to 2.35380, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.35380 to 2.07201, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.07201 to 1.82412, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.82412 to 1.62922, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.62922 to 1.43826, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.43826 to 1.33310, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.33310 to 1.16823, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.16823 to 1.06999, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.06999 to 0.99339, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.99339 to 0.90450, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.90450 to 0.84303, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.84303 to 0.79287, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.79287 to 0.73742, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.73742 to 0.70757, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.70757 to 0.66872, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.66872 to 0.64418, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.64418 to 0.62006, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.62006 to 0.59882, saving model to weights.best.hdf5
# Epoch 00030: val_loss did not improve
# Epoch 00031: val_loss improved from 0.59882 to 0.56533, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.56533 to 0.54253, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.54253 to 0.53985, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.53985 to 0.52012, saving model to weights.best.hdf5
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss improved from 0.52012 to 0.50442, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 0.50442 to 0.50018, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.50018 to 0.48376, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 0.48376 to 0.48298, saving model to weights.best.hdf5
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss improved from 0.48298 to 0.47806, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.47806 to 0.47638, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.47638 to 0.46717, saving model to weights.best.hdf5
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss improved from 0.46717 to 0.46245, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss improved from 0.46245 to 0.46235, saving model to weights.best.hdf5
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.46235 to 0.46173, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.46173 to 0.45943, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.45943 to 0.45683, saving model to weights.best.hdf5
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss improved from 0.45683 to 0.45487, saving model to weights.best.hdf5
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     136    Best: 0.52406784445
# Best val_loss at iteratation: 124    Best: 0.454866980182

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (536, 1)
# (536,)
# MAE:  190.075
# RMSE: 250.575
# R2:   0.483

# %% [markdown]
# ## MLP with weather + events information (no text)

# %%
def build_model_events(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_events(1, NUM_LAGS+len(sel), 4, 1)
#print model_weather.summary()
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_1/concat:0", shape=(?, 18), dtype=float32)
# Epoch 00000: val_loss improved from inf to 13.17798, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 13.17798 to 11.10542, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.10542 to 9.34664, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 9.34664 to 7.83755, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 7.83755 to 6.61649, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 6.61649 to 5.57469, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 5.57469 to 4.70670, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 4.70670 to 3.97972, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 3.97972 to 3.38006, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 3.38006 to 2.88810, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 2.88810 to 2.47415, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 2.47415 to 2.14353, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.14353 to 1.87363, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 1.87363 to 1.62768, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.62768 to 1.47330, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.47330 to 1.29196, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.29196 to 1.16180, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.16180 to 1.04410, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.04410 to 0.97424, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 0.97424 to 0.88798, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 0.88798 to 0.82576, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.82576 to 0.77135, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.77135 to 0.74000, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.74000 to 0.71336, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.71336 to 0.64786, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.64786 to 0.62656, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.62656 to 0.61343, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.61343 to 0.58341, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.58341 to 0.56067, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.56067 to 0.54850, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.54850 to 0.54609, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.54609 to 0.53084, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.53084 to 0.50432, saving model to weights.best.hdf5
# Epoch 00033: val_loss did not improve
# Epoch 00034: val_loss improved from 0.50432 to 0.50211, saving model to weights.best.hdf5
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss improved from 0.50211 to 0.48601, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 0.48601 to 0.48145, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.48145 to 0.46142, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 0.46142 to 0.45526, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.45526 to 0.45506, saving model to weights.best.hdf5
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss improved from 0.45506 to 0.44637, saving model to weights.best.hdf5
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss improved from 0.44637 to 0.44524, saving model to weights.best.hdf5
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss improved from 0.44524 to 0.43711, saving model to weights.best.hdf5
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     234    Best: 0.502701659501
# Best val_loss at iteratation: 281    Best: 0.4371123751

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.417156607802
# (536, 1)
# (536,)
# MAE:  186.079
# RMSE: 244.866
# R2:   0.506

# %% [markdown]
# ## MLP with weather + events information (no text) + event_lags

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_events(1, NUM_LAGS+len(sel), 4+len(sel2), 1)
#print model_weather.summary()
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train[:,sel2]], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val[:,sel2]], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_4/concat:0", shape=(?, 22), dtype=float32)
# Epoch 00000: val_loss improved from inf to 14.17113, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 14.17113 to 11.75768, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.75768 to 9.72564, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 9.72564 to 7.99428, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 7.99428 to 6.58129, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 6.58129 to 5.45019, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 5.45019 to 4.52105, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 4.52105 to 3.76794, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 3.76794 to 3.16214, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 3.16214 to 2.66397, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 2.66397 to 2.27369, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 2.27369 to 1.94904, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 1.94904 to 1.68797, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 1.68797 to 1.47899, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.47899 to 1.29098, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.29098 to 1.18600, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.18600 to 1.05292, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.05292 to 0.96880, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 0.96880 to 0.89465, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 0.89465 to 0.81814, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 0.81814 to 0.76484, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.76484 to 0.71803, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.71803 to 0.68505, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.68505 to 0.66741, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.66741 to 0.63728, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.63728 to 0.59100, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.59100 to 0.56078, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.56078 to 0.55529, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.55529 to 0.53911, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.53911 to 0.52475, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.52475 to 0.49908, saving model to weights.best.hdf5
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss improved from 0.49908 to 0.49740, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.49740 to 0.49452, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.49452 to 0.47927, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 0.47927 to 0.46475, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.46475 to 0.45308, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 0.45308 to 0.44980, saving model to weights.best.hdf5
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.44980 to 0.43997, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.43997 to 0.43620, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss improved from 0.43620 to 0.43546, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     268    Best: 0.510309424996
# Best val_loss at iteratation: 83    Best: 0.435458805826

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test[:,sel2]], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test[:,sel2]], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.451285952952
# (536, 1)
# (536,)
# MAE:  198.649
# RMSE: 254.211
# R2:   0.468

# %% [markdown]
# ## MLP with weather + events information (no text) + TEXT

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 2943 unique tokens.
# ('Shape of train tensor:', (1280, 600))
# ('Shape of val tensor:', (180, 600))
# ('Shape of test tensor:', (536, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model_text(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_text(1, NUM_LAGS+len(sel), 4, 1)
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:]], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:]], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_1/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_11:0", shape=(?, 14), dtype=float32)
# Tensor("input_12:0", shape=(?, 4), dtype=float32)
# Tensor("dropout_17/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_6/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 11.33489, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 11.33489 to 8.01939, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 8.01939 to 5.67634, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 5.67634 to 4.06296, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 4.06296 to 2.93740, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 2.93740 to 2.20093, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 2.20093 to 1.68597, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 1.68597 to 1.38129, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 1.38129 to 1.15117, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 1.15117 to 1.00302, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 1.00302 to 0.90456, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 0.90456 to 0.85282, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 0.85282 to 0.78723, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 0.78723 to 0.77160, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 0.77160 to 0.72680, saving model to weights.best.hdf5
# Epoch 00015: val_loss did not improve
# Epoch 00016: val_loss improved from 0.72680 to 0.69166, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 0.69166 to 0.68023, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 0.68023 to 0.64450, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 0.64450 to 0.64097, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 0.64097 to 0.61493, saving model to weights.best.hdf5
# Epoch 00021: val_loss did not improve
# Epoch 00022: val_loss improved from 0.61493 to 0.55931, saving model to weights.best.hdf5
# Epoch 00023: val_loss did not improve
# Epoch 00024: val_loss improved from 0.55931 to 0.55891, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.55891 to 0.53392, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.53392 to 0.52536, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.52536 to 0.51270, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.51270 to 0.50244, saving model to weights.best.hdf5
# Epoch 00029: val_loss did not improve
# Epoch 00030: val_loss improved from 0.50244 to 0.47523, saving model to weights.best.hdf5
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 0.47523 to 0.46811, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.46811 to 0.46349, saving model to weights.best.hdf5
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss did not improve
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss did not improve
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss improved from 0.46349 to 0.45568, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss improved from 0.45568 to 0.45241, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss improved from 0.45241 to 0.44564, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss improved from 0.44564 to 0.44322, saving model to weights.best.hdf5
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss improved from 0.44322 to 0.43901, saving model to weights.best.hdf5
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss improved from 0.43901 to 0.43810, saving model to weights.best.hdf5
# Epoch 00100: val_loss improved from 0.43810 to 0.43781, saving model to weights.best.hdf5
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss improved from 0.43781 to 0.43719, saving model to weights.best.hdf5
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss improved from 0.43719 to 0.43375, saving model to weights.best.hdf5
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss improved from 0.43375 to 0.42980, saving model to weights.best.hdf5
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss improved from 0.42980 to 0.42706, saving model to weights.best.hdf5
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss improved from 0.42706 to 0.42510, saving model to weights.best.hdf5
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss improved from 0.42510 to 0.42301, saving model to weights.best.hdf5
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss improved from 0.42301 to 0.41991, saving model to weights.best.hdf5
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     413    Best: 0.426302813739
# Best val_loss at iteratation: 272    Best: 0.419907854663

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.412008488134
# (536, 1)
# (536,)
# MAE:  183.718
# RMSE: 243.902
# R2:   0.510

# %% [markdown]
# ## MLP with weather + events information (no text) + event_lags + TEXT

# %%
def build_model_text_v2(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(100, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_text_v2(1, NUM_LAGS+len(sel), 4+len(sel2), 1)
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train[:,sel2]], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val[:,sel2]], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_2/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_14:0", shape=(?, 14), dtype=float32)
# Tensor("input_15:0", shape=(?, 8), dtype=float32)
# Tensor("dropout_22/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_8/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 12.12986, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 12.12986 to 8.43024, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 8.43024 to 5.88312, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 5.88312 to 4.11013, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 4.11013 to 2.93801, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 2.93801 to 2.18419, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 2.18419 to 1.68386, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 1.68386 to 1.36716, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 1.36716 to 1.17835, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 1.17835 to 1.01202, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 1.01202 to 0.95005, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 0.95005 to 0.84019, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 0.84019 to 0.81227, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 0.81227 to 0.76159, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 0.76159 to 0.73679, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 0.73679 to 0.69687, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 0.69687 to 0.68825, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 0.68825 to 0.67433, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 0.67433 to 0.64663, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 0.64663 to 0.63322, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 0.63322 to 0.62320, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.62320 to 0.59057, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.59057 to 0.56226, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.56226 to 0.54546, saving model to weights.best.hdf5
# Epoch 00024: val_loss did not improve
# Epoch 00025: val_loss improved from 0.54546 to 0.51623, saving model to weights.best.hdf5
# Epoch 00026: val_loss did not improve
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss did not improve
# Epoch 00029: val_loss improved from 0.51623 to 0.51600, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.51600 to 0.51505, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.51505 to 0.47169, saving model to weights.best.hdf5
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss did not improve
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss did not improve
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 0.47169 to 0.47062, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 0.47062 to 0.46994, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.46994 to 0.45897, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.45897 to 0.45415, saving model to weights.best.hdf5
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss improved from 0.45415 to 0.45408, saving model to weights.best.hdf5
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss improved from 0.45408 to 0.44755, saving model to weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss improved from 0.44755 to 0.44072, saving model to weights.best.hdf5
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss improved from 0.44072 to 0.43531, saving model to weights.best.hdf5
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss improved from 0.43531 to 0.42879, saving model to weights.best.hdf5
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss improved from 0.42879 to 0.41563, saving model to weights.best.hdf5
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss improved from 0.41563 to 0.41388, saving model to weights.best.hdf5
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss improved from 0.41388 to 0.41369, saving model to weights.best.hdf5
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss improved from 0.41369 to 0.41048, saving model to weights.best.hdf5
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss improved from 0.41048 to 0.40379, saving model to weights.best.hdf5
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     400    Best: 0.415233968198
# Best val_loss at iteratation: 313    Best: 0.403790536192

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test[:,sel2]], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test[:,sel2]], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.412011767056
# (536, 1)
# (536,)
# MAE:  186.755
# RMSE: 245.080
# R2:   0.505
