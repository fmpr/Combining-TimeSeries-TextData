# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)

# %% [markdown]
# ## Load weather data

# %%
# load data
df = pd.read_csv("../central_park_weather.csv")
df = df.set_index("date")

# replace predefined values with NaN
df = df.replace(99.99, np.nan)
df = df.replace(999.9, np.nan)
df = df.replace(9999.9, np.nan)

# replace NaN with 0 for snow depth
df["snow_depth"] = df["snow_depth"].fillna(0)

# do interpolation for the remaining NaNs
df = df.interpolate()

# standardize data
removed_mean = df.mean()
removed_std = df.std()
weather = (df - removed_mean) / removed_std

weather.head()
# Out:
#             min_temp  max_temp  wind_speed  wind_gust  visibility  pressure  \
# date
# 2009-01-01 -2.016735 -2.128488    2.946112   2.512634    0.666065  0.571023
# 2009-01-02 -1.602221 -1.739134    0.276908  -0.188044    0.236614 -0.040850
# 2009-01-03 -1.108462 -1.472148    1.211129   0.018115    0.666065 -0.503153
# 2009-01-04 -1.413252 -1.238535    1.033182  -0.579745    0.666065  0.244691
# 2009-01-05 -0.626895 -1.188475    0.588315  -1.218837    0.666065 -0.272002
#
#             precipitation  snow_depth       fog  rain_drizzle  snow_ice  \
# date
# 2009-01-01      -0.273606   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-02      -0.378683   -0.240596 -0.326133     -0.709709  3.913921
# 2009-01-03      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-04      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-05      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
#
#              thunder
# date
# 2009-01-01 -0.037018
# ...

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("terminal5_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2014-03-15  2014-03-15 20:00:00
# 1           1  2014-11-11  2014-11-11 20:00:00
# 2           2  2014-10-17  2014-10-17 19:00:00
# 3           3  2015-11-19  2015-11-19 19:00:00
# 4           4  2013-10-22  2013-10-22 19:00:00
#
#                                  title               url  \
# 0                Carnage at Terminal 5   593163697436226
# 1         London Grammar at Terminal 5  1465453707047232
# 2  Citizen Cope at Terminal 5 on 10/17   265560376982598
# 3                        Azealia Banks  1526707847627630
# 4          Cold War Kids at Terminal 5   641278195885283
#
#                                          description
# 0  carnage carnage tbp im who carnage sat march w...
# 1  london grammar london grammar bit ly who londo...
# 2  citizen cope clarence greenwood recording 10th...
# 3                          azealia bank azealia bank
# 4  cold war kid cold war kid cold war kid are com...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                title  \
# 0  2014-03-15 2014-03-15 20:00:00                Carnage at Terminal 5
# 1  2014-11-11 2014-11-11 20:00:00         London Grammar at Terminal 5
# 2  2014-10-17 2014-10-17 19:00:00  Citizen Cope at Terminal 5 on 10/17
# 3  2015-11-19 2015-11-19 19:00:00                        Azealia Banks
# 4  2013-10-22 2013-10-22 19:00:00          Cold War Kids at Terminal 5
#
#                 url                                        description
# 0   593163697436226  carnage carnage tbp im who carnage sat march w...
# 1  1465453707047232  london grammar london grammar bit ly who londo...
# 2   265560376982598  citizen cope clarence greenwood recording 10th...
# 3  1526707847627630                          azealia bank azealia bank
# 4   641278195885283  cold war kid cold war kid cold war kid are com...

# %%
# late events
print len(events["start_time"].dt.hour.values)
print np.sum(events["start_time"].dt.hour.values >= 20)
print np.sum(events["start_time"].dt.hour.values >= 21)
plt.hist(events["start_time"].dt.hour.values)
# Out:
# 591
# 220
# 24
# (array([   7.,    3.,    5.,    1.,    1.,    0.,    1.,    5.,  348.,  220.]),
#  array([  0. ,   2.2,   4.4,   6.6,   8.8,  11. ,  13.2,  15.4,  17.6,
#          19.8,  22. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/home/fmpr/data/pickups_terminal_5_0.003.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0       24
# 1  2009-01-01     0       1       35
# 2  2009-01-01     1       0       25
# 3  2009-01-01     1       1       25
# 4  2009-01-01     2       0       16

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      560  2009-01-01    3
# 2009-01-02      761  2009-01-02    4
# 2009-01-03      730  2009-01-03    5
# 2009-01-04      640  2009-01-04    6
# 2009-01-05     1127  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
late_event = np.zeros((len(df_sum)))
really_late_event = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
        for e in events[events.date == df_sum.iloc[i].date]["start_time"]:
            if e.hour >= 20:
                late_event[i] = 1
            if e.hour >= 21:
                really_late_event[i] = 1
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["late_event"] = late_event
df_sum["really_late_event"] = really_late_event
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["late_event_next_day"] = pd.Series(df_sum["late_event"]).shift(-1)
df_sum["really_late_event_next_day"] = pd.Series(df_sum["really_late_event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      560  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      761  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      730  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      640  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05     1127  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day event_next_day_desc
# date
# 2009-01-01                         0.0                None
# ...

# %%
# merge with weather data
df_sum = df_sum.join(weather, how='inner')
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      560  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      761  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      730  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      640  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05     1127  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day    ...    wind_speed  wind_gust  \
# date                                      ...
# ...

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01     2324  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02     1167  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03     1312  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04     1537  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05     1293  2013-01-05    5    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2013-01-01       None             0.0                  0.0
# 2013-01-02       None             0.0                  0.0
# 2013-01-03       None             0.0                  0.0
# 2013-01-04       None             0.0                  0.0
# 2013-01-05       None             0.0                  0.0
#
#             really_late_event_next_day    ...    wind_speed  wind_gust  \
# date                                      ...
# ...

# %%
df_sum.describe()
# Out:
#            pickups          dow        event   late_event  really_late_event  \
# count  1277.000000  1277.000000  1277.000000  1277.000000        1277.000000
# mean   1369.550509     2.997651     0.239624     0.080658           0.009397
# std     390.695578     1.999411     0.427021     0.272416           0.096520
# min     253.000000     0.000000     0.000000     0.000000           0.000000
# 25%    1085.000000     1.000000     0.000000     0.000000           0.000000
# 50%    1367.000000     3.000000     0.000000     0.000000           0.000000
# 75%    1587.000000     5.000000     0.000000     0.000000           0.000000
# max    3313.000000     6.000000     1.000000     1.000000           1.000000
#
#        event_next_day  late_event_next_day  really_late_event_next_day  \
# count     1276.000000          1276.000000                 1276.000000
# mean         0.239812             0.080721                    0.009404
# ...

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01     2324  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02     1167  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03     1312  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04     1537  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05     1293  2013-01-05    5    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2013-01-01       None             0.0                  0.0
# 2013-01-02       None             0.0                  0.0
# 2013-01-03       None             0.0                  0.0
# 2013-01-04       None             0.0                  0.0
# 2013-01-05       None             0.0                  0.0
#
#             really_late_event_next_day  ...  wind_gust  visibility  pressure  \
# date                                    ...
# ...

# %%
trend_mean = df_sum[df_sum.index.year < 2015].groupby(["dow"]).mean()["pickups"]
trend_mean
# Out:
# dow
# 0    1487.846154
# 1    1613.161905
# 2    1613.771429
# 3    1626.442308
# 4    1611.201923
# 5    1437.384615
# 6    1184.567308
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 390.69557775411482

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1277

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01     2324  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02     1167  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03     1312  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04     1537  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05     1293  2013-01-05    5    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2013-01-01       None             0.0                  0.0
# 2013-01-02       None             0.0                  0.0
# 2013-01-03       None             0.0                  0.0
# 2013-01-04       None             0.0                  0.0
# 2013-01-05       None             0.0                  0.0
#
#             really_late_event_next_day    ...     precipitation  snow_depth  \
# date                                      ...
# ...

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2015, "detrended"][:50], "k-")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "event"][:50], "r--")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "late_event"][:50], "b--")

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.25764673],
#        [ 0.25764673,  1.        ]])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"][:-1], df_sum["late_event_next_day"][:-1])
# Out:
# array([[ 1.        ,  0.06322205],
#        [ 0.06322205,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.28085488187935581, pvalue=1.4076002387344309e-24)

# %% [markdown]
# ## Build lags and features

# %%
df_sum.columns
# Out:
# Index([u'pickups', u'date', u'dow', u'event', u'late_event',
#        u'really_late_event', u'event_desc', u'event_next_day',
#        u'late_event_next_day', u'really_late_event_next_day',
#        u'event_next_day_desc', u'min_temp', u'max_temp', u'wind_speed',
#        u'wind_gust', u'visibility', u'pressure', u'precipitation',
#        u'snow_depth', u'fog', u'rain_drizzle', u'snow_ice', u'thunder',
#        u'year', u'trend', u'std', u'detrended'],
#       dtype='object')

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = np.concatenate([df_sum["event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["late_event"].as_matrix()[:,np.newaxis],
                             #df_sum["late_event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event_next_day"].as_matrix()[:,np.newaxis]], axis=1)
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
weather_feats = df_sum[['min_temp', u'max_temp', u'wind_speed',
       u'wind_gust', u'visibility', u'pressure', u'precipitation',
       u'snow_depth', u'fog', u'rain_drizzle', u'snow_ice', u'thunder']].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1,:]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
weather_feats = weather_feats[NUM_LAGS:-1,:]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "weather_feats:", weather_feats.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1266, 10)
# event_feats: (1266, 4)
# lags_event_feats: (1266, 10)
# event_texts: (1266,)
# weather_feats: (1266, 12)
# preds: (1266,)
# trends: (1266,)
# stds: (1266,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.693960789124
# 1 0.539872012582
# 2 0.424040817795
# 3 0.361553269932
# 4 0.317054747489
# 5 0.331908457232
# 6 0.353612066378
# 7 0.353453262896
# 8 0.333569101726
# 9 0.322188836361

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.26105980477
# 1 0.260681546597
# 2 0.260461788351
# 3 0.258927343054
# 4 0.257410483303
# 5 0.256816070543
# 6 0.258775487847
# 7 0.258319909187
# 8 0.258087601227

# %%
np.corrcoef(preds[:], event_feats[:,0])
# Out:
# array([[ 1.        ,  0.26159273],
#        [ 0.26159273,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train,:] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
weather_feats_train = weather_feats[:i_train,:] # weather data
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val,:] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
weather_feats_val = weather_feats[i_train:i_val,:] # weather data
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test,:]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
weather_feats_test = weather_feats[i_val:i_test,:]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "weather_feats_train:", weather_feats_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640, 4)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# weather_feats_train: (640, 12)
# y_train: (640,)
# y_val: (90,)
# y_test: (535,)
# trend_test: (535,)
# std_test: (535,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline (just lags)

# %%
# linear regression (just lags)
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  197.930
# RMSE: 257.471
# R2:   0.429

# %% [markdown]
# ## Linear regression with weather

# %%
# linear regression lags + weather
sel = [0,2,4,5,7,8,9]
sel = [5,7]
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  198.200
# RMSE: 257.471
# R2:   0.429

# %% [markdown]
# ## Linear regression with weather + events

# %%
# linear regression lags + weather + events
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel], event_feats_train[:,:1]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel], event_feats_test[:,:1]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  197.153
# RMSE: 252.964
# R2:   0.449

# %%
# linear regression lags + weather + events + late
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel], event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel], event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  196.762
# RMSE: 252.697
# R2:   0.450

# %%
# linear regression lags + weather + events + late + event_lags
regr = linear_model.LinearRegression()
sel2 = [0,1,2]
regr.fit(np.concatenate([lags_train, event_feats_train, lags_event_feats_train[:,sel2], weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test, lags_event_feats_test[:,sel2], weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  191.678
# RMSE: 248.074
# R2:   0.470

# %%
# linear regression lags + weather + events + late + event_lags
regr = linear_model.LinearRegression()
sel2 = [0,1,2,7]
regr.fit(np.concatenate([lags_train, event_feats_train, lags_event_feats_train[:,sel2], weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test, lags_event_feats_test[:,sel2], weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  191.008
# RMSE: 247.583
# R2:   0.472

# %% [markdown]
# ## LSTM (just lags)

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,1))
    
    x = input_lags
    x = BatchNormalization()(x)
    x = LSTM(units=200, 
             kernel_regularizer=keras.regularizers.l2(0.001), 
             recurrent_regularizer=keras.regularizers.l2(0.001), 
             return_sequences=False)(x)
    x = Activation("tanh")(x)
    x = Dropout(0.5)(x)
    #preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.01))(x)
    preds = Dense(units=num_preds)(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights2.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    #lags_train,
    np.concatenate([lags_train], axis=1)[:,:,np.newaxis],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_data=(lags_val, y_val),
    validation_data=(np.concatenate([lags_val], axis=1)[:,:,np.newaxis], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 0.94508, saving model to weights2.best.hdf5
# Epoch 00001: val_loss improved from 0.94508 to 0.88530, saving model to weights2.best.hdf5
# Epoch 00002: val_loss improved from 0.88530 to 0.79920, saving model to weights2.best.hdf5
# Epoch 00003: val_loss improved from 0.79920 to 0.76074, saving model to weights2.best.hdf5
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss improved from 0.76074 to 0.75482, saving model to weights2.best.hdf5
# Epoch 00006: val_loss improved from 0.75482 to 0.71546, saving model to weights2.best.hdf5
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss improved from 0.71546 to 0.69890, saving model to weights2.best.hdf5
# Epoch 00009: val_loss did not improve
# Epoch 00010: val_loss did not improve
# Epoch 00011: val_loss improved from 0.69890 to 0.69328, saving model to weights2.best.hdf5
# Epoch 00012: val_loss did not improve
# ...

# %%
# load weights
model.load_weights("weights2.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1)[:,:,np.newaxis])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  201.413
# RMSE: 261.916
# R2:   0.409

# %% [markdown]
# ## MLP (just lags)

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = Dense(units=50, activation="tanh")(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = Dense(units=50, activation="tanh")(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    #preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.1))(x)
    preds = Dense(units=num_preds)(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights2.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    #lags_train,
    np.concatenate([lags_train], axis=1),
    y_train,
    batch_size=64,
    epochs=300,
    #validation_data=(lags_val, y_val),
    validation_data=(np.concatenate([lags_val], axis=1), y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 7.07275, saving model to weights2.best.hdf5
# Epoch 00001: val_loss improved from 7.07275 to 6.67384, saving model to weights2.best.hdf5
# Epoch 00002: val_loss improved from 6.67384 to 6.30239, saving model to weights2.best.hdf5
# Epoch 00003: val_loss improved from 6.30239 to 5.97596, saving model to weights2.best.hdf5
# Epoch 00004: val_loss improved from 5.97596 to 5.68471, saving model to weights2.best.hdf5
# Epoch 00005: val_loss improved from 5.68471 to 5.39835, saving model to weights2.best.hdf5
# Epoch 00006: val_loss improved from 5.39835 to 5.11999, saving model to weights2.best.hdf5
# Epoch 00007: val_loss improved from 5.11999 to 4.85640, saving model to weights2.best.hdf5
# Epoch 00008: val_loss improved from 4.85640 to 4.60528, saving model to weights2.best.hdf5
# Epoch 00009: val_loss improved from 4.60528 to 4.37308, saving model to weights2.best.hdf5
# ...

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     256    Best: 0.472381556034
# Best val_loss at iteratation: 276    Best: 0.598105461068

# %%
# load weights
model.load_weights("weights2.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  197.351
# RMSE: 255.888
# R2:   0.436

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  191.604
# RMSE: 251.497
# R2:   0.455

# %% [markdown]
# ## MLP lags + weather

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS+len(sel), 1)
model.fit(
    #lags_train,
    np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1),
    y_train,
    batch_size=64,
    epochs=300,
    #validation_data=(lags_val, y_val),
    validation_data=(np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 12.48370, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 12.48370 to 11.66006, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.66006 to 10.89197, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.89197 to 10.08953, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 10.08953 to 9.34360, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 9.34360 to 8.65515, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.65515 to 8.04552, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 8.04552 to 7.48052, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 7.48052 to 6.94204, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.94204 to 6.40871, saving model to weights.best.hdf5
# ...

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     153    Best: 0.49182253778
# Best val_loss at iteratation: 160    Best: 0.611830222607

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  189.163
# RMSE: 248.949
# R2:   0.466

# %% [markdown]
# ## MLP with weather + events information (no text)

# %%
def build_model_events(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.05))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_events(1, NUM_LAGS+len(sel), 4, 1)
#print model_weather.summary()
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_3/concat:0", shape=(?, 16), dtype=float32)
# Epoch 00000: val_loss improved from inf to 13.58450, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 13.58450 to 12.63949, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 12.63949 to 11.71298, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 11.71298 to 10.82233, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 10.82233 to 9.96408, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 9.96408 to 9.18079, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 9.18079 to 8.44955, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 8.44955 to 7.82515, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 7.82515 to 7.25651, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 7.25651 to 6.69582, saving model to weights.best.hdf5
# ...

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     127    Best: 0.468366751075
# Best val_loss at iteratation: 118    Best: 0.606358027458

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.430243292785
# (535, 1)
# (535,)
# MAE:  188.113
# RMSE: 246.021
# R2:   0.479

# %% [markdown]
# ## MLP with weather + events information (no text) + event_lags

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_events(1, NUM_LAGS+len(sel), 14, 1)
#print model_weather.summary()
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_4/concat:0", shape=(?, 26), dtype=float32)
# Epoch 00000: val_loss improved from inf to 16.90046, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 16.90046 to 15.52212, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 15.52212 to 14.19819, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 14.19819 to 13.02725, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 13.02725 to 11.99225, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 11.99225 to 10.94912, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 10.94912 to 9.99705, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 9.99705 to 9.12459, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 9.12459 to 8.36130, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 8.36130 to 7.64199, saving model to weights.best.hdf5
# ...

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     139    Best: 0.466257870197
# Best val_loss at iteratation: 96    Best: 0.592280362712

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.427562090727
# (535, 1)
# (535,)
# MAE:  180.825
# RMSE: 241.763
# R2:   0.496

# %% [markdown]
# ## MLP with weather + events information (no text) + TEXT

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 350 #1000
MAX_NB_WORDS = 600 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 965 unique tokens.
# ('Shape of train tensor:', (640, 350))
# ('Shape of val tensor:', (90, 350))
# ('Shape of test tensor:', (535, 350))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model_text(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_text(1, NUM_LAGS+len(sel), 4, 1)
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:]], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:]], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_3/Gather:0", shape=(?, 350, 300), dtype=float32)
# Tensor("input_23:0", shape=(?, 12), dtype=float32)
# Tensor("input_24:0", shape=(?, 4), dtype=float32)
# Tensor("dropout_39/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_10/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 13.39239, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 13.39239 to 11.50855, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.50855 to 9.87073, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 9.87073 to 8.46586, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 8.46586 to 7.25025, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 7.25025 to 6.20447, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 6.20447 to 5.30332, saving model to weights.best.hdf5
# ...

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     494    Best: 0.451793250442
# Best val_loss at iteratation: 340    Best: 0.593113225036

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.420159888518
# (535, 1)
# (535,)
# MAE:  182.785
# RMSE: 241.406
# R2:   0.498

# %% [markdown]
# ## MLP with weather + events information (no text) + event_lags + TEXT

# %%
def build_model_text_v2(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(100, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_text_v2(1, NUM_LAGS+len(sel), 14, 1)
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_4/Gather:0", shape=(?, 350, 300), dtype=float32)
# Tensor("input_26:0", shape=(?, 12), dtype=float32)
# Tensor("input_27:0", shape=(?, 14), dtype=float32)
# Tensor("dropout_44/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_12/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 15.91396, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 15.91396 to 13.37540, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 13.37540 to 11.18590, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 11.18590 to 9.32412, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.32412 to 7.77379, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 7.77379 to 6.47099, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 6.47099 to 5.40621, saving model to weights.best.hdf5
# ...

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     493    Best: 0.452794131637
# Best val_loss at iteratation: 452    Best: 0.576828714212

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.430270010261
# (535, 1)
# (535,)
# MAE:  183.307
# RMSE: 243.176
# R2:   0.491
