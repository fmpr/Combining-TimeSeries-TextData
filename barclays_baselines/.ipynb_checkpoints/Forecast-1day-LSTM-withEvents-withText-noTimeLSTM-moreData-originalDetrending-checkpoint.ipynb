# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("barclays_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2013-02-22  2013-02-22 19:30:00
# 1           1  2015-10-09  2015-10-09 19:30:00
# 2           2  2015-03-20  2015-03-20 19:30:00
# 3           3  2013-11-18  2013-11-18 19:30:00
# 4           4  2015-04-12  2015-04-12 20:00:00
#
#                                        title  \
# 0           Brooklyn Nets vs Houston Rockets
# 1  New York Islanders vs. Chicago Blackhawks
# 2          Brooklyn Nets vs. Milwaukee Bucks
# 3   Brooklyn Nets vs. Portland Trail Blazers
# 4                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                      title  \
# 0  2013-02-22 2013-02-22 19:30:00           Brooklyn Nets vs Houston Rockets
# 1  2015-10-09 2015-10-09 19:30:00  New York Islanders vs. Chicago Blackhawks
# 2  2015-03-20 2015-03-20 19:30:00          Brooklyn Nets vs. Milwaukee Bucks
# 3  2013-11-18 2013-11-18 19:30:00   Brooklyn Nets vs. Portland Trail Blazers
# 4  2015-04-12 2015-04-12 20:00:00                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/mnt/sdb1/nyc_taxi_data/venue-centered_anomalies/30min/data/pickups_barclays_center_0.003.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0        2
# 1  2009-01-01     0       1       15
# 2  2009-01-01     1       0       13
# 3  2009-01-01     1       1       16
# 4  2009-01-01     2       0       19

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      253  2009-01-01    3
# 2009-01-02      137  2009-01-02    4
# 2009-01-03      239  2009-01-03    5
# 2009-01-04      218  2009-01-04    6
# 2009-01-05       92  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event event_desc  event_next_day  \
# date
# 2009-01-01      253  2009-01-01    3    0.0       None             0.0
# 2009-01-02      137  2009-01-02    4    0.0       None             0.0
# 2009-01-03      239  2009-01-03    5    0.0       None             0.0
# 2009-01-04      218  2009-01-04    6    0.0       None             0.0
# 2009-01-05       92  2009-01-05    0    0.0       None             0.0
#
#            event_next_day_desc
# date
# 2009-01-01                None
# 2009-01-02                None
# 2009-01-03                None
# 2009-01-04                None
# 2009-01-05                None

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc
# date
# 2013-01-01                                               None
# 2013-01-02                                               None
# 2013-01-03                                               None
# 2013-01-04  net home game schedule highlight include oneti...
# 2013-01-05                                               None

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013

# %%
trend_mean = df_sum.groupby(["dow"]).mean()["pickups"]
trend_mean
# Out:
# dow
# 0    596.714286
# 1    601.322404
# 2    661.841530
# 3    673.224044
# 4    824.873626
# 5    994.197802
# 6    883.769231
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 313.32834892618996

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1277

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  601.322404  313.328349  -0.042519
# 2013-01-02  661.841530  313.328349  -1.525050
# 2013-01-03  673.224044  313.328349  -1.570953
# 2013-01-04  824.873626  313.328349  -1.901755
# 2013-01-05  994.197802  313.328349  -1.468740

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.29222202],
#        [ 0.29222202,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.30837038745794626, pvalue=1.5562559832009572e-29)

# %% [markdown]
# ## Build lags

# %%
df_sum.head()
# Out:
#             pickups        date  dow  event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0
# 2013-01-02      184  2013-01-02    2    0.0
# 2013-01-03      181  2013-01-03    3    0.0
# 2013-01-04      229  2013-01-04    4    0.0
# 2013-01-05      534  2013-01-05    5    1.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#                                           event_next_day_desc  year  \
# date
# 2013-01-01                                               None  2013
# 2013-01-02                                               None  2013
# 2013-01-03                                               None  2013
# 2013-01-04  net home game schedule highlight include oneti...  2013
# 2013-01-05                                               None  2013
#
#                  trend         std  detrended
# date
# 2013-01-01  601.322404  313.328349  -0.042519
# 2013-01-02  661.841530  313.328349  -1.525050
# 2013-01-03  673.224044  313.328349  -1.570953
# 2013-01-04  824.873626  313.328349  -1.901755
# 2013-01-05  994.197802  313.328349  -1.468740

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = df_sum["event_next_day"].as_matrix()
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1266, 10)
# event_feats: (1266,)
# lags_event_feats: (1266, 10)
# event_texts: (1266,)
# preds: (1266,)
# trends: (1266,)
# stds: (1266,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.783749460823
# 1 0.737279119787
# 2 0.700385593038
# 3 0.713158248055
# 4 0.717319427601
# 5 0.715063910678
# 6 0.740552803863
# 7 0.720824061499
# 8 0.701379864767
# 9 0.690002139757

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.288330806602
# 1 0.289076261548
# 2 0.290048476859
# 3 0.291066458368
# 4 0.292466236169
# 5 0.293911594119
# 6 0.292687800948
# 7 0.292817344108
# 8 0.293806330206

# %%
np.corrcoef(preds[:], event_feats[:])
# Out:
# array([[ 1.       ,  0.2898478],
#        [ 0.2898478,  1.       ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640,)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# y_train: (640,)
# y_val: (90,)
# y_test: (535,)
# trend_test: (535,)
# std_test: (535,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline

# %%
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  116.196
# RMSE: 161.270
# R2:   0.504

# %% [markdown]
# ## Linear regression with events

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train[:,np.newaxis]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test[:,np.newaxis]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  99.876
# RMSE: 141.993
# R2:   0.615

# %%
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, lags_event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, lags_event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  95.018
# RMSE: 137.355
# R2:   0.640

# %% [markdown]
# ## Simple LSTM

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    #preds = Dense(units=num_preds)(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.5))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    lags_train,
    y_train,
    batch_size=64,
    epochs=3000,
    validation_data=(lags_val, y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 6.67660, saving model to weights.best.hdf5
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss improved from 6.67660 to 6.49012, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 6.49012 to 6.22028, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 6.22028 to 5.93131, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.93131 to 5.63822, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.63822 to 5.34836, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 5.34836 to 5.07707, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 5.07707 to 4.80682, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 4.80682 to 4.55004, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 4.55004 to 4.31556, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 4.31556 to 4.08785, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 4.08785 to 3.88467, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 3.88467 to 3.69644, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 3.69644 to 3.52235, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 3.52235 to 3.36371, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 3.36371 to 3.23000, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 3.23000 to 3.09914, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 3.09914 to 2.98566, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.98566 to 2.87636, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 2.87636 to 2.77904, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 2.77904 to 2.68879, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 2.68879 to 2.59742, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 2.59742 to 2.51650, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 2.51650 to 2.44336, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 2.44336 to 2.37510, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 2.37510 to 2.30642, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 2.30642 to 2.24689, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 2.24689 to 2.18870, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 2.18870 to 2.13337, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 2.13337 to 2.07852, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 2.07852 to 2.02685, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 2.02685 to 1.98034, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.98034 to 1.93633, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.93633 to 1.88771, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.88771 to 1.84860, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.84860 to 1.80619, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.80619 to 1.76641, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 1.76641 to 1.73017, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 1.73017 to 1.68906, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.68906 to 1.65264, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 1.65264 to 1.61576, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 1.61576 to 1.58157, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 1.58157 to 1.54817, saving model to weights.best.hdf5
# Epoch 00051: val_loss improved from 1.54817 to 1.51464, saving model to weights.best.hdf5
# Epoch 00052: val_loss improved from 1.51464 to 1.48366, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 1.48366 to 1.45493, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 1.45493 to 1.42468, saving model to weights.best.hdf5
# Epoch 00055: val_loss improved from 1.42468 to 1.39846, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 1.39846 to 1.37015, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 1.37015 to 1.34442, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 1.34442 to 1.31514, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 1.31514 to 1.29057, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 1.29057 to 1.26788, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 1.26788 to 1.24121, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 1.24121 to 1.21920, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 1.21920 to 1.19602, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 1.19602 to 1.17458, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 1.17458 to 1.15433, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 1.15433 to 1.13318, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 1.13318 to 1.11268, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 1.11268 to 1.09357, saving model to weights.best.hdf5
# Epoch 00069: val_loss improved from 1.09357 to 1.07360, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 1.07360 to 1.05679, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 1.05679 to 1.03813, saving model to weights.best.hdf5
# Epoch 00072: val_loss improved from 1.03813 to 1.01874, saving model to weights.best.hdf5
# Epoch 00073: val_loss improved from 1.01874 to 1.00197, saving model to weights.best.hdf5
# Epoch 00074: val_loss improved from 1.00197 to 0.98471, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.98471 to 0.97000, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.97000 to 0.95233, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.95233 to 0.93952, saving model to weights.best.hdf5
# Epoch 00078: val_loss improved from 0.93952 to 0.92422, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.92422 to 0.91055, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.91055 to 0.89703, saving model to weights.best.hdf5
# Epoch 00081: val_loss improved from 0.89703 to 0.88440, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.88440 to 0.87074, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.87074 to 0.85757, saving model to weights.best.hdf5
# Epoch 00084: val_loss improved from 0.85757 to 0.84469, saving model to weights.best.hdf5
# Epoch 00085: val_loss improved from 0.84469 to 0.83294, saving model to weights.best.hdf5
# Epoch 00086: val_loss improved from 0.83294 to 0.82029, saving model to weights.best.hdf5
# Epoch 00087: val_loss improved from 0.82029 to 0.80901, saving model to weights.best.hdf5
# Epoch 00088: val_loss improved from 0.80901 to 0.79692, saving model to weights.best.hdf5
# Epoch 00089: val_loss improved from 0.79692 to 0.78604, saving model to weights.best.hdf5
# Epoch 00090: val_loss improved from 0.78604 to 0.77495, saving model to weights.best.hdf5
# Epoch 00091: val_loss improved from 0.77495 to 0.76424, saving model to weights.best.hdf5
# Epoch 00092: val_loss improved from 0.76424 to 0.75281, saving model to weights.best.hdf5
# Epoch 00093: val_loss improved from 0.75281 to 0.74333, saving model to weights.best.hdf5
# Epoch 00094: val_loss improved from 0.74333 to 0.73618, saving model to weights.best.hdf5
# Epoch 00095: val_loss improved from 0.73618 to 0.72630, saving model to weights.best.hdf5
# Epoch 00096: val_loss improved from 0.72630 to 0.71726, saving model to weights.best.hdf5
# Epoch 00097: val_loss improved from 0.71726 to 0.70687, saving model to weights.best.hdf5
# Epoch 00098: val_loss improved from 0.70687 to 0.69818, saving model to weights.best.hdf5
# Epoch 00099: val_loss improved from 0.69818 to 0.68904, saving model to weights.best.hdf5
# Epoch 00100: val_loss improved from 0.68904 to 0.68133, saving model to weights.best.hdf5
# Epoch 00101: val_loss improved from 0.68133 to 0.67342, saving model to weights.best.hdf5
# Epoch 00102: val_loss improved from 0.67342 to 0.66483, saving model to weights.best.hdf5
# Epoch 00103: val_loss improved from 0.66483 to 0.65736, saving model to weights.best.hdf5
# Epoch 00104: val_loss improved from 0.65736 to 0.65000, saving model to weights.best.hdf5
# Epoch 00105: val_loss improved from 0.65000 to 0.64217, saving model to weights.best.hdf5
# Epoch 00106: val_loss improved from 0.64217 to 0.63583, saving model to weights.best.hdf5
# Epoch 00107: val_loss improved from 0.63583 to 0.62948, saving model to weights.best.hdf5
# Epoch 00108: val_loss improved from 0.62948 to 0.62249, saving model to weights.best.hdf5
# Epoch 00109: val_loss improved from 0.62249 to 0.61545, saving model to weights.best.hdf5
# Epoch 00110: val_loss improved from 0.61545 to 0.60843, saving model to weights.best.hdf5
# Epoch 00111: val_loss improved from 0.60843 to 0.60223, saving model to weights.best.hdf5
# Epoch 00112: val_loss improved from 0.60223 to 0.59584, saving model to weights.best.hdf5
# Epoch 00113: val_loss improved from 0.59584 to 0.59003, saving model to weights.best.hdf5
# Epoch 00114: val_loss improved from 0.59003 to 0.58457, saving model to weights.best.hdf5
# Epoch 00115: val_loss improved from 0.58457 to 0.57812, saving model to weights.best.hdf5
# Epoch 00116: val_loss improved from 0.57812 to 0.57258, saving model to weights.best.hdf5
# Epoch 00117: val_loss improved from 0.57258 to 0.56796, saving model to weights.best.hdf5
# Epoch 00118: val_loss improved from 0.56796 to 0.56268, saving model to weights.best.hdf5
# Epoch 00119: val_loss improved from 0.56268 to 0.55746, saving model to weights.best.hdf5
# Epoch 00120: val_loss improved from 0.55746 to 0.55302, saving model to weights.best.hdf5
# Epoch 00121: val_loss improved from 0.55302 to 0.54782, saving model to weights.best.hdf5
# Epoch 00122: val_loss improved from 0.54782 to 0.54368, saving model to weights.best.hdf5
# Epoch 00123: val_loss improved from 0.54368 to 0.53846, saving model to weights.best.hdf5
# Epoch 00124: val_loss improved from 0.53846 to 0.53375, saving model to weights.best.hdf5
# Epoch 00125: val_loss improved from 0.53375 to 0.52815, saving model to weights.best.hdf5
# Epoch 00126: val_loss improved from 0.52815 to 0.52486, saving model to weights.best.hdf5
# Epoch 00127: val_loss improved from 0.52486 to 0.52161, saving model to weights.best.hdf5
# Epoch 00128: val_loss improved from 0.52161 to 0.51814, saving model to weights.best.hdf5
# Epoch 00129: val_loss improved from 0.51814 to 0.51381, saving model to weights.best.hdf5
# Epoch 00130: val_loss improved from 0.51381 to 0.50920, saving model to weights.best.hdf5
# Epoch 00131: val_loss improved from 0.50920 to 0.50569, saving model to weights.best.hdf5
# Epoch 00132: val_loss improved from 0.50569 to 0.50318, saving model to weights.best.hdf5
# Epoch 00133: val_loss improved from 0.50318 to 0.49918, saving model to weights.best.hdf5
# Epoch 00134: val_loss improved from 0.49918 to 0.49514, saving model to weights.best.hdf5
# Epoch 00135: val_loss improved from 0.49514 to 0.49234, saving model to weights.best.hdf5
# Epoch 00136: val_loss improved from 0.49234 to 0.48837, saving model to weights.best.hdf5
# Epoch 00137: val_loss improved from 0.48837 to 0.48537, saving model to weights.best.hdf5
# Epoch 00138: val_loss improved from 0.48537 to 0.48174, saving model to weights.best.hdf5
# Epoch 00139: val_loss improved from 0.48174 to 0.47964, saving model to weights.best.hdf5
# Epoch 00140: val_loss improved from 0.47964 to 0.47659, saving model to weights.best.hdf5
# Epoch 00141: val_loss improved from 0.47659 to 0.47323, saving model to weights.best.hdf5
# Epoch 00142: val_loss improved from 0.47323 to 0.47123, saving model to weights.best.hdf5
# Epoch 00143: val_loss improved from 0.47123 to 0.46784, saving model to weights.best.hdf5
# Epoch 00144: val_loss improved from 0.46784 to 0.46482, saving model to weights.best.hdf5
# Epoch 00145: val_loss improved from 0.46482 to 0.46369, saving model to weights.best.hdf5
# Epoch 00146: val_loss improved from 0.46369 to 0.46035, saving model to weights.best.hdf5
# Epoch 00147: val_loss improved from 0.46035 to 0.45852, saving model to weights.best.hdf5
# Epoch 00148: val_loss improved from 0.45852 to 0.45600, saving model to weights.best.hdf5
# Epoch 00149: val_loss improved from 0.45600 to 0.45315, saving model to weights.best.hdf5
# Epoch 00150: val_loss improved from 0.45315 to 0.45088, saving model to weights.best.hdf5
# Epoch 00151: val_loss improved from 0.45088 to 0.44823, saving model to weights.best.hdf5
# Epoch 00152: val_loss improved from 0.44823 to 0.44696, saving model to weights.best.hdf5
# Epoch 00153: val_loss improved from 0.44696 to 0.44450, saving model to weights.best.hdf5
# Epoch 00154: val_loss improved from 0.44450 to 0.44189, saving model to weights.best.hdf5
# Epoch 00155: val_loss improved from 0.44189 to 0.44133, saving model to weights.best.hdf5
# Epoch 00156: val_loss improved from 0.44133 to 0.43943, saving model to weights.best.hdf5
# Epoch 00157: val_loss improved from 0.43943 to 0.43693, saving model to weights.best.hdf5
# Epoch 00158: val_loss improved from 0.43693 to 0.43534, saving model to weights.best.hdf5
# Epoch 00159: val_loss improved from 0.43534 to 0.43397, saving model to weights.best.hdf5
# Epoch 00160: val_loss improved from 0.43397 to 0.43169, saving model to weights.best.hdf5
# Epoch 00161: val_loss improved from 0.43169 to 0.43021, saving model to weights.best.hdf5
# Epoch 00162: val_loss improved from 0.43021 to 0.42819, saving model to weights.best.hdf5
# Epoch 00163: val_loss improved from 0.42819 to 0.42585, saving model to weights.best.hdf5
# Epoch 00164: val_loss improved from 0.42585 to 0.42426, saving model to weights.best.hdf5
# Epoch 00165: val_loss improved from 0.42426 to 0.42343, saving model to weights.best.hdf5
# Epoch 00166: val_loss improved from 0.42343 to 0.42144, saving model to weights.best.hdf5
# Epoch 00167: val_loss improved from 0.42144 to 0.42083, saving model to weights.best.hdf5
# Epoch 00168: val_loss improved from 0.42083 to 0.41837, saving model to weights.best.hdf5
# Epoch 00169: val_loss improved from 0.41837 to 0.41700, saving model to weights.best.hdf5
# Epoch 00170: val_loss improved from 0.41700 to 0.41555, saving model to weights.best.hdf5
# Epoch 00171: val_loss improved from 0.41555 to 0.41451, saving model to weights.best.hdf5
# Epoch 00172: val_loss improved from 0.41451 to 0.41325, saving model to weights.best.hdf5
# Epoch 00173: val_loss improved from 0.41325 to 0.41265, saving model to weights.best.hdf5
# Epoch 00174: val_loss improved from 0.41265 to 0.41133, saving model to weights.best.hdf5
# Epoch 00175: val_loss improved from 0.41133 to 0.40914, saving model to weights.best.hdf5
# Epoch 00176: val_loss improved from 0.40914 to 0.40769, saving model to weights.best.hdf5
# Epoch 00177: val_loss improved from 0.40769 to 0.40715, saving model to weights.best.hdf5
# Epoch 00178: val_loss improved from 0.40715 to 0.40611, saving model to weights.best.hdf5
# Epoch 00179: val_loss improved from 0.40611 to 0.40511, saving model to weights.best.hdf5
# Epoch 00180: val_loss improved from 0.40511 to 0.40444, saving model to weights.best.hdf5
# Epoch 00181: val_loss improved from 0.40444 to 0.40312, saving model to weights.best.hdf5
# Epoch 00182: val_loss improved from 0.40312 to 0.40251, saving model to weights.best.hdf5
# Epoch 00183: val_loss improved from 0.40251 to 0.40228, saving model to weights.best.hdf5
# Epoch 00184: val_loss improved from 0.40228 to 0.40080, saving model to weights.best.hdf5
# Epoch 00185: val_loss improved from 0.40080 to 0.39974, saving model to weights.best.hdf5
# Epoch 00186: val_loss improved from 0.39974 to 0.39879, saving model to weights.best.hdf5
# Epoch 00187: val_loss improved from 0.39879 to 0.39872, saving model to weights.best.hdf5
# Epoch 00188: val_loss improved from 0.39872 to 0.39677, saving model to weights.best.hdf5
# Epoch 00189: val_loss improved from 0.39677 to 0.39644, saving model to weights.best.hdf5
# Epoch 00190: val_loss improved from 0.39644 to 0.39511, saving model to weights.best.hdf5
# Epoch 00191: val_loss improved from 0.39511 to 0.39425, saving model to weights.best.hdf5
# Epoch 00192: val_loss improved from 0.39425 to 0.39325, saving model to weights.best.hdf5
# Epoch 00193: val_loss improved from 0.39325 to 0.39305, saving model to weights.best.hdf5
# Epoch 00194: val_loss improved from 0.39305 to 0.39201, saving model to weights.best.hdf5
# Epoch 00195: val_loss improved from 0.39201 to 0.39075, saving model to weights.best.hdf5
# Epoch 00196: val_loss improved from 0.39075 to 0.39074, saving model to weights.best.hdf5
# Epoch 00197: val_loss improved from 0.39074 to 0.39049, saving model to weights.best.hdf5
# Epoch 00198: val_loss improved from 0.39049 to 0.38962, saving model to weights.best.hdf5
# Epoch 00199: val_loss improved from 0.38962 to 0.38889, saving model to weights.best.hdf5
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss improved from 0.38889 to 0.38841, saving model to weights.best.hdf5
# Epoch 00202: val_loss improved from 0.38841 to 0.38705, saving model to weights.best.hdf5
# Epoch 00203: val_loss improved from 0.38705 to 0.38675, saving model to weights.best.hdf5
# Epoch 00204: val_loss improved from 0.38675 to 0.38570, saving model to weights.best.hdf5
# Epoch 00205: val_loss improved from 0.38570 to 0.38567, saving model to weights.best.hdf5
# Epoch 00206: val_loss improved from 0.38567 to 0.38499, saving model to weights.best.hdf5
# Epoch 00207: val_loss improved from 0.38499 to 0.38424, saving model to weights.best.hdf5
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss improved from 0.38424 to 0.38378, saving model to weights.best.hdf5
# Epoch 00210: val_loss improved from 0.38378 to 0.38257, saving model to weights.best.hdf5
# Epoch 00211: val_loss improved from 0.38257 to 0.38200, saving model to weights.best.hdf5
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss improved from 0.38200 to 0.38194, saving model to weights.best.hdf5
# Epoch 00215: val_loss improved from 0.38194 to 0.38140, saving model to weights.best.hdf5
# Epoch 00216: val_loss improved from 0.38140 to 0.38000, saving model to weights.best.hdf5
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss improved from 0.38000 to 0.37978, saving model to weights.best.hdf5
# Epoch 00219: val_loss improved from 0.37978 to 0.37964, saving model to weights.best.hdf5
# Epoch 00220: val_loss improved from 0.37964 to 0.37937, saving model to weights.best.hdf5
# Epoch 00221: val_loss improved from 0.37937 to 0.37876, saving model to weights.best.hdf5
# Epoch 00222: val_loss improved from 0.37876 to 0.37810, saving model to weights.best.hdf5
# Epoch 00223: val_loss improved from 0.37810 to 0.37792, saving model to weights.best.hdf5
# Epoch 00224: val_loss improved from 0.37792 to 0.37718, saving model to weights.best.hdf5
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss improved from 0.37718 to 0.37703, saving model to weights.best.hdf5
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss improved from 0.37703 to 0.37594, saving model to weights.best.hdf5
# Epoch 00230: val_loss improved from 0.37594 to 0.37544, saving model to weights.best.hdf5
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss improved from 0.37544 to 0.37483, saving model to weights.best.hdf5
# Epoch 00235: val_loss improved from 0.37483 to 0.37422, saving model to weights.best.hdf5
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss improved from 0.37422 to 0.37410, saving model to weights.best.hdf5
# Epoch 00238: val_loss improved from 0.37410 to 0.37295, saving model to weights.best.hdf5
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss improved from 0.37295 to 0.37274, saving model to weights.best.hdf5
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss improved from 0.37274 to 0.37223, saving model to weights.best.hdf5
# Epoch 00245: val_loss improved from 0.37223 to 0.37157, saving model to weights.best.hdf5
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss improved from 0.37157 to 0.37049, saving model to weights.best.hdf5
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss improved from 0.37049 to 0.36989, saving model to weights.best.hdf5
# Epoch 00260: val_loss improved from 0.36989 to 0.36951, saving model to weights.best.hdf5
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss improved from 0.36951 to 0.36938, saving model to weights.best.hdf5
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss improved from 0.36938 to 0.36929, saving model to weights.best.hdf5
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss improved from 0.36929 to 0.36913, saving model to weights.best.hdf5
# Epoch 00270: val_loss improved from 0.36913 to 0.36884, saving model to weights.best.hdf5
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss improved from 0.36884 to 0.36880, saving model to weights.best.hdf5
# Epoch 00274: val_loss improved from 0.36880 to 0.36864, saving model to weights.best.hdf5
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss improved from 0.36864 to 0.36797, saving model to weights.best.hdf5
# Epoch 00281: val_loss improved from 0.36797 to 0.36792, saving model to weights.best.hdf5
# Epoch 00282: val_loss improved from 0.36792 to 0.36786, saving model to weights.best.hdf5
# Epoch 00283: val_loss improved from 0.36786 to 0.36671, saving model to weights.best.hdf5
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss improved from 0.36671 to 0.36655, saving model to weights.best.hdf5
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss improved from 0.36655 to 0.36594, saving model to weights.best.hdf5
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss improved from 0.36594 to 0.36567, saving model to weights.best.hdf5
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss improved from 0.36567 to 0.36540, saving model to weights.best.hdf5
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss improved from 0.36540 to 0.36399, saving model to weights.best.hdf5
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss improved from 0.36399 to 0.36365, saving model to weights.best.hdf5
# Epoch 00340: val_loss improved from 0.36365 to 0.36290, saving model to weights.best.hdf5
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss improved from 0.36290 to 0.36216, saving model to weights.best.hdf5
# Epoch 00360: val_loss improved from 0.36216 to 0.36198, saving model to weights.best.hdf5
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss improved from 0.36198 to 0.36196, saving model to weights.best.hdf5
# Epoch 00382: val_loss improved from 0.36196 to 0.36138, saving model to weights.best.hdf5
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss improved from 0.36138 to 0.36127, saving model to weights.best.hdf5
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss improved from 0.36127 to 0.36123, saving model to weights.best.hdf5
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss improved from 0.36123 to 0.36061, saving model to weights.best.hdf5
# Epoch 00427: val_loss improved from 0.36061 to 0.35955, saving model to weights.best.hdf5
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss improved from 0.35955 to 0.35949, saving model to weights.best.hdf5
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss improved from 0.35949 to 0.35876, saving model to weights.best.hdf5
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss improved from 0.35876 to 0.35870, saving model to weights.best.hdf5
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss improved from 0.35870 to 0.35870, saving model to weights.best.hdf5
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve
# Epoch 00500: val_loss improved from 0.35870 to 0.35856, saving model to weights.best.hdf5
# Epoch 00501: val_loss improved from 0.35856 to 0.35722, saving model to weights.best.hdf5
# Epoch 00502: val_loss did not improve
# Epoch 00503: val_loss did not improve
# Epoch 00504: val_loss did not improve
# Epoch 00505: val_loss did not improve
# Epoch 00506: val_loss did not improve
# Epoch 00507: val_loss did not improve
# Epoch 00508: val_loss did not improve
# Epoch 00509: val_loss did not improve
# Epoch 00510: val_loss did not improve
# Epoch 00511: val_loss did not improve
# Epoch 00512: val_loss did not improve
# Epoch 00513: val_loss did not improve
# Epoch 00514: val_loss did not improve
# Epoch 00515: val_loss improved from 0.35722 to 0.35645, saving model to weights.best.hdf5
# Epoch 00516: val_loss did not improve
# Epoch 00517: val_loss did not improve
# Epoch 00518: val_loss did not improve
# Epoch 00519: val_loss did not improve
# Epoch 00520: val_loss did not improve
# Epoch 00521: val_loss did not improve
# Epoch 00522: val_loss did not improve
# Epoch 00523: val_loss did not improve
# Epoch 00524: val_loss did not improve
# Epoch 00525: val_loss did not improve
# Epoch 00526: val_loss did not improve
# Epoch 00527: val_loss did not improve
# Epoch 00528: val_loss did not improve
# Epoch 00529: val_loss did not improve
# Epoch 00530: val_loss did not improve
# Epoch 00531: val_loss did not improve
# Epoch 00532: val_loss did not improve
# Epoch 00533: val_loss did not improve
# Epoch 00534: val_loss did not improve
# Epoch 00535: val_loss did not improve
# Epoch 00536: val_loss improved from 0.35645 to 0.35573, saving model to weights.best.hdf5
# Epoch 00537: val_loss did not improve
# Epoch 00538: val_loss did not improve
# Epoch 00539: val_loss did not improve
# Epoch 00540: val_loss did not improve
# Epoch 00541: val_loss did not improve
# Epoch 00542: val_loss did not improve
# Epoch 00543: val_loss did not improve
# Epoch 00544: val_loss did not improve
# Epoch 00545: val_loss did not improve
# Epoch 00546: val_loss did not improve
# Epoch 00547: val_loss did not improve
# Epoch 00548: val_loss did not improve
# Epoch 00549: val_loss did not improve
# Epoch 00550: val_loss did not improve
# Epoch 00551: val_loss did not improve
# Epoch 00552: val_loss did not improve
# Epoch 00553: val_loss did not improve
# Epoch 00554: val_loss did not improve
# Epoch 00555: val_loss did not improve
# Epoch 00556: val_loss did not improve
# Epoch 00557: val_loss did not improve
# Epoch 00558: val_loss did not improve
# Epoch 00559: val_loss did not improve
# Epoch 00560: val_loss did not improve
# Epoch 00561: val_loss did not improve
# Epoch 00562: val_loss did not improve
# Epoch 00563: val_loss did not improve
# Epoch 00564: val_loss did not improve
# Epoch 00565: val_loss improved from 0.35573 to 0.35403, saving model to weights.best.hdf5
# Epoch 00566: val_loss did not improve
# Epoch 00567: val_loss did not improve
# Epoch 00568: val_loss did not improve
# Epoch 00569: val_loss did not improve
# Epoch 00570: val_loss did not improve
# Epoch 00571: val_loss did not improve
# Epoch 00572: val_loss did not improve
# Epoch 00573: val_loss did not improve
# Epoch 00574: val_loss did not improve
# Epoch 00575: val_loss did not improve
# Epoch 00576: val_loss did not improve
# Epoch 00577: val_loss did not improve
# Epoch 00578: val_loss did not improve
# Epoch 00579: val_loss did not improve
# Epoch 00580: val_loss did not improve
# Epoch 00581: val_loss did not improve
# Epoch 00582: val_loss did not improve
# Epoch 00583: val_loss did not improve
# Epoch 00584: val_loss did not improve
# Epoch 00585: val_loss did not improve
# Epoch 00586: val_loss did not improve
# Epoch 00587: val_loss did not improve
# Epoch 00588: val_loss did not improve
# Epoch 00589: val_loss improved from 0.35403 to 0.35386, saving model to weights.best.hdf5
# Epoch 00590: val_loss did not improve
# Epoch 00591: val_loss did not improve
# Epoch 00592: val_loss improved from 0.35386 to 0.35382, saving model to weights.best.hdf5
# Epoch 00593: val_loss did not improve
# Epoch 00594: val_loss did not improve
# Epoch 00595: val_loss did not improve
# Epoch 00596: val_loss did not improve
# Epoch 00597: val_loss did not improve
# Epoch 00598: val_loss did not improve
# Epoch 00599: val_loss did not improve
# Epoch 00600: val_loss did not improve
# Epoch 00601: val_loss improved from 0.35382 to 0.35292, saving model to weights.best.hdf5
# Epoch 00602: val_loss improved from 0.35292 to 0.35258, saving model to weights.best.hdf5
# Epoch 00603: val_loss did not improve
# Epoch 00604: val_loss did not improve
# Epoch 00605: val_loss did not improve
# Epoch 00606: val_loss did not improve
# Epoch 00607: val_loss did not improve
# Epoch 00608: val_loss improved from 0.35258 to 0.35188, saving model to weights.best.hdf5
# Epoch 00609: val_loss did not improve
# Epoch 00610: val_loss did not improve
# Epoch 00611: val_loss did not improve
# Epoch 00612: val_loss did not improve
# Epoch 00613: val_loss did not improve
# Epoch 00614: val_loss did not improve
# Epoch 00615: val_loss did not improve
# Epoch 00616: val_loss did not improve
# Epoch 00617: val_loss did not improve
# Epoch 00618: val_loss did not improve
# Epoch 00619: val_loss did not improve
# Epoch 00620: val_loss did not improve
# Epoch 00621: val_loss did not improve
# Epoch 00622: val_loss did not improve
# Epoch 00623: val_loss did not improve
# Epoch 00624: val_loss did not improve
# Epoch 00625: val_loss did not improve
# Epoch 00626: val_loss did not improve
# Epoch 00627: val_loss did not improve
# Epoch 00628: val_loss did not improve
# Epoch 00629: val_loss did not improve
# Epoch 00630: val_loss did not improve
# Epoch 00631: val_loss did not improve
# Epoch 00632: val_loss did not improve
# Epoch 00633: val_loss improved from 0.35188 to 0.35160, saving model to weights.best.hdf5
# Epoch 00634: val_loss did not improve
# Epoch 00635: val_loss did not improve
# Epoch 00636: val_loss did not improve
# Epoch 00637: val_loss did not improve
# Epoch 00638: val_loss did not improve
# Epoch 00639: val_loss did not improve
# Epoch 00640: val_loss improved from 0.35160 to 0.35145, saving model to weights.best.hdf5
# Epoch 00641: val_loss did not improve
# Epoch 00642: val_loss did not improve
# Epoch 00643: val_loss did not improve
# Epoch 00644: val_loss did not improve
# Epoch 00645: val_loss did not improve
# Epoch 00646: val_loss did not improve
# Epoch 00647: val_loss did not improve
# Epoch 00648: val_loss did not improve
# Epoch 00649: val_loss did not improve
# Epoch 00650: val_loss did not improve
# Epoch 00651: val_loss did not improve
# Epoch 00652: val_loss did not improve
# Epoch 00653: val_loss did not improve
# Epoch 00654: val_loss did not improve
# Epoch 00655: val_loss did not improve
# Epoch 00656: val_loss did not improve
# Epoch 00657: val_loss did not improve
# Epoch 00658: val_loss did not improve
# Epoch 00659: val_loss did not improve
# Epoch 00660: val_loss did not improve
# Epoch 00661: val_loss did not improve
# Epoch 00662: val_loss did not improve
# Epoch 00663: val_loss did not improve
# Epoch 00664: val_loss did not improve
# Epoch 00665: val_loss did not improve
# Epoch 00666: val_loss did not improve
# Epoch 00667: val_loss did not improve
# Epoch 00668: val_loss did not improve
# Epoch 00669: val_loss improved from 0.35145 to 0.35116, saving model to weights.best.hdf5
# Epoch 00670: val_loss improved from 0.35116 to 0.34999, saving model to weights.best.hdf5
# Epoch 00671: val_loss did not improve
# Epoch 00672: val_loss did not improve
# Epoch 00673: val_loss did not improve
# Epoch 00674: val_loss did not improve
# Epoch 00675: val_loss did not improve
# Epoch 00676: val_loss did not improve
# Epoch 00677: val_loss did not improve
# Epoch 00678: val_loss did not improve
# Epoch 00679: val_loss did not improve
# Epoch 00680: val_loss did not improve
# Epoch 00681: val_loss did not improve
# Epoch 00682: val_loss did not improve
# Epoch 00683: val_loss did not improve
# Epoch 00684: val_loss did not improve
# Epoch 00685: val_loss did not improve
# Epoch 00686: val_loss did not improve
# Epoch 00687: val_loss did not improve
# Epoch 00688: val_loss did not improve
# Epoch 00689: val_loss did not improve
# Epoch 00690: val_loss did not improve
# Epoch 00691: val_loss did not improve
# Epoch 00692: val_loss did not improve
# Epoch 00693: val_loss did not improve
# Epoch 00694: val_loss did not improve
# Epoch 00695: val_loss did not improve
# Epoch 00696: val_loss did not improve
# Epoch 00697: val_loss did not improve
# Epoch 00698: val_loss did not improve
# Epoch 00699: val_loss did not improve
# Epoch 00700: val_loss did not improve
# Epoch 00701: val_loss did not improve
# Epoch 00702: val_loss did not improve
# Epoch 00703: val_loss did not improve
# Epoch 00704: val_loss did not improve
# Epoch 00705: val_loss did not improve
# Epoch 00706: val_loss did not improve
# Epoch 00707: val_loss improved from 0.34999 to 0.34921, saving model to weights.best.hdf5
# Epoch 00708: val_loss did not improve
# Epoch 00709: val_loss did not improve
# Epoch 00710: val_loss did not improve
# Epoch 00711: val_loss did not improve
# Epoch 00712: val_loss did not improve
# Epoch 00713: val_loss did not improve
# Epoch 00714: val_loss did not improve
# Epoch 00715: val_loss did not improve
# Epoch 00716: val_loss did not improve
# Epoch 00717: val_loss did not improve
# Epoch 00718: val_loss did not improve
# Epoch 00719: val_loss did not improve
# Epoch 00720: val_loss did not improve
# Epoch 00721: val_loss did not improve
# Epoch 00722: val_loss did not improve
# Epoch 00723: val_loss did not improve
# Epoch 00724: val_loss did not improve
# Epoch 00725: val_loss did not improve
# Epoch 00726: val_loss did not improve
# Epoch 00727: val_loss did not improve
# Epoch 00728: val_loss did not improve
# Epoch 00729: val_loss improved from 0.34921 to 0.34861, saving model to weights.best.hdf5
# Epoch 00730: val_loss improved from 0.34861 to 0.34772, saving model to weights.best.hdf5
# Epoch 00731: val_loss did not improve
# Epoch 00732: val_loss did not improve
# Epoch 00733: val_loss did not improve
# Epoch 00734: val_loss did not improve
# Epoch 00735: val_loss did not improve
# Epoch 00736: val_loss did not improve
# Epoch 00737: val_loss did not improve
# Epoch 00738: val_loss did not improve
# Epoch 00739: val_loss did not improve
# Epoch 00740: val_loss did not improve
# Epoch 00741: val_loss did not improve
# Epoch 00742: val_loss did not improve
# Epoch 00743: val_loss did not improve
# Epoch 00744: val_loss did not improve
# Epoch 00745: val_loss did not improve
# Epoch 00746: val_loss did not improve
# Epoch 00747: val_loss improved from 0.34772 to 0.34664, saving model to weights.best.hdf5
# Epoch 00748: val_loss did not improve
# Epoch 00749: val_loss did not improve
# Epoch 00750: val_loss did not improve
# Epoch 00751: val_loss did not improve
# Epoch 00752: val_loss did not improve
# Epoch 00753: val_loss did not improve
# Epoch 00754: val_loss did not improve
# Epoch 00755: val_loss did not improve
# Epoch 00756: val_loss did not improve
# Epoch 00757: val_loss did not improve
# Epoch 00758: val_loss did not improve
# Epoch 00759: val_loss did not improve
# Epoch 00760: val_loss did not improve
# Epoch 00761: val_loss did not improve
# Epoch 00762: val_loss did not improve
# Epoch 00763: val_loss did not improve
# Epoch 00764: val_loss did not improve
# Epoch 00765: val_loss did not improve
# Epoch 00766: val_loss did not improve
# Epoch 00767: val_loss did not improve
# Epoch 00768: val_loss did not improve
# Epoch 00769: val_loss did not improve
# Epoch 00770: val_loss did not improve
# Epoch 00771: val_loss did not improve
# Epoch 00772: val_loss did not improve
# Epoch 00773: val_loss did not improve
# Epoch 00774: val_loss did not improve
# Epoch 00775: val_loss did not improve
# Epoch 00776: val_loss did not improve
# Epoch 00777: val_loss did not improve
# Epoch 00778: val_loss did not improve
# Epoch 00779: val_loss did not improve
# Epoch 00780: val_loss did not improve
# Epoch 00781: val_loss did not improve
# Epoch 00782: val_loss did not improve
# Epoch 00783: val_loss did not improve
# Epoch 00784: val_loss did not improve
# Epoch 00785: val_loss did not improve
# Epoch 00786: val_loss did not improve
# Epoch 00787: val_loss did not improve
# Epoch 00788: val_loss did not improve
# Epoch 00789: val_loss did not improve
# Epoch 00790: val_loss did not improve
# Epoch 00791: val_loss did not improve
# Epoch 00792: val_loss did not improve
# Epoch 00793: val_loss did not improve
# Epoch 00794: val_loss improved from 0.34664 to 0.34550, saving model to weights.best.hdf5
# Epoch 00795: val_loss did not improve
# Epoch 00796: val_loss did not improve
# Epoch 00797: val_loss did not improve
# Epoch 00798: val_loss did not improve
# Epoch 00799: val_loss did not improve
# Epoch 00800: val_loss improved from 0.34550 to 0.34504, saving model to weights.best.hdf5
# Epoch 00801: val_loss did not improve
# Epoch 00802: val_loss did not improve
# Epoch 00803: val_loss did not improve
# Epoch 00804: val_loss did not improve
# Epoch 00805: val_loss did not improve
# Epoch 00806: val_loss did not improve
# Epoch 00807: val_loss did not improve
# Epoch 00808: val_loss did not improve
# Epoch 00809: val_loss did not improve
# Epoch 00810: val_loss did not improve
# Epoch 00811: val_loss did not improve
# Epoch 00812: val_loss did not improve
# Epoch 00813: val_loss did not improve
# Epoch 00814: val_loss did not improve
# Epoch 00815: val_loss did not improve
# Epoch 00816: val_loss did not improve
# Epoch 00817: val_loss did not improve
# Epoch 00818: val_loss did not improve
# Epoch 00819: val_loss did not improve
# Epoch 00820: val_loss did not improve
# Epoch 00821: val_loss did not improve
# Epoch 00822: val_loss did not improve
# Epoch 00823: val_loss did not improve
# Epoch 00824: val_loss did not improve
# Epoch 00825: val_loss did not improve
# Epoch 00826: val_loss did not improve
# Epoch 00827: val_loss did not improve
# Epoch 00828: val_loss did not improve
# Epoch 00829: val_loss did not improve
# Epoch 00830: val_loss did not improve
# Epoch 00831: val_loss did not improve
# Epoch 00832: val_loss did not improve
# Epoch 00833: val_loss did not improve
# Epoch 00834: val_loss did not improve
# Epoch 00835: val_loss did not improve
# Epoch 00836: val_loss did not improve
# Epoch 00837: val_loss did not improve
# Epoch 00838: val_loss did not improve
# Epoch 00839: val_loss did not improve
# Epoch 00840: val_loss did not improve
# Epoch 00841: val_loss did not improve
# Epoch 00842: val_loss improved from 0.34504 to 0.34477, saving model to weights.best.hdf5
# Epoch 00843: val_loss did not improve
# Epoch 00844: val_loss did not improve
# Epoch 00845: val_loss did not improve
# Epoch 00846: val_loss did not improve
# Epoch 00847: val_loss did not improve
# Epoch 00848: val_loss did not improve
# Epoch 00849: val_loss did not improve
# Epoch 00850: val_loss did not improve
# Epoch 00851: val_loss did not improve
# Epoch 00852: val_loss did not improve
# Epoch 00853: val_loss did not improve
# Epoch 00854: val_loss did not improve
# Epoch 00855: val_loss did not improve
# Epoch 00856: val_loss did not improve
# Epoch 00857: val_loss did not improve
# Epoch 00858: val_loss did not improve
# Epoch 00859: val_loss did not improve
# Epoch 00860: val_loss did not improve
# Epoch 00861: val_loss did not improve
# Epoch 00862: val_loss did not improve
# Epoch 00863: val_loss did not improve
# Epoch 00864: val_loss did not improve
# Epoch 00865: val_loss did not improve
# Epoch 00866: val_loss did not improve
# Epoch 00867: val_loss did not improve
# Epoch 00868: val_loss did not improve
# Epoch 00869: val_loss did not improve
# Epoch 00870: val_loss did not improve
# Epoch 00871: val_loss did not improve
# Epoch 00872: val_loss did not improve
# Epoch 00873: val_loss did not improve
# Epoch 00874: val_loss did not improve
# Epoch 00875: val_loss did not improve
# Epoch 00876: val_loss did not improve
# Epoch 00877: val_loss did not improve
# Epoch 00878: val_loss improved from 0.34477 to 0.34434, saving model to weights.best.hdf5
# Epoch 00879: val_loss did not improve
# Epoch 00880: val_loss did not improve
# Epoch 00881: val_loss did not improve
# Epoch 00882: val_loss did not improve
# Epoch 00883: val_loss did not improve
# Epoch 00884: val_loss did not improve
# ...
# Epoch 02581: val_loss did not improve
# Epoch 02582: val_loss did not improve
# Epoch 02583: val_loss did not improve
# Epoch 02584: val_loss did not improve
# Epoch 02585: val_loss did not improve
# Epoch 02586: val_loss did not improve
# Epoch 02587: val_loss did not improve
# Epoch 02588: val_loss did not improve
# Epoch 02589: val_loss did not improve
# Epoch 02590: val_loss did not improve
# Epoch 02591: val_loss did not improve
# Epoch 02592: val_loss did not improve
# Epoch 02593: val_loss did not improve
# Epoch 02594: val_loss did not improve
# Epoch 02595: val_loss did not improve
# Epoch 02596: val_loss did not improve
# Epoch 02597: val_loss did not improve
# Epoch 02598: val_loss did not improve
# Epoch 02599: val_loss did not improve
# Epoch 02600: val_loss did not improve
# Epoch 02601: val_loss did not improve
# Epoch 02602: val_loss did not improve
# Epoch 02603: val_loss did not improve
# Epoch 02604: val_loss did not improve
# Epoch 02605: val_loss did not improve
# Epoch 02606: val_loss did not improve
# Epoch 02607: val_loss did not improve
# Epoch 02608: val_loss did not improve
# Epoch 02609: val_loss did not improve
# Epoch 02610: val_loss did not improve
# Epoch 02611: val_loss did not improve
# Epoch 02612: val_loss did not improve
# Epoch 02613: val_loss did not improve
# Epoch 02614: val_loss did not improve
# Epoch 02615: val_loss did not improve
# Epoch 02616: val_loss did not improve
# Epoch 02617: val_loss did not improve
# Epoch 02618: val_loss did not improve
# Epoch 02619: val_loss did not improve
# Epoch 02620: val_loss did not improve
# Epoch 02621: val_loss did not improve
# Epoch 02622: val_loss did not improve
# Epoch 02623: val_loss did not improve
# Epoch 02624: val_loss did not improve
# Epoch 02625: val_loss did not improve
# Epoch 02626: val_loss did not improve
# Epoch 02627: val_loss did not improve
# Epoch 02628: val_loss did not improve
# Epoch 02629: val_loss did not improve
# Epoch 02630: val_loss did not improve
# Epoch 02631: val_loss did not improve
# Epoch 02632: val_loss did not improve
# Epoch 02633: val_loss did not improve
# Epoch 02634: val_loss did not improve
# Epoch 02635: val_loss did not improve
# Epoch 02636: val_loss did not improve
# Epoch 02637: val_loss did not improve
# Epoch 02638: val_loss did not improve
# Epoch 02639: val_loss did not improve
# Epoch 02640: val_loss did not improve
# Epoch 02641: val_loss did not improve
# Epoch 02642: val_loss did not improve
# Epoch 02643: val_loss did not improve
# Epoch 02644: val_loss did not improve
# Epoch 02645: val_loss did not improve
# Epoch 02646: val_loss did not improve
# Epoch 02647: val_loss did not improve
# Epoch 02648: val_loss did not improve
# Epoch 02649: val_loss did not improve
# Epoch 02650: val_loss did not improve
# Epoch 02651: val_loss did not improve
# Epoch 02652: val_loss did not improve
# Epoch 02653: val_loss did not improve
# Epoch 02654: val_loss did not improve
# Epoch 02655: val_loss did not improve
# Epoch 02656: val_loss did not improve
# Epoch 02657: val_loss did not improve
# Epoch 02658: val_loss did not improve
# Epoch 02659: val_loss did not improve
# Epoch 02660: val_loss did not improve
# Epoch 02661: val_loss did not improve
# Epoch 02662: val_loss did not improve
# Epoch 02663: val_loss did not improve
# Epoch 02664: val_loss did not improve
# Epoch 02665: val_loss did not improve
# Epoch 02666: val_loss did not improve
# Epoch 02667: val_loss did not improve
# Epoch 02668: val_loss did not improve
# Epoch 02669: val_loss did not improve
# Epoch 02670: val_loss did not improve
# Epoch 02671: val_loss did not improve
# Epoch 02672: val_loss did not improve
# Epoch 02673: val_loss did not improve
# Epoch 02674: val_loss did not improve
# Epoch 02675: val_loss did not improve
# Epoch 02676: val_loss did not improve
# Epoch 02677: val_loss did not improve
# Epoch 02678: val_loss did not improve
# Epoch 02679: val_loss did not improve
# Epoch 02680: val_loss did not improve
# Epoch 02681: val_loss did not improve
# Epoch 02682: val_loss did not improve
# Epoch 02683: val_loss did not improve
# Epoch 02684: val_loss did not improve
# Epoch 02685: val_loss did not improve
# Epoch 02686: val_loss did not improve
# Epoch 02687: val_loss did not improve
# Epoch 02688: val_loss did not improve
# Epoch 02689: val_loss did not improve
# Epoch 02690: val_loss did not improve
# Epoch 02691: val_loss did not improve
# Epoch 02692: val_loss did not improve
# Epoch 02693: val_loss did not improve
# Epoch 02694: val_loss did not improve
# Epoch 02695: val_loss did not improve
# Epoch 02696: val_loss did not improve
# Epoch 02697: val_loss did not improve
# Epoch 02698: val_loss did not improve
# Epoch 02699: val_loss did not improve
# Epoch 02700: val_loss did not improve
# Epoch 02701: val_loss did not improve
# Epoch 02702: val_loss did not improve
# Epoch 02703: val_loss did not improve
# Epoch 02704: val_loss did not improve
# Epoch 02705: val_loss did not improve
# Epoch 02706: val_loss did not improve
# Epoch 02707: val_loss did not improve
# Epoch 02708: val_loss did not improve
# Epoch 02709: val_loss did not improve
# Epoch 02710: val_loss did not improve
# Epoch 02711: val_loss did not improve
# Epoch 02712: val_loss did not improve
# Epoch 02713: val_loss did not improve
# Epoch 02714: val_loss did not improve
# Epoch 02715: val_loss did not improve
# Epoch 02716: val_loss did not improve
# Epoch 02717: val_loss did not improve
# Epoch 02718: val_loss did not improve
# Epoch 02719: val_loss did not improve
# Epoch 02720: val_loss did not improve
# Epoch 02721: val_loss did not improve
# Epoch 02722: val_loss did not improve
# Epoch 02723: val_loss did not improve
# Epoch 02724: val_loss did not improve
# Epoch 02725: val_loss did not improve
# Epoch 02726: val_loss did not improve
# Epoch 02727: val_loss did not improve
# Epoch 02728: val_loss did not improve
# Epoch 02729: val_loss did not improve
# Epoch 02730: val_loss did not improve
# Epoch 02731: val_loss did not improve
# Epoch 02732: val_loss did not improve
# Epoch 02733: val_loss did not improve
# Epoch 02734: val_loss did not improve
# Epoch 02735: val_loss did not improve
# Epoch 02736: val_loss did not improve
# Epoch 02737: val_loss did not improve
# Epoch 02738: val_loss did not improve
# Epoch 02739: val_loss did not improve
# Epoch 02740: val_loss did not improve
# Epoch 02741: val_loss did not improve
# Epoch 02742: val_loss did not improve
# Epoch 02743: val_loss did not improve
# Epoch 02744: val_loss did not improve
# Epoch 02745: val_loss did not improve
# Epoch 02746: val_loss did not improve
# Epoch 02747: val_loss did not improve
# Epoch 02748: val_loss did not improve
# Epoch 02749: val_loss did not improve
# Epoch 02750: val_loss did not improve
# Epoch 02751: val_loss did not improve
# Epoch 02752: val_loss did not improve
# Epoch 02753: val_loss did not improve
# Epoch 02754: val_loss did not improve
# Epoch 02755: val_loss did not improve
# Epoch 02756: val_loss did not improve
# Epoch 02757: val_loss did not improve
# Epoch 02758: val_loss did not improve
# Epoch 02759: val_loss did not improve
# Epoch 02760: val_loss did not improve
# Epoch 02761: val_loss did not improve
# Epoch 02762: val_loss did not improve
# Epoch 02763: val_loss did not improve
# Epoch 02764: val_loss did not improve
# Epoch 02765: val_loss did not improve
# Epoch 02766: val_loss did not improve
# Epoch 02767: val_loss did not improve
# Epoch 02768: val_loss did not improve
# Epoch 02769: val_loss did not improve
# Epoch 02770: val_loss did not improve
# Epoch 02771: val_loss did not improve
# Epoch 02772: val_loss did not improve
# Epoch 02773: val_loss did not improve
# Epoch 02774: val_loss did not improve
# Epoch 02775: val_loss did not improve
# Epoch 02776: val_loss did not improve
# Epoch 02777: val_loss did not improve
# Epoch 02778: val_loss did not improve
# Epoch 02779: val_loss did not improve
# Epoch 02780: val_loss did not improve
# Epoch 02781: val_loss did not improve
# Epoch 02782: val_loss did not improve
# Epoch 02783: val_loss did not improve
# Epoch 02784: val_loss did not improve
# Epoch 02785: val_loss did not improve
# Epoch 02786: val_loss did not improve
# Epoch 02787: val_loss did not improve
# Epoch 02788: val_loss did not improve
# Epoch 02789: val_loss did not improve
# Epoch 02790: val_loss did not improve
# Epoch 02791: val_loss did not improve
# Epoch 02792: val_loss did not improve
# Epoch 02793: val_loss did not improve
# Epoch 02794: val_loss did not improve
# Epoch 02795: val_loss did not improve
# Epoch 02796: val_loss did not improve
# Epoch 02797: val_loss did not improve
# Epoch 02798: val_loss did not improve
# Epoch 02799: val_loss did not improve
# Epoch 02800: val_loss did not improve
# Epoch 02801: val_loss did not improve
# Epoch 02802: val_loss did not improve
# Epoch 02803: val_loss did not improve
# Epoch 02804: val_loss did not improve
# Epoch 02805: val_loss did not improve
# Epoch 02806: val_loss did not improve
# Epoch 02807: val_loss did not improve
# Epoch 02808: val_loss did not improve
# Epoch 02809: val_loss did not improve
# Epoch 02810: val_loss did not improve
# Epoch 02811: val_loss did not improve
# Epoch 02812: val_loss did not improve
# Epoch 02813: val_loss did not improve
# Epoch 02814: val_loss did not improve
# Epoch 02815: val_loss did not improve
# Epoch 02816: val_loss did not improve
# Epoch 02817: val_loss did not improve
# Epoch 02818: val_loss did not improve
# Epoch 02819: val_loss did not improve
# Epoch 02820: val_loss did not improve
# Epoch 02821: val_loss did not improve
# Epoch 02822: val_loss did not improve
# Epoch 02823: val_loss did not improve
# Epoch 02824: val_loss did not improve
# Epoch 02825: val_loss did not improve
# Epoch 02826: val_loss did not improve
# Epoch 02827: val_loss did not improve
# Epoch 02828: val_loss did not improve
# Epoch 02829: val_loss did not improve
# Epoch 02830: val_loss did not improve
# Epoch 02831: val_loss did not improve
# Epoch 02832: val_loss did not improve
# Epoch 02833: val_loss did not improve
# Epoch 02834: val_loss did not improve
# Epoch 02835: val_loss did not improve
# Epoch 02836: val_loss did not improve
# Epoch 02837: val_loss did not improve
# Epoch 02838: val_loss did not improve
# Epoch 02839: val_loss did not improve
# Epoch 02840: val_loss did not improve
# Epoch 02841: val_loss did not improve
# Epoch 02842: val_loss did not improve
# Epoch 02843: val_loss did not improve
# Epoch 02844: val_loss did not improve
# Epoch 02845: val_loss did not improve
# Epoch 02846: val_loss did not improve
# Epoch 02847: val_loss did not improve
# Epoch 02848: val_loss did not improve
# Epoch 02849: val_loss did not improve
# Epoch 02850: val_loss did not improve
# Epoch 02851: val_loss did not improve
# Epoch 02852: val_loss did not improve
# Epoch 02853: val_loss did not improve
# Epoch 02854: val_loss did not improve
# Epoch 02855: val_loss did not improve
# Epoch 02856: val_loss did not improve
# Epoch 02857: val_loss did not improve
# Epoch 02858: val_loss did not improve
# Epoch 02859: val_loss did not improve
# Epoch 02860: val_loss did not improve
# Epoch 02861: val_loss did not improve
# Epoch 02862: val_loss did not improve
# Epoch 02863: val_loss did not improve
# Epoch 02864: val_loss did not improve
# Epoch 02865: val_loss improved from 0.32797 to 0.32766, saving model to weights.best.hdf5
# Epoch 02866: val_loss did not improve
# Epoch 02867: val_loss did not improve
# Epoch 02868: val_loss did not improve
# Epoch 02869: val_loss did not improve
# Epoch 02870: val_loss did not improve
# Epoch 02871: val_loss did not improve
# Epoch 02872: val_loss did not improve
# Epoch 02873: val_loss did not improve
# Epoch 02874: val_loss did not improve
# Epoch 02875: val_loss did not improve
# Epoch 02876: val_loss did not improve
# Epoch 02877: val_loss did not improve
# Epoch 02878: val_loss did not improve
# Epoch 02879: val_loss did not improve
# Epoch 02880: val_loss did not improve
# Epoch 02881: val_loss did not improve
# Epoch 02882: val_loss did not improve
# Epoch 02883: val_loss did not improve
# Epoch 02884: val_loss did not improve
# Epoch 02885: val_loss did not improve
# Epoch 02886: val_loss did not improve
# Epoch 02887: val_loss did not improve
# Epoch 02888: val_loss did not improve
# Epoch 02889: val_loss did not improve
# Epoch 02890: val_loss did not improve
# Epoch 02891: val_loss did not improve
# Epoch 02892: val_loss did not improve
# Epoch 02893: val_loss did not improve
# Epoch 02894: val_loss did not improve
# Epoch 02895: val_loss did not improve
# Epoch 02896: val_loss did not improve
# Epoch 02897: val_loss did not improve
# Epoch 02898: val_loss did not improve
# Epoch 02899: val_loss did not improve
# Epoch 02900: val_loss did not improve
# Epoch 02901: val_loss did not improve
# Epoch 02902: val_loss did not improve
# Epoch 02903: val_loss did not improve
# Epoch 02904: val_loss did not improve
# Epoch 02905: val_loss did not improve
# Epoch 02906: val_loss did not improve
# Epoch 02907: val_loss did not improve
# Epoch 02908: val_loss did not improve
# Epoch 02909: val_loss did not improve
# Epoch 02910: val_loss did not improve
# Epoch 02911: val_loss did not improve
# Epoch 02912: val_loss did not improve
# Epoch 02913: val_loss did not improve
# Epoch 02914: val_loss did not improve
# Epoch 02915: val_loss did not improve
# Epoch 02916: val_loss did not improve
# Epoch 02917: val_loss did not improve
# Epoch 02918: val_loss did not improve
# Epoch 02919: val_loss did not improve
# Epoch 02920: val_loss did not improve
# Epoch 02921: val_loss did not improve
# Epoch 02922: val_loss did not improve
# Epoch 02923: val_loss did not improve
# Epoch 02924: val_loss did not improve
# Epoch 02925: val_loss did not improve
# Epoch 02926: val_loss did not improve
# Epoch 02927: val_loss did not improve
# Epoch 02928: val_loss did not improve
# Epoch 02929: val_loss did not improve
# Epoch 02930: val_loss did not improve
# Epoch 02931: val_loss did not improve
# Epoch 02932: val_loss did not improve
# Epoch 02933: val_loss did not improve
# Epoch 02934: val_loss did not improve
# Epoch 02935: val_loss did not improve
# Epoch 02936: val_loss did not improve
# Epoch 02937: val_loss did not improve
# Epoch 02938: val_loss did not improve
# Epoch 02939: val_loss did not improve
# Epoch 02940: val_loss did not improve
# Epoch 02941: val_loss did not improve
# Epoch 02942: val_loss did not improve
# Epoch 02943: val_loss did not improve
# Epoch 02944: val_loss did not improve
# Epoch 02945: val_loss did not improve
# Epoch 02946: val_loss did not improve
# Epoch 02947: val_loss did not improve
# Epoch 02948: val_loss did not improve
# Epoch 02949: val_loss did not improve
# Epoch 02950: val_loss did not improve
# Epoch 02951: val_loss did not improve
# Epoch 02952: val_loss did not improve
# Epoch 02953: val_loss did not improve
# Epoch 02954: val_loss did not improve
# Epoch 02955: val_loss did not improve
# Epoch 02956: val_loss did not improve
# Epoch 02957: val_loss did not improve
# Epoch 02958: val_loss did not improve
# Epoch 02959: val_loss did not improve
# Epoch 02960: val_loss did not improve
# Epoch 02961: val_loss did not improve
# Epoch 02962: val_loss did not improve
# Epoch 02963: val_loss did not improve
# Epoch 02964: val_loss did not improve
# Epoch 02965: val_loss did not improve
# Epoch 02966: val_loss did not improve
# Epoch 02967: val_loss did not improve
# Epoch 02968: val_loss did not improve
# Epoch 02969: val_loss did not improve
# Epoch 02970: val_loss did not improve
# Epoch 02971: val_loss did not improve
# Epoch 02972: val_loss did not improve
# Epoch 02973: val_loss did not improve
# Epoch 02974: val_loss did not improve
# Epoch 02975: val_loss did not improve
# Epoch 02976: val_loss did not improve
# Epoch 02977: val_loss did not improve
# Epoch 02978: val_loss did not improve
# Epoch 02979: val_loss did not improve
# Epoch 02980: val_loss did not improve
# Epoch 02981: val_loss did not improve
# Epoch 02982: val_loss did not improve
# Epoch 02983: val_loss did not improve
# Epoch 02984: val_loss did not improve
# Epoch 02985: val_loss did not improve
# Epoch 02986: val_loss did not improve
# Epoch 02987: val_loss did not improve
# Epoch 02988: val_loss did not improve
# Epoch 02989: val_loss did not improve
# Epoch 02990: val_loss did not improve
# Epoch 02991: val_loss did not improve
# Epoch 02992: val_loss did not improve
# Epoch 02993: val_loss did not improve
# Epoch 02994: val_loss did not improve
# Epoch 02995: val_loss did not improve
# Epoch 02996: val_loss did not improve
# Epoch 02997: val_loss did not improve
# Epoch 02998: val_loss did not improve
# Epoch 02999: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   3000
# Best loss at iteratation:     2434    Best: 0.188080946356
# Best val_loss at iteratation: 2865    Best: 0.327663362026

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  115.834
# RMSE: 160.279
# R2:   0.510

# %% [markdown]
# ## LSTM with events information (no text)

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    feat = BatchNormalization()(feat)
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.5))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
#print model_weather.summary()
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=1000,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_1/concat:0", shape=(?, 21), dtype=float32)
# Epoch 00000: val_loss improved from inf to 2.41285, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 2.41285 to 2.31899, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 2.31899 to 2.22296, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 2.22296 to 2.13099, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 2.13099 to 2.03163, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 2.03163 to 1.94402, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 1.94402 to 1.85700, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 1.85700 to 1.77226, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 1.77226 to 1.68625, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 1.68625 to 1.61361, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 1.61361 to 1.53867, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 1.53867 to 1.46393, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 1.46393 to 1.39357, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 1.39357 to 1.32553, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 1.32553 to 1.26070, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 1.26070 to 1.20076, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 1.20076 to 1.14495, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 1.14495 to 1.09621, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.09621 to 1.04769, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.04769 to 1.00324, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.00324 to 0.96090, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.96090 to 0.92246, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.92246 to 0.88525, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.88525 to 0.84954, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.84954 to 0.81654, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.81654 to 0.78475, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.78475 to 0.75567, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.75567 to 0.72730, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.72730 to 0.70261, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.70261 to 0.67757, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.67757 to 0.65475, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.65475 to 0.63436, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.63436 to 0.61471, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.61471 to 0.59575, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.59575 to 0.57886, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 0.57886 to 0.56121, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.56121 to 0.54378, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 0.54378 to 0.52940, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 0.52940 to 0.51433, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.51433 to 0.49999, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 0.49999 to 0.48633, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 0.48633 to 0.47502, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.47502 to 0.46394, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.46394 to 0.45260, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.45260 to 0.44213, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.44213 to 0.43271, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.43271 to 0.42444, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 0.42444 to 0.41552, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 0.41552 to 0.40719, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 0.40719 to 0.39913, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 0.39913 to 0.39131, saving model to weights.best.hdf5
# Epoch 00051: val_loss improved from 0.39131 to 0.38496, saving model to weights.best.hdf5
# Epoch 00052: val_loss improved from 0.38496 to 0.37821, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.37821 to 0.37279, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 0.37279 to 0.36625, saving model to weights.best.hdf5
# Epoch 00055: val_loss improved from 0.36625 to 0.36063, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.36063 to 0.35507, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.35507 to 0.34979, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.34979 to 0.34582, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.34582 to 0.34186, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.34186 to 0.33803, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.33803 to 0.33388, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.33388 to 0.33038, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.33038 to 0.32711, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.32711 to 0.32355, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.32355 to 0.31976, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 0.31976 to 0.31673, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.31673 to 0.31392, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.31392 to 0.31174, saving model to weights.best.hdf5
# Epoch 00069: val_loss improved from 0.31174 to 0.30912, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.30912 to 0.30665, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.30665 to 0.30516, saving model to weights.best.hdf5
# Epoch 00072: val_loss improved from 0.30516 to 0.30253, saving model to weights.best.hdf5
# Epoch 00073: val_loss improved from 0.30253 to 0.30141, saving model to weights.best.hdf5
# Epoch 00074: val_loss improved from 0.30141 to 0.29962, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.29962 to 0.29790, saving model to weights.best.hdf5
# Epoch 00076: val_loss improved from 0.29790 to 0.29592, saving model to weights.best.hdf5
# Epoch 00077: val_loss improved from 0.29592 to 0.29396, saving model to weights.best.hdf5
# Epoch 00078: val_loss improved from 0.29396 to 0.29327, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.29327 to 0.29174, saving model to weights.best.hdf5
# Epoch 00080: val_loss improved from 0.29174 to 0.29049, saving model to weights.best.hdf5
# Epoch 00081: val_loss improved from 0.29049 to 0.29005, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.29005 to 0.28916, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.28916 to 0.28703, saving model to weights.best.hdf5
# Epoch 00084: val_loss improved from 0.28703 to 0.28556, saving model to weights.best.hdf5
# Epoch 00085: val_loss improved from 0.28556 to 0.28523, saving model to weights.best.hdf5
# Epoch 00086: val_loss improved from 0.28523 to 0.28432, saving model to weights.best.hdf5
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss improved from 0.28432 to 0.28304, saving model to weights.best.hdf5
# Epoch 00089: val_loss improved from 0.28304 to 0.28114, saving model to weights.best.hdf5
# Epoch 00090: val_loss improved from 0.28114 to 0.28061, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss improved from 0.28061 to 0.27947, saving model to weights.best.hdf5
# Epoch 00093: val_loss improved from 0.27947 to 0.27864, saving model to weights.best.hdf5
# Epoch 00094: val_loss improved from 0.27864 to 0.27858, saving model to weights.best.hdf5
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss improved from 0.27858 to 0.27777, saving model to weights.best.hdf5
# Epoch 00097: val_loss improved from 0.27777 to 0.27629, saving model to weights.best.hdf5
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss improved from 0.27629 to 0.27511, saving model to weights.best.hdf5
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss improved from 0.27511 to 0.27448, saving model to weights.best.hdf5
# Epoch 00104: val_loss improved from 0.27448 to 0.27418, saving model to weights.best.hdf5
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss improved from 0.27418 to 0.27385, saving model to weights.best.hdf5
# Epoch 00108: val_loss improved from 0.27385 to 0.27384, saving model to weights.best.hdf5
# Epoch 00109: val_loss improved from 0.27384 to 0.27379, saving model to weights.best.hdf5
# Epoch 00110: val_loss improved from 0.27379 to 0.27372, saving model to weights.best.hdf5
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss improved from 0.27372 to 0.27321, saving model to weights.best.hdf5
# Epoch 00113: val_loss improved from 0.27321 to 0.27251, saving model to weights.best.hdf5
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss improved from 0.27251 to 0.27223, saving model to weights.best.hdf5
# Epoch 00118: val_loss improved from 0.27223 to 0.27169, saving model to weights.best.hdf5
# Epoch 00119: val_loss improved from 0.27169 to 0.27123, saving model to weights.best.hdf5
# Epoch 00120: val_loss improved from 0.27123 to 0.27113, saving model to weights.best.hdf5
# Epoch 00121: val_loss improved from 0.27113 to 0.27081, saving model to weights.best.hdf5
# Epoch 00122: val_loss improved from 0.27081 to 0.27052, saving model to weights.best.hdf5
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss improved from 0.27052 to 0.27031, saving model to weights.best.hdf5
# Epoch 00126: val_loss improved from 0.27031 to 0.26998, saving model to weights.best.hdf5
# Epoch 00127: val_loss improved from 0.26998 to 0.26937, saving model to weights.best.hdf5
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss improved from 0.26937 to 0.26909, saving model to weights.best.hdf5
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss improved from 0.26909 to 0.26891, saving model to weights.best.hdf5
# Epoch 00136: val_loss improved from 0.26891 to 0.26775, saving model to weights.best.hdf5
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss improved from 0.26775 to 0.26714, saving model to weights.best.hdf5
# Epoch 00155: val_loss improved from 0.26714 to 0.26712, saving model to weights.best.hdf5
# Epoch 00156: val_loss improved from 0.26712 to 0.26698, saving model to weights.best.hdf5
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss improved from 0.26698 to 0.26576, saving model to weights.best.hdf5
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss improved from 0.26576 to 0.26565, saving model to weights.best.hdf5
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss improved from 0.26565 to 0.26531, saving model to weights.best.hdf5
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss improved from 0.26531 to 0.26417, saving model to weights.best.hdf5
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss improved from 0.26417 to 0.26392, saving model to weights.best.hdf5
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss improved from 0.26392 to 0.26356, saving model to weights.best.hdf5
# Epoch 00195: val_loss improved from 0.26356 to 0.26333, saving model to weights.best.hdf5
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss improved from 0.26333 to 0.26278, saving model to weights.best.hdf5
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss improved from 0.26278 to 0.26253, saving model to weights.best.hdf5
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss improved from 0.26253 to 0.26241, saving model to weights.best.hdf5
# Epoch 00204: val_loss improved from 0.26241 to 0.26140, saving model to weights.best.hdf5
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss improved from 0.26140 to 0.26047, saving model to weights.best.hdf5
# Epoch 00213: val_loss improved from 0.26047 to 0.25982, saving model to weights.best.hdf5
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss improved from 0.25982 to 0.25966, saving model to weights.best.hdf5
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss improved from 0.25966 to 0.25815, saving model to weights.best.hdf5
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss improved from 0.25815 to 0.25749, saving model to weights.best.hdf5
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss improved from 0.25749 to 0.25728, saving model to weights.best.hdf5
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss improved from 0.25728 to 0.25627, saving model to weights.best.hdf5
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss improved from 0.25627 to 0.25617, saving model to weights.best.hdf5
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss improved from 0.25617 to 0.25615, saving model to weights.best.hdf5
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss improved from 0.25615 to 0.25593, saving model to weights.best.hdf5
# Epoch 00278: val_loss improved from 0.25593 to 0.25462, saving model to weights.best.hdf5
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss improved from 0.25462 to 0.25397, saving model to weights.best.hdf5
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss improved from 0.25397 to 0.25344, saving model to weights.best.hdf5
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss improved from 0.25344 to 0.25312, saving model to weights.best.hdf5
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss improved from 0.25312 to 0.25252, saving model to weights.best.hdf5
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss improved from 0.25252 to 0.25216, saving model to weights.best.hdf5
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss improved from 0.25216 to 0.25087, saving model to weights.best.hdf5
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss improved from 0.25087 to 0.24938, saving model to weights.best.hdf5
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss improved from 0.24938 to 0.24914, saving model to weights.best.hdf5
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss improved from 0.24914 to 0.24843, saving model to weights.best.hdf5
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss improved from 0.24843 to 0.24818, saving model to weights.best.hdf5
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss improved from 0.24818 to 0.24653, saving model to weights.best.hdf5
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss improved from 0.24653 to 0.24651, saving model to weights.best.hdf5
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss improved from 0.24651 to 0.24642, saving model to weights.best.hdf5
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss improved from 0.24642 to 0.24580, saving model to weights.best.hdf5
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss improved from 0.24580 to 0.24528, saving model to weights.best.hdf5
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss improved from 0.24528 to 0.24338, saving model to weights.best.hdf5
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss improved from 0.24338 to 0.24150, saving model to weights.best.hdf5
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss improved from 0.24150 to 0.23950, saving model to weights.best.hdf5
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss improved from 0.23950 to 0.23918, saving model to weights.best.hdf5
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss improved from 0.23918 to 0.23858, saving model to weights.best.hdf5
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss improved from 0.23858 to 0.23747, saving model to weights.best.hdf5
# Epoch 00500: val_loss did not improve
# Epoch 00501: val_loss did not improve
# Epoch 00502: val_loss did not improve
# Epoch 00503: val_loss did not improve
# Epoch 00504: val_loss did not improve
# Epoch 00505: val_loss did not improve
# Epoch 00506: val_loss did not improve
# Epoch 00507: val_loss did not improve
# Epoch 00508: val_loss did not improve
# Epoch 00509: val_loss did not improve
# Epoch 00510: val_loss did not improve
# Epoch 00511: val_loss did not improve
# Epoch 00512: val_loss did not improve
# Epoch 00513: val_loss did not improve
# Epoch 00514: val_loss did not improve
# Epoch 00515: val_loss did not improve
# Epoch 00516: val_loss did not improve
# Epoch 00517: val_loss did not improve
# Epoch 00518: val_loss did not improve
# Epoch 00519: val_loss did not improve
# Epoch 00520: val_loss did not improve
# Epoch 00521: val_loss did not improve
# Epoch 00522: val_loss did not improve
# Epoch 00523: val_loss did not improve
# Epoch 00524: val_loss did not improve
# Epoch 00525: val_loss did not improve
# Epoch 00526: val_loss did not improve
# Epoch 00527: val_loss did not improve
# Epoch 00528: val_loss did not improve
# Epoch 00529: val_loss did not improve
# Epoch 00530: val_loss did not improve
# Epoch 00531: val_loss did not improve
# Epoch 00532: val_loss did not improve
# Epoch 00533: val_loss did not improve
# Epoch 00534: val_loss did not improve
# Epoch 00535: val_loss did not improve
# Epoch 00536: val_loss did not improve
# Epoch 00537: val_loss did not improve
# Epoch 00538: val_loss did not improve
# Epoch 00539: val_loss did not improve
# Epoch 00540: val_loss did not improve
# Epoch 00541: val_loss did not improve
# Epoch 00542: val_loss did not improve
# Epoch 00543: val_loss did not improve
# Epoch 00544: val_loss improved from 0.23747 to 0.23683, saving model to weights.best.hdf5
# Epoch 00545: val_loss did not improve
# Epoch 00546: val_loss did not improve
# Epoch 00547: val_loss did not improve
# Epoch 00548: val_loss did not improve
# Epoch 00549: val_loss did not improve
# Epoch 00550: val_loss did not improve
# Epoch 00551: val_loss did not improve
# Epoch 00552: val_loss did not improve
# Epoch 00553: val_loss did not improve
# Epoch 00554: val_loss did not improve
# Epoch 00555: val_loss did not improve
# Epoch 00556: val_loss did not improve
# Epoch 00557: val_loss did not improve
# Epoch 00558: val_loss did not improve
# Epoch 00559: val_loss did not improve
# Epoch 00560: val_loss did not improve
# Epoch 00561: val_loss did not improve
# Epoch 00562: val_loss did not improve
# Epoch 00563: val_loss did not improve
# Epoch 00564: val_loss did not improve
# Epoch 00565: val_loss did not improve
# Epoch 00566: val_loss did not improve
# Epoch 00567: val_loss did not improve
# Epoch 00568: val_loss improved from 0.23683 to 0.23558, saving model to weights.best.hdf5
# Epoch 00569: val_loss did not improve
# Epoch 00570: val_loss did not improve
# Epoch 00571: val_loss did not improve
# Epoch 00572: val_loss did not improve
# Epoch 00573: val_loss did not improve
# Epoch 00574: val_loss did not improve
# Epoch 00575: val_loss did not improve
# Epoch 00576: val_loss did not improve
# Epoch 00577: val_loss did not improve
# Epoch 00578: val_loss did not improve
# Epoch 00579: val_loss did not improve
# Epoch 00580: val_loss did not improve
# Epoch 00581: val_loss did not improve
# Epoch 00582: val_loss did not improve
# Epoch 00583: val_loss did not improve
# Epoch 00584: val_loss did not improve
# Epoch 00585: val_loss did not improve
# Epoch 00586: val_loss did not improve
# Epoch 00587: val_loss did not improve
# Epoch 00588: val_loss did not improve
# Epoch 00589: val_loss did not improve
# Epoch 00590: val_loss did not improve
# Epoch 00591: val_loss did not improve
# Epoch 00592: val_loss did not improve
# Epoch 00593: val_loss did not improve
# Epoch 00594: val_loss did not improve
# Epoch 00595: val_loss did not improve
# Epoch 00596: val_loss did not improve
# Epoch 00597: val_loss improved from 0.23558 to 0.23538, saving model to weights.best.hdf5
# Epoch 00598: val_loss did not improve
# Epoch 00599: val_loss did not improve
# Epoch 00600: val_loss did not improve
# Epoch 00601: val_loss did not improve
# Epoch 00602: val_loss did not improve
# Epoch 00603: val_loss did not improve
# Epoch 00604: val_loss did not improve
# Epoch 00605: val_loss did not improve
# Epoch 00606: val_loss did not improve
# Epoch 00607: val_loss did not improve
# Epoch 00608: val_loss did not improve
# Epoch 00609: val_loss did not improve
# Epoch 00610: val_loss improved from 0.23538 to 0.23416, saving model to weights.best.hdf5
# Epoch 00611: val_loss did not improve
# Epoch 00612: val_loss did not improve
# Epoch 00613: val_loss did not improve
# Epoch 00614: val_loss did not improve
# Epoch 00615: val_loss did not improve
# Epoch 00616: val_loss did not improve
# Epoch 00617: val_loss did not improve
# Epoch 00618: val_loss did not improve
# Epoch 00619: val_loss did not improve
# Epoch 00620: val_loss did not improve
# Epoch 00621: val_loss did not improve
# Epoch 00622: val_loss did not improve
# Epoch 00623: val_loss did not improve
# Epoch 00624: val_loss did not improve
# Epoch 00625: val_loss did not improve
# Epoch 00626: val_loss did not improve
# Epoch 00627: val_loss did not improve
# Epoch 00628: val_loss did not improve
# Epoch 00629: val_loss did not improve
# Epoch 00630: val_loss did not improve
# Epoch 00631: val_loss did not improve
# Epoch 00632: val_loss did not improve
# Epoch 00633: val_loss did not improve
# Epoch 00634: val_loss did not improve
# Epoch 00635: val_loss did not improve
# Epoch 00636: val_loss did not improve
# Epoch 00637: val_loss did not improve
# Epoch 00638: val_loss did not improve
# Epoch 00639: val_loss did not improve
# Epoch 00640: val_loss improved from 0.23416 to 0.23400, saving model to weights.best.hdf5
# Epoch 00641: val_loss did not improve
# Epoch 00642: val_loss did not improve
# Epoch 00643: val_loss did not improve
# Epoch 00644: val_loss did not improve
# Epoch 00645: val_loss did not improve
# Epoch 00646: val_loss did not improve
# Epoch 00647: val_loss did not improve
# Epoch 00648: val_loss did not improve
# Epoch 00649: val_loss did not improve
# Epoch 00650: val_loss did not improve
# Epoch 00651: val_loss did not improve
# Epoch 00652: val_loss did not improve
# Epoch 00653: val_loss did not improve
# Epoch 00654: val_loss did not improve
# Epoch 00655: val_loss did not improve
# Epoch 00656: val_loss did not improve
# Epoch 00657: val_loss did not improve
# Epoch 00658: val_loss improved from 0.23400 to 0.23390, saving model to weights.best.hdf5
# Epoch 00659: val_loss improved from 0.23390 to 0.23294, saving model to weights.best.hdf5
# Epoch 00660: val_loss did not improve
# Epoch 00661: val_loss did not improve
# Epoch 00662: val_loss did not improve
# Epoch 00663: val_loss improved from 0.23294 to 0.23291, saving model to weights.best.hdf5
# Epoch 00664: val_loss did not improve
# Epoch 00665: val_loss did not improve
# Epoch 00666: val_loss did not improve
# Epoch 00667: val_loss did not improve
# Epoch 00668: val_loss did not improve
# Epoch 00669: val_loss did not improve
# Epoch 00670: val_loss did not improve
# Epoch 00671: val_loss did not improve
# Epoch 00672: val_loss did not improve
# Epoch 00673: val_loss did not improve
# Epoch 00674: val_loss did not improve
# Epoch 00675: val_loss did not improve
# Epoch 00676: val_loss did not improve
# Epoch 00677: val_loss did not improve
# Epoch 00678: val_loss did not improve
# Epoch 00679: val_loss did not improve
# Epoch 00680: val_loss improved from 0.23291 to 0.23183, saving model to weights.best.hdf5
# Epoch 00681: val_loss did not improve
# Epoch 00682: val_loss did not improve
# Epoch 00683: val_loss did not improve
# Epoch 00684: val_loss did not improve
# Epoch 00685: val_loss did not improve
# Epoch 00686: val_loss did not improve
# Epoch 00687: val_loss did not improve
# Epoch 00688: val_loss did not improve
# Epoch 00689: val_loss did not improve
# Epoch 00690: val_loss did not improve
# Epoch 00691: val_loss did not improve
# Epoch 00692: val_loss did not improve
# Epoch 00693: val_loss did not improve
# Epoch 00694: val_loss did not improve
# Epoch 00695: val_loss did not improve
# Epoch 00696: val_loss did not improve
# Epoch 00697: val_loss did not improve
# Epoch 00698: val_loss did not improve
# Epoch 00699: val_loss did not improve
# Epoch 00700: val_loss did not improve
# Epoch 00701: val_loss did not improve
# Epoch 00702: val_loss did not improve
# Epoch 00703: val_loss did not improve
# Epoch 00704: val_loss did not improve
# Epoch 00705: val_loss did not improve
# Epoch 00706: val_loss improved from 0.23183 to 0.23144, saving model to weights.best.hdf5
# Epoch 00707: val_loss did not improve
# Epoch 00708: val_loss did not improve
# Epoch 00709: val_loss did not improve
# Epoch 00710: val_loss did not improve
# Epoch 00711: val_loss did not improve
# Epoch 00712: val_loss did not improve
# Epoch 00713: val_loss improved from 0.23144 to 0.23120, saving model to weights.best.hdf5
# Epoch 00714: val_loss did not improve
# Epoch 00715: val_loss did not improve
# Epoch 00716: val_loss did not improve
# Epoch 00717: val_loss did not improve
# Epoch 00718: val_loss did not improve
# Epoch 00719: val_loss did not improve
# Epoch 00720: val_loss did not improve
# Epoch 00721: val_loss did not improve
# Epoch 00722: val_loss did not improve
# Epoch 00723: val_loss did not improve
# Epoch 00724: val_loss did not improve
# Epoch 00725: val_loss did not improve
# Epoch 00726: val_loss improved from 0.23120 to 0.23091, saving model to weights.best.hdf5
# Epoch 00727: val_loss did not improve
# Epoch 00728: val_loss did not improve
# Epoch 00729: val_loss did not improve
# Epoch 00730: val_loss did not improve
# Epoch 00731: val_loss did not improve
# Epoch 00732: val_loss did not improve
# Epoch 00733: val_loss did not improve
# Epoch 00734: val_loss did not improve
# Epoch 00735: val_loss did not improve
# Epoch 00736: val_loss did not improve
# Epoch 00737: val_loss did not improve
# Epoch 00738: val_loss did not improve
# Epoch 00739: val_loss did not improve
# Epoch 00740: val_loss did not improve
# Epoch 00741: val_loss did not improve
# Epoch 00742: val_loss did not improve
# Epoch 00743: val_loss did not improve
# Epoch 00744: val_loss did not improve
# Epoch 00745: val_loss did not improve
# Epoch 00746: val_loss did not improve
# Epoch 00747: val_loss did not improve
# Epoch 00748: val_loss did not improve
# Epoch 00749: val_loss did not improve
# Epoch 00750: val_loss did not improve
# Epoch 00751: val_loss did not improve
# Epoch 00752: val_loss did not improve
# Epoch 00753: val_loss did not improve
# Epoch 00754: val_loss did not improve
# Epoch 00755: val_loss did not improve
# Epoch 00756: val_loss did not improve
# Epoch 00757: val_loss did not improve
# Epoch 00758: val_loss did not improve
# Epoch 00759: val_loss did not improve
# Epoch 00760: val_loss did not improve
# Epoch 00761: val_loss did not improve
# Epoch 00762: val_loss improved from 0.23091 to 0.22944, saving model to weights.best.hdf5
# Epoch 00763: val_loss did not improve
# Epoch 00764: val_loss did not improve
# Epoch 00765: val_loss did not improve
# Epoch 00766: val_loss did not improve
# Epoch 00767: val_loss did not improve
# Epoch 00768: val_loss did not improve
# Epoch 00769: val_loss did not improve
# Epoch 00770: val_loss did not improve
# Epoch 00771: val_loss did not improve
# Epoch 00772: val_loss did not improve
# Epoch 00773: val_loss did not improve
# Epoch 00774: val_loss did not improve
# Epoch 00775: val_loss did not improve
# Epoch 00776: val_loss did not improve
# Epoch 00777: val_loss did not improve
# Epoch 00778: val_loss did not improve
# Epoch 00779: val_loss did not improve
# Epoch 00780: val_loss did not improve
# Epoch 00781: val_loss did not improve
# Epoch 00782: val_loss did not improve
# Epoch 00783: val_loss did not improve
# Epoch 00784: val_loss did not improve
# Epoch 00785: val_loss did not improve
# Epoch 00786: val_loss did not improve
# Epoch 00787: val_loss did not improve
# Epoch 00788: val_loss did not improve
# Epoch 00789: val_loss did not improve
# Epoch 00790: val_loss did not improve
# Epoch 00791: val_loss did not improve
# Epoch 00792: val_loss did not improve
# Epoch 00793: val_loss did not improve
# Epoch 00794: val_loss did not improve
# Epoch 00795: val_loss did not improve
# Epoch 00796: val_loss did not improve
# Epoch 00797: val_loss did not improve
# Epoch 00798: val_loss did not improve
# Epoch 00799: val_loss did not improve
# Epoch 00800: val_loss did not improve
# Epoch 00801: val_loss improved from 0.22944 to 0.22937, saving model to weights.best.hdf5
# Epoch 00802: val_loss did not improve
# Epoch 00803: val_loss did not improve
# Epoch 00804: val_loss did not improve
# Epoch 00805: val_loss did not improve
# Epoch 00806: val_loss did not improve
# Epoch 00807: val_loss did not improve
# Epoch 00808: val_loss did not improve
# Epoch 00809: val_loss did not improve
# Epoch 00810: val_loss did not improve
# Epoch 00811: val_loss did not improve
# Epoch 00812: val_loss did not improve
# Epoch 00813: val_loss did not improve
# Epoch 00814: val_loss did not improve
# Epoch 00815: val_loss did not improve
# Epoch 00816: val_loss did not improve
# Epoch 00817: val_loss did not improve
# Epoch 00818: val_loss did not improve
# Epoch 00819: val_loss did not improve
# Epoch 00820: val_loss did not improve
# Epoch 00821: val_loss did not improve
# Epoch 00822: val_loss did not improve
# Epoch 00823: val_loss did not improve
# Epoch 00824: val_loss did not improve
# Epoch 00825: val_loss did not improve
# Epoch 00826: val_loss did not improve
# Epoch 00827: val_loss did not improve
# Epoch 00828: val_loss improved from 0.22937 to 0.22806, saving model to weights.best.hdf5
# Epoch 00829: val_loss did not improve
# Epoch 00830: val_loss did not improve
# Epoch 00831: val_loss did not improve
# Epoch 00832: val_loss did not improve
# Epoch 00833: val_loss did not improve
# Epoch 00834: val_loss did not improve
# Epoch 00835: val_loss did not improve
# Epoch 00836: val_loss did not improve
# Epoch 00837: val_loss did not improve
# Epoch 00838: val_loss did not improve
# Epoch 00839: val_loss did not improve
# Epoch 00840: val_loss did not improve
# Epoch 00841: val_loss did not improve
# Epoch 00842: val_loss did not improve
# Epoch 00843: val_loss did not improve
# Epoch 00844: val_loss did not improve
# Epoch 00845: val_loss did not improve
# Epoch 00846: val_loss did not improve
# Epoch 00847: val_loss did not improve
# Epoch 00848: val_loss did not improve
# Epoch 00849: val_loss did not improve
# Epoch 00850: val_loss did not improve
# Epoch 00851: val_loss did not improve
# Epoch 00852: val_loss did not improve
# Epoch 00853: val_loss did not improve
# Epoch 00854: val_loss did not improve
# Epoch 00855: val_loss did not improve
# Epoch 00856: val_loss did not improve
# Epoch 00857: val_loss did not improve
# Epoch 00858: val_loss did not improve
# Epoch 00859: val_loss did not improve
# Epoch 00860: val_loss did not improve
# Epoch 00861: val_loss did not improve
# Epoch 00862: val_loss did not improve
# Epoch 00863: val_loss did not improve
# Epoch 00864: val_loss did not improve
# Epoch 00865: val_loss did not improve
# Epoch 00866: val_loss did not improve
# Epoch 00867: val_loss did not improve
# Epoch 00868: val_loss did not improve
# Epoch 00869: val_loss did not improve
# Epoch 00870: val_loss did not improve
# Epoch 00871: val_loss did not improve
# Epoch 00872: val_loss did not improve
# Epoch 00873: val_loss did not improve
# Epoch 00874: val_loss did not improve
# Epoch 00875: val_loss did not improve
# Epoch 00876: val_loss did not improve
# Epoch 00877: val_loss did not improve
# Epoch 00878: val_loss did not improve
# Epoch 00879: val_loss did not improve
# Epoch 00880: val_loss did not improve
# Epoch 00881: val_loss improved from 0.22806 to 0.22800, saving model to weights.best.hdf5
# Epoch 00882: val_loss did not improve
# Epoch 00883: val_loss did not improve
# Epoch 00884: val_loss did not improve
# Epoch 00885: val_loss did not improve
# Epoch 00886: val_loss did not improve
# Epoch 00887: val_loss did not improve
# Epoch 00888: val_loss did not improve
# Epoch 00889: val_loss did not improve
# Epoch 00890: val_loss did not improve
# Epoch 00891: val_loss did not improve
# Epoch 00892: val_loss did not improve
# Epoch 00893: val_loss did not improve
# Epoch 00894: val_loss did not improve
# Epoch 00895: val_loss improved from 0.22800 to 0.22732, saving model to weights.best.hdf5
# Epoch 00896: val_loss did not improve
# Epoch 00897: val_loss did not improve
# Epoch 00898: val_loss did not improve
# Epoch 00899: val_loss did not improve
# Epoch 00900: val_loss did not improve
# Epoch 00901: val_loss did not improve
# Epoch 00902: val_loss did not improve
# Epoch 00903: val_loss did not improve
# Epoch 00904: val_loss did not improve
# Epoch 00905: val_loss did not improve
# Epoch 00906: val_loss did not improve
# Epoch 00907: val_loss did not improve
# Epoch 00908: val_loss did not improve
# Epoch 00909: val_loss did not improve
# Epoch 00910: val_loss did not improve
# Epoch 00911: val_loss did not improve
# Epoch 00912: val_loss did not improve
# Epoch 00913: val_loss did not improve
# Epoch 00914: val_loss did not improve
# Epoch 00915: val_loss did not improve
# Epoch 00916: val_loss did not improve
# Epoch 00917: val_loss did not improve
# Epoch 00918: val_loss did not improve
# Epoch 00919: val_loss did not improve
# Epoch 00920: val_loss did not improve
# Epoch 00921: val_loss did not improve
# Epoch 00922: val_loss did not improve
# Epoch 00923: val_loss did not improve
# Epoch 00924: val_loss did not improve
# Epoch 00925: val_loss did not improve
# Epoch 00926: val_loss did not improve
# Epoch 00927: val_loss did not improve
# Epoch 00928: val_loss did not improve
# Epoch 00929: val_loss did not improve
# Epoch 00930: val_loss did not improve
# Epoch 00931: val_loss did not improve
# Epoch 00932: val_loss did not improve
# Epoch 00933: val_loss did not improve
# Epoch 00934: val_loss did not improve
# Epoch 00935: val_loss improved from 0.22732 to 0.22678, saving model to weights.best.hdf5
# Epoch 00936: val_loss did not improve
# Epoch 00937: val_loss did not improve
# Epoch 00938: val_loss did not improve
# Epoch 00939: val_loss did not improve
# Epoch 00940: val_loss did not improve
# Epoch 00941: val_loss did not improve
# Epoch 00942: val_loss did not improve
# Epoch 00943: val_loss did not improve
# Epoch 00944: val_loss did not improve
# Epoch 00945: val_loss did not improve
# Epoch 00946: val_loss did not improve
# Epoch 00947: val_loss did not improve
# Epoch 00948: val_loss did not improve
# Epoch 00949: val_loss did not improve
# Epoch 00950: val_loss did not improve
# Epoch 00951: val_loss did not improve
# Epoch 00952: val_loss did not improve
# Epoch 00953: val_loss did not improve
# Epoch 00954: val_loss did not improve
# Epoch 00955: val_loss did not improve
# Epoch 00956: val_loss did not improve
# Epoch 00957: val_loss did not improve
# Epoch 00958: val_loss did not improve
# Epoch 00959: val_loss improved from 0.22678 to 0.22652, saving model to weights.best.hdf5
# Epoch 00960: val_loss did not improve
# Epoch 00961: val_loss did not improve
# Epoch 00962: val_loss did not improve
# Epoch 00963: val_loss did not improve
# Epoch 00964: val_loss did not improve
# Epoch 00965: val_loss did not improve
# Epoch 00966: val_loss did not improve
# Epoch 00967: val_loss did not improve
# Epoch 00968: val_loss did not improve
# Epoch 00969: val_loss did not improve
# Epoch 00970: val_loss did not improve
# Epoch 00971: val_loss did not improve
# Epoch 00972: val_loss did not improve
# Epoch 00973: val_loss did not improve
# Epoch 00974: val_loss did not improve
# Epoch 00975: val_loss did not improve
# Epoch 00976: val_loss did not improve
# Epoch 00977: val_loss did not improve
# Epoch 00978: val_loss did not improve
# Epoch 00979: val_loss did not improve
# Epoch 00980: val_loss did not improve
# Epoch 00981: val_loss did not improve
# Epoch 00982: val_loss did not improve
# Epoch 00983: val_loss did not improve
# Epoch 00984: val_loss did not improve
# Epoch 00985: val_loss did not improve
# Epoch 00986: val_loss did not improve
# Epoch 00987: val_loss did not improve
# Epoch 00988: val_loss did not improve
# Epoch 00989: val_loss did not improve
# Epoch 00990: val_loss did not improve
# Epoch 00991: val_loss did not improve
# Epoch 00992: val_loss did not improve
# Epoch 00993: val_loss did not improve
# Epoch 00994: val_loss improved from 0.22652 to 0.22541, saving model to weights.best.hdf5
# Epoch 00995: val_loss did not improve
# Epoch 00996: val_loss did not improve
# Epoch 00997: val_loss improved from 0.22541 to 0.22532, saving model to weights.best.hdf5
# Epoch 00998: val_loss did not improve
# Epoch 00999: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   1000
# Best loss at iteratation:     941    Best: 0.149373470992
# Best val_loss at iteratation: 997    Best: 0.225320468346

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.200518847494
# (535, 1)
# (535,)
# MAE:  94.967
# RMSE: 137.336
# R2:   0.640

# %% [markdown]
# ## LSTM with events information + event text

# %%
#GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 3461 unique tokens.
# ('Shape of train tensor:', (640, 600))
# ('Shape of val tensor:', (90, 600))
# ('Shape of test tensor:', (535, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model(1, NUM_LAGS, 11, 1)
model.fit(
    [lags_train, 
     np.concatenate([event_feats_train[:,np.newaxis], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([lags_val, 
                      np.concatenate([event_feats_val[:,np.newaxis], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_2/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_7:0", shape=(?, 10), dtype=float32)
# Tensor("input_8:0", shape=(?, 11), dtype=float32)
# Tensor("dropout_6/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_5/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 1.16886, saving model to weights.best.hdf5
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss improved from 1.16886 to 1.15198, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 1.15198 to 0.97658, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 0.97658 to 0.87798, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 0.87798 to 0.81871, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 0.81871 to 0.79506, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 0.79506 to 0.74299, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 0.74299 to 0.70021, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 0.70021 to 0.64767, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 0.64767 to 0.61241, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 0.61241 to 0.55244, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 0.55244 to 0.54361, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 0.54361 to 0.53366, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 0.53366 to 0.50131, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 0.50131 to 0.46991, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 0.46991 to 0.46083, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 0.46083 to 0.43598, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 0.43598 to 0.41700, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 0.41700 to 0.41102, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 0.41102 to 0.39909, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 0.39909 to 0.38879, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 0.38879 to 0.38038, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 0.38038 to 0.36751, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 0.36751 to 0.35982, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 0.35982 to 0.35169, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 0.35169 to 0.34254, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 0.34254 to 0.33715, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 0.33715 to 0.33291, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 0.33291 to 0.32674, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 0.32674 to 0.31997, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 0.31997 to 0.31789, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 0.31789 to 0.31015, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 0.31015 to 0.30644, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 0.30644 to 0.30008, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 0.30008 to 0.29523, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 0.29523 to 0.29304, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 0.29304 to 0.28854, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 0.28854 to 0.28509, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 0.28509 to 0.28261, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.28261 to 0.27961, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.27961 to 0.27549, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.27549 to 0.27321, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.27321 to 0.27235, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.27235 to 0.26915, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 0.26915 to 0.26694, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss improved from 0.26694 to 0.26163, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 0.26163 to 0.25990, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.25990 to 0.25772, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.25772 to 0.25622, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 0.25622 to 0.25529, saving model to weights.best.hdf5
# Epoch 00055: val_loss improved from 0.25529 to 0.25201, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.25201 to 0.24952, saving model to weights.best.hdf5
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss improved from 0.24952 to 0.24659, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.24659 to 0.24511, saving model to weights.best.hdf5
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss improved from 0.24511 to 0.24305, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.24305 to 0.24203, saving model to weights.best.hdf5
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss improved from 0.24203 to 0.24030, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.24030 to 0.23930, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss improved from 0.23930 to 0.23746, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.23746 to 0.23520, saving model to weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss improved from 0.23520 to 0.23421, saving model to weights.best.hdf5
# Epoch 00072: val_loss improved from 0.23421 to 0.23380, saving model to weights.best.hdf5
# Epoch 00073: val_loss improved from 0.23380 to 0.23379, saving model to weights.best.hdf5
# Epoch 00074: val_loss improved from 0.23379 to 0.23133, saving model to weights.best.hdf5
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss improved from 0.23133 to 0.22953, saving model to weights.best.hdf5
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss improved from 0.22953 to 0.22865, saving model to weights.best.hdf5
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss improved from 0.22865 to 0.22819, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.22819 to 0.22658, saving model to weights.best.hdf5
# Epoch 00084: val_loss improved from 0.22658 to 0.22637, saving model to weights.best.hdf5
# Epoch 00085: val_loss improved from 0.22637 to 0.22595, saving model to weights.best.hdf5
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss improved from 0.22595 to 0.22579, saving model to weights.best.hdf5
# Epoch 00089: val_loss improved from 0.22579 to 0.22381, saving model to weights.best.hdf5
# Epoch 00090: val_loss improved from 0.22381 to 0.22358, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss improved from 0.22358 to 0.22307, saving model to weights.best.hdf5
# Epoch 00093: val_loss improved from 0.22307 to 0.22299, saving model to weights.best.hdf5
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss improved from 0.22299 to 0.22203, saving model to weights.best.hdf5
# Epoch 00096: val_loss improved from 0.22203 to 0.22201, saving model to weights.best.hdf5
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss improved from 0.22201 to 0.22103, saving model to weights.best.hdf5
# Epoch 00101: val_loss improved from 0.22103 to 0.21987, saving model to weights.best.hdf5
# Epoch 00102: val_loss improved from 0.21987 to 0.21836, saving model to weights.best.hdf5
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss improved from 0.21836 to 0.21816, saving model to weights.best.hdf5
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss improved from 0.21816 to 0.21735, saving model to weights.best.hdf5
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss improved from 0.21735 to 0.21683, saving model to weights.best.hdf5
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss improved from 0.21683 to 0.21642, saving model to weights.best.hdf5
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss improved from 0.21642 to 0.21599, saving model to weights.best.hdf5
# Epoch 00123: val_loss improved from 0.21599 to 0.21577, saving model to weights.best.hdf5
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss improved from 0.21577 to 0.21459, saving model to weights.best.hdf5
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss improved from 0.21459 to 0.21450, saving model to weights.best.hdf5
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss improved from 0.21450 to 0.21350, saving model to weights.best.hdf5
# Epoch 00135: val_loss improved from 0.21350 to 0.21301, saving model to weights.best.hdf5
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss improved from 0.21301 to 0.21205, saving model to weights.best.hdf5
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss improved from 0.21205 to 0.21122, saving model to weights.best.hdf5
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss improved from 0.21122 to 0.21100, saving model to weights.best.hdf5
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss improved from 0.21100 to 0.21024, saving model to weights.best.hdf5
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss improved from 0.21024 to 0.20971, saving model to weights.best.hdf5
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss improved from 0.20971 to 0.20936, saving model to weights.best.hdf5
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss improved from 0.20936 to 0.20854, saving model to weights.best.hdf5
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss improved from 0.20854 to 0.20794, saving model to weights.best.hdf5
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss improved from 0.20794 to 0.20784, saving model to weights.best.hdf5
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss improved from 0.20784 to 0.20770, saving model to weights.best.hdf5
# Epoch 00215: val_loss improved from 0.20770 to 0.20749, saving model to weights.best.hdf5
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss improved from 0.20749 to 0.20691, saving model to weights.best.hdf5
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss improved from 0.20691 to 0.20543, saving model to weights.best.hdf5
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss improved from 0.20543 to 0.20435, saving model to weights.best.hdf5
# Epoch 00243: val_loss improved from 0.20435 to 0.20387, saving model to weights.best.hdf5
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss improved from 0.20387 to 0.20374, saving model to weights.best.hdf5
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss improved from 0.20374 to 0.20344, saving model to weights.best.hdf5
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve
# Epoch 00500: val_loss did not improve
# Epoch 00501: val_loss did not improve
# Epoch 00502: val_loss did not improve
# Epoch 00503: val_loss did not improve
# Epoch 00504: val_loss did not improve
# Epoch 00505: val_loss did not improve
# Epoch 00506: val_loss did not improve
# Epoch 00507: val_loss did not improve
# Epoch 00508: val_loss did not improve
# Epoch 00509: val_loss did not improve
# Epoch 00510: val_loss did not improve
# Epoch 00511: val_loss did not improve
# Epoch 00512: val_loss did not improve
# Epoch 00513: val_loss did not improve
# Epoch 00514: val_loss did not improve
# Epoch 00515: val_loss did not improve
# Epoch 00516: val_loss did not improve
# Epoch 00517: val_loss did not improve
# Epoch 00518: val_loss did not improve
# Epoch 00519: val_loss did not improve
# Epoch 00520: val_loss did not improve
# Epoch 00521: val_loss did not improve
# Epoch 00522: val_loss did not improve
# Epoch 00523: val_loss did not improve
# Epoch 00524: val_loss did not improve
# Epoch 00525: val_loss did not improve
# Epoch 00526: val_loss did not improve
# Epoch 00527: val_loss did not improve
# Epoch 00528: val_loss did not improve
# Epoch 00529: val_loss did not improve
# Epoch 00530: val_loss did not improve
# Epoch 00531: val_loss did not improve
# Epoch 00532: val_loss did not improve
# Epoch 00533: val_loss did not improve
# Epoch 00534: val_loss did not improve
# Epoch 00535: val_loss did not improve
# Epoch 00536: val_loss did not improve
# Epoch 00537: val_loss did not improve
# Epoch 00538: val_loss did not improve
# Epoch 00539: val_loss did not improve
# Epoch 00540: val_loss did not improve
# Epoch 00541: val_loss did not improve
# Epoch 00542: val_loss did not improve
# Epoch 00543: val_loss did not improve
# Epoch 00544: val_loss did not improve
# Epoch 00545: val_loss did not improve
# Epoch 00546: val_loss did not improve
# Epoch 00547: val_loss did not improve
# Epoch 00548: val_loss did not improve
# Epoch 00549: val_loss did not improve
# Epoch 00550: val_loss did not improve
# Epoch 00551: val_loss did not improve
# Epoch 00552: val_loss did not improve
# Epoch 00553: val_loss did not improve
# Epoch 00554: val_loss did not improve
# Epoch 00555: val_loss did not improve
# Epoch 00556: val_loss did not improve
# Epoch 00557: val_loss did not improve
# Epoch 00558: val_loss did not improve
# Epoch 00559: val_loss did not improve
# Epoch 00560: val_loss did not improve
# Epoch 00561: val_loss did not improve
# Epoch 00562: val_loss did not improve
# Epoch 00563: val_loss did not improve
# Epoch 00564: val_loss did not improve
# Epoch 00565: val_loss did not improve
# Epoch 00566: val_loss did not improve
# Epoch 00567: val_loss did not improve
# Epoch 00568: val_loss did not improve
# Epoch 00569: val_loss did not improve
# Epoch 00570: val_loss did not improve
# Epoch 00571: val_loss did not improve
# Epoch 00572: val_loss did not improve
# Epoch 00573: val_loss did not improve
# Epoch 00574: val_loss did not improve
# Epoch 00575: val_loss did not improve
# Epoch 00576: val_loss did not improve
# Epoch 00577: val_loss did not improve
# Epoch 00578: val_loss did not improve
# Epoch 00579: val_loss did not improve
# Epoch 00580: val_loss did not improve
# Epoch 00581: val_loss did not improve
# Epoch 00582: val_loss did not improve
# Epoch 00583: val_loss did not improve
# Epoch 00584: val_loss did not improve
# Epoch 00585: val_loss did not improve
# Epoch 00586: val_loss did not improve
# Epoch 00587: val_loss did not improve
# Epoch 00588: val_loss did not improve
# Epoch 00589: val_loss did not improve
# Epoch 00590: val_loss did not improve
# Epoch 00591: val_loss did not improve
# Epoch 00592: val_loss did not improve
# Epoch 00593: val_loss did not improve
# Epoch 00594: val_loss did not improve
# Epoch 00595: val_loss did not improve
# Epoch 00596: val_loss did not improve
# Epoch 00597: val_loss did not improve
# Epoch 00598: val_loss did not improve
# Epoch 00599: val_loss did not improve
# Epoch 00600: val_loss did not improve
# Epoch 00601: val_loss did not improve
# Epoch 00602: val_loss did not improve
# Epoch 00603: val_loss did not improve
# Epoch 00604: val_loss did not improve
# Epoch 00605: val_loss did not improve
# Epoch 00606: val_loss did not improve
# Epoch 00607: val_loss did not improve
# Epoch 00608: val_loss did not improve
# Epoch 00609: val_loss did not improve
# Epoch 00610: val_loss did not improve
# Epoch 00611: val_loss did not improve
# Epoch 00612: val_loss did not improve
# Epoch 00613: val_loss did not improve
# Epoch 00614: val_loss did not improve
# Epoch 00615: val_loss did not improve
# Epoch 00616: val_loss did not improve
# Epoch 00617: val_loss did not improve
# Epoch 00618: val_loss did not improve
# Epoch 00619: val_loss did not improve
# Epoch 00620: val_loss did not improve
# Epoch 00621: val_loss did not improve
# Epoch 00622: val_loss did not improve
# Epoch 00623: val_loss did not improve
# Epoch 00624: val_loss did not improve
# Epoch 00625: val_loss did not improve
# Epoch 00626: val_loss did not improve
# Epoch 00627: val_loss did not improve
# Epoch 00628: val_loss did not improve
# Epoch 00629: val_loss did not improve
# Epoch 00630: val_loss did not improve
# Epoch 00631: val_loss did not improve
# Epoch 00632: val_loss did not improve
# Epoch 00633: val_loss did not improve
# Epoch 00634: val_loss did not improve
# Epoch 00635: val_loss did not improve
# Epoch 00636: val_loss did not improve
# Epoch 00637: val_loss did not improve
# Epoch 00638: val_loss did not improve
# Epoch 00639: val_loss did not improve
# Epoch 00640: val_loss did not improve
# Epoch 00641: val_loss did not improve
# Epoch 00642: val_loss did not improve
# Epoch 00643: val_loss did not improve
# Epoch 00644: val_loss did not improve
# Epoch 00645: val_loss did not improve
# Epoch 00646: val_loss did not improve
# Epoch 00647: val_loss did not improve
# Epoch 00648: val_loss did not improve
# Epoch 00649: val_loss did not improve
# Epoch 00650: val_loss did not improve
# Epoch 00651: val_loss did not improve
# Epoch 00652: val_loss did not improve
# Epoch 00653: val_loss did not improve
# Epoch 00654: val_loss did not improve
# Epoch 00655: val_loss did not improve
# Epoch 00656: val_loss did not improve
# Epoch 00657: val_loss did not improve
# Epoch 00658: val_loss did not improve
# Epoch 00659: val_loss did not improve
# Epoch 00660: val_loss did not improve
# Epoch 00661: val_loss did not improve
# Epoch 00662: val_loss did not improve
# Epoch 00663: val_loss did not improve
# Epoch 00664: val_loss did not improve
# Epoch 00665: val_loss did not improve
# Epoch 00666: val_loss did not improve
# Epoch 00667: val_loss did not improve
# Epoch 00668: val_loss did not improve
# Epoch 00669: val_loss did not improve
# Epoch 00670: val_loss did not improve
# Epoch 00671: val_loss did not improve
# Epoch 00672: val_loss did not improve
# Epoch 00673: val_loss did not improve
# Epoch 00674: val_loss did not improve
# Epoch 00675: val_loss did not improve
# Epoch 00676: val_loss did not improve
# Epoch 00677: val_loss did not improve
# Epoch 00678: val_loss did not improve
# Epoch 00679: val_loss did not improve
# Epoch 00680: val_loss did not improve
# Epoch 00681: val_loss did not improve
# Epoch 00682: val_loss did not improve
# Epoch 00683: val_loss did not improve
# Epoch 00684: val_loss did not improve
# Epoch 00685: val_loss did not improve
# Epoch 00686: val_loss did not improve
# Epoch 00687: val_loss did not improve
# Epoch 00688: val_loss did not improve
# Epoch 00689: val_loss did not improve
# Epoch 00690: val_loss did not improve
# Epoch 00691: val_loss did not improve
# Epoch 00692: val_loss did not improve
# Epoch 00693: val_loss did not improve
# Epoch 00694: val_loss did not improve
# Epoch 00695: val_loss did not improve
# Epoch 00696: val_loss did not improve
# Epoch 00697: val_loss did not improve
# Epoch 00698: val_loss did not improve
# Epoch 00699: val_loss did not improve
# Epoch 00700: val_loss did not improve
# Epoch 00701: val_loss did not improve
# Epoch 00702: val_loss did not improve
# Epoch 00703: val_loss did not improve
# Epoch 00704: val_loss did not improve
# Epoch 00705: val_loss did not improve
# Epoch 00706: val_loss did not improve
# Epoch 00707: val_loss did not improve
# Epoch 00708: val_loss did not improve
# Epoch 00709: val_loss did not improve
# Epoch 00710: val_loss did not improve
# Epoch 00711: val_loss did not improve
# Epoch 00712: val_loss did not improve
# Epoch 00713: val_loss did not improve
# Epoch 00714: val_loss did not improve
# Epoch 00715: val_loss did not improve
# Epoch 00716: val_loss did not improve
# Epoch 00717: val_loss did not improve
# Epoch 00718: val_loss did not improve
# Epoch 00719: val_loss did not improve
# Epoch 00720: val_loss did not improve
# Epoch 00721: val_loss did not improve
# Epoch 00722: val_loss did not improve
# Epoch 00723: val_loss did not improve
# Epoch 00724: val_loss did not improve
# Epoch 00725: val_loss did not improve
# Epoch 00726: val_loss did not improve
# Epoch 00727: val_loss did not improve
# Epoch 00728: val_loss did not improve
# Epoch 00729: val_loss did not improve
# Epoch 00730: val_loss did not improve
# Epoch 00731: val_loss did not improve
# Epoch 00732: val_loss did not improve
# Epoch 00733: val_loss did not improve
# Epoch 00734: val_loss did not improve
# Epoch 00735: val_loss did not improve
# Epoch 00736: val_loss did not improve
# Epoch 00737: val_loss did not improve
# Epoch 00738: val_loss did not improve
# Epoch 00739: val_loss did not improve
# Epoch 00740: val_loss did not improve
# Epoch 00741: val_loss did not improve
# Epoch 00742: val_loss did not improve
# Epoch 00743: val_loss did not improve
# Epoch 00744: val_loss did not improve
# Epoch 00745: val_loss did not improve
# Epoch 00746: val_loss did not improve
# Epoch 00747: val_loss did not improve
# Epoch 00748: val_loss did not improve
# Epoch 00749: val_loss did not improve
# Epoch 00750: val_loss did not improve
# Epoch 00751: val_loss did not improve
# Epoch 00752: val_loss did not improve
# Epoch 00753: val_loss did not improve
# Epoch 00754: val_loss did not improve
# Epoch 00755: val_loss did not improve
# Epoch 00756: val_loss did not improve
# Epoch 00757: val_loss did not improve
# Epoch 00758: val_loss did not improve
# Epoch 00759: val_loss did not improve
# Epoch 00760: val_loss did not improve
# Epoch 00761: val_loss did not improve
# Epoch 00762: val_loss did not improve
# Epoch 00763: val_loss did not improve
# Epoch 00764: val_loss did not improve
# Epoch 00765: val_loss did not improve
# Epoch 00766: val_loss did not improve
# Epoch 00767: val_loss did not improve
# Epoch 00768: val_loss did not improve
# Epoch 00769: val_loss did not improve
# Epoch 00770: val_loss did not improve
# Epoch 00771: val_loss did not improve
# Epoch 00772: val_loss did not improve
# Epoch 00773: val_loss did not improve
# Epoch 00774: val_loss did not improve
# Epoch 00775: val_loss did not improve
# Epoch 00776: val_loss did not improve
# Epoch 00777: val_loss did not improve
# Epoch 00778: val_loss did not improve
# Epoch 00779: val_loss did not improve
# Epoch 00780: val_loss did not improve
# Epoch 00781: val_loss did not improve
# Epoch 00782: val_loss did not improve
# Epoch 00783: val_loss did not improve
# Epoch 00784: val_loss did not improve
# Epoch 00785: val_loss did not improve
# Epoch 00786: val_loss did not improve
# Epoch 00787: val_loss did not improve
# Epoch 00788: val_loss did not improve
# Epoch 00789: val_loss did not improve
# Epoch 00790: val_loss did not improve
# Epoch 00791: val_loss did not improve
# Epoch 00792: val_loss did not improve
# Epoch 00793: val_loss did not improve
# Epoch 00794: val_loss did not improve
# Epoch 00795: val_loss did not improve
# Epoch 00796: val_loss did not improve
# Epoch 00797: val_loss did not improve
# Epoch 00798: val_loss did not improve
# Epoch 00799: val_loss did not improve
# Epoch 00800: val_loss did not improve
# Epoch 00801: val_loss did not improve
# Epoch 00802: val_loss did not improve
# Epoch 00803: val_loss did not improve
# Epoch 00804: val_loss did not improve
# Epoch 00805: val_loss did not improve
# Epoch 00806: val_loss did not improve
# Epoch 00807: val_loss did not improve
# Epoch 00808: val_loss did not improve
# Epoch 00809: val_loss did not improve
# Epoch 00810: val_loss did not improve
# Epoch 00811: val_loss did not improve
# Epoch 00812: val_loss did not improve
# Epoch 00813: val_loss did not improve
# Epoch 00814: val_loss did not improve
# Epoch 00815: val_loss did not improve
# Epoch 00816: val_loss did not improve
# Epoch 00817: val_loss did not improve
# Epoch 00818: val_loss did not improve
# Epoch 00819: val_loss did not improve
# Epoch 00820: val_loss did not improve
# Epoch 00821: val_loss did not improve
# Epoch 00822: val_loss did not improve
# Epoch 00823: val_loss did not improve
# Epoch 00824: val_loss did not improve
# Epoch 00825: val_loss did not improve
# Epoch 00826: val_loss did not improve
# Epoch 00827: val_loss did not improve
# Epoch 00828: val_loss did not improve
# Epoch 00829: val_loss did not improve
# Epoch 00830: val_loss did not improve
# Epoch 00831: val_loss did not improve
# Epoch 00832: val_loss did not improve
# Epoch 00833: val_loss did not improve
# Epoch 00834: val_loss did not improve
# Epoch 00835: val_loss did not improve
# Epoch 00836: val_loss did not improve
# Epoch 00837: val_loss did not improve
# Epoch 00838: val_loss did not improve
# Epoch 00839: val_loss did not improve
# Epoch 00840: val_loss did not improve
# Epoch 00841: val_loss did not improve
# Epoch 00842: val_loss did not improve
# Epoch 00843: val_loss did not improve
# Epoch 00844: val_loss did not improve
# Epoch 00845: val_loss did not improve
# Epoch 00846: val_loss did not improve
# Epoch 00847: val_loss did not improve
# Epoch 00848: val_loss did not improve
# Epoch 00849: val_loss did not improve
# Epoch 00850: val_loss did not improve
# Epoch 00851: val_loss did not improve
# Epoch 00852: val_loss did not improve
# Epoch 00853: val_loss did not improve
# Epoch 00854: val_loss did not improve
# Epoch 00855: val_loss did not improve
# Epoch 00856: val_loss did not improve
# Epoch 00857: val_loss did not improve
# Epoch 00858: val_loss did not improve
# Epoch 00859: val_loss did not improve
# Epoch 00860: val_loss did not improve
# Epoch 00861: val_loss did not improve
# Epoch 00862: val_loss did not improve
# Epoch 00863: val_loss did not improve
# Epoch 00864: val_loss did not improve
# Epoch 00865: val_loss did not improve
# Epoch 00866: val_loss did not improve
# Epoch 00867: val_loss did not improve
# Epoch 00868: val_loss did not improve
# Epoch 00869: val_loss did not improve
# Epoch 00870: val_loss did not improve
# Epoch 00871: val_loss did not improve
# Epoch 00872: val_loss did not improve
# Epoch 00873: val_loss did not improve
# Epoch 00874: val_loss did not improve
# Epoch 00875: val_loss did not improve
# Epoch 00876: val_loss did not improve
# Epoch 00877: val_loss did not improve
# Epoch 00878: val_loss did not improve
# Epoch 00879: val_loss did not improve
# Epoch 00880: val_loss did not improve
# Epoch 00881: val_loss did not improve
# Epoch 00882: val_loss did not improve
# Epoch 00883: val_loss did not improve
# Epoch 00884: val_loss did not improve
# Epoch 00885: val_loss did not improve
# Epoch 00886: val_loss did not improve
# Epoch 00887: val_loss did not improve
# Epoch 00888: val_loss did not improve
# Epoch 00889: val_loss did not improve
# Epoch 00890: val_loss did not improve
# Epoch 00891: val_loss did not improve
# Epoch 00892: val_loss did not improve
# Epoch 00893: val_loss did not improve
# Epoch 00894: val_loss did not improve
# Epoch 00895: val_loss did not improve
# Epoch 00896: val_loss did not improve
# Epoch 00897: val_loss did not improve
# Epoch 00898: val_loss did not improve
# Epoch 00899: val_loss did not improve
# Epoch 00900: val_loss did not improve
# Epoch 00901: val_loss did not improve
# Epoch 00902: val_loss did not improve
# Epoch 00903: val_loss did not improve
# Epoch 00904: val_loss did not improve
# Epoch 00905: val_loss did not improve
# Epoch 00906: val_loss did not improve
# Epoch 00907: val_loss did not improve
# Epoch 00908: val_loss did not improve
# Epoch 00909: val_loss did not improve
# Epoch 00910: val_loss did not improve
# Epoch 00911: val_loss did not improve
# Epoch 00912: val_loss did not improve
# Epoch 00913: val_loss did not improve
# Epoch 00914: val_loss did not improve
# Epoch 00915: val_loss did not improve
# Epoch 00916: val_loss did not improve
# Epoch 00917: val_loss did not improve
# Epoch 00918: val_loss did not improve
# Epoch 00919: val_loss did not improve
# Epoch 00920: val_loss did not improve
# Epoch 00921: val_loss did not improve
# Epoch 00922: val_loss did not improve
# Epoch 00923: val_loss did not improve
# Epoch 00924: val_loss did not improve
# Epoch 00925: val_loss did not improve
# Epoch 00926: val_loss did not improve
# Epoch 00927: val_loss did not improve
# Epoch 00928: val_loss did not improve
# Epoch 00929: val_loss did not improve
# Epoch 00930: val_loss did not improve
# Epoch 00931: val_loss did not improve
# Epoch 00932: val_loss did not improve
# Epoch 00933: val_loss did not improve
# Epoch 00934: val_loss did not improve
# Epoch 00935: val_loss did not improve
# Epoch 00936: val_loss did not improve
# Epoch 00937: val_loss did not improve
# Epoch 00938: val_loss did not improve
# Epoch 00939: val_loss did not improve
# Epoch 00940: val_loss did not improve
# Epoch 00941: val_loss did not improve
# Epoch 00942: val_loss did not improve
# Epoch 00943: val_loss did not improve
# Epoch 00944: val_loss did not improve
# Epoch 00945: val_loss did not improve
# Epoch 00946: val_loss did not improve
# Epoch 00947: val_loss did not improve
# Epoch 00948: val_loss did not improve
# Epoch 00949: val_loss did not improve
# Epoch 00950: val_loss did not improve
# Epoch 00951: val_loss did not improve
# Epoch 00952: val_loss did not improve
# Epoch 00953: val_loss did not improve
# Epoch 00954: val_loss did not improve
# Epoch 00955: val_loss did not improve
# Epoch 00956: val_loss did not improve
# Epoch 00957: val_loss did not improve
# Epoch 00958: val_loss did not improve
# Epoch 00959: val_loss did not improve
# Epoch 00960: val_loss did not improve
# Epoch 00961: val_loss did not improve
# Epoch 00962: val_loss did not improve
# Epoch 00963: val_loss did not improve
# Epoch 00964: val_loss did not improve
# Epoch 00965: val_loss did not improve
# Epoch 00966: val_loss did not improve
# Epoch 00967: val_loss did not improve
# Epoch 00968: val_loss did not improve
# Epoch 00969: val_loss did not improve
# Epoch 00970: val_loss did not improve
# Epoch 00971: val_loss did not improve
# Epoch 00972: val_loss did not improve
# Epoch 00973: val_loss did not improve
# Epoch 00974: val_loss did not improve
# Epoch 00975: val_loss did not improve
# Epoch 00976: val_loss did not improve
# Epoch 00977: val_loss did not improve
# Epoch 00978: val_loss did not improve
# Epoch 00979: val_loss did not improve
# Epoch 00980: val_loss did not improve
# Epoch 00981: val_loss did not improve
# Epoch 00982: val_loss did not improve
# Epoch 00983: val_loss did not improve
# Epoch 00984: val_loss did not improve
# Epoch 00985: val_loss did not improve
# Epoch 00986: val_loss did not improve
# Epoch 00987: val_loss did not improve
# Epoch 00988: val_loss did not improve
# Epoch 00989: val_loss did not improve
# Epoch 00990: val_loss did not improve
# Epoch 00991: val_loss did not improve
# Epoch 00992: val_loss did not improve
# Epoch 00993: val_loss did not improve
# Epoch 00994: val_loss did not improve
# Epoch 00995: val_loss did not improve
# Epoch 00996: val_loss did not improve
# Epoch 00997: val_loss did not improve
# Epoch 00998: val_loss did not improve
# Epoch 00999: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   1000
# Best loss at iteratation:     993    Best: 0.0869412902743
# Best val_loss at iteratation: 263    Best: 0.203437958161

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.194896164133
# (535, 1)
# (535,)
# MAE:  92.622
# RMSE: 133.183
# R2:   0.661

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:]], axis=1), 
                      np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:]], axis=1), 
                            np.concatenate([event_feats_test[:,np.newaxis], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.194896164133
# (535, 1)
# (535,)
# MAE:  92.622
# RMSE: 133.183
# R2:   0.661
