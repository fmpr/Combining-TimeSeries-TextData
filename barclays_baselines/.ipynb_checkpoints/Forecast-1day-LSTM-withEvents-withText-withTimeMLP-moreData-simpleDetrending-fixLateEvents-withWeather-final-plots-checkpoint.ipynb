# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from datetime import datetime
from sklearn import datasets, linear_model
from matplotlib import pyplot as plt
from matplotlib import cm
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import BatchNormalization, Input, Embedding, Concatenate, Conv1D, MaxPooling1D, Flatten
from keras.models import Sequential, Model
import keras.backend as K
import statsmodels.formula.api as smf
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# prevent tensorflow from allocating the entire GPU memory at once
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# Using TensorFlow backend.

# %% [markdown]
# ## Load weather data

# %%
# load data
df = pd.read_csv("../central_park_weather.csv")
df = df.set_index("date")

# replace predefined values with NaN
df = df.replace(99.99, np.nan)
df = df.replace(999.9, np.nan)
df = df.replace(9999.9, np.nan)

# replace NaN with 0 for snow depth
df["snow_depth"] = df["snow_depth"].fillna(0)

# do interpolation for the remaining NaNs
df = df.interpolate()

# standardize data
removed_mean = df.mean()
removed_std = df.std()
weather = (df - removed_mean) / removed_std

weather.head()
# Out:
#             min_temp  max_temp  wind_speed  wind_gust  visibility  pressure  \
# date
# 2009-01-01 -2.016735 -2.128488    2.946112   2.512634    0.666065  0.571023
# 2009-01-02 -1.602221 -1.739134    0.276908  -0.188044    0.236614 -0.040850
# 2009-01-03 -1.108462 -1.472148    1.211129   0.018115    0.666065 -0.503153
# 2009-01-04 -1.413252 -1.238535    1.033182  -0.579745    0.666065  0.244691
# 2009-01-05 -0.626895 -1.188475    0.588315  -1.218837    0.666065 -0.272002
#
#             precipitation  snow_depth       fog  rain_drizzle  snow_ice  \
# date
# 2009-01-01      -0.273606   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-02      -0.378683   -0.240596 -0.326133     -0.709709  3.913921
# 2009-01-03      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-04      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2009-01-05      -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
#
#              thunder
# date
# 2009-01-01 -0.037018
# 2009-01-02 -0.037018
# 2009-01-03 -0.037018
# 2009-01-04 -0.037018
# 2009-01-05 -0.037018

# %% [markdown]
# ## Load events data

# %%
events = pd.read_csv("barclays_events_preprocessed.tsv", sep="\t")
events.head()
# Out:
#    Unnamed: 0        date           start_time  \
# 0           0  2013-02-22  2013-02-22 19:30:00
# 1           1  2015-10-09  2015-10-09 19:30:00
# 2           2  2015-03-20  2015-03-20 19:30:00
# 3           3  2013-11-18  2013-11-18 19:30:00
# 4           4  2015-04-12  2015-04-12 20:00:00
#
#                                        title  \
# 0           Brooklyn Nets vs Houston Rockets
# 1  New York Islanders vs. Chicago Blackhawks
# 2          Brooklyn Nets vs. Milwaukee Bucks
# 3   Brooklyn Nets vs. Portland Trail Blazers
# 4                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
events['start_time'] = pd.to_datetime(events['start_time'], format='%Y-%m-%d %H:%M')
events['date'] = events['start_time'].dt.strftime("%Y-%m-%d")
events = events[["date","start_time","title","url","description"]]
events.head()
# Out:
#          date          start_time                                      title  \
# 0  2013-02-22 2013-02-22 19:30:00           Brooklyn Nets vs Houston Rockets
# 1  2015-10-09 2015-10-09 19:30:00  New York Islanders vs. Chicago Blackhawks
# 2  2015-03-20 2015-03-20 19:30:00          Brooklyn Nets vs. Milwaukee Bucks
# 3  2013-11-18 2013-11-18 19:30:00   Brooklyn Nets vs. Portland Trail Blazers
# 4  2015-04-12 2015-04-12 20:00:00                              Stevie Wonder
#
#                                                  url  \
# 0  http://www.barclayscenter.com/events/detail/br...
# 1  http://www.barclayscenter.com/events/detail/ne...
# 2  http://www.barclayscenter.com/events/detail/br...
# 3  http://www.barclayscenter.com/events/detail/br...
# 4  http://www.barclayscenter.com/events/detail/st...
#
#                                          description
# 0  jeremy james harden make their only appearance...
# 1  make dinner reservation today calling emailing...
# 2                                                NaN
# 3                                                NaN
# 4  legendary singer songwriter musician bringing ...

# %%
# late events
print len(events["start_time"].dt.hour.values)
print np.sum(events["start_time"].dt.hour.values >= 20)
print np.sum(events["start_time"].dt.hour.values >= 21)
plt.hist(events["start_time"].dt.hour.values)
# Out:
# 885
# 172
# 11
# (array([  31.,    0.,    0.,    0.,   13.,   67.,   63.,   51.,  488.,  172.]),
#  array([  0. ,   2.2,   4.4,   6.6,   8.8,  11. ,  13.2,  15.4,  17.6,
#          19.8,  22. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("/home/fmpr/data/pickups_barclays_center_0.003.csv")
df.head()
# Out:
#          date  hour  minute  pickups
# 0  2009-01-01     0       0        2
# 1  2009-01-01     0       1       15
# 2  2009-01-01     1       0       13
# 3  2009-01-01     1       1       16
# 4  2009-01-01     2       0       19

# %%
df_sum = pd.DataFrame(df.groupby("date")["pickups"].sum())
df_sum["date"] = df_sum.index
df_sum.index = pd.to_datetime(df_sum.index, format='%Y-%m-%d %H:%M')
df_sum["dow"] = df_sum.index.weekday
df_sum.head()
# Out:
#             pickups        date  dow
# date
# 2009-01-01      253  2009-01-01    3
# 2009-01-02      137  2009-01-02    4
# 2009-01-03      239  2009-01-03    5
# 2009-01-04      218  2009-01-04    6
# 2009-01-05       92  2009-01-05    0

# %%
plt.plot(df_sum["pickups"])

# %%
# add events information
event_col = np.zeros((len(df_sum)))
late_event = np.zeros((len(df_sum)))
really_late_event = np.zeros((len(df_sum)))
event_desc_col = []
for i in xrange(len(df_sum)):
    if df_sum.iloc[i].date in events["date"].values:
        event_col[i] = 1
        event_descr = ""
        for e in events[events.date == df_sum.iloc[i].date]["description"]:
            event_descr += str(e) + " "
        event_desc_col.append(event_descr)
        for e in events[events.date == df_sum.iloc[i].date]["start_time"]:
            if e.hour >= 20:
                late_event[i] = 1
            if e.hour >= 21:
                really_late_event[i] = 1
    else:
        event_desc_col.append("None")
df_sum["event"] = event_col
df_sum["late_event"] = late_event
df_sum["really_late_event"] = really_late_event
df_sum["event_desc"] = event_desc_col
df_sum["event_next_day"] = pd.Series(df_sum["event"]).shift(-1)
df_sum["late_event_next_day"] = pd.Series(df_sum["late_event"]).shift(-1)
df_sum["really_late_event_next_day"] = pd.Series(df_sum["really_late_event"]).shift(-1)
df_sum["event_next_day_desc"] = pd.Series(df_sum["event_desc"]).shift(-1)
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      253  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      137  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      239  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      218  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05       92  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day event_next_day_desc
# date
# 2009-01-01                         0.0                None
# 2009-01-02                         0.0                None
# 2009-01-03                         0.0                None
# 2009-01-04                         0.0                None
# 2009-01-05                         0.0                None

# %%
# merge with weather data
df_sum = df_sum.join(weather, how='inner')
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2009-01-01      253  2009-01-01    3    0.0         0.0                0.0
# 2009-01-02      137  2009-01-02    4    0.0         0.0                0.0
# 2009-01-03      239  2009-01-03    5    0.0         0.0                0.0
# 2009-01-04      218  2009-01-04    6    0.0         0.0                0.0
# 2009-01-05       92  2009-01-05    0    0.0         0.0                0.0
#
#            event_desc  event_next_day  late_event_next_day  \
# date
# 2009-01-01       None             0.0                  0.0
# 2009-01-02       None             0.0                  0.0
# 2009-01-03       None             0.0                  0.0
# 2009-01-04       None             0.0                  0.0
# 2009-01-05       None             0.0                  0.0
#
#             really_late_event_next_day    ...    wind_speed  wind_gust  \
# date                                      ...
# 2009-01-01                         0.0    ...      2.946112   2.512634
# 2009-01-02                         0.0    ...      0.276908  -0.188044
# 2009-01-03                         0.0    ...      1.211129   0.018115
# 2009-01-04                         0.0    ...      1.033182  -0.579745
# 2009-01-05                         0.0    ...      0.588315  -1.218837
#
#             visibility  pressure  precipitation  snow_depth       fog  \
# date
# 2009-01-01    0.666065  0.571023      -0.273606   -0.240596 -0.326133
# 2009-01-02    0.236614 -0.040850      -0.378683   -0.240596 -0.326133
# 2009-01-03    0.666065 -0.503153      -0.378683   -0.240596 -0.326133
# 2009-01-04    0.666065  0.244691      -0.378683   -0.240596 -0.326133
# 2009-01-05    0.666065 -0.272002      -0.378683   -0.240596 -0.326133
#
#             rain_drizzle  snow_ice   thunder
# date
# 2009-01-01     -0.709709 -0.255411 -0.037018
# 2009-01-02     -0.709709  3.913921 -0.037018
# 2009-01-03     -0.709709 -0.255411 -0.037018
# 2009-01-04     -0.709709 -0.255411 -0.037018
# 2009-01-05     -0.709709 -0.255411 -0.037018
#
# [5 rows x 23 columns]

# %%
# keep only data after 2013
START_YEAR = 2013
df_sum = df_sum.loc[df_sum.index.year >= START_YEAR]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      184  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      181  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      229  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05      534  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day    ...     \
# date                                                           ...
# 2013-01-01                  0.0                         0.0    ...
# 2013-01-02                  0.0                         0.0    ...
# 2013-01-03                  0.0                         0.0    ...
# 2013-01-04                  0.0                         0.0    ...
# 2013-01-05                  0.0                         0.0    ...
#
#            wind_speed  wind_gust  visibility  pressure  precipitation  \
# date
# 2013-01-01   0.499342  -0.188044    0.666065 -0.598334      -0.378683
# 2013-01-02   0.143448  -0.188044    0.666065  0.067928      -0.378683
# 2013-01-03  -0.568340  -1.012679    0.666065  0.584620      -0.378683
# 2013-01-04   0.677289   0.863365    0.666065  0.095122      -0.378683
# 2013-01-05   0.721775   0.224273    0.666065  0.584620      -0.378683
#
#             snow_depth       fog  rain_drizzle  snow_ice   thunder
# date
# 2013-01-01   -0.240596 -0.326133     -0.709709 -0.255411 -0.037018
# 2013-01-02   -0.240596 -0.326133     -0.709709 -0.255411 -0.037018
# 2013-01-03   -0.240596 -0.326133     -0.709709 -0.255411 -0.037018
# 2013-01-04   -0.240596 -0.326133     -0.709709 -0.255411 -0.037018
# 2013-01-05   -0.240596 -0.326133     -0.709709 -0.255411 -0.037018
#
# [5 rows x 23 columns]

# %%
df_sum.describe()
# Out:
#            pickups          dow        event   late_event  really_late_event  \
# count  1277.000000  1277.000000  1277.000000  1277.000000        1277.000000
# mean    747.750979     2.997651     0.431480     0.097103           0.006265
# std     313.328349     1.999411     0.495477     0.296213           0.078932
# min     156.000000     0.000000     0.000000     0.000000           0.000000
# 25%     532.000000     1.000000     0.000000     0.000000           0.000000
# 50%     734.000000     3.000000     0.000000     0.000000           0.000000
# 75%     968.000000     5.000000     1.000000     0.000000           0.000000
# max    1908.000000     6.000000     1.000000     1.000000           1.000000
#
#        event_next_day  late_event_next_day  really_late_event_next_day  \
# count     1276.000000          1276.000000                 1276.000000
# mean         0.431818             0.097179                    0.006270
# std          0.495524             0.296317                    0.078963
# min          0.000000             0.000000                    0.000000
# 25%          0.000000             0.000000                    0.000000
# 50%          0.000000             0.000000                    0.000000
# 75%          1.000000             0.000000                    0.000000
# max          1.000000             1.000000                    1.000000
#
#           min_temp     max_temp   wind_speed    wind_gust   visibility  \
# count  1277.000000  1277.000000  1277.000000  1277.000000  1277.000000
# mean     -0.085462    -0.007284    -0.121661    -0.049800     0.022417
# std       1.053628     1.023326     0.889573     0.894912     0.987062
# min      -2.992062    -2.601275    -1.902942    -1.218837    -4.425996
# 25%      -0.864630    -0.860305    -0.746287    -0.722182    -0.254187
# 50%      -0.011219     0.090832    -0.256933    -0.188044     0.543364
# 75%       0.848287     0.925163     0.365881     0.430432     0.666065
# max       2.116212     1.876300     3.568927     4.141288     0.666065
#
#           pressure  precipitation   snow_depth          fog  rain_drizzle  \
# count  1277.000000    1277.000000  1277.000000  1277.000000   1277.000000
# mean      0.110982      -0.031752     0.070848    -0.079154     -0.086010
# std       0.969564       0.929166     1.111323     0.881587      0.965859
# min      -3.358559      -0.378683    -0.240596    -0.326133     -0.709709
# 25%      -0.530348      -0.378683    -0.240596    -0.326133     -0.709709
# 50%       0.095122      -0.378683    -0.240596    -0.326133     -0.709709
# 75%       0.734189      -0.221068    -0.240596    -0.326133      1.408545
# max       3.494414      11.521269     8.586790     3.065185      1.408545
#
#           snow_ice       thunder
# count  1277.000000  1.277000e+03
# mean      0.048229 -3.701801e-02
# std       1.083835  6.941612e-18
# min      -0.255411 -3.701801e-02
# 25%      -0.255411 -3.701801e-02
# 50%      -0.255411 -3.701801e-02
# 75%      -0.255411 -3.701801e-02
# max       3.913921 -3.701801e-02

# %%
df_sum["year"] = df_sum.index.year
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      184  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      181  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      229  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05      534  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day  ...  wind_gust  \
# date                                                         ...
# 2013-01-01                  0.0                         0.0  ...  -0.188044
# 2013-01-02                  0.0                         0.0  ...  -0.188044
# 2013-01-03                  0.0                         0.0  ...  -1.012679
# 2013-01-04                  0.0                         0.0  ...   0.863365
# 2013-01-05                  0.0                         0.0  ...   0.224273
#
#             visibility  pressure  precipitation  snow_depth       fog  \
# date
# 2013-01-01    0.666065 -0.598334      -0.378683   -0.240596 -0.326133
# 2013-01-02    0.666065  0.067928      -0.378683   -0.240596 -0.326133
# 2013-01-03    0.666065  0.584620      -0.378683   -0.240596 -0.326133
# 2013-01-04    0.666065  0.095122      -0.378683   -0.240596 -0.326133
# 2013-01-05    0.666065  0.584620      -0.378683   -0.240596 -0.326133
#
#             rain_drizzle  snow_ice   thunder  year
# date
# 2013-01-01     -0.709709 -0.255411 -0.037018  2013
# 2013-01-02     -0.709709 -0.255411 -0.037018  2013
# 2013-01-03     -0.709709 -0.255411 -0.037018  2013
# 2013-01-04     -0.709709 -0.255411 -0.037018  2013
# 2013-01-05     -0.709709 -0.255411 -0.037018  2013
#
# [5 rows x 24 columns]

# %%
trend_mean = df_sum[df_sum.index.year < 2015].groupby(["dow"]).mean()["pickups"]
trend_mean
# Out:
# dow
# 0    470.538462
# 1    483.285714
# 2    526.504762
# 3    527.576923
# 4    653.596154
# 5    812.192308
# 6    738.471154
# Name: pickups, dtype: float64

# %%
#trend_std = df_sum.groupby(["year"]).std()["pickups"]
trend_std = df_sum["pickups"].std()
trend_std
# Out:
# 313.32834892618996

# %%
# build vectors with trend to remove and std
trend = []
std = []
for ix, row in df_sum.iterrows():
    trend.append(trend_mean[row.dow])
    #std.append(trend_std[row.year])
    std.append(trend_std)
print len(trend)
df_sum["trend"] = trend
df_sum["std"] = std
# Out:
# 1277

# %%
# detrend data
df_sum["detrended"] = (df_sum["pickups"] - df_sum["trend"]) / df_sum["std"]
df_sum.head()
# Out:
#             pickups        date  dow  event  late_event  really_late_event  \
# date
# 2013-01-01      588  2013-01-01    1    0.0         0.0                0.0
# 2013-01-02      184  2013-01-02    2    0.0         0.0                0.0
# 2013-01-03      181  2013-01-03    3    0.0         0.0                0.0
# 2013-01-04      229  2013-01-04    4    0.0         0.0                0.0
# 2013-01-05      534  2013-01-05    5    1.0         0.0                0.0
#
#                                                    event_desc  event_next_day  \
# date
# 2013-01-01                                               None             0.0
# 2013-01-02                                               None             0.0
# 2013-01-03                                               None             0.0
# 2013-01-04                                               None             1.0
# 2013-01-05  net home game schedule highlight include oneti...             0.0
#
#             late_event_next_day  really_late_event_next_day    ...      \
# date                                                           ...
# 2013-01-01                  0.0                         0.0    ...
# 2013-01-02                  0.0                         0.0    ...
# 2013-01-03                  0.0                         0.0    ...
# 2013-01-04                  0.0                         0.0    ...
# 2013-01-05                  0.0                         0.0    ...
#
#            precipitation  snow_depth       fog  rain_drizzle  snow_ice  \
# date
# 2013-01-01     -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2013-01-02     -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2013-01-03     -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2013-01-04     -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
# 2013-01-05     -0.378683   -0.240596 -0.326133     -0.709709 -0.255411
#
#              thunder  year       trend         std  detrended
# date
# 2013-01-01 -0.037018  2013  483.285714  313.328349   0.334200
# 2013-01-02 -0.037018  2013  526.504762  313.328349  -1.093118
# 2013-01-03 -0.037018  2013  527.576923  313.328349  -1.106114
# 2013-01-04 -0.037018  2013  653.596154  313.328349  -1.355116
# 2013-01-05 -0.037018  2013  812.192308  313.328349  -0.887862
#
# [5 rows x 27 columns]

# %%
plt.plot(df_sum["pickups"])
plt.plot(df_sum["trend"])
plt.plot(df_sum["std"])

# %%
plt.plot(df_sum["detrended"])
plt.plot(df_sum["event"])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2016, "detrended"][:30])
plt.plot(df_sum.loc[df_sum.index.year == 2016, "event"][:30])

# %%
plt.plot(df_sum.loc[df_sum.index.year == 2015, "detrended"][:50], "k-")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "event"][:50], "r--")
plt.plot(df_sum.loc[df_sum.index.year == 2015, "late_event"][:50], "b--")

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"], df_sum["event"])
# Out:
# array([[ 1.        ,  0.30268346],
#        [ 0.30268346,  1.        ]])

# %%
# compute correlation between pickups and event signal
np.corrcoef(df_sum["detrended"][:-1], df_sum["late_event_next_day"][:-1])
# Out:
# array([[ 1.        , -0.09115803],
#        [-0.09115803,  1.        ]])

# %%
import scipy
scipy.stats.spearmanr(df_sum["detrended"], df_sum["event"])
# Out:
# SpearmanrResult(correlation=0.31527138544703964, pvalue=7.2897955011241835e-31)

# %% [markdown]
# ## Build lags and features

# %%
df_sum.columns
# Out:
# Index([u'pickups', u'date', u'dow', u'event', u'late_event',
#        u'really_late_event', u'event_desc', u'event_next_day',
#        u'late_event_next_day', u'really_late_event_next_day',
#        u'event_next_day_desc', u'min_temp', u'max_temp', u'wind_speed',
#        u'wind_gust', u'visibility', u'pressure', u'precipitation',
#        u'snow_depth', u'fog', u'rain_drizzle', u'snow_ice', u'thunder',
#        u'year', u'trend', u'std', u'detrended'],
#       dtype='object')

# %%
NUM_LAGS = 10

lags = pd.concat([pd.Series(df_sum["detrended"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_feats = np.concatenate([df_sum["event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["late_event"].as_matrix()[:,np.newaxis],
                             #df_sum["late_event_next_day"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event"].as_matrix()[:,np.newaxis],
                             df_sum["really_late_event_next_day"].as_matrix()[:,np.newaxis]], axis=1)
lags_event_feats = pd.concat([pd.Series(df_sum["event_next_day"]).shift(x) for x in range(0,NUM_LAGS)],axis=1).as_matrix()
event_texts = df_sum["event_next_day_desc"].as_matrix()
weather_feats = df_sum[['min_temp', u'max_temp', u'wind_speed',
       u'wind_gust', u'visibility', u'pressure', u'precipitation',
       u'snow_depth', u'fog', u'rain_drizzle', u'snow_ice', u'thunder']].as_matrix()
preds = pd.Series(df_sum["detrended"]).shift(-1).as_matrix()
trends = df_sum["trend"].as_matrix()
stds = df_sum["std"].as_matrix()

lags = lags[NUM_LAGS:-1,:]
event_feats = event_feats[NUM_LAGS:-1,:]
lags_event_feats = lags_event_feats[NUM_LAGS:-1,:]
event_texts = event_texts[NUM_LAGS:-1]
weather_feats = weather_feats[NUM_LAGS:-1,:]
preds = preds[NUM_LAGS:-1]
trends = trends[NUM_LAGS:-1]
stds = stds[NUM_LAGS:-1]
print "lags:", lags.shape
print "event_feats:", event_feats.shape
print "lags_event_feats:", lags_event_feats.shape
print "event_texts:", event_texts.shape
print "weather_feats:", weather_feats.shape
print "preds:", preds.shape
print "trends:", trends.shape
print "stds:", stds.shape
# Out:
# lags: (1266, 10)
# event_feats: (1266, 4)
# lags_event_feats: (1266, 10)
# event_texts: (1266,)
# weather_feats: (1266, 12)
# preds: (1266,)
# trends: (1266,)
# stds: (1266,)

# %%
for i in xrange(NUM_LAGS):
    print i, np.corrcoef(lags[:,i], preds)[0,1]
# Out:
# 0 0.782244174305
# 1 0.731196742354
# 2 0.691024188265
# 3 0.703718031704
# 4 0.711376942428
# 5 0.713914167655
# 6 0.742115173222
# 7 0.719673348891
# 8 0.69565035192
# 9 0.681006060537

# %%
for i in xrange(NUM_LAGS-1):
    print i, np.corrcoef(lags[:,i], lags_event_feats[:,i+1])[0,1]
# Out:
# 0 0.298651917502
# 1 0.299359667567
# 2 0.300257449504
# 3 0.301239297957
# 4 0.302651598162
# 5 0.304190996274
# 6 0.303205486189
# 7 0.303308801188
# 8 0.304255471815

# %%
np.corrcoef(preds[:], event_feats[:,0])
# Out:
# array([[ 1.        ,  0.30006484],
#        [ 0.30006484,  1.        ]])

# %% [markdown]
# ## Train/test split

# %%
i_train = 365*2-90 # 2013 and 2014
i_val = 365*2
i_test = -1 # 2015 and 2016 (everything else)

lags_train = lags[:i_train,:] # time series lags
event_feats_train = event_feats[:i_train,:] # event/no_event
lags_event_feats_train = lags_event_feats[:i_train,:] # lags for event/no_event
event_texts_train = event_texts[:i_train] # event text descriptions
weather_feats_train = weather_feats[:i_train,:] # weather data
y_train = preds[:i_train] # target values

lags_val = lags[i_train:i_val,:] # time series lags
event_feats_val = event_feats[i_train:i_val,:] # event/no_event
lags_event_feats_val = lags_event_feats[i_train:i_val,:] # lags for event/no_event
event_texts_val = event_texts[i_train:i_val] # event text descriptions
weather_feats_val = weather_feats[i_train:i_val,:] # weather data
y_val = preds[i_train:i_val] # target values

lags_test = lags[i_val:i_test,:]
event_feats_test = event_feats[i_val:i_test,:]
lags_event_feats_test = lags_event_feats[i_val:i_test,:]
event_texts_test = event_texts[i_val:i_test]
weather_feats_test = weather_feats[i_val:i_test,:]
y_test = preds[i_val:i_test]
trend_test = trends[i_val:i_test]
std_test = stds[i_val:i_test]

print "lags_train:", lags_train.shape
print "event_feats_train:", event_feats_train.shape
print "lags_event_feats_train:", lags_event_feats_train.shape
print "event_texts_train:", event_texts_train.shape
print "weather_feats_train:", weather_feats_train.shape
print "y_train:", y_train.shape

print "y_val:", y_val.shape
print "y_test:", y_test.shape

print "trend_test:", trend_test.shape
print "std_test:", std_test.shape
# Out:
# lags_train: (640, 10)
# event_feats_train: (640, 4)
# lags_event_feats_train: (640, 10)
# event_texts_train: (640,)
# weather_feats_train: (640, 12)
# y_train: (640,)
# y_val: (90,)
# y_test: (535,)
# trend_test: (535,)
# std_test: (535,)

# %% [markdown]
# ## Evaluation function

# %%
def compute_error(trues, predicted):
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %%
def compute_error_filtered(trues, predicted, filt):
    trues = trues[filt]
    predicted = predicted[filt]
    corr = np.corrcoef(predicted, trues)[0,1]
    mae = np.mean(np.abs(predicted - trues))
    mse = np.mean((predicted - trues)**2)
    rae = np.sum(np.abs(predicted - trues)) / np.sum(np.abs(trues - np.mean(trues)))
    rmse = np.sqrt(np.mean((predicted - trues)**2))
    r2 = max(0, 1 - np.sum((trues-predicted)**2) / np.sum((trues - np.mean(trues))**2))
    return corr, mae, mse, rae, rmse, r2

# %% [markdown]
# ## Linear regression baseline (just lags)

# %%
# linear regression (just lags)
regr = linear_model.LinearRegression()
regr.fit(lags_train, y_train)
preds_lr = regr.predict(lags_test)
preds_lr_lags = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr_lags)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  119.619
# RMSE: 164.510
# R2:   0.448

# %% [markdown]
# ## Linear regression with weather

# %%
# linear regression lags + weather
sel = [0,2,4,5,7,8,9]
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  119.179
# RMSE: 164.009
# R2:   0.452

# %% [markdown]
# ## Linear regression with weather + events

# %%
# linear regression lags + weather + events
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel], event_feats_train[:,:1]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel], event_feats_test[:,:1]], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  100.877
# RMSE: 142.710
# R2:   0.585

# %%
# linear regression lags + weather + events + late
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, weather_feats_train[:,sel], event_feats_train], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, weather_feats_test[:,sel], event_feats_test], axis=1))
preds_lr = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  99.661
# RMSE: 141.063
# R2:   0.594

# %%
# linear regression lags + weather + events + late + event_lags
regr = linear_model.LinearRegression()
regr.fit(np.concatenate([lags_train, event_feats_train, lags_event_feats_train, weather_feats_train[:,sel]], axis=1), y_train)
preds_lr = regr.predict(np.concatenate([lags_test, event_feats_test, lags_event_feats_test, weather_feats_test[:,sel]], axis=1))
preds_lr_events = preds_lr * std_test + trend_test
y_true = y_test * std_test + trend_test
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lr_events)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# MAE:  95.042
# RMSE: 135.896
# R2:   0.624

# %%
print len(y_true)
x = range(31,120)
plt.plot(x, y_true[x], 'k-')
plt.plot(x, preds_lr_lags[x], 'r--')
plt.plot(x, preds_lr_events[x], 'g--')
# Out:
# 535

# %% [markdown]
# ## MLP (just lags)

# %%
def build_model(num_inputs, num_lags, num_preds):
    input_lags = Input(shape=(num_lags,))
    
    x = input_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    
    model = Model(input_lags, preds)
    
    #rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS, 1)
model.fit(
    #lags_train,
    np.concatenate([lags_train], axis=1),
    y_train,
    batch_size=64,
    epochs=300,
    #validation_data=(lags_val, y_val),
    validation_data=(np.concatenate([lags_val], axis=1), y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 11.96880, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 11.96880 to 11.55969, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 11.55969 to 10.26649, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.26649 to 9.85632, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.85632 to 8.85510, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 8.85510 to 8.04806, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.04806 to 7.56849, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 7.56849 to 6.85494, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 6.85494 to 6.24218, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.24218 to 5.79820, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 5.79820 to 5.33810, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 5.33810 to 5.02043, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.02043 to 4.58716, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 4.58716 to 4.24489, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.24489 to 4.00095, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 4.00095 to 3.66878, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.66878 to 3.41556, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.41556 to 3.15189, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.15189 to 2.91776, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 2.91776 to 2.80784, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.80784 to 2.65708, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.65708 to 2.56610, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.56610 to 2.32309, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.32309 to 2.26599, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.26599 to 2.09178, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.09178 to 2.00603, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.00603 to 1.93894, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.93894 to 1.85703, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.85703 to 1.81901, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.81901 to 1.75997, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.75997 to 1.69606, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.69606 to 1.55562, saving model to weights.best.hdf5
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 1.55562 to 1.50166, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.50166 to 1.39426, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.39426 to 1.37325, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.37325 to 1.28409, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 1.28409 to 1.23971, saving model to weights.best.hdf5
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 1.23971 to 1.18202, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.18202 to 1.16734, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.16734 to 1.13505, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.13505 to 1.11838, saving model to weights.best.hdf5
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss improved from 1.11838 to 1.07433, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 1.07433 to 1.03886, saving model to weights.best.hdf5
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 1.03886 to 1.00283, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 1.00283 to 0.97663, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.97663 to 0.94668, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss improved from 0.94668 to 0.84192, saving model to weights.best.hdf5
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss improved from 0.84192 to 0.78783, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss improved from 0.78783 to 0.71899, saving model to weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.71899 to 0.71061, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.71061 to 0.65893, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.65893 to 0.63386, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.63386 to 0.53865, saving model to weights.best.hdf5
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss improved from 0.53865 to 0.52276, saving model to weights.best.hdf5
# Epoch 00071: val_loss improved from 0.52276 to 0.52240, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.52240 to 0.47835, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.47835 to 0.38490, saving model to weights.best.hdf5
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss improved from 0.38490 to 0.37691, saving model to weights.best.hdf5
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss improved from 0.37691 to 0.34597, saving model to weights.best.hdf5
# Epoch 00088: val_loss improved from 0.34597 to 0.34254, saving model to weights.best.hdf5
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss improved from 0.34254 to 0.33956, saving model to weights.best.hdf5
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss improved from 0.33956 to 0.33911, saving model to weights.best.hdf5
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss improved from 0.33911 to 0.33885, saving model to weights.best.hdf5
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss improved from 0.33885 to 0.33546, saving model to weights.best.hdf5
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     136    Best: 0.203347171843
# Best val_loss at iteratation: 270    Best: 0.335463520553

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  120.620
# RMSE: 161.352
# R2:   0.469

# %% [markdown]
# ## MLP lags + weather

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

model, input_lags, preds = build_model(1, NUM_LAGS+len(sel), 1)
model.fit(
    #lags_train,
    np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1),
    y_train,
    batch_size=64,
    epochs=300,
    #validation_data=(lags_val, y_val),
    validation_data=(np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Epoch 00000: val_loss improved from inf to 14.06826, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 14.06826 to 12.70526, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 12.70526 to 11.70272, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 11.70272 to 10.47589, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 10.47589 to 9.48230, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 9.48230 to 8.59543, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 8.59543 to 7.80952, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 7.80952 to 7.12581, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 7.12581 to 6.44851, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 6.44851 to 5.81691, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 5.81691 to 5.26991, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 5.26991 to 4.88833, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 4.88833 to 4.47940, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 4.47940 to 3.99907, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 3.99907 to 3.68271, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 3.68271 to 3.38384, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.38384 to 3.20534, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.20534 to 2.95647, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 2.95647 to 2.71929, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 2.71929 to 2.65872, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.65872 to 2.40764, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.40764 to 2.29381, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.29381 to 2.19154, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.19154 to 2.00276, saving model to weights.best.hdf5
# Epoch 00024: val_loss did not improve
# Epoch 00025: val_loss improved from 2.00276 to 1.84173, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.84173 to 1.80429, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.80429 to 1.68032, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.68032 to 1.64558, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.64558 to 1.58656, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.58656 to 1.51194, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.51194 to 1.50622, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.50622 to 1.46458, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.46458 to 1.43478, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.43478 to 1.41664, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.41664 to 1.35999, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.35999 to 1.27360, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 1.27360 to 1.25583, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.25583 to 1.23492, saving model to weights.best.hdf5
# Epoch 00040: val_loss improved from 1.23492 to 1.21347, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.21347 to 1.17273, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.17273 to 1.16583, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.16583 to 1.07050, saving model to weights.best.hdf5
# Epoch 00044: val_loss did not improve
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss improved from 1.07050 to 0.96041, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.96041 to 0.92361, saving model to weights.best.hdf5
# Epoch 00053: val_loss improved from 0.92361 to 0.85681, saving model to weights.best.hdf5
# Epoch 00054: val_loss improved from 0.85681 to 0.81072, saving model to weights.best.hdf5
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.81072 to 0.73296, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.73296 to 0.72591, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss improved from 0.72591 to 0.72395, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.72395 to 0.67063, saving model to weights.best.hdf5
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.67063 to 0.63895, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.63895 to 0.58536, saving model to weights.best.hdf5
# Epoch 00065: val_loss improved from 0.58536 to 0.54886, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss improved from 0.54886 to 0.53524, saving model to weights.best.hdf5
# Epoch 00070: val_loss improved from 0.53524 to 0.48336, saving model to weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss improved from 0.48336 to 0.44495, saving model to weights.best.hdf5
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.44495 to 0.40102, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.40102 to 0.38810, saving model to weights.best.hdf5
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.38810 to 0.36212, saving model to weights.best.hdf5
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss improved from 0.36212 to 0.35039, saving model to weights.best.hdf5
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss improved from 0.35039 to 0.35036, saving model to weights.best.hdf5
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss improved from 0.35036 to 0.34966, saving model to weights.best.hdf5
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss improved from 0.34966 to 0.34870, saving model to weights.best.hdf5
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss improved from 0.34870 to 0.34565, saving model to weights.best.hdf5
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss improved from 0.34565 to 0.34434, saving model to weights.best.hdf5
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     182    Best: 0.209473741055
# Best val_loss at iteratation: 250    Best: 0.34434396161

# %%
# load weights
model.load_weights("weights.best.hdf5")

# make predictions
preds_lstm = model.predict(np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1))
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# (535, 1)
# (535,)
# MAE:  120.080
# RMSE: 160.247
# R2:   0.477

# %% [markdown]
# ## MLP with weather + events information (no text)

# %%
def build_model_events(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    feat = Concatenate(axis=1)([input_lags, input_events])
    print feat
    
    x = feat
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(x)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_events(1, NUM_LAGS+len(sel), 4, 1)
#print model_weather.summary()
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_1/concat:0", shape=(?, 21), dtype=float32)
# Epoch 00000: val_loss improved from inf to 15.27446, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 15.27446 to 14.26188, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 14.26188 to 12.87283, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 12.87283 to 12.00919, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 12.00919 to 11.27730, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 11.27730 to 10.07599, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 10.07599 to 9.17425, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 9.17425 to 8.32070, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 8.32070 to 7.60867, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 7.60867 to 6.94817, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 6.94817 to 6.34676, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 6.34676 to 5.82397, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.82397 to 5.31964, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.31964 to 4.92590, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.92590 to 4.49925, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 4.49925 to 4.17583, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 4.17583 to 3.87597, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.87597 to 3.49048, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.49048 to 3.30052, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 3.30052 to 3.10584, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 3.10584 to 2.80902, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.80902 to 2.67043, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.67043 to 2.49761, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.49761 to 2.30745, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.30745 to 2.15118, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 2.15118 to 2.08909, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 2.08909 to 1.98058, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.98058 to 1.87566, saving model to weights.best.hdf5
# Epoch 00028: val_loss did not improve
# Epoch 00029: val_loss improved from 1.87566 to 1.67207, saving model to weights.best.hdf5
# Epoch 00030: val_loss did not improve
# Epoch 00031: val_loss improved from 1.67207 to 1.58513, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.58513 to 1.58158, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.58158 to 1.51173, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.51173 to 1.41295, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.41295 to 1.37073, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.37073 to 1.36944, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.36944 to 1.29776, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.29776 to 1.25248, saving model to weights.best.hdf5
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss improved from 1.25248 to 1.24828, saving model to weights.best.hdf5
# Epoch 00041: val_loss improved from 1.24828 to 1.22599, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 1.22599 to 1.20066, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 1.20066 to 1.13669, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 1.13669 to 1.13565, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 1.13565 to 1.13202, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.13202 to 1.02492, saving model to weights.best.hdf5
# Epoch 00048: val_loss did not improve
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 1.02492 to 0.98184, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss improved from 0.98184 to 0.93009, saving model to weights.best.hdf5
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.93009 to 0.88052, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.88052 to 0.80439, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss improved from 0.80439 to 0.77685, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.77685 to 0.76094, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.76094 to 0.68272, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.68272 to 0.66436, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.66436 to 0.65269, saving model to weights.best.hdf5
# Epoch 00064: val_loss improved from 0.65269 to 0.61149, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss improved from 0.61149 to 0.57874, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.57874 to 0.53711, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.53711 to 0.50639, saving model to weights.best.hdf5
# Epoch 00069: val_loss improved from 0.50639 to 0.49346, saving model to weights.best.hdf5
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss improved from 0.49346 to 0.45511, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss improved from 0.45511 to 0.39485, saving model to weights.best.hdf5
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss improved from 0.39485 to 0.37008, saving model to weights.best.hdf5
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss improved from 0.37008 to 0.31157, saving model to weights.best.hdf5
# Epoch 00079: val_loss improved from 0.31157 to 0.30149, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss improved from 0.30149 to 0.27661, saving model to weights.best.hdf5
# Epoch 00082: val_loss improved from 0.27661 to 0.27015, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.27015 to 0.25974, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss improved from 0.25974 to 0.25553, saving model to weights.best.hdf5
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss improved from 0.25553 to 0.25347, saving model to weights.best.hdf5
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     103    Best: 0.173354846239
# Best val_loss at iteratation: 210    Best: 0.253473953406

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.223063651855
# (535, 1)
# (535,)
# MAE:  98.323
# RMSE: 138.271
# R2:   0.610

# %% [markdown]
# ## MLP with weather + events information (no text) + event_lags

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_events(1, NUM_LAGS+len(sel), 14, 1)
#print model_weather.summary()
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1)],
    y_train,
    batch_size=64,
    epochs=300,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1)], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("concatenate_2/concat:0", shape=(?, 31), dtype=float32)
# Epoch 00000: val_loss improved from inf to 17.75354, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 17.75354 to 16.40458, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 16.40458 to 14.85891, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 14.85891 to 13.24041, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 13.24041 to 12.00960, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 12.00960 to 10.81648, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 10.81648 to 9.69157, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 9.69157 to 8.65153, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 8.65153 to 7.86132, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 7.86132 to 7.10415, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 7.10415 to 6.38067, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 6.38067 to 5.63117, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 5.63117 to 5.11980, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 5.11980 to 4.61946, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 4.61946 to 4.28082, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 4.28082 to 3.86844, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 3.86844 to 3.56388, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 3.56388 to 3.25818, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 3.25818 to 2.91095, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 2.91095 to 2.77454, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 2.77454 to 2.51840, saving model to weights.best.hdf5
# Epoch 00021: val_loss improved from 2.51840 to 2.28203, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 2.28203 to 2.23797, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 2.23797 to 2.06150, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 2.06150 to 1.94727, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.94727 to 1.85287, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.85287 to 1.79854, saving model to weights.best.hdf5
# Epoch 00027: val_loss improved from 1.79854 to 1.70997, saving model to weights.best.hdf5
# Epoch 00028: val_loss improved from 1.70997 to 1.61667, saving model to weights.best.hdf5
# Epoch 00029: val_loss improved from 1.61667 to 1.53595, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.53595 to 1.47689, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.47689 to 1.42826, saving model to weights.best.hdf5
# Epoch 00032: val_loss improved from 1.42826 to 1.36930, saving model to weights.best.hdf5
# Epoch 00033: val_loss did not improve
# Epoch 00034: val_loss improved from 1.36930 to 1.32100, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.32100 to 1.29952, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.29952 to 1.28369, saving model to weights.best.hdf5
# Epoch 00037: val_loss improved from 1.28369 to 1.25435, saving model to weights.best.hdf5
# Epoch 00038: val_loss improved from 1.25435 to 1.25400, saving model to weights.best.hdf5
# Epoch 00039: val_loss improved from 1.25400 to 1.20380, saving model to weights.best.hdf5
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 1.20380 to 1.18220, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 1.18220 to 1.15898, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 1.15898 to 1.08597, saving model to weights.best.hdf5
# Epoch 00045: val_loss did not improve
# Epoch 00046: val_loss improved from 1.08597 to 1.08027, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 1.08027 to 1.05156, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 1.05156 to 1.03571, saving model to weights.best.hdf5
# Epoch 00049: val_loss improved from 1.03571 to 1.01097, saving model to weights.best.hdf5
# Epoch 00050: val_loss improved from 1.01097 to 0.93096, saving model to weights.best.hdf5
# Epoch 00051: val_loss improved from 0.93096 to 0.90434, saving model to weights.best.hdf5
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss did not improve
# Epoch 00055: val_loss improved from 0.90434 to 0.87228, saving model to weights.best.hdf5
# Epoch 00056: val_loss improved from 0.87228 to 0.81179, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.81179 to 0.75046, saving model to weights.best.hdf5
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss improved from 0.75046 to 0.71210, saving model to weights.best.hdf5
# Epoch 00060: val_loss did not improve
# Epoch 00061: val_loss improved from 0.71210 to 0.62302, saving model to weights.best.hdf5
# Epoch 00062: val_loss improved from 0.62302 to 0.59642, saving model to weights.best.hdf5
# Epoch 00063: val_loss improved from 0.59642 to 0.57158, saving model to weights.best.hdf5
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.57158 to 0.53792, saving model to weights.best.hdf5
# Epoch 00066: val_loss improved from 0.53792 to 0.52166, saving model to weights.best.hdf5
# Epoch 00067: val_loss improved from 0.52166 to 0.44220, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.44220 to 0.41188, saving model to weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss improved from 0.41188 to 0.35740, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.35740 to 0.33172, saving model to weights.best.hdf5
# Epoch 00075: val_loss improved from 0.33172 to 0.28408, saving model to weights.best.hdf5
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss improved from 0.28408 to 0.27774, saving model to weights.best.hdf5
# Epoch 00081: val_loss improved from 0.27774 to 0.26220, saving model to weights.best.hdf5
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss improved from 0.26220 to 0.25802, saving model to weights.best.hdf5
# Epoch 00087: val_loss improved from 0.25802 to 0.25088, saving model to weights.best.hdf5
# Epoch 00088: val_loss improved from 0.25088 to 0.25002, saving model to weights.best.hdf5
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss improved from 0.25002 to 0.24735, saving model to weights.best.hdf5
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss improved from 0.24735 to 0.24586, saving model to weights.best.hdf5
# Epoch 00105: val_loss improved from 0.24586 to 0.24318, saving model to weights.best.hdf5
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss improved from 0.24318 to 0.23828, saving model to weights.best.hdf5
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss improved from 0.23828 to 0.23458, saving model to weights.best.hdf5
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,300,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   300
# Best loss at iteratation:     90    Best: 0.171461536735
# Best val_loss at iteratation: 142    Best: 0.234577523337

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)], 
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1)])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.209421737631
# (535, 1)
# (535,)
# MAE:  93.929
# RMSE: 133.171
# R2:   0.638

# %% [markdown]
# ## MLP with weather + events information (no text) + TEXT

# %%
GLOVE_DIR = "/home/fmpr/datasets/glove.6B/"
#GLOVE_DIR = "/mnt/sdb1/datasets/glove.6B/"
MAX_SEQUENCE_LENGTH = 600 #1000
MAX_NB_WORDS = 5000 #20000
EMBEDDING_DIM = 300 #300

# %%
# Build index mapping words in the embeddings set to their embedding vector
embeddings_index = {}
f = open(GLOVE_DIR + 'glove.6B.%dd.txt' % (EMBEDDING_DIM,))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
# Vectorize the text samples into a 2D integer tensor and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(event_texts)
sequences_train = tokenizer.texts_to_sequences(event_texts_train)
sequences_val = tokenizer.texts_to_sequences(event_texts_val)
sequences_test = tokenizer.texts_to_sequences(event_texts_test)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data_train = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
data_val = pad_sequences(sequences_val, maxlen=MAX_SEQUENCE_LENGTH)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of train tensor:', data_train.shape)
print('Shape of val tensor:', data_val.shape)
print('Shape of test tensor:', data_test.shape)
# Out:
# Found 3461 unique tokens.
# ('Shape of train tensor:', (640, 600))
# ('Shape of val tensor:', (90, 600))
# ('Shape of test tensor:', (535, 600))

# %%
# Prepare embedding matrix
print('Preparing embedding matrix.')
num_words = min(MAX_NB_WORDS, len(word_index)+1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    #print i
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Preparing embedding matrix.

# %%
def build_model_text(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(50, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(50, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_text(1, NUM_LAGS+len(sel), 4, 1)
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:]], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:]], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_1/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_8:0", shape=(?, 17), dtype=float32)
# Tensor("input_9:0", shape=(?, 4), dtype=float32)
# Tensor("dropout_15/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_4/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 14.73406, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 14.73406 to 12.44133, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 12.44133 to 10.65363, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 10.65363 to 9.17681, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 9.17681 to 7.75905, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 7.75905 to 6.62488, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 6.62488 to 5.66984, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 5.66984 to 4.98701, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 4.98701 to 4.32942, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 4.32942 to 3.84018, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 3.84018 to 3.35434, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.35434 to 2.95344, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 2.95344 to 2.76380, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.76380 to 2.57749, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.57749 to 2.43697, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.43697 to 2.14198, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 2.14198 to 2.07750, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 2.07750 to 1.95860, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.95860 to 1.84445, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.84445 to 1.73247, saving model to weights.best.hdf5
# Epoch 00020: val_loss did not improve
# Epoch 00021: val_loss improved from 1.73247 to 1.69496, saving model to weights.best.hdf5
# Epoch 00022: val_loss improved from 1.69496 to 1.62592, saving model to weights.best.hdf5
# Epoch 00023: val_loss improved from 1.62592 to 1.61277, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 1.61277 to 1.57465, saving model to weights.best.hdf5
# Epoch 00025: val_loss improved from 1.57465 to 1.48216, saving model to weights.best.hdf5
# Epoch 00026: val_loss improved from 1.48216 to 1.42676, saving model to weights.best.hdf5
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss did not improve
# Epoch 00029: val_loss improved from 1.42676 to 1.37823, saving model to weights.best.hdf5
# Epoch 00030: val_loss improved from 1.37823 to 1.36762, saving model to weights.best.hdf5
# Epoch 00031: val_loss improved from 1.36762 to 1.35995, saving model to weights.best.hdf5
# Epoch 00032: val_loss did not improve
# Epoch 00033: val_loss improved from 1.35995 to 1.22244, saving model to weights.best.hdf5
# Epoch 00034: val_loss improved from 1.22244 to 1.18416, saving model to weights.best.hdf5
# Epoch 00035: val_loss improved from 1.18416 to 1.13955, saving model to weights.best.hdf5
# Epoch 00036: val_loss improved from 1.13955 to 1.10603, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss improved from 1.10603 to 1.04741, saving model to weights.best.hdf5
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 1.04741 to 0.97929, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.97929 to 0.91014, saving model to weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 0.91014 to 0.90672, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.90672 to 0.74569, saving model to weights.best.hdf5
# Epoch 00046: val_loss improved from 0.74569 to 0.67788, saving model to weights.best.hdf5
# Epoch 00047: val_loss improved from 0.67788 to 0.57749, saving model to weights.best.hdf5
# Epoch 00048: val_loss improved from 0.57749 to 0.52740, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss did not improve
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss improved from 0.52740 to 0.52007, saving model to weights.best.hdf5
# Epoch 00055: val_loss improved from 0.52007 to 0.43718, saving model to weights.best.hdf5
# Epoch 00056: val_loss did not improve
# Epoch 00057: val_loss did not improve
# Epoch 00058: val_loss did not improve
# Epoch 00059: val_loss did not improve
# Epoch 00060: val_loss improved from 0.43718 to 0.37729, saving model to weights.best.hdf5
# Epoch 00061: val_loss improved from 0.37729 to 0.36465, saving model to weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 0.36465 to 0.31805, saving model to weights.best.hdf5
# Epoch 00064: val_loss did not improve
# Epoch 00065: val_loss improved from 0.31805 to 0.28143, saving model to weights.best.hdf5
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss did not improve
# Epoch 00068: val_loss did not improve
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss improved from 0.28143 to 0.25911, saving model to weights.best.hdf5
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 0.25911 to 0.25237, saving model to weights.best.hdf5
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss did not improve
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss improved from 0.25237 to 0.24803, saving model to weights.best.hdf5
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss did not improve
# Epoch 00083: val_loss did not improve
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss did not improve
# Epoch 00090: val_loss improved from 0.24803 to 0.24609, saving model to weights.best.hdf5
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss did not improve
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss improved from 0.24609 to 0.23721, saving model to weights.best.hdf5
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss did not improve
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss did not improve
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss improved from 0.23721 to 0.23586, saving model to weights.best.hdf5
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss did not improve
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss improved from 0.23586 to 0.23484, saving model to weights.best.hdf5
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss improved from 0.23484 to 0.23340, saving model to weights.best.hdf5
# Epoch 00207: val_loss improved from 0.23340 to 0.23318, saving model to weights.best.hdf5
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss improved from 0.23318 to 0.23155, saving model to weights.best.hdf5
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss did not improve
# Epoch 00245: val_loss improved from 0.23155 to 0.22987, saving model to weights.best.hdf5
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss improved from 0.22987 to 0.22972, saving model to weights.best.hdf5
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     499    Best: 0.124056965113
# Best val_loss at iteratation: 253    Best: 0.229723189274

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:]], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:]], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.216225752792
# (535, 1)
# (535,)
# MAE:  95.313
# RMSE: 134.691
# R2:   0.630

# %% [markdown]
# ## MLP with weather + events information (no text) + event_lags + TEXT

# %%
def build_model_text_v2(num_inputs, num_lags, num_feat, num_preds):
    input_lags = Input(shape=(num_lags,))
    input_events = Input(shape=(num_feat,))
    
    x_lags = Concatenate(axis=1)([input_lags, input_events])
    #x_lags = BatchNormalization()(x_lags)
    
    x = x_lags
    x = BatchNormalization()(x)
    x = Dense(units=200, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.2))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(units=50, activation="tanh", kernel_regularizer=keras.regularizers.l2(0.1))(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x_lags = BatchNormalization()(x)
    
    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
    embedding_layer = Embedding(num_words,
                                EMBEDDING_DIM,
                                weights=[embedding_matrix],
                                input_length=MAX_SEQUENCE_LENGTH,
                                trainable=False)
    embedded_sequences = embedding_layer(sequence_input)
    print embedded_sequences
    x = Conv1D(100, 3, activation='relu')(embedded_sequences)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 3, activation='relu')(x)
    x = MaxPooling1D(3)(x)
    x = Dropout(0.5)(x)
    x = Conv1D(100, 5, activation='relu')(x)
    x = MaxPooling1D(5)(x)
    #x = Dropout(0.1)(x)
    #x = Conv1D(50, 5, activation='relu')(x)
    #x = MaxPooling1D(5)(x)
    text_embedding = Flatten()(x)
    text_embedding = Dropout(0.5)(text_embedding)
    #text_embedding = Dense(units=100, activation='relu')(text_embedding)
    #text_embedding = Dropout(0.5)(text_embedding)
    
    print input_lags
    print input_events
    print text_embedding
    feat = Concatenate(axis=1)([x_lags, text_embedding])
    print feat
    
    feat = BatchNormalization()(feat)
    #feat = Dense(units=50, activation='relu')(feat)
    #feat = Dropout(0.5)(feat)
    
    #preds = Dense(units=num_preds)(feat)
    preds = Dense(units=num_preds, kernel_regularizer=keras.regularizers.l2(0.2))(feat)
    preds = Activation("linear")(preds)
    
    model = Model([input_lags, input_events, sequence_input], preds)
    
    rmsp = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
    #model.compile(loss="mse", optimizer=rmsp)
    model.compile(loss="mse", optimizer="adam")
    
    return model, input_lags, preds

# %%
# checkpoint best model
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# fit model to the mean
model, input_lags, preds = build_model_text_v2(1, NUM_LAGS+len(sel), 14, 1)
model.fit(
    [np.concatenate([lags_train, weather_feats_train[:,sel]], axis=1), 
     np.concatenate([event_feats_train[:,:], lags_event_feats_train], axis=1),
     data_train],
    y_train,
    batch_size=64,
    epochs=500,
    #validation_split=0.2,
    validation_data=([np.concatenate([lags_val, weather_feats_val[:,sel]], axis=1), 
                      np.concatenate([event_feats_val[:,:], lags_event_feats_val], axis=1),
                      data_val], y_val),
    callbacks=[checkpoint],
    verbose=0)
# Out:
# Tensor("embedding_1/Gather:0", shape=(?, 600, 300), dtype=float32)
# Tensor("input_1:0", shape=(?, 17), dtype=float32)
# Tensor("input_2:0", shape=(?, 14), dtype=float32)
# Tensor("dropout_5/cond/Merge:0", shape=(?, ?), dtype=float32)
# Tensor("concatenate_2/concat:0", shape=(?, ?), dtype=float32)
# Epoch 00000: val_loss improved from inf to 17.85020, saving model to weights.best.hdf5
# Epoch 00001: val_loss improved from 17.85020 to 14.78353, saving model to weights.best.hdf5
# Epoch 00002: val_loss improved from 14.78353 to 12.22534, saving model to weights.best.hdf5
# Epoch 00003: val_loss improved from 12.22534 to 10.36928, saving model to weights.best.hdf5
# Epoch 00004: val_loss improved from 10.36928 to 8.76851, saving model to weights.best.hdf5
# Epoch 00005: val_loss improved from 8.76851 to 7.30290, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 7.30290 to 6.16302, saving model to weights.best.hdf5
# Epoch 00007: val_loss improved from 6.16302 to 5.34405, saving model to weights.best.hdf5
# Epoch 00008: val_loss improved from 5.34405 to 4.62164, saving model to weights.best.hdf5
# Epoch 00009: val_loss improved from 4.62164 to 3.94962, saving model to weights.best.hdf5
# Epoch 00010: val_loss improved from 3.94962 to 3.48941, saving model to weights.best.hdf5
# Epoch 00011: val_loss improved from 3.48941 to 3.09508, saving model to weights.best.hdf5
# Epoch 00012: val_loss improved from 3.09508 to 2.83117, saving model to weights.best.hdf5
# Epoch 00013: val_loss improved from 2.83117 to 2.62400, saving model to weights.best.hdf5
# Epoch 00014: val_loss improved from 2.62400 to 2.38793, saving model to weights.best.hdf5
# Epoch 00015: val_loss improved from 2.38793 to 2.15568, saving model to weights.best.hdf5
# Epoch 00016: val_loss improved from 2.15568 to 2.00481, saving model to weights.best.hdf5
# Epoch 00017: val_loss improved from 2.00481 to 1.93575, saving model to weights.best.hdf5
# Epoch 00018: val_loss improved from 1.93575 to 1.85927, saving model to weights.best.hdf5
# Epoch 00019: val_loss improved from 1.85927 to 1.75265, saving model to weights.best.hdf5
# Epoch 00020: val_loss improved from 1.75265 to 1.64349, saving model to weights.best.hdf5
# Epoch 00021: val_loss did not improve
# Epoch 00022: val_loss did not improve
# Epoch 00023: val_loss improved from 1.64349 to 1.63262, saving model to weights.best.hdf5
# Epoch 00024: val_loss improved from 1.63262 to 1.44594, saving model to weights.best.hdf5
# Epoch 00025: val_loss did not improve
# Epoch 00026: val_loss did not improve
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss did not improve
# Epoch 00029: val_loss did not improve
# Epoch 00030: val_loss improved from 1.44594 to 1.34238, saving model to weights.best.hdf5
# Epoch 00031: val_loss did not improve
# Epoch 00032: val_loss improved from 1.34238 to 1.33066, saving model to weights.best.hdf5
# Epoch 00033: val_loss improved from 1.33066 to 1.14861, saving model to weights.best.hdf5
# Epoch 00034: val_loss did not improve
# Epoch 00035: val_loss did not improve
# Epoch 00036: val_loss improved from 1.14861 to 0.97461, saving model to weights.best.hdf5
# Epoch 00037: val_loss did not improve
# Epoch 00038: val_loss did not improve
# Epoch 00039: val_loss did not improve
# Epoch 00040: val_loss did not improve
# Epoch 00041: val_loss improved from 0.97461 to 0.95976, saving model to weights.best.hdf5
# Epoch 00042: val_loss improved from 0.95976 to 0.95641, saving model to weights.best.hdf5
# Epoch 00043: val_loss improved from 0.95641 to 0.89783, saving model to weights.best.hdf5
# Epoch 00044: val_loss improved from 0.89783 to 0.77699, saving model to weights.best.hdf5
# Epoch 00045: val_loss improved from 0.77699 to 0.69652, saving model to weights.best.hdf5
# Epoch 00046: val_loss did not improve
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 0.69652 to 0.62513, saving model to weights.best.hdf5
# Epoch 00049: val_loss did not improve
# Epoch 00050: val_loss improved from 0.62513 to 0.61102, saving model to weights.best.hdf5
# Epoch 00051: val_loss did not improve
# Epoch 00052: val_loss improved from 0.61102 to 0.56600, saving model to weights.best.hdf5
# Epoch 00053: val_loss did not improve
# Epoch 00054: val_loss improved from 0.56600 to 0.49634, saving model to weights.best.hdf5
# Epoch 00055: val_loss did not improve
# Epoch 00056: val_loss improved from 0.49634 to 0.47063, saving model to weights.best.hdf5
# Epoch 00057: val_loss improved from 0.47063 to 0.37499, saving model to weights.best.hdf5
# Epoch 00058: val_loss improved from 0.37499 to 0.35124, saving model to weights.best.hdf5
# Epoch 00059: val_loss improved from 0.35124 to 0.34213, saving model to weights.best.hdf5
# Epoch 00060: val_loss improved from 0.34213 to 0.32421, saving model to weights.best.hdf5
# Epoch 00061: val_loss did not improve
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss did not improve
# Epoch 00064: val_loss improved from 0.32421 to 0.31367, saving model to weights.best.hdf5
# Epoch 00065: val_loss did not improve
# Epoch 00066: val_loss did not improve
# Epoch 00067: val_loss improved from 0.31367 to 0.27287, saving model to weights.best.hdf5
# Epoch 00068: val_loss improved from 0.27287 to 0.26549, saving model to weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss did not improve
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss improved from 0.26549 to 0.25660, saving model to weights.best.hdf5
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss did not improve
# Epoch 00075: val_loss did not improve
# Epoch 00076: val_loss improved from 0.25660 to 0.25558, saving model to weights.best.hdf5
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss did not improve
# Epoch 00079: val_loss improved from 0.25558 to 0.25121, saving model to weights.best.hdf5
# Epoch 00080: val_loss did not improve
# Epoch 00081: val_loss did not improve
# Epoch 00082: val_loss improved from 0.25121 to 0.24837, saving model to weights.best.hdf5
# Epoch 00083: val_loss improved from 0.24837 to 0.24300, saving model to weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss did not improve
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss did not improve
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss improved from 0.24300 to 0.24182, saving model to weights.best.hdf5
# Epoch 00090: val_loss did not improve
# Epoch 00091: val_loss did not improve
# Epoch 00092: val_loss improved from 0.24182 to 0.24118, saving model to weights.best.hdf5
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss did not improve
# Epoch 00096: val_loss did not improve
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss did not improve
# Epoch 00099: val_loss did not improve
# Epoch 00100: val_loss did not improve
# Epoch 00101: val_loss improved from 0.24118 to 0.23862, saving model to weights.best.hdf5
# Epoch 00102: val_loss did not improve
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss improved from 0.23862 to 0.23844, saving model to weights.best.hdf5
# Epoch 00105: val_loss did not improve
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss did not improve
# Epoch 00109: val_loss did not improve
# Epoch 00110: val_loss improved from 0.23844 to 0.23299, saving model to weights.best.hdf5
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss improved from 0.23299 to 0.23106, saving model to weights.best.hdf5
# Epoch 00114: val_loss did not improve
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss did not improve
# Epoch 00118: val_loss did not improve
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss did not improve
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss did not improve
# Epoch 00123: val_loss did not improve
# Epoch 00124: val_loss did not improve
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss did not improve
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss did not improve
# Epoch 00134: val_loss did not improve
# Epoch 00135: val_loss did not improve
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss did not improve
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss did not improve
# Epoch 00143: val_loss did not improve
# Epoch 00144: val_loss did not improve
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss did not improve
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss did not improve
# Epoch 00150: val_loss did not improve
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss did not improve
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss did not improve
# Epoch 00160: val_loss did not improve
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss did not improve
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss did not improve
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss did not improve
# Epoch 00178: val_loss improved from 0.23106 to 0.22778, saving model to weights.best.hdf5
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss did not improve
# Epoch 00188: val_loss did not improve
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss did not improve
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss did not improve
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss did not improve
# Epoch 00204: val_loss did not improve
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss did not improve
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss did not improve
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss did not improve
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss did not improve
# Epoch 00214: val_loss did not improve
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss did not improve
# Epoch 00220: val_loss improved from 0.22778 to 0.22772, saving model to weights.best.hdf5
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss did not improve
# Epoch 00223: val_loss did not improve
# Epoch 00224: val_loss did not improve
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00236: val_loss did not improve
# Epoch 00237: val_loss did not improve
# Epoch 00238: val_loss did not improve
# Epoch 00239: val_loss did not improve
# Epoch 00240: val_loss did not improve
# Epoch 00241: val_loss did not improve
# Epoch 00242: val_loss did not improve
# Epoch 00243: val_loss did not improve
# Epoch 00244: val_loss improved from 0.22772 to 0.22507, saving model to weights.best.hdf5
# Epoch 00245: val_loss did not improve
# Epoch 00246: val_loss did not improve
# Epoch 00247: val_loss did not improve
# Epoch 00248: val_loss did not improve
# Epoch 00249: val_loss did not improve
# Epoch 00250: val_loss did not improve
# Epoch 00251: val_loss did not improve
# Epoch 00252: val_loss did not improve
# Epoch 00253: val_loss did not improve
# Epoch 00254: val_loss did not improve
# Epoch 00255: val_loss did not improve
# Epoch 00256: val_loss did not improve
# Epoch 00257: val_loss did not improve
# Epoch 00258: val_loss did not improve
# Epoch 00259: val_loss did not improve
# Epoch 00260: val_loss did not improve
# Epoch 00261: val_loss did not improve
# Epoch 00262: val_loss did not improve
# Epoch 00263: val_loss did not improve
# Epoch 00264: val_loss did not improve
# Epoch 00265: val_loss did not improve
# Epoch 00266: val_loss did not improve
# Epoch 00267: val_loss did not improve
# Epoch 00268: val_loss did not improve
# Epoch 00269: val_loss did not improve
# Epoch 00270: val_loss did not improve
# Epoch 00271: val_loss did not improve
# Epoch 00272: val_loss did not improve
# Epoch 00273: val_loss did not improve
# Epoch 00274: val_loss did not improve
# Epoch 00275: val_loss did not improve
# Epoch 00276: val_loss did not improve
# Epoch 00277: val_loss did not improve
# Epoch 00278: val_loss did not improve
# Epoch 00279: val_loss did not improve
# Epoch 00280: val_loss did not improve
# Epoch 00281: val_loss did not improve
# Epoch 00282: val_loss did not improve
# Epoch 00283: val_loss did not improve
# Epoch 00284: val_loss did not improve
# Epoch 00285: val_loss did not improve
# Epoch 00286: val_loss did not improve
# Epoch 00287: val_loss did not improve
# Epoch 00288: val_loss did not improve
# Epoch 00289: val_loss did not improve
# Epoch 00290: val_loss did not improve
# Epoch 00291: val_loss did not improve
# Epoch 00292: val_loss did not improve
# Epoch 00293: val_loss did not improve
# Epoch 00294: val_loss did not improve
# Epoch 00295: val_loss did not improve
# Epoch 00296: val_loss did not improve
# Epoch 00297: val_loss did not improve
# Epoch 00298: val_loss did not improve
# Epoch 00299: val_loss did not improve
# Epoch 00300: val_loss did not improve
# Epoch 00301: val_loss did not improve
# Epoch 00302: val_loss did not improve
# Epoch 00303: val_loss did not improve
# Epoch 00304: val_loss did not improve
# Epoch 00305: val_loss did not improve
# Epoch 00306: val_loss did not improve
# Epoch 00307: val_loss did not improve
# Epoch 00308: val_loss did not improve
# Epoch 00309: val_loss did not improve
# Epoch 00310: val_loss did not improve
# Epoch 00311: val_loss did not improve
# Epoch 00312: val_loss did not improve
# Epoch 00313: val_loss did not improve
# Epoch 00314: val_loss did not improve
# Epoch 00315: val_loss did not improve
# Epoch 00316: val_loss did not improve
# Epoch 00317: val_loss did not improve
# Epoch 00318: val_loss did not improve
# Epoch 00319: val_loss did not improve
# Epoch 00320: val_loss did not improve
# Epoch 00321: val_loss did not improve
# Epoch 00322: val_loss did not improve
# Epoch 00323: val_loss did not improve
# Epoch 00324: val_loss did not improve
# Epoch 00325: val_loss did not improve
# Epoch 00326: val_loss did not improve
# Epoch 00327: val_loss did not improve
# Epoch 00328: val_loss did not improve
# Epoch 00329: val_loss did not improve
# Epoch 00330: val_loss did not improve
# Epoch 00331: val_loss did not improve
# Epoch 00332: val_loss did not improve
# Epoch 00333: val_loss did not improve
# Epoch 00334: val_loss did not improve
# Epoch 00335: val_loss did not improve
# Epoch 00336: val_loss did not improve
# Epoch 00337: val_loss did not improve
# Epoch 00338: val_loss did not improve
# Epoch 00339: val_loss did not improve
# Epoch 00340: val_loss did not improve
# Epoch 00341: val_loss did not improve
# Epoch 00342: val_loss did not improve
# Epoch 00343: val_loss did not improve
# Epoch 00344: val_loss did not improve
# Epoch 00345: val_loss did not improve
# Epoch 00346: val_loss did not improve
# Epoch 00347: val_loss did not improve
# Epoch 00348: val_loss did not improve
# Epoch 00349: val_loss did not improve
# Epoch 00350: val_loss did not improve
# Epoch 00351: val_loss did not improve
# Epoch 00352: val_loss did not improve
# Epoch 00353: val_loss did not improve
# Epoch 00354: val_loss did not improve
# Epoch 00355: val_loss did not improve
# Epoch 00356: val_loss did not improve
# Epoch 00357: val_loss did not improve
# Epoch 00358: val_loss did not improve
# Epoch 00359: val_loss did not improve
# Epoch 00360: val_loss did not improve
# Epoch 00361: val_loss did not improve
# Epoch 00362: val_loss did not improve
# Epoch 00363: val_loss did not improve
# Epoch 00364: val_loss did not improve
# Epoch 00365: val_loss did not improve
# Epoch 00366: val_loss did not improve
# Epoch 00367: val_loss did not improve
# Epoch 00368: val_loss did not improve
# Epoch 00369: val_loss did not improve
# Epoch 00370: val_loss did not improve
# Epoch 00371: val_loss did not improve
# Epoch 00372: val_loss did not improve
# Epoch 00373: val_loss did not improve
# Epoch 00374: val_loss did not improve
# Epoch 00375: val_loss did not improve
# Epoch 00376: val_loss did not improve
# Epoch 00377: val_loss did not improve
# Epoch 00378: val_loss did not improve
# Epoch 00379: val_loss did not improve
# Epoch 00380: val_loss did not improve
# Epoch 00381: val_loss did not improve
# Epoch 00382: val_loss did not improve
# Epoch 00383: val_loss did not improve
# Epoch 00384: val_loss did not improve
# Epoch 00385: val_loss did not improve
# Epoch 00386: val_loss did not improve
# Epoch 00387: val_loss did not improve
# Epoch 00388: val_loss did not improve
# Epoch 00389: val_loss did not improve
# Epoch 00390: val_loss did not improve
# Epoch 00391: val_loss did not improve
# Epoch 00392: val_loss did not improve
# Epoch 00393: val_loss did not improve
# Epoch 00394: val_loss did not improve
# Epoch 00395: val_loss did not improve
# Epoch 00396: val_loss did not improve
# Epoch 00397: val_loss did not improve
# Epoch 00398: val_loss did not improve
# Epoch 00399: val_loss did not improve
# Epoch 00400: val_loss did not improve
# Epoch 00401: val_loss did not improve
# Epoch 00402: val_loss did not improve
# Epoch 00403: val_loss did not improve
# Epoch 00404: val_loss did not improve
# Epoch 00405: val_loss did not improve
# Epoch 00406: val_loss did not improve
# Epoch 00407: val_loss did not improve
# Epoch 00408: val_loss did not improve
# Epoch 00409: val_loss did not improve
# Epoch 00410: val_loss did not improve
# Epoch 00411: val_loss did not improve
# Epoch 00412: val_loss did not improve
# Epoch 00413: val_loss did not improve
# Epoch 00414: val_loss did not improve
# Epoch 00415: val_loss did not improve
# Epoch 00416: val_loss did not improve
# Epoch 00417: val_loss did not improve
# Epoch 00418: val_loss did not improve
# Epoch 00419: val_loss did not improve
# Epoch 00420: val_loss did not improve
# Epoch 00421: val_loss did not improve
# Epoch 00422: val_loss did not improve
# Epoch 00423: val_loss did not improve
# Epoch 00424: val_loss did not improve
# Epoch 00425: val_loss did not improve
# Epoch 00426: val_loss did not improve
# Epoch 00427: val_loss did not improve
# Epoch 00428: val_loss did not improve
# Epoch 00429: val_loss did not improve
# Epoch 00430: val_loss did not improve
# Epoch 00431: val_loss did not improve
# Epoch 00432: val_loss did not improve
# Epoch 00433: val_loss did not improve
# Epoch 00434: val_loss did not improve
# Epoch 00435: val_loss did not improve
# Epoch 00436: val_loss did not improve
# Epoch 00437: val_loss did not improve
# Epoch 00438: val_loss did not improve
# Epoch 00439: val_loss did not improve
# Epoch 00440: val_loss did not improve
# Epoch 00441: val_loss did not improve
# Epoch 00442: val_loss did not improve
# Epoch 00443: val_loss did not improve
# Epoch 00444: val_loss did not improve
# Epoch 00445: val_loss did not improve
# Epoch 00446: val_loss did not improve
# Epoch 00447: val_loss did not improve
# Epoch 00448: val_loss did not improve
# Epoch 00449: val_loss did not improve
# Epoch 00450: val_loss did not improve
# Epoch 00451: val_loss did not improve
# Epoch 00452: val_loss did not improve
# Epoch 00453: val_loss did not improve
# Epoch 00454: val_loss did not improve
# Epoch 00455: val_loss did not improve
# Epoch 00456: val_loss did not improve
# Epoch 00457: val_loss did not improve
# Epoch 00458: val_loss did not improve
# Epoch 00459: val_loss did not improve
# Epoch 00460: val_loss did not improve
# Epoch 00461: val_loss did not improve
# Epoch 00462: val_loss did not improve
# Epoch 00463: val_loss did not improve
# Epoch 00464: val_loss did not improve
# Epoch 00465: val_loss did not improve
# Epoch 00466: val_loss did not improve
# Epoch 00467: val_loss did not improve
# Epoch 00468: val_loss did not improve
# Epoch 00469: val_loss did not improve
# Epoch 00470: val_loss did not improve
# Epoch 00471: val_loss did not improve
# Epoch 00472: val_loss did not improve
# Epoch 00473: val_loss did not improve
# Epoch 00474: val_loss did not improve
# Epoch 00475: val_loss did not improve
# Epoch 00476: val_loss did not improve
# Epoch 00477: val_loss did not improve
# Epoch 00478: val_loss did not improve
# Epoch 00479: val_loss did not improve
# Epoch 00480: val_loss did not improve
# Epoch 00481: val_loss did not improve
# Epoch 00482: val_loss did not improve
# Epoch 00483: val_loss did not improve
# Epoch 00484: val_loss did not improve
# Epoch 00485: val_loss did not improve
# Epoch 00486: val_loss did not improve
# Epoch 00487: val_loss did not improve
# Epoch 00488: val_loss did not improve
# Epoch 00489: val_loss did not improve
# Epoch 00490: val_loss did not improve
# Epoch 00491: val_loss did not improve
# Epoch 00492: val_loss did not improve
# Epoch 00493: val_loss did not improve
# Epoch 00494: val_loss did not improve
# Epoch 00495: val_loss did not improve
# Epoch 00496: val_loss did not improve
# Epoch 00497: val_loss did not improve
# Epoch 00498: val_loss did not improve
# Epoch 00499: val_loss did not improve

# %%
print "Total number of iterations:  ", len(model.history.history["loss"])
print "Best loss at iteratation:    ", np.argmin(model.history.history["loss"]), "   Best:", np.min(model.history.history["loss"])
print "Best val_loss at iteratation:", np.argmin(model.history.history["val_loss"]), "   Best:", np.min(model.history.history["val_loss"])
plt.figure(figsize=(10,6))
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.axis([0,500,0,2])
plt.legend(["loss", "val_loss"])
# Out:
# Total number of iterations:   500
# Best loss at iteratation:     449    Best: 0.121263811737
# Best val_loss at iteratation: 244    Best: 0.225068939394

# %%
# load weights
model.load_weights("weights.best.hdf5")

print model.evaluate([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                      np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                      data_test],
                      y_test, verbose=2)

# make predictions
preds_lstm = model.predict([np.concatenate([lags_test[:,:], weather_feats_test[:,sel]], axis=1), 
                            np.concatenate([event_feats_test[:,:], lags_event_feats_test], axis=1),
                            data_test])
print preds_lstm.shape
preds_lstm = preds_lstm[:,0] * std_test + trend_test
print preds_lstm.shape
corr, mae, mse, rae, rmse, r2 = compute_error(y_true, preds_lstm)
print "MAE:  %.3f\nRMSE: %.3f\nR2:   %.3f" % (mae, rmse, r2)
# Out:
# 0.214940601072
# (535, 1)
# (535,)
# MAE:  93.424
# RMSE: 132.887
# R2:   0.640

# %%
print len(y_true)
x = range(130,170)
plt.plot(x, y_true[x], 'k-')
plt.plot(x, preds_lr_lags[x], 'r--')
plt.plot(x, preds_lr_events[x], 'g--')
plt.plot(x, preds_lstm[x], 'b-')
# Out:
# 535

# %%
print len(y_true)
x = range(1,60)
plt.plot(x, y_true[x], 'k-')
plt.plot(x, preds_lr_lags[x], 'r--')
plt.plot(x, preds_lr_events[x], 'g--')
plt.plot(x, preds_lstm[x], 'b-')
# Out:
# 535
